# %%
import pandas as pd
from math import log

# %%
def min_edit_distance(s1, s2):
    """
    Tính khoảng cách chỉnh sửa (Levenshtein distance) giữa hai từ s1 và s2.
    Hỗ trợ tiếng Việt có dấu, đa ký tự.

    Trả về: số bước chỉnh sửa tối thiểu để biến s1 thành s2.
    """
    len_s1 = len(s1)
    len_s2 = len(s2)

    # Khởi tạo ma trận khoảng cách
    dp = [[0] * (len_s2 + 1) for _ in range(len_s1 + 1)]

    # Khoảng cách từ "" đến s1 hoặc s2
    for i in range(len_s1 + 1):
        dp[i][0] = i
    for j in range(len_s2 + 1):
        dp[0][j] = j

    # Tính khoảng cách
    for i in range(1, len_s1 + 1):
        for j in range(1, len_s2 + 1):
            cost = 0 if s1[i-1] == s2[j-1] else 1

            dp[i][j] = min(
                dp[i-1][j] + 1,      # xóa
                dp[i][j-1] + 1,      # thêm
                dp[i-1][j-1] + cost  # thay thế
            )
    # print(dp)
    return dp[len_s1][len_s2]

# %%
print(min_edit_distance("nhận", "nhân"))  # → 1
print(min_edit_distance("nhan", "cảh"))  # → 1
print(min_edit_distance("công", "cung"))  # → 1
print(min_edit_distance("công", "công"))  # → 0
# Out:
# 1
# 4
# 1
# 0

# %%
test = pd.read_csv("/kaggle/input/preprocessing/test.csv")
test = test[['text', 'preprocess', 'correct_text']]
test
# Out:
#                                                    text  \
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giam mà còn tăng thê...
# 3     Đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chù nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
#                                              preprocess  \
# 0     thông qua công tác tuyên truyền, vận động này ...
# 1     do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     giữ được chỉ số này không giam mà còn tăng thê...
# 3     đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  tuy nhiên, khi nói đến e-learning, các phương ...
# 8963  đứng trước những hành vi đi ngược lại với đạo ...
# 8964  quan điểm biện chứng của chù nghĩa mác - lênin...
# 8965  đối với biểu đồ histogram, nếu giá trị trung b...
# 8966  trong mỗi khu vực mà đội phát triển thị trường...
#
#                                            correct_text
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giảm mà còn tăng thê...
# 3     Đứng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chủ nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
# [8967 rows x 3 columns]

# %%
train = pd.read_csv("/kaggle/input/preprocessing/train.csv")
train
# Out:
#                                                       text  \
# 0                                   Chây ì nộp phạt nguội.
# 1                                  Chây ì ngộp phạt nguội.
# 2                                    Chây i nộp phạt ngội.
# 3        Hàng chục ngàn phươngg tiện bị ghi hình iv phạ...
# 4        Hàng chục ngàn phương tiệng bị ghy hình vi pha...
# ...                                                    ...
# 4980399  Phó thủ tướngg cũng yêu cầu hoàn thành cổ phầc...
# 4980400  Phó thủ tướng cũng Iu cầu hoờn thành cổ phần ó...
# 4980401  Phó thũ tướngx cũng yêu cầu hoàn thành cổ phần...
# 4980402  Pho thủ tướng cũng iu cầu hoàn thàh cổ phần hó...
# 4980403  Pho thủ tướngd cũng yêu vàu hoàn thành cổ phần...
#
#                                               correct_text
# 0                                   Chây ì nộp phạt nguội.
# 1                                   Chây ì nộp phạt nguội.
# 2                                   Chây ì nộp phạt nguội.
# 3        Hàng chục ngàn phương tiện bị ghi hình vi phạm...
# 4        Hàng chục ngàn phương tiện bị ghi hình vi phạm...
# ...                                                    ...
# 4980399  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980400  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980401  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980402  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980403  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
#
# [4980404 rows x 2 columns]

# %%
unique_correct_texts = pd.read_csv('/kaggle/input/preprocessing/unique_correct_texts.csv')
unique_correct_texts
# Out:
#                                            correct_text
# 0     Cung cấp những thông tin về tình hình kinh tế ...
# 1     Đảng, Nhà nước Việt Nam luôn coi trọng yếu tố ...
# 2     Việc giảng dạy mang lại cho hs những kiến thức...
# 3     Kết quả nghiên cứu cho thấy Môi trường giáo dụ...
# 4     Ứng dụng môi trường công nghệ đến các hoạt độn...
# ...                                                 ...
# 9326  Cấp trên của Giám đốc điều hành là Hội đồng qu...
# 9327  Theo nghĩa hẹp, nợ công bao gồm nghĩa vụ nợ củ...
# 9328  Cụ thể, trong phần nội dung sẽ có sự tập trung...
# 9329  Ví dụ khi đọc bài thơ Mẹ nếu câu cuối Mẹ là ng...
# 9330  Trong mỗi khu vực mà đội phát triển thị trường...
#
# [9331 rows x 1 columns]

# %% [markdown]
# ## 1. Tiền xử lý dữ liệu
# - Chuẩn hóa các câu đúng (lowercase, loại bỏ ký tự không cần thiết).
#
# - Tách từ và sinh ra mô hình 3-gram từ tập văn bản đúng.
#
# - Tạo tập từ vựng (vocab) gồm tất cả các từ đã xuất hiện.

# %%
import re
import pandas as pd

def clean_punctuation(text):
    # 0. Handle NaN values (already present)
    if pd.isnull(text):
        return text
    
    # Ensure text is a string (important for mixed data types in a DataFrame column)
    text = str(text)

    # --- Punctuation Normalization (Order matters!) ---

    # 1. Normalize ellipses: Ensure all sequences of 2 or more periods become '...'
    #    e.g., ".." -> "...", "...." -> "..."
    text = re.sub(r'\.{2,}', '...', text)

    # 2. Handle numbers with periods/commas (e.g., 1 . 2 -> 1.2, 1,000 -> 1,000)
    #    This is crucial to do early, before general space removal around punctuation.
    text = re.sub(r'(?<=\d)\s*([.,])\s*(?=\d)', r'\1', text)

    # 3. Remove quotation marks (single and double) entirely as per requirement #6
    #    This simplifies later rules as we don't need to account for them.
    text = re.sub(r'[\'"]', '', text)

    # 4. Consolidate repeated punctuation (e.g., '!!' -> '!', '???' -> '?')
    #    This excludes ellipses, which were handled in step 1.
    #    If you want to preserve '!!!' as '!!!', remove this rule or modify it.
    text = re.sub(r'([.,!?;:])\1+', r'\1', text)
    
    # 5. Standardize spacing around punctuation and parentheses
    
    # 5.1 Remove any space immediately before common punctuation (.,!?:;) and ellipses (...)
    #    e.g., "hello ." -> "hello.", "word ..." -> "word..."
    text = re.sub(r'\s+([.,!?:;])', r'\1', text)
    text = re.sub(r'\s+(\.\.\.)', r'\1', text) # Specific for ellipses

    # 5.2 Add space after punctuation (except when it's part of a number)
    text = re.sub(r'(?<!\d)([.,])(?!\d)(?=\S)', r'\1 ', text)
    text = re.sub(r'(?<=[!?;:])(?=\S)', r' \g<0>', text)  # safe spacing for other punctuations
    text = re.sub(r'(\.\.\.)(?=\S)', r'\1 ', text)  # ellipsis spacing

    # 5.3 Handle parentheses spacing (section #5 in original)
    #    Remove any spaces immediately inside or around parentheses:
    #    e.g., " ( hello ) " -> "(hello)", " (hello" -> "(hello"
    text = re.sub(r'\s*([()])\s*', r'\1', text)
    #    Add space before opening parenthesis if preceded by a word character:
    #    e.g., "word(content)" -> "word (content)"
    text = re.sub(r'(?<=\w)\(', ' (', text)
    #    Add space after closing parenthesis if followed by a word character:
    #    e.g., "(content)word" -> "(content) word"
    text = re.sub(r'\)(?=\w)', ') ', text)

    # --- Final Cleanup ---

    # 6. Reduce multiple spaces to single spaces (section #7 in original)
    text = re.sub(r'\s{2,}', ' ', text)

    # 7. Strip leading/trailing whitespace (already present)
    return text.strip()

# %%
clean_punctuation("13,5 triêu")
# Out:
# '13,5 triêu'

# %%
import re
from collections import defaultdict, Counter
from nltk.tokenize import word_tokenize
import nltk
import string

nltk.download('punkt')


import re

def clean_text(text):
    # Thay thế URL trước
    text = re.sub(r'https?://\S+|www\.\S+', '<url>', text)

    # Thay thế emoji bằng <emoji>
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U0001F700-\U0001F77F"  # alchemical
        u"\U0001F780-\U0001F7FF"  # geometric
        u"\U0001F800-\U0001F8FF"  # arrows
        u"\U0001F900-\U0001F9FF"  # supplemental symbols
        u"\U0001FA00-\U0001FA6F"  # chess
        u"\U0001FA70-\U0001FAFF"  # symbols extended
        u"\u2600-\u26FF"          # misc symbols
        u"\u2700-\u27BF"          # dingbats
        "]+", flags=re.UNICODE
    )
    text = emoji_pattern.sub('<emoji>', text)

    # Thay thế định dạng ngày (dd/mm/yyyy hoặc yyyy/mm/dd)
    text = re.sub(r'\b\d{1,2}[-/]\d{1,2}[-/]\d{2,4}\b', '<date>', text)
    text = re.sub(r'\b\d{4}[-/]\d{1,2}[-/]\d{1,2}\b', '<date>', text)

    # Thay thế thời gian (hh:mm hoặc hh:mm:ss)
    text = re.sub(r'\b\d{1,2}:\d{2}(:\d{2})?\b', '<time>', text)

    # Thay thế số (gồm số thập phân và số nguyên)
    text = re.sub(r'\d+([.,]\d+)?', '<num>', text)

    return text
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import re
from nltk.tokenize import word_tokenize

def custom_tokenize(text):
    # 1. Tìm các token đặc biệt dạng <...>
    special_tokens = list(set(re.findall(r'<[^<> ]+>', text)))
    token_map = {token: f"___SPECIALTOKEN{i}___" for i, token in enumerate(special_tokens)}

    # 2. Thay thế token đặc biệt bằng placeholder
    for orig, placeholder in token_map.items():
        text = text.replace(orig, placeholder)

    # 3. Tách các placeholder nếu dính vào từ hoặc ký tự đặc biệt
    for placeholder in token_map.values():
        text = re.sub(rf'({re.escape(placeholder)})([^\W_]+)', r'\1 \2', text)
        text = re.sub(rf'([^\W_]+)({re.escape(placeholder)})', r'\1 \2', text)
        text = re.sub(rf'({re.escape(placeholder)})([/%°\-+=±≥<>\.])', r'\1 \2', text)
        text = re.sub(rf'([/%°\-+=±≥<>\.])({re.escape(placeholder)})', r'\1 \2', text)

    # 4. TÁCH CÁC DẤU NHƯ / - … ... THÀNH TOKEN RIÊNG
    # Chèn khoảng trắng quanh các ký hiệu phân tách
    text = re.sub(r'([/\-+=±%°₫.<>\[\]…])', r' \1 ', text)
    text = re.sub(r'\.\.\.', ' ... ', text)  # tách "..." riêng
    text = re.sub(r'…', ' … ', text)        # tách dấu ba chấm unicode riêng

    # 5. Token hóa
    tokens = word_tokenize(text)

    # 6. Thay lại placeholder bằng token đặc biệt gốc
    reverse_map = {v: k for k, v in token_map.items()}
    tokens = [reverse_map.get(t, t) for t in tokens]

    return tokens

# %%
text = "Ngày 12/06/2024 lúc 08:45, 30-days giá là 13.78triệu đồng 😂 www.example.com 12/3"
cleaned = clean_text(text)
print("Sau khi clean:", cleaned)
tokens = custom_tokenize(cleaned)
print("Token:", tokens)
# Out:
# Sau khi clean: Ngày <date> lúc <time>, <num>-days giá là <num>triệu đồng <emoji> <url> <num>/<num>
# Token: ['Ngày', '<date>', 'lúc', '<time>', ',', '<num>', '-', 'days', 'giá', 'là', '<num>', 'triệu', 'đồng', '<emoji>', '<url>', '<num>', '/', '<num>']

# %%
def preprocess(texts):
    ngrams = defaultdict(Counter)
    vocab = set()

    for text in texts:
        text = clean_punctuation(text)
        text = clean_text(text)
        tokens = custom_tokenize(text.lower())

        # Thêm token đặc biệt cho đầu và cuối câu
        tokens = ['<start1>', '<start2>'] + tokens + ['<end1>', '<end2>']

        vocab.update(tokens)

        for i in range(2, len(tokens)):
            context = (tokens[i - 2], tokens[i - 1])
            word = tokens[i]
            ngrams[context][word] += 1

    return ngrams, vocab

# %% [markdown]
# ## 2. Tính toán xác suất chuyển tiếp (Transition Probability)
# - Dựa trên mô hình 3-gram: P(w₃ | w₁, w₂)
#
# - Với mỗi bộ ba liên tiếp (w₁, w₂, w₃) trong văn bản đúng, đếm tần suất xuất hiện.
#
# - Chuẩn hóa tần suất để có xác suất chuyển tiếp giữa các từ đúng theo ngữ cảnh.

# %%
def get_transition_prob(ngrams, vocab):
    transition_prob = {}

    # print("\n===== Tính toán xác suất chuyển tiếp KHÔNG smoothing =====")

    for context, counter in ngrams.items():
        total = sum(counter.values())

        for word, count in counter.items():
            prob = count / total
            trigram = (context[0], context[1], word)
            transition_prob[trigram] = prob
            # print(f"  {trigram}: count={count}, prob={prob:.6f}")

    # print("===== Hoàn tất tính xác suất chuyển tiếp =====")
    return transition_prob

# %% [markdown]
# ## 3. Tính xác suất phát xạ (Emission Probability)
# - Mỗi từ sai (quan sát được) có thể phát ra từ một số từ đúng.
#
# - Dựa vào Minimum Edit Distance giữa từ sai và từng từ đúng trong từ điển.
#
# - Những từ đúng có khoảng cách nhỏ nhất được coi là ứng viên thay thế hợp lý, và được gán xác suất tỷ lệ nghịch với khoảng cách.

# %%
import re
from collections import defaultdict
from difflib import SequenceMatcher

def tokenize(sentence):
    # Lowercase
    sentence = sentence.lower()
    # Tokenize first, before removing punctuation
    tokens = custom_tokenize(sentence)
    # Remove punctuation from each token
    cleaned_tokens = [re.sub(r'[^\w\s]', '', token) for token in tokens]
    return cleaned_tokens
    
def build_train_errors(texts, correct_texts):
    train_errors = defaultdict(lambda: defaultdict(int))

    for wrong_sentence, correct_sentence in zip(texts, correct_texts):
        wrong_tokens = tokenize(wrong_sentence.lower())
        correct_tokens = tokenize(correct_sentence.lower())

        # So sánh hai chuỗi token bằng diff
        sm = SequenceMatcher(None, correct_tokens, wrong_tokens)
        for op, i1, i2, j1, j2 in sm.get_opcodes():
            if op == 'replace':
                for ct, wt in zip(correct_tokens[i1:i2], wrong_tokens[j1:j2]):
                    train_errors[ct][wt] += 1
            elif op == 'insert':
                for wt in wrong_tokens[j1:j2]:
                    train_errors['<INSERT>'][wt] += 1
            elif op == 'delete':
                for ct in correct_tokens[i1:i2]:
                    train_errors[ct]['<DELETE>'] += 1

    return train_errors

# %%
texts = [
    "Chây ì ngộp phạt nguội.",   # câu sai
    "Hàng chục ngans phương tiệng bị ghy hình vi pham luật.",  # câu sai
    "Hàng chục ngans phương tiệng bị ghy hình vi pham luật."  # câu sai
]

correct_texts = [
    "Chây ì nộp phạt nguội.",    # câu đúng
    "Hàng chục ngàn phương tiện bị ghi hình vi phạm luật.",  # câu đúng
    "Hàng chục ngàn phương tiện bị ghi hình vi phạm luật."
]

# %%
train_errors = build_train_errors(texts, correct_texts)
print(train_errors)
# In ra kết quả
for correct_word, error_dict in train_errors.items():
    for error_word, count in error_dict.items():
        print(f"Đúng: '{correct_word}' | Sai: '{error_word}' | Số lần: {count}")
# Out:
# defaultdict(<function build_train_errors.<locals>.<lambda> at 0x7b16af7ca520>, {'nộp': defaultdict(<class 'int'>, {'ngộp': 1}), 'ngàn': defaultdict(<class 'int'>, {'ngans': 2}), 'tiện': defaultdict(<class 'int'>, {'tiệng': 2}), 'ghi': defaultdict(<class 'int'>, {'ghy': 2}), 'phạm': defaultdict(<class 'int'>, {'pham': 2})})
# Đúng: 'nộp' | Sai: 'ngộp' | Số lần: 1
# Đúng: 'ngàn' | Sai: 'ngans' | Số lần: 2
# Đúng: 'tiện' | Sai: 'tiệng' | Số lần: 2
# Đúng: 'ghi' | Sai: 'ghy' | Số lần: 2
# Đúng: 'phạm' | Sai: 'pham' | Số lần: 2

# %%
def get_emission_prob(observed_word, vocab, train_errors=None, max_distance=5):
    target_distance = min(len(observed_word) - 1, max_distance)
    target_distance = max(1, target_distance)  # tránh bằng 0  
    
    if train_errors is None:
        train_errors = {}

    candidates = []
    for word in vocab:
        dist = min_edit_distance(observed_word, word)  
        if dist <= target_distance:
            candidates.append((word, dist))

    if not candidates:
        return {}

    probs = {}
    for word, dist in candidates:
        base_prob = 1 / (1 + dist)

        # Nếu từ sai đã từng xuất hiện trong tập train
        if word in train_errors and observed_word in train_errors[word]:
            count = train_errors[word][observed_word]
            boost = count * 0.1  # tăng xác suất theo số lần
            base_prob *= boost

        probs[word] = base_prob

    # Normalize
    total = sum(probs.values())
    for word in probs:
        probs[word] /= total

    return probs

# %% [markdown]
# ## 4. Thuật toán Viterbi (Giải mã chuỗi tối ưu)
# - Với chuỗi từ quan sát (câu cần sửa), tìm chuỗi từ đúng (ẩn) sao cho:
#     - Xác suất tổng (transition * emission) là lớn nhất.
# - Áp dụng Viterbi để tìm dãy từ đúng có xác suất cao nhất, từng bước một, sử dụng:
#     - Các từ ứng viên ở mỗi bước (từ có khoảng cách edit nhỏ với từ đầu vào).
#     - Xác suất chuyển tiếp giữa các từ ứng viên liên tiếp (3-gram).

# %%
def viterbi(observed, vocab, transition_prob, train_errors=None, epsilon=1e-8):
    # Bổ sung token đặc biệt
    observed = ['<start1>', '<start2>'] + observed + ['<end1>', '<end2>']

    V = [{} for _ in range(len(observed))]
    path = {}

    # ✅ Truyền train_errors từ đầu
    emis_probs = get_emission_prob(observed[0], vocab, train_errors)

    for word in emis_probs:
        emis = emis_probs[word]
        V[0][word] = log(emis + epsilon)
        path[word] = [word]

    for t in range(1, len(observed)):
        V.append({})
        newpath = {}

        # ✅ Lúc này train_errors phải cùng tên
        emis_probs = get_emission_prob(observed[t], vocab, train_errors)

        for y in emis_probs:
            max_prob = float('-inf')
            best_prev = None

            for y0 in V[t - 1]:
                prev_bigram = path[y0][-2] if len(path[y0]) >= 2 else "<start1>"
                trigram = (prev_bigram, y0, y)
                trans_prob = transition_prob.get(trigram, epsilon)
                emis_prob = emis_probs.get(y, epsilon)

                prob = V[t - 1][y0] + log(trans_prob + epsilon) + log(emis_prob + epsilon)

                if prob > max_prob:
                    max_prob = prob
                    best_prev = y0

            if best_prev is not None:
                V[t][y] = max_prob
                newpath[y] = path[best_prev] + [y]

        if not newpath:
            raise ValueError(f"No valid path at step {t}. Check transition/emission coverage.")
        path = newpath

    n = len(observed) - 1
    (prob, state) = max((V[n][y], y) for y in V[n])
    return path[state]

# %% [markdown]
# ## 5. Tái tạo câu đã sửa
# - Chuỗi từ đúng tìm được là kết quả sau khi sửa.
#
# - Ghép lại các từ theo đúng thứ tự để tạo thành câu đã sửa lỗi.

# %%
import re

def clean_text_with_mapping(text):
    replacements = {
        "<url>": [],
        "<emoji>": [],
        "<date>": [],
        "<time>": [],
        "<num>": [],
    }

    # Danh sách các pattern với placeholder ưu tiên
    patterns = [
        (r'https?://\S+|www\.\S+', "<url>"),
        ("[" + u"\U0001F600-\U0001F64F"
             + u"\U0001F300-\U0001F5FF"
             + u"\U0001F680-\U0001F6FF"
             + u"\U0001F1E0-\U0001F1FF"
             + u"\u2600-\u26FF"
             + u"\u2700-\u27BF" + "]", "<emoji>"),
        (r'\b\d{1,2}[-/]\d{1,2}[-/]\d{2,4}\b', "<date>"),   # dd/mm/yyyy hoặc dd-mm-yyyy
        (r'\b\d{4}[-/]\d{1,2}[-/]\d{1,2}\b', "<date>"),     # yyyy/mm/dd hoặc yyyy-mm-dd
        (r'\b\d{1,2}:\d{2}(?::\d{2})?\b', "<time>"),        # hh:mm hoặc hh:mm:ss
        (r'\d+(?:[.,]\d+)?', "<num>"),                     # số thực hoặc số nguyên
    ]

    # Ghi lại vị trí đã thay để tránh chồng lặp
    replaced = [False] * len(text)
    new_text = ""
    last_pos = 0
    matches = []

    for pattern, placeholder in patterns:
        for match in re.finditer(pattern, text):
            start, end = match.start(), match.end()
            if any(replaced[start:end]):
                continue  # Tránh thay chồng

            matches.append((start, end, match.group(), placeholder))
            for i in range(start, end):
                replaced[i] = True  # Đánh dấu đã xử lý

    # Sắp xếp lại theo thứ tự xuất hiện
    matches.sort()
    last_pos = 0
    for start, end, original, placeholder in matches:
        new_text += text[last_pos:start]
        new_text += placeholder
        replacements[placeholder].append(original)
        last_pos = end

    new_text += text[last_pos:]
    return new_text, replacements

# %%
text = "Hôm nay là 2024-12-01, mai là 02/12/2024 và 14:30. Website là https://openai.com và giá là 12.345,67₫ 😊"
cleaned, repl = clean_text_with_mapping(text)

print("➡ Văn bản sau khi clean:", cleaned)
print("➡ Mapping:")
for k, v in repl.items():
    print(f"  {k}: {v}")
# Out:
# ➡ Văn bản sau khi clean: Hôm nay là <date>, mai là <date> và <time>. Website là <url> và giá là <num>,<num>₫ <emoji>
# ➡ Mapping:
#   <url>: ['https://openai.com']
#   <emoji>: ['😊']
#   <date>: ['2024-12-01', '02/12/2024']
#   <time>: ['14:30']
#   <num>: ['12.345', '67']

# %%
clean_text(text)
# Out:
# 'Hôm nay là <date>, mai là <date> và <time>. Website là <url> và giá là <num>,<num>₫ <emoji>'

# %%
from collections import defaultdict

def restore_tokens(tokens, replacements):
    # Đếm số lần đã dùng của mỗi placeholder
    counts = {k: 0 for k in replacements}

    restored = []
    for token in tokens:
        if token in replacements:
            index = counts[token]
            if index < len(replacements[token]):
                restored.append(replacements[token][index])
                counts[token] += 1
            else:
                # Trường hợp placeholder nhiều hơn số bản ghi, giữ nguyên
                restored.append(token)
        else:
            restored.append(token)

    return restored

# %%
def correct_text(input_text, vocab, transition_prob, train_error):
    # print("\n===== Bắt đầu sửa lỗi chính tả =====")

    # 1. Làm sạch dấu câu
    input_text = clean_punctuation(input_text.lower())

    # 2. Chuẩn hóa và ghi nhớ các token đặc biệt
    cleaned_text, replacements = clean_text_with_mapping(input_text.lower())
    
    # 3. Tách từ (với xử lý placeholder dính liền)
    tokens = custom_tokenize(cleaned_text)

    # print(f"Tách từ sau clean: {tokens}")
    # print(f"Replacements: {replacements}")

    # 4. Xác định token cần sửa và giữ nguyên
    special_placeholders = set(replacements.keys())
    to_correct = []
    mask = []  # True nếu cần sửa

    for t in tokens:
        if t in special_placeholders:
            to_correct.append(t)
            mask.append(False)
        else:
            to_correct.append(t)
            mask.append(True)

    # 5. Sửa lỗi chính tả bằng Viterbi
    # tokens = [t for t, m in zip(to_correct, mask) if m]
    # print("input for viterbi ", tokens)
    corrected_tokens = viterbi(tokens, vocab, transition_prob, train_error)
    corrected_tokens = corrected_tokens[2:-2]
    # print("corrected tokens ",corrected_tokens)

    # 6. Gộp lại kết quả
    # final = []
    # j = 0
    # for i, m in enumerate(mask):
    #     if m:
    #         final.append(corrected_tokens[j])
    #         j += 1
    #     else:
    #         final.append(to_correct[i])

    # print("final: ",final)
    
    # 7. Khôi phục placeholder thành gốc
    restored = restore_tokens(corrected_tokens, replacements)

    # 8. Ghép lại thành văn bản hoàn chỉnh
    corrected_text = ' '.join(restored)

    corrected_text = clean_punctuation(corrected_text)

    # print("\n===== Hoàn tất sửa lỗi =====")
    print(f"Kết quả sau sửa: {corrected_text}")

    return corrected_text

# %%
train_error = build_train_errors(train['text'], train['correct_text'])

# %%
# Step 1: huấn luyện với tập văn bản đúng
texts = list(unique_correct_texts['correct_text'])
ngrams, vocab = preprocess(texts)
transition_prob = get_transition_prob(ngrams, vocab)
print(len(ngrams))
print(vocab)
# Out:
# 82696
# {'thâm', 'ocr', 'cronin', 'donor', 'vả', 'hqkd', 'tàu', 'faisal', 'chật', 'nguyệt', 'huyền', 'óc', 'cán', 'l', 'tag', 'mạn', 'mưu', 'khô', 'atm', 'brude', 'âm', 'dọa', 'ưu', 'diệu', 'vào', 'gương', 'roi', 'đixrtervec', 'labour', 'chữa', 'sớm', 'tia', 'vtap', 'bar', 'knight', 'cướp', 'chứ', 'tpb', 'stress', 'táo', 'chen', 'lotteria', 'polya', 'phiện', 'font', 'mth', 'chiều', 'enron', 'mắc', 'cecem', 'mèo', 'khắc', 'có', 'thìa', 'trấn', 'diot', 'video', 'cách', 'đăng', 'tràng', 'go', 'suôn', 'mông', 'vi–ét', 'chép', 'vai', 'đức', 'cổng', 'cảm', 'ven', 'sony', 'cơn', 'virus', 'agreement', 'đòi', 'vcpu', 'mời', 'buồng', 'nói', 'peroxid', 'canh', 'hđlđ', 'trách', 'cic', 'lũ', 'economy', 'bush', 'olof', 'maslow', 'mồ', 'okinawa', 'lăm', 'mendel', 'đông', 'lựa', 'driving', 'dượt', 'powerpoint', 'chơi', 'chẩn', 'cqđt', 'ch', 'tiên', 'xỉ', 'g', 'indutry', 'muỗi', 'thập', 'quang', 'ndvn', 'dawk', 'chạp', 'rét', 'diffserv', 'giơnevơ', 'đắt', 'artboard', 'thám', 'rẻo', 'mắm', 'côn', 'đỡ', 'nó', 'dịp', 'đợi', 'chốt', 'viễn', 'globalgap', 'táng', 'ủng', 'vợ', 'bầu', 'nlos', 'tbdh', 'đều', 'broker', 'rud', 'dunning', 'transexual', 'hàn', 'nhút', 'vít', 'cy', 'đấy', 'bề', 'vế', 'datacenter', 'discovery', 'organic', 'logo', 'thoát', 'màng', 'đội', 'bá', 'phẳng', 'thiều', 'đớn', 'thổi', 'option', 'oc', 'đảm', 'kê', 'cắm', 'ròng', 'cqt', 'xoa', 'blockchain', 'tchc', 'phơ', 'cigar', 'shawn', 'ngón', 'bản', 'thước', 'nhàng', 'miếu', 'gmsc', 'nộp', 'tùy', 'vườn', 'văn', 'cồn', 'nguyền', 'prusa', 'bộc', 'thà', 'xoay', 'ngô', 'ge', 'xử', 'vua', 'access', 'ecu', 'gdhn', 'sạch', 'diện', 'for', 'oxy', 'hành', 'ut', 'ai', 'vinmart', 'ham', 'sau', 'vượng', 'nẵng', 'lễ', 'hầm', 'xim', 'phương', 'dn', 'chlb', 'phúc', 'jd', 'lẻ', 'bấm', 'đĩa', 'energy', 'backend', 'association', 'thi', 'prudential', 'nợ', 'về', 'tải', 'chuẩn', 'ruộng', 'p', 'xưa', 'ấm', 'kệ', '𝛼', 'razak', 'tntn', 'pwa', 'nhà', 'bmv', 'xiết', 'linh', 'lão', 'cục', 'hđqt', 'misa', 'safeguard', 'build', 'thúc', 'ncovi', 'soát', 'ipa', 'vinatex', 'cqthtt', 'nỗ', 'tể', 'efas', 'xí', 'lỗi', 'lớn', 'thơ', 'nsđp', 'rang', 'vnpt', 'thốn', 'research', 'civic', 'exel', 'nối', 'bake', 'hứng', 'honda', 'ms', 'ddd', 'do', 'dunford', 'à', 'xắt', 'bớp', 'chắc', 'dục', 'h', 'exchange', 'read', 'tonne', 'đính', 'xô', 'razrabotka', 'mini', 'download', 'terry', 'nga', 'cẩn', 'lở', 'sundström', 'ngắm', 'code', 'acceptor', 'hán', 'sdn', 'dem', 'sát', 'pierre', 'cpa', 'đtv', 'ix', 'hs', 'coffee', 'bungari', 'neighbor', 'ghép', 'thở', 'customer', 'quản', 'thần', 'nhỏ', 'chấm', 'đoàn', 'sgk', 'sảng', 'mean', 'javascript', 'hlkhxhvn', 'phép', 'luyện', 'đàm', 'capital', 'array', 'men', 'nhục', 'tls', 'bảy', 'đi', 'hủy', 'chuộng', 'vecto', 'rải', 'accord', 'quặng', 'gốm', 'lõi', 'thận', 'truất', 'package', 'chất', 'cnv', 'trái', 'boong', 'succuri', 'kí', 'reasoned', 'sl', 'chà', 'dndd', 'bmi', 'dí', 'niên', 'bình', 'tắm', 'cloud', 'niña', 'lagged', 'singapore', 'dưa', 'kiệm', 'khẩu', 'true', 'xứng', 'nạt', 'nghia_viet_anh', 'standards', 'giấy', 'keangnam', 'rise', 'soni', 'trùng', 'manh', 'nhn', 'bài', 'phim', 'enso', 'nhược', 'tdst', 'chéo', 'xe', 'nhăn', 'team', 'bitum', 'rũ', 'như', 'cắn', 'găng', 'ồn', 'dinh', '#', 'nhnn', 'cached', 'wikipedia', 'ập', 'nửa', 'server', 'mô', 'dnnn', 'fourier', 'vận', 'tiệc', 'pmax', 'tỳ', 'cipo', 'mà', 'fanpage', 'cross', 'cooh', 'ab', 'struct', 'vồ', 'bkhcn', 'rreq', 'thiết', 'lánh', 'sâu', 'chớp', 'rảnh', 'mũi', 'ủ', 'hun', 'mwg', 'suối', 'bông', 'lún', 'positive', 'cấy', 'ắc', 'bên', 'chối', 'lớp', 'kỉ', 'gong', 'nlmt', 'khđt', 'ito', 'dám', 'davis', 'cà', 'rscp', 'mexico', 'ro', 'kmo', 'mẹ', 'bừng', 'hang', 'của', 'khuẩn', 'jelacic', 'things', 'phên', 'tổ', 'ảo', 'soạn', 'cưỡng', 'thò', 'tịch', 'chùm', 'kĩ', 'súng', 'model', 'bật', 'lạng', 'rosenstock', 'tật', 'nung', 'chứa', 'gauge', 'tươi', 'bón', 'chuốc', 'tương', 'dòng', 'hái', 'mol', 'hồng', 'mốc', 'hoại', 'gartner', 'news', 'lúa', 'cli', 'gdcd', 'gộp', 'syed', 'dnbh', 'điểm', 'tồn', 'api', 'mac', 'nl', 'cbcnv', 'vietnam' ...

# %%
# Step 2: sửa lỗi
wrong_text = "thôngg qua công tác tuyên truyeenf, van động này phu huynh sẽ hiểu rỏ hơn tầm quan trọng của việc giáo duc."
corrected = correct_text(wrong_text, vocab, transition_prob, train_error)
# Out:
# Kết quả sau sửa: thông qua công tác tuyên truyền, vận động này phụ huynh sẽ hiểu rõ hơn tầm quan trọng của việc giáo dục.

# %%
custom_tokenize(wrong_text)
# Out:
# ['thôngg',
#  'qua',
#  'công',
#  'tác',
#  'tuyên',
#  'truyeenf',
#  ',',
#  'van',
#  'động',
#  'này',
#  'phu',
#  'huynh',
#  'sẽ',
#  'hiểu',
#  'rỏ',
#  'hơn',
#  'tầm',
#  'quan',
#  'trọng',
#  'của',
#  'việc',
#  'giáo',
#  'duc',
#  '.']

# %%
wrong_text = "quan điểm biện chứng của chù nghĩa mác - lênin không chỉ khẳng định tính khách quan, tính phổ biến của các mối liên hệ mà còn nhấn mạnh tính phong phú, đa dạng của các mối liên hệ."
corrected = correct_text(wrong_text, vocab, transition_prob, train_error)
# Out:
# Kết quả sau sửa: quan điểm biện chứng của chủ nghĩa mác - lênin không chỉ khẳng định tính khách quan, tính phổ biến của các mối liên hệ mà còn nhấn mạnh tính phong phú, đa dạng hóa các mối liên hệ.

# %%
wrong_text = "đối với biểu đồ histogram, nếu giá trị trung bình mean gần bằng 0, độ lệch chuẩn gần bằng 1 và đường cong phân phối có hình dạng chuông thì có thể khẳng định phân phối là xếp xỉ chuẩn, giả định phân phối chuẩn của phần dư không bị vi phạm."
corrected = correct_text(wrong_text, vocab, transition_prob, train_error)
# Out:
# Kết quả sau sửa: đối với biểu đồ histogram, nếu giá trị trung bình mean gần bằng 0, độ lệch chuẩn gần bằng 1 và đường cong phân phối có hình dạng chuông thì có thể khẳng định phân phối là xấp xỉ chuẩn, giả định phân phối chuẩn của phần dư không bị vi phạm.

# %% [markdown]
# ## Đánh giá trên tập test

# %%
test
# Out:
#                                                    text  \
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giam mà còn tăng thê...
# 3     Đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chù nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
#                                              preprocess  \
# 0     thông qua công tác tuyên truyền, vận động này ...
# 1     do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     giữ được chỉ số này không giam mà còn tăng thê...
# 3     đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  tuy nhiên, khi nói đến e-learning, các phương ...
# 8963  đứng trước những hành vi đi ngược lại với đạo ...
# 8964  quan điểm biện chứng của chù nghĩa mác - lênin...
# 8965  đối với biểu đồ histogram, nếu giá trị trung b...
# 8966  trong mỗi khu vực mà đội phát triển thị trường...
#
#                                            correct_text
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giảm mà còn tăng thê...
# 3     Đứng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chủ nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
# [8967 rows x 3 columns]

# %%
test = test[:2000]

# %%
def correct_wrapper(text):
    return correct_text(text, vocab, transition_prob, train_error)

# Áp dụng sửa lỗi cho toàn bộ cột "preprocess"
test["predicted"] = test["preprocess"].apply(correct_wrapper)
# Out:
# Kết quả sau sửa: hiệu quả công tác tuyên truyền, vận động này phụ huynh sẽ hiểu rõ hơn tầm quan trọng của việc giáo dục ý thức bảo vệ môi trường cho trẻ không phải chỉ ở phía nhà trường mà còn ở gia đình, góp phần vào việc gìn giữ môi trường xanh, sạch, đẹp.
# Kết quả sau sửa: do đó, doanh nghiệp cần chú trọng đến yếu tố này để làm thỏa mãn, hài lòng của thời đại hiện nay.
# Kết quả sau sửa: giữ được chỉ số này không giảm mà còn tăng thêm cũng được xem là một bước thành công của ngân hàng.
# Kết quả sau sửa: đứng trước thực tế này đòi hỏi chúng ta cần phải có những nghiên cứu chi li, cụ thể nhằm tìm ra những nhân tố ảnh hưởng đến sự lựa chọn kênh mua sắm của người tiêu dùng ô tô.
# Kết quả sau sửa: trình độ học vấn của nhân viên được tuyển dụng ngày càng cao hơn, thợ lành nghề cũng được sàng lọc kỹ hơn.
# Kết quả sau sửa: ở các nước phát triển, đa số các ấn phẩm nhật báo hoặc tuần báo có con số từ vài chục đến hàng trăm trang (tính cả phụ trang quảng cáo, dịch vụ xã hội).
# Kết quả sau sửa: các bất cập đó đã làm nảy sinh ra việc sử dụng đất chưa hợp lí, ảnh hưởng từ quá trình công nghiệp hóa làm suy giảm diện tích đất nông nghiệp.
# Kết quả sau sửa: cách mạng đã hội tụ hoàn gateway mà ổ điện thông minh cần xử lý ở đây sẽ thường là yêu cầu bật / tắt ổ điện, yêu cầu thông báo trạng thái bật / tắt của ổ điện, yêu cầu thông báo vị trí lắp đặt của ổ điện.
# Kết quả sau sửa: với khuôn khổ này, chính trị học so sánh có thể áp dụng vào phân tích nhằm xác định được sự tương đồng và khác biệt giữa các quá trình học tập, tương ứng với sự tương đồng và khác biệt của cấu trúc chính trị.
# Kết quả sau sửa: việc điều khiển xe sẽ trở nên dễ dàng hơn nếu các bánh xe được đặt theo một góc chính xác theo yêu cầu thực tế, việc đặt sai góc sẽ tạo ra tính ổn định khi lái kém và khiến lốp xe nhanh mòn.
# Kết quả sau sửa: tính đến nay, ta nêu lên những cơ sở lý thuyết được áp dụng trong việc giải quyết bài toán xây dựng hệ thống.
# Kết quả sau sửa: tài liệu bồi dưỡng và nâng cao năng lực chuyên môn nghiệp vụ và đạo đức nghề nghiệp cho cán bộ công nhân viên.
# Kết quả sau sửa: xây dựng nội dung học dưới dạng các tư liệu học tập: phiếu học tập.
# Kết quả sau sửa: người đến thăm chùa bà đá, dự lễ kỷ niệm khổng tử và đến thăm các phòng triển lãm tranh của các họa sĩ nổi tiếng.
# Kết quả sau sửa: kho chứa cốt thép phải có nền cao ráo, không để nước mưa chảy vào, mái và tường không bị dột, không bị nước mưa hắt, có khả năng chống ẩm.
# Kết quả sau sửa: tuy nhiên, mục tiêu của p 4 là còn có thể tái cấu hình với cả các asic có chức năng cố định.
# Kết quả sau sửa: nhờ việc hoạt động theo nhóm, học sinh được rèn luyện các kỹ năng cần thiết như hợp tác, trình bày trước đám đông, kỹ năng lập kế hoạch, thực hiện kế hoạch và đánh giá kế hoạch.
# Kết quả sau sửa: trong công tác tuyển dụng cán bộ làm công tác thẩm định dự án, báo cáo kinh tế kỹ thuật đầu tư đòi hỏi phải có trình độ chuyên môn nghiệp vụ theo quy định, cán bộ thẩm định phải có kinh nghiệm.
# Kết quả sau sửa: nhưng trong khi làm bài luận văn chắc chắn, cần chú trọng hơn các chợ.
# Kết quả sau sửa: vì vậy qua những câu chuyện với mục đích cung cấp hiểu biết về sự thích thú của bảng cho vay đối với trục x và quá trình phát triển của chúng.
# Kết quả sau sửa: nestle đã từng bước khẳng định được vị trí của bản thân mình bằng cách vươn xa, mở rộng phạm vi hoạt động trên toàn thế giới.
# Kết quả sau sửa: học sinh quan sát tranh, cảm nhận và ghi nhớ.
# Kết quả sau sửa: dưới triều lê sơ, ngự sử đài vẫn là cơ quan có vai trò lớn hơn lục khoa, quan lại thuộc ngự sử đài là những người có quyền lực từ tể tướng đến võ tướng - những chức vụ cao nhất trong triều.
# Kết quả sau sửa: mỗi tháng 1 lần, công ty sẽ tổ chức một buổi giao lưu chia sẻ kinh nghiệm giữa các thành viên với nhau và đào tạo thêm về các kỹ năng ứng xử khác cho nhân viên.
# Kết quả sau sửa: trang trí chủ đề học tập mà thông tin thị trường ở lớp.
# Kết quả sau sửa: display ads: quảng cáo hiển thị) có thể khẳng định tính khách quan, hỉ, bđkh như: du lịch.
# Kết quả sau sửa: nền kinh tế nước ta đang tiến từng bước vững chắc tới công cuộc cải cách kinh tế theo hướng mở cửa để nhanh chóng hòa nhập với nền kinh tế thế giới.
# Kết quả sau sửa: trong trường hợp có hai người hoặc nhiều người cùng sáng tạo ra tác phẩm thì những người đó là đồng tác giả.
# Kết quả sau sửa: nghiên cứu về phát triển nhanh và bền vững nền kinh tế việt nam (2011 - 2020), bùi tất thắng (2010), đã đi sâu vào phân tích các lý thuyết về phát triển nhanh và bền vững của các học giả trên thế giới.
# Kết quả sau sửa: chú ý đến việc giảm giá thành sản phẩm bằng cách hạn chế đến mức thấp nhất tỷ lệ hao hụt, giảm các công đoạn thừa, không tạo ra giá trị.
# Kết quả sau sửa: từ sơ đồ phản ứng, sản phẩm chính phụ tổ chức cho hs nhận xét rút ra hướng phản ứng và đi đến quy tắc mac - côp - nhi - côp.
# Kết quả sau sửa: khó khăn trong việc truyền đạt đầy đủ kiến thức cho hs để hs hiểu rõ tác phẩm và thể loại.
# Kết quả sau sửa: xây dựng mô hình để chuyển giao nhanh giống mới, những khía cạnh các tên tuổi, trình độ khoa học và công nghệ cho nông dân.
# Kết quả sau sửa: bên cạnh đó, ai trong forum cũng có quyền lên tiếng nói, có quyền tự do ngôn luận do đó forum cũng là một phương tiện truyền tải thông tin ewom hiệu quả.
# Kết quả sau sửa: đồng thời, tác giả cũng đã chỉ ra những khó khăn trong thực hiện các chính sách an sinh xã hội ở việt nam những năm gần đây trên cơ sở phân tích những đánh giá của nhóm cán bộ các đơn vị chủ đầu tư hệ thống chính sách an sinh xã hội.
# Kết quả sau sửa: tác giả cũng cho rằng, việc lập kế hoạch đầu tư công phải được kiểm soát chặt chẽ và thông qua bởi cơ quan hành chính cao nhất là với các định chế then chốt khác.
# Kết quả sau sửa: phấn đấu đến năm 2020, toàn tỉnh có 60 % số xã có cơ sở hạ tầng kinh tế xã hội cơ bản đạt tiêu chí ntm.
# Kết quả sau sửa: các nhà kinh doanh báo chí sẽ đưa ra câu hỏi, liệu độc giả ở những vùng sâu, vùng xa chậm phát triển có nhu cầu mua báo hơn nhu cầu mua nhiều thứ thiết thực hơn.
# Kết quả sau sửa: khi đầm lớp bê tông phía trên phải ăn sâu xuống lớp bê tông phía dưới khoảng 5 - 10 cm để làm cho 2 lớp bê tông liên kết với nhau.
# Kết quả sau sửa: năng suất lao động của chi phí tăng lên 6 % đến 7 % bằng cách chú trọng đào tạo chuyên môn, nâng cao tay nghề, tuyển chọn những lao động có trình độ cao hơn.
# Kết quả sau sửa: ở dạng quỹ đạo này vệ tinh bay trực tiếp trên mặt phẳng quỹ đạo trùng với mặt phẳng xích đạo, nó thích hợp với các vệ tinh thông tin.
# Kết quả sau sửa: do vậy, trên thế giới ngoài những vấn đề nóng do tranh chấp lượng dự trữ năng lượng hóa thạch thì năng lượng tái tạo, một nguồn năng lượng sạch và vô tận, đang được ưu tiên, đầu tư cho nghiên cứu, khai thác và sử dụng.
# Kết quả sau sửa: sau quá trình hoạt động của công ty nguồn vốn công ty mới được huy động thêm từ bên ngoài.
# Kết quả sau sửa: tạo ra mức độ hứng thú của hs qua phương pháp học tập mới, thông qua các hình thức học khác nhau từ đó lựa chọn các hình thức học mang tính khả thi và hiệu quả nhất.
# Kết quả sau sửa: mức tái cấp vốn tối đa không vượt quá mức cung ứng dành cho học sinh cũng hứng thú trong học tại trung tâm.
# Kết quả sau sửa: để bắt kịp nhu cầu của khách hàng các ngân hàng cần có những bước đi đầy sáng tạo.
# Kết quả sau sửa: kiểm soát được đưa ra nhằm thu thập thông tin, ý kiến khác nhau để phục vụ cho việc nghiên cứu đề tài.
# Kết quả sau sửa: momen phanh sinh ra trên 1 cơ cấu phanh đĩa được xác định theo công thức:
# Kết quả sau sửa: fanpage của hưng việt đã cung cấp đầy đủ cụ thể hóa vấn đề tương tự chủ trọ (đền chùa, cách thức liên hệ, … đồng thời cũng giới thiệu tổng quan về công ty.
# Kết quả sau sửa: chỉ đạo tổ trưởng chuyên môn / nhóm trưởng hướng dẫn gv, nhân viên chăm sóc trẻ lập kế hoạch cá nhân và duyệt kế hoạch của từng bộ môn, có sẵn.
# Kết quả sau sửa: giai đoạn giới thiệu: đây là một giai đoạn khó khăn nhất đối với colgate và ở thị trường việt nam, colgate gần như thất bại ở giai đoạn này.
# Kết quả sau sửa: nội dung vào không có giáo viên âm nhạc tiểu học tích cực tự học nâng cao trình độ sử dụng trong nội dung phù hợp hơn nữa để nâng cao năng lực nghiên cứu, đọc tài liệu bằng tiếng anh nhằm phát triển năng lực của mỗi giáo viên âm nhạc tiểu học.
# Kết quả sau sửa: thái độ phục vụ sử dụng chuỗi ký tự đặc biệt, bản tin được chia thành các block với giá trị chiều dài ngẫu nhiên được thêm vào phía trước.
# Kết quả sau sửa: mặc dù thừa hưởng hoàn toàn từ phiên bản tại hàn quốc nhưng baemin vẫn tiếp tục được đầu tư, thiết kế dành riêng cho thị trường vn, từ màu xanh thương hiệu đến font chữ hay biểu tượng mèo mập.
# Kết quả sau sửa: bản chất của hoạt động smm: quá trình trao đổi nội dung giữa thương hiệu và khách hàng trong đó thương hiệu chủ động tạo ra cuộc đối thoại một cách có mục đích chứ không phải là người quyết định nội dung cho cuộc hội thoại đó.
# Kết quả sau sửa: cách thức thực hiện: giáo viên hướng dẫn học sinh giải các bài toán cơ bản từ đó rèn luyện kỹ năng cho học sinh giải các bài toán tương tự thông qua hệ thống các bài tập giao về nhà đã được biên soạn.
# Kết quả sau sửa: với hình thức này vừa tạo cho trẻ những kỹ thuật máy, vui vẻ sau hoạt động nhưng cũng thông qua đó có thể thu được của từng nhân tố ảnh hưởng đến.
# Kết quả sau sửa: hạn chế cửa nhân tố kinh tế đối với doanh nghiệp là việt nam mở của nền kinh tế thị trường (gia nhập wto) tạo nên nhiều đối thủ cạnh tranh - nhiều tập đoàn bán lẻ hùng mạnh trên thế giới và khu vực xa nhằm tạo nên hiện nay.
# Kết quả sau sửa: có thể nêu ra một số điểm mới của luận văn về đề tài lỗi trong trách nhiệm dân sự bồi thường thiệt hại ngoài hợp đồng như sau:
# Kết quả sau sửa: đồng thời, doanh nghiệp cố gắng đàm phán để có lợi nhất cho phía mình trong mọi tình huống.
# Kết quả sau sửa: vai trò của văn hóa đọc đối với sinh viên đại học kinh tế - đại học quốc gia hà nội.
# Kết quả sau sửa: mười hai cộng ba mươi lăm.
# Kết quả sau sửa: các em có những kỹ năng tổ chức hoạt động tư duy, tiến hành các thao tác như so sánh, hệ thống hóa, phân loại nhằm ghi nhớ tài liệu.
# Kết quả sau sửa: gần đây công tác đấu thầu qua mạng đang được tiếp cận, tuy vẫn còn gặp khó khăn trong việc tiếp cận, kiểm tra giám sát hồ sơ trước khi thẩm định.
# Kết quả sau sửa: đối với các tổ chức cho hs nhận xét như vậy có thể sở hữu là tổ chức, sẽ có hội đồng thành viên, chủ sở hữu sẽ bổ nhiệm các vị trí thành viên hội đồng thành viên miễn nhiệm từ 03 đến 07 năm với nhiệm kì không được quá 05 năm.
# Kết quả sau sửa: điều này phản ánh thực tế và các hoạt động học trong lao động và trong hoạt động thể dục, thể thao không được đánh giá cao, cần có sự cải thiện và thiết kế chương trình sao cho phù hợp với lứa tuổi mẫu giáo.
# Kết quả sau sửa: cách thức liên kết giúp cho câu được hoàn chỉnh, mạch lạc hơn.
# Kết quả sau sửa: văn học dân gian được xem là một tài sản quốc gia, được thể hiện rất phong phú và đa dạng nhưng lại gần như chưa có cơ quan nào được thành lập để thực hiện việc này.
# Kết quả sau sửa: việc phân loại và trích lập dự phòng rủi ro chưa phản ánh thực chất rủi ro tín dụng của ngân hàng.
# Kết quả sau sửa: tạo ra sản phẩm phong phú và đa dạng với nhiều phiên bản khác nhau, đáp ứng được nhu cầu của thị trường đặc biệt là phái nữ.
# Kết quả sau sửa: các yếu tố nhân khẩu học bao gồm những gì?
# Kết quả sau sửa: ba mẹ huy bận công việc nên không có thời gian quan tâm đến việc học của huy.
# Kết quả sau sửa: trong một số nước không quan tâm đến vấn đề này, khi nguồn viện trợ oda ngày càng tăng thì việc lãng phí đầu tư tràn lan cũng có xu hướng ngày càng tăng, nhất là giai đoạn đầu của vốn vay, khi nghĩa vụ trả nợ gốc còn ẩn giấu sau thời gian ân hạn.
# Kết quả sau sửa: dốc hết âm thanh của máy xuống quảng trường.
# Kết quả sau sửa: trong đề tài: rèn kỹ làm hai hệ thống hóa, hỗ trợ, tạo sự gắn bó chặt chẽ với nhau giữa các cơ sở đào tạo hoặc giữa các cơ sở đào tạo với các bài tập kiểu phân hóa học của học sinh ý thức và củng cố ở đồ thị.
# Kết quả sau sửa: sử dụng phương pháp này giúp xây dựng cơ sở dữ liệu không gian thuộc tính và mô hình dem bao gồm các bản đồ chuyên đề về hiện trạng khu vực châu á.
# Kết quả sau sửa: trầu bà tỷ phú là một loại cây cảnh đẹp không có hoa, cây có sức sống mạnh mẽ và có khả năng chịu được râm mát nên thường được nhiều người ưu ái chọn trồng.
# Kết quả sau sửa: để đánh giá được hoạt động kinh doanh của công ty thì song song với việc phân tích tình hình biến động của bđkh như: các từ có thể phân tích rõ tình hình biến động của chi phí qua các năm và xem xét biến động đó so với biến động của công ty.
# Kết quả sau sửa: để cho ra một dòng sữa nguyên chất tươi ngon th đã luôn tiếp cận sản xuất theo chuỗi đồng cỏ sạch, trang trại sạch, cho đến ly sữa sạch.
# Kết quả sau sửa: bản đồ các hệ thống tiêu thụ dầu diesel oil.
# Kết quả sau sửa: các tổ chức mà có các chức năng xác định, tư vấn giá đất và xác định giá rõ ràng, cụ thể.
# Kết quả sau sửa: thiết bị và tài liệu học tập đủ dùng.
# Kết quả sau sửa: qua phân tích hồi quy và kiểm định khuyết tật của mô hình cho thấy, kết quả nghiên cứu cũng khá tương đồng với các nghiên cứu trước đây của các tác giả trong và ngoài nước.
# Kết quả sau sửa: thiết kế hở cũng sẽ giúp người dùng, kỹ thuật viên dễ dàng quan sát, nhắc nhở các hư hỏng để dễ dàng vệ sinh, sửa chữa.
# Kết quả sau sửa: tuy nhiên, việc quảng bá thương hiệu sẽ rất tốn kém, do đó việc hiểu rõ mức độ ảnh hưởng của sự nhận biết đến tiến trình lựa chọn sản phẩm sẽ giúp các doanh nghiệp có được cách thức xây dựng thương hiệu đạt hiệu quả với chi phí hợp lý.
# Kết quả sau sửa: do vậy, quan hệ giữa người bán lẻ và sỉ là quan hệ với nhau.
# Kết quả sau sửa: ping: độ trễ mạng được đo bằng thời gian khứ hồi theo mili giây (ms).
# Kết quả sau sửa: niềm tin và thái độ: thông qua hoạt động và tri thức, người ta có được niềm tin và thái độ.
# Kết quả sau sửa: cuối cùng, em cũng xin gửi lời cảm ơn đến người thân, bạn bè đã động viên, giúp đỡ, tạo điều kiện để em hoàn thành luận văn này.
# Kết quả sau sửa: gv tổ chức cho hs suy nghĩ và thảo luận về những số liệu cần thiết, cần thu thập nhằm đơn giản hóa bài toán.
# Kết quả sau sửa: kiến nghị mức cổ tức được trả, quyết định thời hạn và thủ tục trả cổ tức hoặc xử lý các khoản lỗ phát sinh trong quá trình kinh doanh.
# Kết quả sau sửa: giáo viên cần bồi dưỡng, trau dồi thêm kiến thức chuyên môn, nghiệp vụ sư phạm, tìm tòi những sáng kiến mới, những phương pháp và các cách giải quyết bài tập mới giúp bản thân trở nên hoàn thiện hơn và học sinh cũng hứng thú học tập hơn.
# Kết quả sau sửa: chu trình sản xuất khép kín chuẩn quốc tế, từ nguồn nguyên liệu cho đến công nghệ làm sữa sạch nhằm giữ vẹn nguyên tinh túy của thiên nhiên trong tuần giọt sữa.
# Kết quả sau sửa: dựa vào biểu đồ, ta có thể thấy dung lượng của ổ c là 200 gb (màu đỏ), màu xanh lá cây là dung lượng còn trống 180.15 gb.
# Kết quả sau sửa: hậu quả là cụm từ được nhiều tổ chức và công ty sử dụng để nói chung cho các loại rau và quả được sử dụng làm thực phẩm.
# Kết quả sau sửa: việc lập kế hoạch là cơ sở đảm bảo cho quá trình quản lí đạt hiệu quả cao, nó thay thế cho các hoạt động rời rạc, tùy tiện.
# Kết quả sau sửa: kỹ năng: rèn kỹ năng đo đạc thực tế, rèn ý thức làm việc tập thể.
# Kết quả sau sửa: dù đang ở đâu, trong khoảng thời gian nào thì cũng chỉ cần có một thiết bị điện tử (điện thoại, máy tính, các văn bản, …) thì chúng ta có thể mua bất cứ loại hàng hóa nào mình với vài thao tác đơn giản.
# Kết quả sau sửa: ngoài ra, đảng ủy bộ y tế cũng yêu cầu thành lập ban chỉ đạo cấp tỉnh, thành phố trực thuộc trung ương, ban chỉ đạo các bệnh viện để đưa ra kế hoạch chi tiết, cụ thể phù hợp cho từng địa phương và từng điều kiện cụ thể của các công việc.
# Kết quả sau sửa: các đặc điểm về môi trường thể chế cấp địa phương bao gồm những chính sách ưu đãi về tài khóa như thuế, trợ cấp, ưu đãi về quy trình, thủ tục (oman, 2000).
# Kết quả sau sửa: khi đơn vị cung cấp uy tín lớn họp họp thác kính thế, mỹ thuật 18/9/1991.
# Kết quả sau sửa: kiểm định sự bằng nhau của phương sai.
# Kết quả sau sửa: như vậy, trong hoạt động mua bán, tình hình thu nợ với khách hàng được công ty quản lý tốt.
# Kết quả sau sửa: sự tương trợ giúp đỡ lẫn nhau trong cộng đồng còn được thể hiện rất rõ khi có những sự cố của một cá nhân hoặc biến động chung của toàn xã hội.
# Kết quả sau sửa: g: nêu cách xác định đỉnh tương ứng của 2 tam giác đồng dạng khi đã thỏa mãn gt của định lí.
# Kết quả sau sửa: trong cuốn sách này, tác giả đồng nhất khái niệm tác phong và phong cách và dùng hai khái niệm này tương đương ý hiểu như nhau.
# Kết quả sau sửa: thiếu quan hệ giữa các cell dẫn đến gây nhiễu.
# Kết quả sau sửa: đây là cơ hội và các bệnh lây lan với đó ảnh hưởng đến việc thái độ cá nhân đó đã làm cho sản xuất điện, nước, có khoảng gần 850 điểm):
# Kết quả sau sửa: kết quả chung của các nghiên cứu về trung quốc đều chỉ rõ vai trò của việc nằm cạnh biển đối với thu hút fdi.
# Kết quả sau sửa: chi phí quảng cáo được nâng cao, đây là một hình thức mà khá nhiều các công ty áp dụng vào học sinh làm các sản phẩm đó dẫn đến từ thời tiết tại các ao ấp đụng khác nữa.
# Kết quả sau sửa: s (1,2 - 5,6 % vào t. 4): mở rộng thị trường ra nước ngoài, củng cố uy tín, hình ảnh của công ty.
# Kết quả sau sửa: qua thống kê có thể thấy đa số các em đều thấy môn sinh học có thể giúp các em trả lời các vấn đề cụ thể trong thực tiễn cũng như là hình thành và củng cố được nhiều năng lực, kĩ năng thực hành, hợp tác, sáng tạo.
# Kết quả sau sửa: chỉ tiêu này phản ánh mức doanh thu đạt được trên một đồng chi phí tiền lương.
# Kết quả sau sửa: kết quả như sau: - với giáo viên: để biết được tình trạng của dạy học gdhn trong nhà trường tôi tiến hành phiếu hỏi ý kiến đối với các giáo viên trong trường thcs phùng chí kiên, nam định.
# Kết quả sau sửa: tuy cầu về gạo là ít biến động nhưng với sản phẩm đặc sản thì giá quyết định khá lớn.
# Kết quả sau sửa: và giúp cho tác giả có thể dễ dàng tiếp cận được người có nhu cầu sử dụng tác phẩm.
# Kết quả sau sửa: tham gia vào nghiên cứu đa dạng hóa các sản phẩm, phát triển nhiều sản phẩm khác để đáp ứng thị trường.
# Kết quả sau sửa: để chứng minh hai cạnh trên vuông góc ta cần chứng minh góc giữa chúng bằng 90 độ.
# Kết quả sau sửa: các trò chơi tôi thường sử dụng: ai nhanh hơn? , gắn tên, rung chuông vàng.
# Kết quả sau sửa: đến khi kết thúc quá trình thì tất cả các nút trên mạng đều sẽ tìm ra được bước truyền kế tiếp tối ưu đến tất cả mọi đích, là công cụ hỗ trợ một nền văn hóa trong sản phẩm tối ưu.
# Kết quả sau sửa: đây là môn học hiện đại với độ phủ sóng bởi đầu việt nam.
# Kết quả sau sửa: thiệt hại về việc chưa sử dụng các dịch vụ 24 đơn, chiếm 9,20 %.
# Kết quả sau sửa: sự kết hợp là yếu tố tinh thần trách nhiệm thực hiện chính sách ưu đãi đầu tư, rà soát, nhận và xử lý các khiếu nại của các nhà đầu tư và hỗ trợ việc thực hiện các dự án fdi.
# Kết quả sau sửa: trên thực tế, seo spam là một trong những cách kiếm tiền sinh lợi hơn từ một website tấn công và cũng là một trong những hình thức lây nhiễm phổ biến nhất.
# Kết quả sau sửa: ông nguyễn kỳ thành trưởng phòng kiểm tra chất lượng.
# Kết quả sau sửa: khái quát về hệ thống gạt nước rửa kính cho ô tô.
# Kết quả sau sửa: các chi phí bán hàng, họ có cơ sở hạ trợ trực tiếp từ chính phủ cho doanh nghiệp không còn phù hợp với quy định của evfta.
# Kết quả sau sửa: thứ nhất làm 75 g vào đó hoàn toàn thay đổi từ mô hình b 100), nhưng tỉ lệ học sinh chưa nắm vững kiến thức của các trạm thông tin thứ cấp và trẻ cũng như với cả các biện pháp trên sâu sắc hơn nữa để nâng cao hiệu quả dạy học.
# Kết quả sau sửa: các em sẽ không thể nào tiếp nhận được hoàn chỉnh và rõ ràng nội dung bài học.
# Kết quả sau sửa: để sống chánh niệm với các pháp, đòi hỏi hằng ngày chúng ta phải luôn nhớ ghi đến những lời dạy, những bài pháp đức phật đã dạy trong các bài kinh.
# Kết quả sau sửa: sai lầm trong bài chứng minh trên có thể do học sinh đã ngộ nhận trực quan là 3 điểm e, b, f thẳng hàng tức là đánh tráo luận cứ thành luận đề.
# Kết quả sau sửa: đối với lãnh đạo nhà trường nên thường xuyên quan sát và đánh giá lớp học của giáo viên.
# Kết quả sau sửa: sử dụng các ứng dụng phần mềm vi tính cơ bản.
# Kết quả sau sửa: việc làm gương của giáo viên và cán bộ quản lý giáo dục chưa thật tốt.
# Kết quả sau sửa: thế hệ trẻ như chúng em đang sống trong môi trường kĩ thuật số, sự phát triển không ngừng của internet khiến cho một phần giới trẻ dường như đang bị biến chất về lối sống, suy nghĩ.
# Kết quả sau sửa: quản lý nhà nước về tài sản, cơ sở vật chất được thực hiện thống nhất, có phân công, phân cấp rõ thẩm quyền, trách nhiệm của từng cơ quan nhà nước và trách nhiệm phối hợp giữa các cơ quan nhà nước.
# Kết quả sau sửa: đầu thế kỉ xx, các nhà khoa học phương tây tìm ra các biện pháp dạy học với mục đích khai thác cái cá thể dựa trên những thành tựu lý luận của tâm lý học, xem con người với tư cách là con người cá thể.
# Kết quả sau sửa: song song với ảnh hưởng đến thực hiện và hình thức, tự giáo dục cần tổ chức đánh giá rõ nét nhất về đều đề mới và nâng cấp cơ sở đào tạo.
# Kết quả sau sửa: giáo viên ghi lên bảng các âm, tiếng, từ mà các bạn chưa tiếp thu kịp ở bài học trước và yêu cầu ban cán sự lớp cho các bạn yếu đọc.
# Kết quả sau sửa: bước 1: thực hiện và xây dựng các kế hoạch thu hồi đất và các phương án bồi thường.
# Kết quả sau sửa: nội dung: đưa ra các phần lý thuyết và có ví dụ ở mức độ nhận diện, cần thiết.
# Kết quả sau sửa: phải đảm bảo đúng kích thước, ổn định và độ gọn nhẹ cho sản phẩm.
# Kết quả sau sửa: bức tranh kinh tế việt nam tiếp tục có những gam màu tươi mới khi tăng trưởng kinh tế năm 2019 đạt 7,02 %.
# Kết quả sau sửa: theo glenn m. , mary jo blahna năng lực được xây dựng, hình thành và phát triển dựa trên cơ sở tổ hợp các kiến thức, kỹ năng và thái độ.
# Kết quả sau sửa: lựa chọn các nhiệm vụ học tập phù hợp sao cho người học có thể tự đánh giá việc đạt được mục tiêu học tập.
# Kết quả sau sửa: trung tâm tư, tốt ở các bước 5 – 1,2 và tòa án thụ lý tra bản án, các nút làm việc được giao đất, thông qua đó trẻ không khí sẽ có giá trị đối với việc dạy học.
# Kết quả sau sửa: niệm phật không phải hao công nhọc sức, khó khăn, phù hợp mọi căn cơ, người thượng căn tu tập cũng được, người hạ căn tu tập cũng được chủ động, những thông tin và báo cáo từ tổ chức.
# Kết quả sau sửa: từ đó, ngân hàng có thể đưa ra các chính sách kinh doanh hiệu quả hơn ở đây.
# Kết quả sau sửa: nhưng mặt khác, trung quốc lại có những biện pháp tránh những phát sinh xung đột trực diện với mỹ, thực hiện chiến lược vừa bắn vừa ngừng, đánh nhưng không đổ bộ, đứt nhưng không chết và chỉ đánh tàu tưởng, không đánh tàu mỹ.
# Kết quả sau sửa: nội dung hàm số và đồ thị trong các chương lớp 7, lớp 9 ở chương trình thcs.
# Kết quả sau sửa: bài nghiên cứu cho thấy hoạt động lò than ở huyện châu thành, tỉnh hậu giang làm năng suất trái cây giảm khoảng 20 - 30 % nếu so với các vườn cây không có lò than lân cận.
# Kết quả sau sửa: thứ hai, khu vực châu á có dân số đông.
# Kết quả sau sửa: nhiệm vụ: tìm kiếm khách hàng, đàm phán và kí kết hợp đồng mang về lợi nhuận của công ty.
# Kết quả sau sửa: tuy nhiên bọn em không thể tránh khỏi những sai sót trong quá trình làm bài.
# Kết quả sau sửa: điều này khác với mạng nơ - ron truyền thống, trong đó trọng số không bị ràng buộc và các bộ tham số riêng biệt được học ở mỗi vị trí.
# Kết quả sau sửa: các yếu tố được khảo sát là những nội dung cần làm của cbql trong nhà trường thực hiện, các yếu tố nội dung phát triển chương trình giáo dục trong nhà trường.
# Kết quả sau sửa: khi lợi ích được bảo vệ, các bên liên quan sẽ có quyền được khiếu nại khi họ bị xâm phạm về quyền lợi của mình.
# Kết quả sau sửa: thực hiện nội quy văn hóa công ty.
# Kết quả sau sửa: đối với đánh giá trình độ, khi quy định tất cả máy móc phục vụ khách hàng đồng ý với mô hình nhóm tác giả đề xuất.
# Kết quả sau sửa: trong quá trình giảng dạy trên lớp, nghiên cứu thực trạng việc phát âm của học sinh, tôi nhận thấy: nhiều học sinh phát âm theo tiếng địa phương; do trong quá trình dạy học và giáo viên và học sinh giáo viên chưa chú trọng sửa chữa và uốn nắn kịp thời.
# Kết quả sau sửa: còn gì đau đớn hơn khi trong lòng chúng ta có thể kể đến khi ra được một khoản chi phí lao động, chất lượng sản phẩm như tên, rồi lướt qua nhau như những người dưng qua đường.
# Kết quả sau sửa: từ đó đề xây dựng khái niệm động lượng, giáo viên cho học sinh thực hiện phiếu học tập số 2.
# Kết quả sau sửa: ngành nghề dịch vụ bảo vệ và người bảo vệ luôn là những con người đáng được trân quý và tôn trọng.
# Kết quả sau sửa: máy phát điện được kết nối ats (automatic transfe switch) tự động truyền tải từ nguồn chính sang nguồn dự phòng khi nguồn chính bị sự cố, nhanh chóng khởi động cấp điện cho toàn bộ khách sạn mường thanh quảng ninh trong khoảng thời gian là 45 giây.
# Kết quả sau sửa: phần lớn các đối tượng học sinh còn tham gia đề án môn học cụ thể (xem xét, cán bộ y tế cũng như việt nam.
# Kết quả sau sửa: ngoài những kiến thức cơ bản trong sách giáo khoa, để làm phong phú và cập nhật hơn cho nội dung của bài học chúng tôi có tham khảo thêm một số tài liệu sau:
# Kết quả sau sửa: quan hệ giữa học máy liên hợp, chỉ cần xác định tài sản tặng cho học, do nhóm sinh viên sẽ có được những vấn đề được giới hạn. tòa án, căn cứ vào các dịch vụ khác.
# Kết quả sau sửa: vì vậy, tự học cũng cần được chú trọng để có thể theo kịp bài giảng trên lớp, đạt được điểm số cao.
# Kết quả sau sửa: mặt khác, các biện pháp được khảo sát ở mức độ rất cần thiết trung bình là 42.9 %, cao nhất là 31.0 % và đtb = 3.13, điều này chứng tỏ các biện pháp là rất cần thiết khi đạt ở mức khá cao.
# Kết quả sau sửa: nhắc đến bồi thường thiệt hại chúng ta sẽ nhận biết được ngay nó sẽ có trường hợp btth do vi phạm trong hợp đồng và ngoài hợp đồng.
# Kết quả sau sửa: tuy nhiên bài viết lại chưa phân tích các yếu tố ảnh hưởng tới ý định khởi nghiệp.
# Kết quả sau sửa: sự quan tâm của mỹ đối với đài loan từ năm 2003 đã giảm đi rõ rệt, một phần vì chương trình ly khai có vẻ mập mờ của tổng thống đài loan trần thủy biển.
# Kết quả sau sửa: như vậy, chứ không phải là người học tích lũy sẽ được áp dụng thử nghiệm vào thực tế.
# Kết quả sau sửa: cơ hội từ xu hướng chuyển đổi số trên phạm vi toàn cầu.
# Kết quả sau sửa: hiện nay có ảnh hưởng lớn đến chất lượng giảng dạy.
# Kết quả sau sửa: quảng cáo, tài chính nhiệm vụ bảo vệ môi trường của đội ngũ cán bộ quản lý các cấp, các ngành, doanh nghiệp và mọi người dân.
# Kết quả sau sửa: hằng năm, doanh nghiệp hoạch định và dự đoán nhu cầu thị trường, tình hình biến động giá cả để xác định nguồn nguyên liệu cần phải mua và đưa ra mức giá phù hợp với mục tiêu kinh doanh của doanh nghiệp.
# Kết quả sau sửa: tấn công chiếm quyền root (u 2 r) là dạng tấn công mà kẻ tấn công cố gắng truy cập vào máy tính nạn nhân như một người dùng bình thường bằng các kỹ thuật khác nhau như dò tìm mật khẩu, tấn công từ điển.
# Kết quả sau sửa: kết quả điều tra với câu hỏi 1 sau khi tốt nghiệp thcs, em lựa chọn hướng đi như sau:
# Kết quả sau sửa: hình 2.4 mô hình sự hài lòng trong giao dịch của parasuraman và cộng sự.
# Kết quả sau sửa: như đã liệt kê ở trên, nhà máy có nhiều hệ thống sử dụng điện như dây chuyền sản xuất gạch, hệ thống chiếu sáng, hệ thống máy nén khí, hệ thống quạt lò.
# Kết quả sau sửa: điều này cho thấy hà nội là thành phố có môi trường kinh doanh, chất lượng điều hành kinh tế tốt và thể hiện nỗ lực cải cách hành chính của chính quyền thành phố trong việc cải thiện môi trường kinh doanh.
# Kết quả sau sửa: số phần trăm giảm của buổi chiều là: 15 % + 5 % = 20).
# Kết quả sau sửa: reit được quản lý bởi công ty bất động sản.
# Kết quả sau sửa: tiếp đến người quản trị website thường xuyên cập nhật các tin tức về sản phẩm về phản hồi của khách hàng thường xuyên, nhanh chóng.
# Kết quả sau sửa: luận án ghi nhận được sự khác biệt có ý nghĩa thống kê giữa học sinh nam và học sinh nữ khi đánh giá về nhóm hành vi cha - mẹ hỗ trợ.
# Kết quả sau sửa: bởi vì, có hạnh phúc khi được sử dụng vẫn có thể đáp ứng được những yêu cầu của các nguyên tắc nói trên nhưng tính hiệu quả lại không cao.
# Kết quả sau sửa: đây còn gọi là kỹ năng tham gia vào giải quyết vấn đề.
# Kết quả sau sửa: broadman và recanatini (2001) sử dụng chiều dài đường có vỉa hè (paved road) tính theo diện tích của vùng.
# Kết quả sau sửa: tập luyện nề nếp, thói quen tốt trong sinh hoạt.
# Kết quả sau sửa: các tổ chức và công ty sử dụng cụm từ này có thể kể đến như: viện nghiên cứu rau quả.
# Kết quả sau sửa: theo cách tiếp cận của các tác giả đã đề cập đến vai trò của nét đẹp của điểm đến du lịch.
# Kết quả sau sửa: cục khí tượng thủy văn và biến đổi khí hậu (2015): sinh kế thích ứng với biến đổi khí hậu: tiêu chí đánh giá và cách điển hình.
# Kết quả sau sửa: tích cực trong việc đưa ra một vài trang mạng xã hội vừa là nơi giải trí, vừa là nơi trao đổi thông tin giữa các nền văn hóa văn hóa giữa các đơn vị xác định, giáo viên với giáo viên.
# Kết quả sau sửa: tính tới năm 2018 là 2019, với cư dân bản địa thì có một điểm rõ ràng mà tôi nhận thấy, đó là trong hai năm trở lại đây, hình ảnh đất nước mà còn được phân phối đa lượng khách hàng tốt hơn trong quá khứ, nhân tố con người việt nam.
# Kết quả sau sửa: nội dung giáo dục hướng nghiệp phải được xây dựng trên cơ sở phù hợp với tình hình thực tế của nhà trường và địa phương.
# Kết quả sau sửa: sau đó tiến hành loại bỏ.
# Kết quả sau sửa: các nghiên cứu về chất lượng các khoản tín dụng bên cạnh những điểm còn lại là những hình thức nhanh chóng hơn do họ cần phải làm việc cật lực và xác định mục tiêu của ứng viên.
# Kết quả sau sửa: chiến lược là suy nghĩ về một kịch bản và phương hướng cần phải có để phát triển trong tương lai. những suy nghĩ như ngay từ đầu đến làm thế nào thì tốt hay làm như thế nào thì sẽ sinh lời.
# Kết quả sau sửa: số lượng hàng năm được xác định theo công thức sau:
# Kết quả sau sửa: công tác ndt hay việc tổ chức phục vụ học liệu cho ndt là một hoạt động của thư viện nhằm thúc đẩy, phát triển và thỏa mãn nhu cầu, hứng thú đọc tài liệu thông qua việc tuyên truyền, hướng dẫn và cung cấp tài liệu dưới nhiều hình thức.
# Kết quả sau sửa: đây là một câu lệnh rất quan trọng của terraform commands vì nó sẽ cho ta biết được cụ thể những gì sẽ xảy ra nếu ta thực hiện áp dụng tệp cấu hình.
# Kết quả sau sửa: hình 2.17: đồ thị tỷ lệ thuận giữa áp suất và điện thế ra của cảm biến áp suất ống rail.
# Kết quả sau sửa: nếu sig < 0.05, ta kết luận mô hình hồi quy phù hợp với tập dữ liệu và có thể sử dụng đất.
# Kết quả sau sửa: thứ hai, cùng với sự phát triển của thực tiễn và của nhận thức, con người càng ngày càng có sự hiểu biết đầy đủ hơn, sâu sắc hơn, ham học hỏi và dần dần từ quy.
# Kết quả sau sửa: kinh nghiệm quản lý nhân sự trên địa bàn huyện mỹ hào tỉnh hưng yên.
# Kết quả sau sửa: trường mầm non huyện yên phong đã long trọng tổ chức lễ khai giảng năm học mới.
# Kết quả sau sửa: nhằm thỏa mãn nhu cầu tồn tại và phát triển của mỗi cá nhân, đáp ứng yêu cầu nhân lực của xã hội trong một giai đoạn lịch sử nhất định.
# Kết quả sau sửa: cái tên honda vision ngụ ý một dự định, hoài bão được hướng đến mọi mục tiêu cần được đặt ra và hoàn thành trong tương lai.
# Kết quả sau sửa: đây được xem là phép lịch sự tối thiểu khi tới hàn quốc.
# Kết quả sau sửa: cung cấp tín dụng hội sở cho thế hệ, mối quan tâm trí người lái. để giáo viên sử dụng trong quá trình giảng dạy.
# Kết quả sau sửa: chính sách động viên, hầu hết cán bộ dân tộc thiểu số về công tác tại các địa phương, cơ sở chưa thỏa đáng.
# Kết quả sau sửa: kết nối được tạo bằng cách mở kết nối tcp đến máy chủ đích.
# Kết quả sau sửa: mở đầu: giới thiệu, đặt vấn đề và khái quát chung về nội dung bài toán.
# Kết quả sau sửa: sau khi tiến hành nghiên cứu định lượng với mẫu là 199 và thực hiện xử lý và phân tích dữ liệu bằng phần mềm spss, kết quả nghiên cứu cho thấy sự chấp nhận thông tin ewom tác động tích cực đến quyết định mua mỹ phẩm của người tiêu dùng.
# Kết quả sau sửa: theo các nghiên cứu tôi đã thực thi nhanh do mỏi tên thể hiện cho đến hết năm 2050.
# Kết quả sau sửa: hầu hết các công nghệ cao được dự đoán sẽ có lợi cho mọi người dân, kể cả người nghèo bởi lẽ khi sản lượng nông nghiệp tăng thì thu nhập của người nông dân cũng gia tăng.
# Kết quả sau sửa: acfta hiệp định thương mại tự do asean - trung quốc.
# Kết quả sau sửa: khi truy cập vào hệ thống, giao diện đầu tiên màn hình hiển thị các bài viết và thông báo.
# Kết quả sau sửa: thứ hai, khi đất nông nghiệp bị thu hồi, người dân trước mắt là thiệt hại về đất đai và bên cạnh đó có nhiều thiệt hại về các hoa lợi, tài sản, lợi tức thu được do việc sử dụng đất.
# Kết quả sau sửa: phương pháp này rất quan trọng vì khi làm bài tập nhiều, vận dụng các kiến thức đã học mới giúp các em hiểu bài sâu hơn và giúp các em tích lũy được kiến thức cũng như chính phủ trung quốc không ổn định và thực hành cho nhau như:
# Kết quả sau sửa: hoạt động học tập và các hoạt động khác của các học sinh trong các cơ sở đòi hỏi và thúc đẩy các em có thái độ tích cực và độc lập hơn, tạo điều kiện cho các em thỏa mãn nhu cầu giao tiếp của mình.
# Kết quả sau sửa: phân quyền hợp lý tránh tình trạng lạm dụng quyền lực trong đơn vị.
# Kết quả sau sửa: mô tả các bộ phận trong hệ thống.
# Kết quả sau sửa: số liệu thu thập dựa trên báo cáo tăng giảm nguồn vốn do công ty con lập, báo cáo tài chính riêng của các công ty con, sổ chi tiết theo dõi tài khoản đầu tư vào công ty con.
# Kết quả sau sửa: áp suất ống rail giảm khi tốc độ động cơ lên cao.
# Kết quả sau sửa: xây dựng kế hoạch sửa chữa, mua sắm, quản lí các thiết bị đáp ứng mọi hoạt động trong công tác giảng dạy của giáo viên và học tập của học sinh.
# Kết quả sau sửa: đối với những hoạt động sau giúp học sinh, thư viện và thang đo.
# Kết quả sau sửa: lượng khách hàng cảm thấy ưng ý nhất là tại hội chợ triển lãm và qua bán hàng cá nhân, đây là 2 công cụ thu về con số tốt nhất lên tới 91 % khách hàng thấy rất nổi bật và hài lòng với 2 hoạt động truyền thông này.
# Kết quả sau sửa: chính vì lẽ đó phải phát huy đầy đủ dân chủ, xây dựng quan hệ thật tốt, đoàn kết thật chặt chẽ giữa các lực lượng giáo dục: người thầy và người thầy, thầy và trò, trò và trò. . .
# Kết quả sau sửa: nêu rõ hiệp định thương mại tự do việt nam - eu evfta và thực trạng xuất khẩu nông sản của việt nam sang eu.
# Kết quả sau sửa: cuối cùng, em xin kính chúc các thầy giáo, cô giáo trường đại học thủ đô hà nội và đặc biệt là các thầy cô giáo chuyên ngành liên quan đến hàng chục, hàng hóa mà không cần đến sự hài lòng với các vùng.
# Kết quả sau sửa: để xây dựng được một ứng dụng hỗ trợ cho shopify cần sử dụng nhiều công nghệ.
# Kết quả sau sửa: nguyên nhân là do rủi ro trong cho vay mua nhà lớn, các khoản cho vay mua nhà ít có tính nhạy cảm với lãi suất.
# Kết quả sau sửa: các công cụ lập kế hoạch quảng cáo qua facebook chỉ ra rằng người dùng đã nhấn vào nhiều quảng cáo trên nền tảng trong quý i năm 2020 so với cuối năm 2019, cả tương đối và tuyệt đối.
# Kết quả sau sửa: đề tài, tôi luôn có các đặc trưng khi chia đều ấn tượng cho kỷ nâng quảng lý – sản xuất – chế biến – tiêu thụ sản phẩm các đối tượng bao gồm: hộ nông dân, htx, doanh nghiệp sản xuất kinh doanh sản phẩm chè.
# Kết quả sau sửa: góp thêm vào vấn đề công nghiệp hóa, hiện đại hóa ở việt nam hiện nay.
# Kết quả sau sửa: nội dung gồm: mục đích, yêu cầu, phạm vi đối tượng, phương pháp tiến hành thanh tra, tiến độ thực hiện ….
# Kết quả sau sửa: thứ ba, mối quan hệ hợp tác trong quản lý điều hành giữa các ngành, các cấp, đơn vị, cơ quan.
# Kết quả sau sửa: chưa có nghiên cứu nào trước đây thực hiện khảo sát số liệu và nghiên cứu sâu về hành vi của du khách tại điểm đến hòa bình – nơi mang đậm đà bản sắc dân tộc và có tiềm năng phát triển du lịch.
# Kết quả sau sửa: chia sẻ ý tưởng mới với các thành viên trong nhóm.
# Kết quả sau sửa: hình 2.6. doanh thu và số cửa hàng của bách hóa xanh (08 - 2019.06 - 2020).
# Kết quả sau sửa: bò được đeo thẻ và gắn chíp điện tử ở chân để theo dõi tình trạng sức khỏe, chế độ dinh dưỡng và sản lượng sữa.
# Kết quả sau sửa: những chủ trương cục bộ đầu tiên ở các địa phương, những chuyển biến mau lẹ của tình hình nhất là khí thế đấu tranh cách mạng của quần chúng.
# Kết quả sau sửa: trung quốc, sự hình thành các lớp có 12,2 % số dòng thuế thuộc danh mục loại trừ (không tham gia giảm, xóa bỏ thuế), 4,08 % số dòng thuế được giữ nguyên thuế suất cơ sở và 3,37 % số dòng thuế được giảm thuế một phần.
# Kết quả sau sửa: từ đó ta đi xét 2 trường hợp sau:
# Kết quả sau sửa: thứ hai: là học sinh vùng nông thôn nên không phải gia đình nào cũng trang bị cho con em mình những điều kiện cơ sở vật chất giúp các em học tập như: máy tính, laptop, mạng internet và các loại sách tham khảo hữu ích.
# Kết quả sau sửa: hồ chí minh cho rằng một trong những điều kiện để thực hiện một cách tích cực xã hội chính là khách hàng có hiệu quả các chính sách kinh tế.
# Kết quả sau sửa: mặt khác, tác giả luận giải tác động của kinh tế nhà nước đối với thực hiện xóa đói, nghèo tại nông thôn đồng bằng bắc bộ.
# Kết quả sau sửa: cùng với sự bùng nổ của nền kinh tế toàn cầu thì xu hướng vươn ra thị trường quốc tế và một xu hướng chung của tất cả các quốc gia là các doanh nghiệp.
# Kết quả sau sửa: ngành nghề kinh doanh: bảo hiểm phi nhân thọ, tái bảo hiểm, đầu tư vốn.
# Kết quả sau sửa: tuy nhiên vẫn còn một số ít cho rằng xây dựng văn hóa tổ chức nhà trường chỉ là trách nhiệm của mỗi cán bộ quản lý nhà trường, các tổ chức đoàn thể như công đoàn, đoàn thanh niên ….
# Kết quả sau sửa: kết quả, tháng 10 / 1971, đại hội đồng liên hợp quốc khóa 26 đã thông qua nghị quyết số 2758, ta có thể phát triển của hàn quốc, khôi phục lại vị trí và tất cả các quyền lợi hợp pháp của chính phủ nước cộng hòa nhân dân trung hoa ở liên hợp quốc.
# Kết quả sau sửa: đa dạng hóa cơ cấu ngành nghề đáp ứng nhu cầu kinh tế trung ương và địa phương trong hợp tác quốc tế với xu thế toàn cầu hóa.
# Kết quả sau sửa: với việc donor và acceptor được xếp xen kẽ nhau và khoảng cách giữa các vật liệu là 2 %, tăng diện tích tiếp xúc giữa hai vật liệu tạo điều kiện cho các nhân tố là lí tưởng dự án lớn.
# Kết quả sau sửa: đường nét liền khi có bộ điều hòa đã bám sát hơn so với ở điều kiện lí tưởng, do đó chất lượng phanh đã được cải thiện.
# Kết quả sau sửa: phương án sử dụng vốn (phụ lục 2).
# Kết quả sau sửa: khi lý luận nhiều, bạn đồng tu nhắc nhở lại tỏ thái độ không vừa lòng.
# Kết quả sau sửa: thái độ say sưa, hứng thú học tập, lĩnh hội, phát triển trí tuệ, việc hình thành và phát triển cách lập luận độc đáo cùng những nét tính cách quý báu của các em đều do ảnh hưởng của cách dạy và nhân cách con người khác.
# Kết quả sau sửa: rõ ràng, đảng thực thi (bao biện làm thay) quyền lực nhà nước nhưng bộ phận này nằm ngoài nhà nước nên quyền lực đó không được kiểm soát.
# Kết quả sau sửa: một số khoản nợ xấu của cn phát sinh do doanh nghiệp bị đẩy nhóm nợ từ ngân hàng khác, dẫn đến cn cũng bị đẩy nhóm nợ và phải được đảm tập tự chủ,
# Kết quả sau sửa: trong bối cảnh hội nhập kinh tế quốc tế và cạnh tranh ngày càng gay gắt diễn ra như hiện nay, tác giả nhấn mạnh tính phong phú và đồng bộ sẽ giúp các dn nâng cao năng lực cạnh tranh của sản phẩm gỗ việt nam xuất khẩu sang thị trường nhật bản.
# Kết quả sau sửa: tại các khu vực này, điều kiện để tiếp cận, học tập còn nhiều khó khăn.
# Kết quả sau sửa: chất lượng sản phẩm phải đảm bảo thì mới đạt được lòng tin, sự trung thành của khách hàng.
# Kết quả sau sửa: những ứng dụng thực tế của chương các định luật bảo toàn đã mang lại sự hứng khởi cho học sinh.
# Kết quả sau sửa: công ty nên có nhiều buổi bảo trì trang thiết bị, phương tiện dạy học phần đề đảm bảo năng suất làm việc hiệu quả.
# Kết quả sau sửa: hai tín hiệu hoặc các văn hóa vì nó giống như khi chúng ta bán lẻ truyền thống, nếu ông chủ hiểu và biết được thị hiếu của khách hàng mình ông sẽ cho bạn biết sắp đến sẽ có món hàng gì thú vị mà ông tin là bạn chắc hẳn sẽ cần đến nó.
# Kết quả sau sửa: khóa luận tìm hiểu về quá trình phân lớp văn bản bao gồm: thu thập và dán nhãn dữ liệu, tìm hiểu về các phương pháp phân loại, phương pháp biểu diễn văn bản và các kỹ thuật liên quan đến các thành phần tham gia thảo luận.
# Kết quả sau sửa: đặc biệt, mỗi bài giảng đều được tích hợp dưới nhiều hình thức thể hiện khác nhau: video, clip, hiệu ứng âm thanh, hình ảnh minh họa sinh động nhưng vẫn đảm bảo sự tương tác với giáo viên.
# Kết quả sau sửa: tuy nhiên hầu hết nền công nghiệp vẫn thuộc sở hữu nhà nước.
# Kết quả sau sửa: những xung đột văn hóa diễn ra phức tạp quanh co trong đời sống cộng đồng, đòi hỏi chủ thể văn hóa phải có sự thay đổi về nhận thức để tìm ra tiếng nói chung.
# Kết quả sau sửa: với câu slogan vô cùng ấn tượng tinh túy thiên nhiên giữ nguyên trong từng giọt sữa sạch cùng với quy trình chăn nuôi, chăm sóc từng con bò đặc biệt nổi bật đã tạo nên sự khác biệt.
# Kết quả sau sửa: bên cạnh đó chúng em cũng mong muốn được góp ý chân thật nhất để rút kinh nghiệm làm hành trang cho công việc tương lai sau này.
# Kết quả sau sửa: bên cạnh đó, giáo dục cũng có nhiều cải cách, đổi mới để nhằm đào tạo được nguồn nhân lực chất lượng cao.
# Kết quả sau sửa: sự khác biệt về thời gian tham gia giữa các lần tổ chức khác nhau.
# Kết quả sau sửa: đặc điểm của thế năng trọng trường là:
# Kết quả sau sửa: một nguyên tử carbon ở trạng thái thông thường có 2 điện tử lớp ngoài cùng để liên kết cộng hóa trị với hai nguyên tử khác.
# Kết quả sau sửa: lý luận và mô hình hóa hạ tầng bằng mã và sau đó sẽ có khả năng thiết kế, triển khai cơ sở hạ tầng ứng dụng đã thúc đẩy và thu hút rất nhiều nhà phát triển phần mềm và các nhà quản trị công nghệ tiên tiến.
# Kết quả sau sửa: sử dụng công nghệ đóng gói bao bì hiện đại, sữa được rót ở điều kiện vô trùng trong bao bì đặc biệt về tâm lý kho và gây tàn phá án toàn giữ vẹn nguyên giá trị dinh dưỡng, hương vị thơm ngon tự nhiên.
# Kết quả sau sửa: tuy đã vận hành nhưng còn đơn lẻ, chưa cụ thể là chưa đủ mức giải quyết vấn đề thực tiễn về nhu cầu nguồn lực tài chính cho ứng phó với biến đổi khí hậu.
# Kết quả sau sửa: phương pháp đối chiếu, so sánh: một thao tác nghiên cứu được dùng trong nhiều ngành khoa học khác nhau.
# Kết quả sau sửa: rất dễ hiểu nhầm về chức năng và vai trò của hai cơ quan này là một ở trường tiền tệ không phải như vậy.
# Kết quả sau sửa: các loại hình bảo hiểm này không liên quan đến những rủi ro gây tổn thất đến sức khỏe và tuổi thọ con người và hoàn toàn mang tính tự nguyện tham gia, vì vậy được gọi là bảo hiểm phi nhân thọ tự nguyện.
# Kết quả sau sửa: gần đây nhất cái chết của đôi nam nữ tại chung cư cao cấp nằm trên địa bàn quận nam từ liêm đã gây xôn xao cộng đồng người hàn quốc ở hà nội.
# Kết quả sau sửa: sử dụng các phần mềm vẽ đồ thị để tìm ra kết quả của bài toán, đây là hoạt động nhằm tăng cường sử dụng công nghệ thông tin vào giảng dạy.
# Kết quả sau sửa: thiệt hại xảy ra và thang đo, là điều kiện tiên quyết của trách nhiệm bồi thường thiệt hại bởi mục đích của loại trách nhiệm này là nhằm khắc phục thiệt hại do hành vi trái pháp luật gây ra, khôi phục lại tình trạng ban đầu cho chủ thể bị vi phạm.
# Kết quả sau sửa: việc phân tích, đánh giá thực trạng cũng như nhận diện những vấn đề đang đặt ra giúp chúng ta có thể hoàn thành khóa học về những điểm mạnh và điểm yếu trong công tác xây dựng đội ngũ này.
# Kết quả sau sửa: nghị quyết nêu thêm, để đổi mới và nâng cao chất lượng giáo dục cần đổi mới cả về phương pháp.
# Kết quả sau sửa: tóm lại, không tìm được m để thỏa mãn điều kiện của bài toán trên.
# Kết quả sau sửa: yêu cầu và cách thực hiện nguyên tắc phòng chống cúm hiệu quả.
# Kết quả sau sửa: kỳ vọng tỷ lệ đóng góp của knn mang dấu dương (𝛼 > 0).
# Kết quả sau sửa: chẳng hạn nếu cường độ chịu nén của bê tông asphalt ở 20 độ là 2,2 mpa thì ở nhiệt độ 50 độ chỉ còn 0,8 mpa.
# Kết quả sau sửa: đây là một khó khăn và thiệt thòi rất lớn không chỉ đối với bản thân nạn nhân mà còn cho cả những người đang được nạn nhân cấp dưỡng.
# Kết quả sau sửa: có những lỗ trợ các cấu trúc dữ liệu như đối tượng và mảng.
# Kết quả sau sửa: ví dụ trên làm sáng tỏ thêm rằng các chức năng của mọi bài tập toán phụ thuộc vào nội dung cũng như phương pháp khai thác hóa lời hứa.
# Kết quả sau sửa: mối liên kết giữa các nơron được gắn với một trọng số, các trọng số này được thêm vào trong quá trình mỗi khi tín hiệu đi qua liên kết đó.
# Kết quả sau sửa: mặc dù có nhiều cố gắng, tuy nhiên luận văn chắc chắn không thể tránh khỏi những thiếu sót.
# Kết quả sau sửa: thỏa mãn tối đa nhu cầu ngày càng cao của khách hàng: khi nền kinh tế này có thể nói, tuy chỉ là một trong các nghiên cứu dựa vào các chức năng cấp. như nhu cầu học sẻ tạo nên đa dạng phong phú hơn.
# Kết quả sau sửa: học sinh cần nắm được các khái niệm cơ bản về đường tròn định hướng, đường tròn lượng giác, cung và góc lượng giác.
# Kết quả sau sửa: khi hoàn thành đáp ứng 50 % nhu cầu sản phẩm sữa của thị trường trung quốc, từ những nhà cung cấp sữa sạch và sữa tươi tiệt trùng hàng đầu việt nam.
# Kết quả sau sửa: việc sử dụng báo chí để truyền thông thương hiệu còn rất ham chơi, đa phần các bài viết về hanosimex đều nằm tại các trang đặc thù trong ngành dệt may, ít người biết đến.
# Kết quả sau sửa: sau khi nghiên cứu chương trình các môn học, chúng tôi thiết kế và xây dựng các chủ đề phù hợp với nội dung kiến thức, cũng như nhiệm vụ thực hiện đảm bảo các hoạt động dạy học theo định hướng stem.
# Kết quả sau sửa: trong giai đoạn mới trí thức sẽ không mất đi sự khác biệt về vị trí trong quá trình xây dựng đạo đức xã hội, về vai trò trong tổ chức lao động xã hội, về bản chất và nội dung trong hoạt động lao động trí óc.
# Kết quả sau sửa: hòa giải trong thủ tục tố tụng: là việc hòa giải được tiến hành tại tòa án, trọng tài khi các cơ quan này tiến hành giải quyết tranh chấp theo đơn kiện của một bên (hòa giải dưới sự trợ giúp của tòa án hay trọng tài).
# Kết quả sau sửa: về mặt kinh tế, toàn bộ thông tin về các yếu kém, chính phủ vẫn chưa có nhiều chính sách hỗ trợ để cải thiện tình trạng này.
# Kết quả sau sửa: sự phân hủy bởi nhiệt và sự đông tụ của protein.
# Kết quả sau sửa: đào tạo, giao lưu, : với mục đích truyền đạt lại thông tin người khác đã viết và để kiểm tra khả năng phát âm, ngữ âm, ngữ điệu của học sinh thì giáo viên tổ chức cho học sinh đọc to bài đọc trước lớp.
# Kết quả sau sửa: là người học cũng cần đưa ra lời giải.
# Kết quả sau sửa: xác định nội dung của hoạt động trải nghiệm là yêu cầu bắt buộc đối với mỗi giáo viên.
# Kết quả sau sửa: đại diện bộ phận nhân sự là:
# Kết quả sau sửa: do chi nhánh hiệp hòa đạt được đà tăng trưởng mạnh mẽ và đột biến như vậy do họ đã được lãnh đạo và chỉ đạo đúng đắn bởi giám đốc chi nhánh mới lên nhận chức nguyễn phạm hùng.
# Kết quả sau sửa: nhưng nó cũng là một lợi thế của shopify, tính đến ngày 20/11/2020 shopify đã hỗ trợ đến 20 ngôn ngữ trên thế giới cho các sản phẩm của mình.
# Kết quả sau sửa: khả năng lưu dữ van bảng: cho dù trải qua năm tháng dài với sự bùng nổ của môi trường, lịch sử thì báo in vẫn giữ nguyên được giá trị thời đại mà tờ báo và các giấy tờ báo đó chính là nhân chứng.
# Kết quả sau sửa: trong thực tế tại môi trường môi trường đầu tư, ngày càng phù hợp với yêu cầu và đòi hỏi của kinh tế thị trường, mở rộng nhiều lĩnh vực đầu tư, đẩy nhanh sự phát triển của ngành nghề thứ ba và mở rộng thị trường nội địa, tăng trưởng fdi với tốc độ cao.
# Kết quả sau sửa: bên cạnh tính khách quan và tính phổ biến trong mối quan hệ phổ biến thì chúng còn có tính đa dạng, phong phú.
# Kết quả sau sửa: trong đó, thuế thu nhập được tính toán dựa trên đặc điểm cơ bản thu nhập của vợ chồng hơn là thu nhập của cá nhân, người có thu nhập thứ hai có thể bị đánh thuế ở tỷ lệ biên cao tương đối.
# Kết quả sau sửa: am hiểu phong tục tập quán, biết tiếng dân tộc, gần gũi dễ tạo sự đồng thuận của đồng bào dân tộc thiểu số.
# Kết quả sau sửa: ở đây các quan niệm về hạnh phúc, lương tâm, danh dự, thiện ác, công bằng là không có sự đối lập giữa pháp luật và đạo đức.
# Kết quả sau sửa: thêm vào đó, mạng xã hội trong đảng và đã trở thành một đối thủ đáng gờm đối với báo in khi tốc độ lan tỏa của nó là rất lớn.
# Kết quả sau sửa: từ khi giao hàng, đa dạng hóa sản phẩm vào thiết bị một số món quà tặng các chú bộ đội hải quân.
# Kết quả sau sửa: người khmer thì lại khác, nguồn tài chính của gia đình lại tập trung cho việc xây dựng, tu sửa những ngôi chùa nhiều hơn, hoặc ưu tiên tổ chức các lễ hội truyền thống nên nguồn tài chính đầu tư cho học tập của con em bị hạn chế.
# Kết quả sau sửa: hàm lượng chất rắn hòa tan trong nước thấp làm hạn chế sự sinh trưởng hoặc ngăn cản sự sống của thủy sinh.
# Kết quả sau sửa: sự thay đổi tốc độ động cơ quyết định lượng nhiên liệu cấp vào nhiều hay ít, điều đó giúp cho động cơ ổn định không tải.
# Kết quả sau sửa: sau 12 năm hoạt động, đơn vị nay đã cán mốc 3,3 triệu người dùng, hơn 10.000 lượt truy cập và học tập đồng thời và hơn 200.000 lượt truy cập mỗi ngày.
# ...
# Kết quả sau sửa: trên thực tế trong quá trình thực hiện dự án mỗi dự án đều có trình tự cả giai đoạn.
# Kết quả sau sửa: nguyên nhân làm các sản phẩm cho tiêu dùng cũng như không đảm bảo tính hợp lý của khách hàng công nghiệp có số lượng ít nhưng quy mô lớn và tập trung về mặt địa lý.
# Kết quả sau sửa: qua đó có thể đồng nhất giữa các quyết định bản án, giảm thiểu sự mâu thuẫn trong công tác xét xử đối với các vụ án có tình tiết tương tự nhau.
# Kết quả sau sửa: cơ chế, chỉ định thầu đang được phát huy được vốn tư nhân ứng phó: vay vốn ngân hàng và thu hút đầu tư trực tiếp nước ngoài.
# Kết quả sau sửa: vì thế, trong lĩnh vực này luôn đòi hỏi khắt khe và chi tiết về kỹ năng người lao động nhằm tối thiểu những vấn đề sai sót xảy ra.
# Kết quả sau sửa: nghiên cứu khoa học và các loại nhiên liệu được tạo thành bởi quá trình phân hủy của các xác sinh vật bị chôn vùi dưới lớp đất đá trong điều kiện thiếu oxi hàng triệu năm.
# Kết quả sau sửa: sau đó dừng cấp không khí và bơm khí n 2 (áp suất 3 lít / phút) mục đích tạo môi trường khí trơ trong lò, sau 3 phút. mẫu được nâng từ đáy lò phản ứng đến vị trí mong muốn và duy trì trong điều kiện n 2 trong 15 phút (tốc độ chảy 3 lít / phút).
# Kết quả sau sửa: bộ giáo dục và đào tạo (2018), dự thảo chương trình các môn học.
# Kết quả sau sửa: tỉnh ủy bắc ninh ban hành nghị quyết số 16 / nq - từ năm 30 đến 10 năm 2009, về phát triển ngành nghề phi nông nghiệp nông thôn tỉnh bắc ninh gắn với xây dựng nông thôn mới theo hướng công nghiệp hóa, hiện đại hóa đến năm 2015, tầm nhìn đến năm 2020.
# Kết quả sau sửa: việc có được sự tôn trọng, lắng nghe, đồng cảm, chia sẻ và yêu mến của bạn bè là điều có ý nghĩa rất lớn đối với lòng tự trọng của thiếu niên.
# Kết quả sau sửa: kỹ năng chuyển từ tư duy thuận sang tư duy nghịch, kĩ năng biến đổi xuôi chiều và ngược chiều là một điều kiện quan trọng để học sinh nắm vững và vận dụng kiến thức, đồng thời nó cũng là một thành phần tư duy quan trọng trong toán học.
# Kết quả sau sửa: do vậy, bài toán cùng nghĩa với đề toán, vấn đề, nhiệm vụ, . . .
# Kết quả sau sửa: những vấn đề lý luận vào thực tiễn pháp lý về chia tài sản chung của vợ chồng khi ly hôn trên địa bàn quận sơn trà.
# Kết quả sau sửa: nhnn việt nam về hướng dẫn dịch vụ thanh toán không dùng tiền mặt.
# Kết quả sau sửa: nếu tình tiết tương đối nhẹ sẽ do đơn vị sở tại hoặc cơ quan chủ quản cấp trên xem xét tình hình xử phạt hành chính.
# Kết quả sau sửa: sự cạnh tranh khốc liệt và mạnh mẽ của các hãng lớn, bởi vì gia nhập sau nên càng bất lợi.
# Kết quả sau sửa: việc làm một trung quốc đều tốt các chiến lược marketing đóng vai trò cực kỳ quan trọng đến doanh số của doanh nghiệp.
# Kết quả sau sửa: hãng đã nỗ lực không ngừng trong việc mua bán, xây dựng hình ảnh, ý tưởng cho các slogan hay, thiết kế logo và quan trọng hơn là quan tâm đến việc thực hiện công tác quản lý môi trường cũng như tiết kiệm năng lượng.
# Kết quả sau sửa: trong phạm vi, nội dung luận án chỉ đề cập đến ba nhân tố, ba tổ chức có tên là: đảng chính trị, nhà nước và tổ chức chính trị - xã hội, mà không trình bày các nhân tố như: truyền thông đại chúng, thể chế tôn giáo, công nghệ bầu cử, v. v. .
# Kết quả sau sửa: xây dựng nội dung rèn luyện khả năng tác chiến của hệ thống chỉ huy, điều khiển, trinh sát và thông tin liên lạc của quân nhà.
# Kết quả sau sửa: giám đốc điều hành cần thực hiện tốt những quan hệ cơ bản giữa bản thân, hội đồng quản trị và nhân viên, là cầu nối đảm bảo rằng hđqt và nhân sự trong công ty có thể nắm bắt được các thông tin liên quan kịp thời, có giá trị, chính xác và thích hợp.
# Kết quả sau sửa: luận văn đã trình bày những khái niệm và tính chất cơ bản của vấn đề tư duy sáng tạo, cũng như những thành phần, vai trò của tư duy sáng tạo áp dụng vào thực tiễn giảng dạy bộ môn.
# Kết quả sau sửa: trang trí hình ảnh ngộ nghĩnh dễ thương sẽ là điểm gây ấn tượng cho trẻ.
# Kết quả sau sửa: sự phát triển nhanh chóng, mạnh mẽ của lực lượng sản xuất hiện đại đang có xu hướng biến cả thế giới thành một tổ hợp sản xuất và cùng chia sẻ chuỗi giá trị toàn cầu.
# Kết quả sau sửa: tùy theo đối tác và hoàn cảnh đàm phán mà áp dụng kiểu đàm phán.
# Kết quả sau sửa: và làm thêm các chỉnh sửa cốp pha cẩm.
# Kết quả sau sửa: và đến cuối thế kỷ xvii thì nội dung của các tờ báo in đã thay đổi rất nhiều về mặt nội dung.
# Kết quả sau sửa: chính quyền tỉnh bắc ninh đã ban hành nhiều nghị quyết, quyết định và hướng dẫn về thực hiện các chính sách huy động vốn để phát triển cơ sở hạ tầng.
# Kết quả sau sửa: có thể dẫn đến tình hình bất ổn định nhiệt độ cao và tính đa quá trình lựa chọn những sản phẩm đúng chất lượng lại kém.
# Kết quả sau sửa: về giá: mặc dù giá là yếu tố không ảnh hưởng nhiều đến quyết định mua rau quả của người tiêu dùng, tuy nhiên theo đánh giá của người trả lời thì siêu thị là nơi có giá trị cao hơn các chợ.
# Kết quả sau sửa: lưu ý khi thực hiện tiến trình dạy học: - giáo viên luôn giữ vai trò định hướng cho học sinh trong các công việc: phân loại dạng toán, phát biểu bài toán, xây dựng công thức giải tổng quát; không làm thay; không dùng phương pháp thuyết trình là chủ yếu.
# Kết quả sau sửa: lượng dầu tiêu thụ tăng đột biến ở tháng 3 và tháng 7 cho máy phát điện để đáp ứng nhu cầu hoạt động của hệ thống điều hòa không khí.
# Kết quả sau sửa: đặc biệt là giáo dục hướng nghiệp đã được chính quyền đương thời quan tâm và có chính sách phát triển lâu dài.
# Kết quả sau sửa: phương thức thanh toán bao gồm thông tin tài khoản ngân hàng hoặc ví điện tử của chủ nhà bao gồm tên chủ sở hữu và số tài khoản.
# Kết quả sau sửa: chuyển nhượng vốn trong công ty tnhh, luận văn thạc sỹ luật học, trường đại học luật thành phố hồ chí minh.
# Kết quả sau sửa: sau khi cài đặt sản phẩm cũng như các hàng / ô xong, khi người quản lý chọn icon cửa hàng ở màn hình khởi động của ủy ban hành, thì ứng dụng sẽ chuyển đến màn hình chính của máy.
# Kết quả sau sửa: trang bị cho thế hệ tương lai một ngoại ngữ mà sẽ giúp họ tiếp cận các tiến bộ và phát triển mới trong khoa học và công nghệ để đáp ứng những thách thức của toàn cầu hóa.
# Kết quả sau sửa: đối với các ứng dụng bao gồm cả publisher và consumer thì có thể tách biệt kết nối của hai thành phần này, vì rabbitmq có thể gây áp lực ngược lên kết nối tcp khi các publisher gửi quá nhiều message để xử lý.
# Kết quả sau sửa: ở nước ta cũng có nhiều công trình nghiên cứu về lí luận và thực tiễn về dạy học nhằm phát triển, rèn luyện năng lực tư duy logic cho học sinh.
# Kết quả sau sửa: hệ thống chính trị cơ sở ở nhiều nơi còn yếu; chất lượng đội ngũ cán bộ, công chức xã còn thấp.
# Kết quả sau sửa: để thu hút khách quay trở lại các địa điểm tham quan phải gia tăng các hoạt động vui chơi để du khách tham gia, đa dạng hàng lưu niệm / sản vật địa phương.
# Kết quả sau sửa: ở giai đoạn 2010 - 2019, knxk sang hoa kỳ và eu là tăng trưởng mạnh nhất, mỗi khu vực đều tăng xấp xỉ 4,5 tỉ usd.
# Kết quả sau sửa: cộng hòa nhân dân trung hoa có nền kinh tế lớn nhất châu á và lớn thứ hai thế giới, sau đó là nhật bản và ấn độ đứng thứ ba và thứ tám trên thế giới.
# Kết quả sau sửa: lưu ý: không được đạo văn (toàn phần hoặc một phần).
# Kết quả sau sửa: phải phù hợp với điều kiện tài chính vào kết quả hoạt động kinh doanh của văn phòng.
# Kết quả sau sửa: trong đó có 39 cửa hàng phân phối và bán lẻ các thiết bị công nghệ tiên tiến, tiến hành dự án.
# Kết quả sau sửa: một số giải pháp hoàn thiện kênh phân phối sản phẩm của công ty cổ phần đầu tư phát triển vicenza.
# Kết quả sau sửa: trong hệ số (nguyên, tối giản) tất cả các chất trong phương trình hóa học của phản ứng trên là:
# Kết quả sau sửa: áp suất dầu được tạo ra từ bơm dầu mà bơm dầu lại được dẫn động từ trục khuỷu của động cơ và bơm luôn luôn hoạt động trong suốt quá trình xe chạy vì vậy làm tốn công suất của động cơ thường xuyên.
# Kết quả sau sửa: công ty cũng thường xuyên cập nhật lại ảnh bìa với các chương trình ưu đãi, kttn đã nâng lên tra của công ty.
# Kết quả sau sửa: trên đèn pha có thiết kế vít để điều chỉnh hoạt động của đèn pha đối với phương thẳng đứng là điều kiện về đặc tính của phần tử quang học và đối với phương ngang là để điều chỉnh sự đúng hướng của chùm ánh sáng.
# Kết quả sau sửa: trẻ em là giai đoạn học, tính thuế, đang vui chơi giải trí của bản đồ thế giới hai cực, do đó cần giáo dục kỹ năng sống cho trẻ để trẻ nhận thức đúng và có hành vi ứng xử phù hợp ngay từ khi còn nhỏ.
# Kết quả sau sửa: vì thế công tác nào thì cũng có mong muốn sự hài lòng trong công việc là rất cần thiết, do đó không tồn tại sự khác biệt về vị trí nghề nghiệp đối với sự hài lòng trong công việc của nhân viên tại trung tâm y tế huyện giồng riềng, tỉnh kiên giang.
# Kết quả sau sửa: năm 20,5 % thị phần sản phẩm quốc dân thực hiện cam kết với người dân đài loan về chủ trương bốn không một chưa và đề cao vấn đề quan hệ hai bờ: nhân dân hai bờ eo biển vốn cùng chung huyết thống, văn hóa và bối cảnh lịch sử.
# Kết quả sau sửa: dù không phải làm một lý thuyết, nhưng cách tiếp cận thể chế có thể đưa ra những giải thích quan trọng cho chi phí giao dịch (meyer, 2001).
# Kết quả sau sửa: kia sorento là dòng xe của hãng kia của quốc gia hàn quốc.
# Kết quả sau sửa: cơ sở hạ tầng cho đmt, hoặc được lắp đặt ở vùng sâu vùng xa ở các nước đang phát triển, hay được tích hợp vào điện lưới để cung cấp cho thành thị ở các nước phát triển, cần được phổ biến và được chấp nhận rộng rãi hơn.
# Kết quả sau sửa: vì vậy, kết quả nghiên cứu của đề tài hỗ trợ hiệu quả cho công tác giảng dạy và nghiên cứu.
# Kết quả sau sửa: sản phẩm tồn tại dưới hai dạng chủ yếu là sản phẩm vật chất và sản phẩm phi vật chất nhằm thỏa mãn nhu cầu của khách hàng trong một thời điểm nhất định.
# Kết quả sau sửa: phương pháp cân đong vật liệu theo thể tích được xác định theo khối vật liệu cung cấp qua thiết bị qua một đơn vị tham gia.
# Kết quả sau sửa: mọi hoạt động trong xã hội hiện đại đều phải dựa trên thông tin.
# Kết quả sau sửa: nhân viên hùng hậu. đỡ đập tấn công, chắn, đỡ bóng và đưa qua tấn công).
# Kết quả sau sửa: quản lý ngân sách đòi hỏi phải công khai, minh bạch xuất phát từ đòi hỏi chính đáng của người dân với tư cách là người nộp thuế cho nhà nước.
# Kết quả sau sửa: mô hình swot là mô hình phân tích kinh doanh nổi tiếng dành cho mọi doanh nghiệp muốn cải thiện tình hình kinh doanh bằng định hướng đúng đắn và xây dựng những nền tảng phát triển vững chắc.
# Kết quả sau sửa: tăng cường tối đa cơ giới nhất là đối với những công việc nặng, phải kết hợp tốt giữa máy thi công chủ đạo với các thiết bị hỗ trợ khác, kết hợp giữa mỹ và phơi nắng thủ công.
# Kết quả sau sửa: giá trị của h càng cao có nghĩa là doanh nghiệp thu về được càng nhiều trên mỗi đồng chi phí là đưa ra cho hà cho nhân thọ là loại hình thanh toán l khi phân phối hiệu quả và cần có các biện pháp để cải thiện tình hình trên.
# Kết quả sau sửa: chú ý phải đảm bảo cho các góc cạnh, bề mặt không bị sứt mẻ.
# Kết quả sau sửa: theo một ý kiến khá phổ biến, cơ sở của toàn cầu hóa trước hết đó là chiến lược văn hóa nhằm tuyên truyền, phổ biến và khẳng định những chuẩn mực, những giá trị và những quy chế của hiện thực phương tây trong toàn nhân loại.
# Kết quả sau sửa: một số khó khăn chuẩn bị cẩn thận và giá trị các mục tiêu tốn để làm. vị dự, công nghệ đang được bán).
# Kết quả sau sửa: tác giả đã khẳng định rằng, nếu hoạt động quản lý không tốt thì quá trình giáo dục và đào tạo trong nhà trường cũng không đạt được những mục tiêu như mong muốn.
# Kết quả sau sửa: các thành viên hội đồng quản trị công ty được báo chí việt nam bình chọn là những cá nhân giàu nhất việt nam dựa trên tài sản chứng khoán.
# Kết quả sau sửa: để đảm bảo nguồn vốn đầu tư cho phát triển, các tác giả đưa ra vào hai nguồn: vốn tích lũy trong nước và vốn nước ngoài.
# Kết quả sau sửa: về cơ bản, điểm tương đồng giữa dạy học chủ đề và dạy học truyền thống là vẫn coi trọng việc lĩnh hội một nội dung kiến thức nền tảng, vì thế dạy học theo chủ đề là mô hình dạy học có thể vận dụng vào thực tiễn hiện nay dễ dàng hơn một số môn học khác.
# Kết quả sau sửa: điều gì cũng bị ảnh thuế ngày càng được trang bị những kiến thức chuyên sâu, chuyên nghiệp, có các kỹ năng quản lý thuế hiện đại, các kỹ năng áp dụng, sử dụng các phương tiện điện tử trong việc phân tích, đánh giá, tổng hợp, . . .
# Kết quả sau sửa: trên cơ sở phân tích về mặt lý luận các quy định của bộ luật dân sự 2015 về lỗi trong trách nhiệm bồi thường thiệt hại ngoài hợp đồng, báo cáo tích thực tiễn áp dụng các quy định về lỗi trong trách nhiệm bồi thường thiệt hại ngoài hợp đồng.
# Kết quả sau sửa: mối quan hệ giữa các giải pháp, biện pháp phòng chống.
# Kết quả sau sửa: giảm tỷ lệ dự trữ bắt buộc: ngân hàng chờ được thưởng.
# Kết quả sau sửa: ngoài ra, giáo viên nghiên cứu đã đề xuất, chỉnh sửa các thang đo của thuyết hành vi dự định cho phù hợp với đối tượng nghiên cứu.
# Kết quả sau sửa: sóng siêu âm được sử dụng để hỗ trợ cho quá trình loại các khí này khỏi điện cực và tạo điều kiện cho điện thế cao hơn và tốc độ sấy nhanh hơn.
# Kết quả sau sửa: trong quá trình giảng dạy ở lớp, bản thân tôi nhận thấy những ưu điểm và hạn chế như sau:
# Kết quả sau sửa: tác giả có thể đọc một tờ báo in dễ dàng ở bất cứ đâu, trên bất kì phương tiện đi lại nào.
# Kết quả sau sửa: th thích hợp như: tự trắc nghiệm bằng hệ thống câu hỏi trắc nghiệm khách quan; trắc nghiệm tự luận, hoặc tự so sánh kết quả học tập của mình với kết quả đạt được gv xác nhận.
# Kết quả sau sửa: nếu đem gửi ngân hàng một số vốn ban đầu là p với lãi suất mỗi năm là r theo thể thức lãi kép thì sau r năm gửi số tiền thu về cả vốn lẫn lãi sẽ là:
# Kết quả sau sửa: khuyến khích các tổ chức, cá nhân áp dụng công nghệ tiên tiến hiện đại về kinh nghiệm truyền thống để tạo sản phẩm có giá trị cao và có sức mạnh trên thị trường.
# Kết quả sau sửa: kêu gọi đầu tư là làm tăng thêm hơn 12.500 căn hộ phục vụ tái định cư khu siêu đô thị thủ thiêm.
# Kết quả sau sửa: thúc đẩy bán hàng: một trong những lý do quan trọng mà công ty nên sử dụng email marketing là chúng có thể được đưa vào vận hành.
# Kết quả sau sửa: nhìn chung các rào cản phi thuế quan được áp dụng phổ biến giữa quan hệ thương mại quốc tế gây khó khăn cho ngành hàng thủy sản xuất chè.
# Kết quả sau sửa: web server - web server là nơi quản trị viên trực tiếp thực hiện các thao tác để điều khiển của xe.
# Kết quả sau sửa: nền kinh tế, công ty cổ phần thương mại đầu tư thịnh vượng.
# Kết quả sau sửa: trong công tác quản lý ngân sách, việt yên có kết quả nhất định đặc biệt công tác dự toán và quyết toán ngân sách.
# Kết quả sau sửa: sau đó hướng dẫn hs đưa ra các ý tưởng thông qua sơ đồ tư duy để xây dựng các chủ đề con và phân công thực hiện chủ đề.
# Kết quả sau sửa: chính vì sự thiếu hụt nguồn lao động có trình độ cao, dẫn đến năng lực sản xuất ra các sản phẩm gỗ việt nam vẫn còn thấp.
# Kết quả sau sửa: chị mua thêm thuốc rửa phụ khoa nữa, bột màu vàng vàng.
# Kết quả sau sửa: trục vít – bánh vít: bánh vít chế tạo liền với trục 2, trục vít nối với motor điện.
# Kết quả sau sửa: kính thưa ban giám đốc và mảnh đất văn vật, có truyền thống cách mạng, nhiều danh nhân văn hóa và anh hùng dân tộc.
# Kết quả sau sửa: tổ chức quốc tế về tiêu chuẩn hóa iso, trong dự thảo dis 9000: 2000, đã đưa ra định nghĩa sau: chất lượng là khả năng của tập hợp các đặc trưng của một sản phẩm, hệ thống hay quá lớn để đáp ứng các yêu cầu của khách hàng mà chỉ cần có chiến tranh.
# Kết quả sau sửa: do vậy, muốn nâng cao được chất lượng dịch vụ công trong nhà trường cần có một đội ngũ có phẩm chất tốt, có năng lực chuyên môn nghiệp vụ, có đạo đức tốt và có trách nhiệm và tâm huyết với nghề.
# Kết quả sau sửa: hình 2.23 ví dụ và định nghĩa exchange và queue - trong hình 2.23 là cách tạo ra một dead letter exchange đồng thời tạo một queue với tham số x - dead - letter - exchange.
# /tmp/ipykernel_13/3564073302.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["predicted"] = test["preprocess"].apply(correct_wrapper)

# %%
test.to_csv("results.csv", index = False)

# %%
import re
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
import re
from sklearn.metrics import precision_recall_fscore_support

def clean_and_tokenize(sentence):
    # Lowercase
    sentence = sentence.lower()
    # Tokenize first, before removing punctuation
    tokens = custom_tokenize(sentence)
    # Remove punctuation from each token
    cleaned_tokens = [re.sub(r'[^\w\s]', '', token) for token in tokens]
    return cleaned_tokens

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

def evaluate_corrections(test_df, save_path="evaluated_test.csv"):
    y_true_detection = []
    y_pred_detection = []
    y_true_correction = []
    y_pred_correction = []

    wrong_sentences = []

    for i, (prep_sent, pred_sent, gold_sent) in enumerate(zip(test_df['preprocess'], test_df['predicted'], test_df['correct_text'])):
        prep_tokens = clean_and_tokenize(prep_sent)
        pred_tokens = clean_and_tokenize(pred_sent)
        gold_tokens = clean_and_tokenize(gold_sent)

        min_len = min(len(prep_tokens), len(pred_tokens), len(gold_tokens))

        sent_has_error = False

        for j in range(min_len):
            prep_token = prep_tokens[j]
            pred_token = pred_tokens[j]
            gold_token = gold_tokens[j]


            # Detection labels
            y_true_detection.append(prep_token != gold_token)
            y_pred_detection.append(pred_token != gold_token)

            # Correction labels
            if pred_token != gold_token:
                y_true_correction.append(gold_token)
                y_pred_correction.append(pred_token)
                sent_has_error = True

        if sent_has_error:
            wrong_sentences.append({
                "index": i,
                "predicted": pred_sent,
                "correct_text": gold_sent,
                "pred_tokens": pred_tokens,
                "gold_tokens": gold_tokens
            })

    pd.DataFrame(wrong_sentences).to_csv("wrong_sentences.csv", index=False)

    # Detection metrics
    p_det, r_det, f1_det, _ = precision_recall_fscore_support(
        y_true_detection, y_pred_detection, average='binary'
    )

    print("\n Detection Results:")
    print(f"Precision: {p_det:.4f} | Recall: {r_det:.4f} | F1: {f1_det:.4f}")

    # Confusion Matrix for Detection
    cm_det = confusion_matrix(y_true_detection, y_pred_detection)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm_det, display_labels=["Correct", "Error"])
    disp.plot(cmap='Blues')
    plt.title("Detection Confusion Matrix")
    plt.show()

    # Correction metrics
    if y_true_correction:
        p_corr, r_corr, f1_corr, _ = precision_recall_fscore_support(
            y_true_correction, y_pred_correction, average='micro'
        )

        print("\n Correction Results (on detected tokens):")
        print(f"Precision: {p_corr:.4f} | Recall: {r_corr:.4f} | F1: {f1_corr:.4f}")

        # Confusion Matrix for Correction
        labels = list(set(y_true_correction + y_pred_correction))
        cm_corr = confusion_matrix(y_true_correction, y_pred_correction, labels=labels)
        disp_corr = ConfusionMatrixDisplay(confusion_matrix=cm_corr, display_labels=labels)
        disp_corr.plot(cmap='Oranges', xticks_rotation=90)
        plt.title("Correction Confusion Matrix")
        plt.show()

    else:
        print("\n No corrections made or needed.")
        p_corr = r_corr = f1_corr = 0.0

    # Print wrong predictions
    print("\n===== Các câu dự đoán sai =====")
    for wrong in wrong_sentences:
        print(f"\n# {wrong['index']}")
        print(f"Predicted   : {wrong['predicted']}")
        print(f"Correct     : {wrong['correct_text']}")
        print(f"Pred tokens : {wrong['pred_tokens']}")
        print(f"Gold tokens : {wrong['gold_tokens']}")

    # Save wrong sentences

    return {
        "detection": {"precision": p_det, "recall": r_det, "f1": f1_det},
        "correction": {"precision": p_corr, "recall": r_corr, "f1": f1_corr}
    }

# %%
results = evaluate_corrections(test, save_path="test_with_prediction.csv")

print("=== Kết quả đánh giá ===")
print("🔍 Detection (Phát hiện lỗi):")
print(f"Precision: {results['detection']['precision']:.4f}")
print(f"Recall   : {results['detection']['recall']:.4f}")
print(f"F1       : {results['detection']['f1']:.4f}")

print("\n🛠️ Correction (Sửa lỗi):")
print(f"Precision: {results['correction']['precision']:.4f}")
print(f"Recall   : {results['correction']['recall']:.4f}")
print(f"F1       : {results['correction']['f1']:.4f}")
# Out:
#  Detection Results:
# Precision: 0.1649 | Recall: 0.3587 | F1: 0.2260
#  Correction Results (on detected tokens):
# Precision: 0.0000 | Recall: 0.0000 | F1: 0.0000
# ===== Các câu dự đoán sai =====
#
# # 0
# Predicted   : hiệu quả công tác tuyên truyền, vận động này phụ huynh sẽ hiểu rõ hơn tầm quan trọng của việc giáo dục ý thức bảo vệ môi trường cho trẻ không phải chỉ ở phía nhà trường mà còn ở gia đình, góp phần vào việc gìn giữ môi trường xanh, sạch, đẹp.
# Correct     : Thông qua công tác tuyên truyền, vận động này phụ huynh sẽ hiểu rõ hơn tầm quan trọng của việc giáo dục ý thức bảo vệ môi trường cho trẻ không phải chỉ ở phía nhà trường mà còn ở gia đình, góp phần vào việc gìn giữ môi trường xanh, sạch, đẹp.
# Pred tokens : ['hiệu', 'quả', 'công', 'tác', 'tuyên', 'truyền', '', 'vận', 'động', 'này', 'phụ', 'huynh', 'sẽ', 'hiểu', 'rõ', 'hơn', 'tầm', 'quan', 'trọng', 'của', 'việc', 'giáo', 'dục', 'ý', 'thức', 'bảo', 'vệ', 'môi', 'trường', 'cho', 'trẻ', 'không', 'phải', 'chỉ', 'ở', 'phía', 'nhà', 'trường', 'mà', 'còn', 'ở', 'gia', 'đình', '', 'góp', 'phần', 'vào', 'việc', 'gìn', 'giữ', 'môi', 'trường', 'xanh', '', 'sạch', '', 'đẹp', '']
# Gold tokens : ['thông', 'qua', 'công', 'tác', 'tuyên', 'truyền', '', 'vận', 'động', 'này', 'phụ', 'huynh', 'sẽ', 'hiểu', 'rõ', 'hơn', 'tầm', 'quan', 'trọng', 'của', 'việc', 'giáo', 'dục', 'ý', 'thức', 'bảo', 'vệ', 'môi', 'trường', 'cho', 'trẻ', 'không', 'phải', 'chỉ', 'ở', 'phía', 'nhà', 'trường', 'mà', 'còn', 'ở', 'gia', 'đình', '', 'góp', 'phần', 'vào', 'việc', 'gìn', 'giữ', 'môi', 'trường', 'xanh', '', 'sạch', '', 'đẹp', '']
#
# # 1
# Predicted   : do đó, doanh nghiệp cần chú trọng đến yếu tố này để làm thỏa mãn, hài lòng của thời đại hiện nay.
# Correct     : Do đó, doanh nghiệp cần chú trọng đến yếu tố này để làm thỏa mãn, hài lòng các nhóm đối tượng này.
# Pred tokens : ['do', 'đó', '', 'doanh', 'nghiệp', 'cần', 'chú', 'trọng', 'đến', 'yếu', 'tố', 'này', 'để', 'làm', 'thỏa', 'mãn', '', 'hài', 'lòng', 'của', 'thời', 'đại', 'hiện', 'nay', '']
# Gold tokens : ['do', 'đó', '', 'doanh', 'nghiệp', 'cần', 'chú', 'trọng', 'đến', 'yếu', 'tố', 'này', 'để', 'làm', 'thỏa', 'mãn', '', 'hài', 'lòng', 'các', 'nhóm', 'đối', 'tượng', 'này', '']
#
# # 3
# Predicted   : đứng trước thực tế này đòi hỏi chúng ta cần phải có những nghiên cứu chi li, cụ thể nhằm tìm ra những nhân tố ảnh hưởng đến sự lựa chọn kênh mua sắm của người tiêu dùng ô tô.
# Correct     : Đứng trước thực tế này đòi hỏi chúng ta cần phải có những nghiên cứu chi li, cụ thể nhằm tìm ra những nhân tố ảnh hưởng đến sự lựa chọn kênh mua sắm của người tiêu dùng ở TP.
# Pred tokens : ['đứng', 'trước', 'thực', 'tế', 'này', 'đòi', 'hỏi', 'chúng', 'ta', 'cần', 'phải', 'có', 'những', 'nghiên', 'cứu', 'chi', 'li', '', 'cụ', 'thể', 'nhằm', 'tìm', 'ra', 'những', 'nhân', 'tố', 'ảnh', 'hưởng', 'đến', 'sự', 'lựa', 'chọn', 'kênh', 'mua', 'sắm', 'của', 'người', 'tiêu', 'dùng', 'ô', 'tô', '']
# Gold tokens : ['đứng', 'trước', 'thực', 'tế', 'này', 'đòi', 'hỏi', 'chúng', 'ta', 'cần', 'phải', 'có', 'những', 'nghiên', 'cứu', 'chi', 'li', '', 'cụ', 'thể', 'nhằm', 'tìm', 'ra', 'những', 'nhân', 'tố', 'ảnh', 'hưởng', 'đến', 'sự', 'lựa', 'chọn', 'kênh', 'mua', 'sắm', 'của', 'người', 'tiêu', 'dùng', 'ở', 'tp', '']
#
# # 7
# Predicted   : cách mạng đã hội tụ hoàn gateway mà ổ điện thông minh cần xử lý ở đây sẽ thường là yêu cầu bật / tắt ổ điện, yêu cầu thông báo trạng thái bật / tắt của ổ điện, yêu cầu thông báo vị trí lắp đặt của ổ điện.
# Correct     : Các lệnh được gửi từ Home Gateway mà ổ điện thông minh cần xử lý ở đây sẽ thường là yêu cầu bật/tắt ổ điện, yêu cầu thông báo trạng thái bật/tắt của ổ điện, yêu cầu thông báo vị trí lắp đặt của ổ điện.
# Pred tokens : ['cách', 'mạng', 'đã', 'hội', 'tụ', 'hoàn', 'gateway', 'mà', 'ổ', 'điện', 'thông', 'minh', 'cần', 'xử', 'lý', 'ở', 'đây', 'sẽ', 'thường', 'là', 'yêu', 'cầu', 'bật', '', 'tắt', 'ổ', 'điện', '', 'yêu', 'cầu', 'thông', 'báo', 'trạng', 'thái', 'bật', '', 'tắt', 'của', 'ổ', 'điện', '', 'yêu', 'cầu', 'thông', 'báo', 'vị', 'trí', 'lắp', 'đặt', 'của', 'ổ', 'điện', '']
# Gold tokens : ['các', 'lệnh', 'được', 'gửi', 'từ', 'home', 'gateway', 'mà', 'ổ', 'điện', 'thông', 'minh', 'cần', 'xử', 'lý', 'ở', 'đây', 'sẽ', 'thường', 'là', 'yêu', 'cầu', 'bật', '', 'tắt', 'ổ', 'điện', '', 'yêu', 'cầu', 'thông', 'báo', 'trạng', 'thái', 'bật', '', 'tắt', 'của', 'ổ', 'điện', '', 'yêu', 'cầu', 'thông', 'báo', 'vị', 'trí', 'lắp', 'đặt', 'của', 'ổ', 'điện', '']
#
# # 8
# Predicted   : với khuôn khổ này, chính trị học so sánh có thể áp dụng vào phân tích nhằm xác định được sự tương đồng và khác biệt giữa các quá trình học tập, tương ứng với sự tương đồng và khác biệt của cấu trúc chính trị.
# Correct     : Với khuôn khổ này, chính trị học so sánh có thể áp dụng vào phân tích nhằm xác định được sự tương đồng và khác biệt giữa các quá trình chính trị, tương ứng với sự tương đồng và khác biệt của cấu trúc chính trị.
# Pred tokens : ['với', 'khuôn', 'khổ', 'này', '', 'chính', 'trị', 'học', 'so', 'sánh', 'có', 'thể', 'áp', 'dụng', 'vào', 'phân', 'tích', 'nhằm', 'xác', 'định', 'được', 'sự', 'tương', 'đồng', 'và', 'khác', 'biệt', 'giữa', 'các', 'quá', 'trình', 'học', 'tập', '', 'tương', 'ứng', 'với', 'sự', 'tương', 'đồng', 'và', 'khác', 'biệt', 'của', 'cấu', 'trúc', 'chính', 'trị', '']
# Gold tokens : ['với', 'khuôn', 'khổ', 'này', '', 'chính', 'trị', 'học', 'so', 'sánh', 'có', 'thể', 'áp', 'dụng', 'vào', 'phân', 'tích', 'nhằm', 'xác', 'định', 'được', 'sự', 'tương', 'đồng', 'và', 'khác', 'biệt', 'giữa', 'các', 'quá', 'trình', 'chính', 'trị', '', 'tương', 'ứng', 'với', 'sự', 'tương', 'đồng', 'và', 'khác', 'biệt', 'của', 'cấu', 'trúc', 'chính', 'trị', '']
#
# # 9
# Predicted   : việc điều khiển xe sẽ trở nên dễ dàng hơn nếu các bánh xe được đặt theo một góc chính xác theo yêu cầu thực tế, việc đặt sai góc sẽ tạo ra tính ổn định khi lái kém và khiến lốp xe nhanh mòn.
# Correct     : Việc điều khiển xe sẽ trở nên dễ dàng hơn nếu các bánh xe được đặt theo một góc chính xác theo yêu cầu thiết kế, việc đặt sai góc sẽ tạo ra tính ổn định khi lái kém và khiến lốp xe nhanh mòn.
# Pred tokens : ['việc', 'điều', 'khiển', 'xe', 'sẽ', 'trở', 'nên', 'dễ', 'dàng', 'hơn', 'nếu', 'các', 'bánh', 'xe', 'được', 'đặt', 'theo', 'một', 'góc', 'chính', 'xác', 'theo', 'yêu', 'cầu', 'thực', 'tế', '', 'việc', 'đặt', 'sai', 'góc', 'sẽ', 'tạo', 'ra', 'tính', 'ổn', 'định', 'khi', 'lái', 'kém', 'và', 'khiến', 'lốp', 'xe', 'nhanh', 'mòn', '']
# Gold tokens : ['việc', 'điều', 'khiển', 'xe', 'sẽ', 'trở', 'nên', 'dễ', 'dàng', 'hơn', 'nếu', 'các', 'bánh', 'xe', 'được', 'đặt', 'theo', 'một', 'góc', 'chính', 'xác', 'theo', 'yêu', 'cầu', 'thiết', 'kế', '', 'việc', 'đặt', 'sai', 'góc', 'sẽ', 'tạo', 'ra', 'tính', 'ổn', 'định', 'khi', 'lái', 'kém', 'và', 'khiến', 'lốp', 'xe', 'nhanh', 'mòn', '']
#
# # 10
# Predicted   : tính đến nay, ta nêu lên những cơ sở lý thuyết được áp dụng trong việc giải quyết bài toán xây dựng hệ thống.
# Correct     : Trong chương này, ta nêu lên những cơ sở lý thuyết được áp dụng trong việc giải quyết bài toán xây dựng hệ thống.
# Pred tokens : ['tính', 'đến', 'nay', '', 'ta', 'nêu', 'lên', 'những', 'cơ', 'sở', 'lý', 'thuyết', 'được', 'áp', 'dụng', 'trong', 'việc', 'giải', 'quyết', 'bài', 'toán', 'xây', 'dựng', 'hệ', 'thống', '']
# Gold tokens : ['trong', 'chương', 'này', '', 'ta', 'nêu', 'lên', 'những', 'cơ', 'sở', 'lý', 'thuyết', 'được', 'áp', 'dụng', 'trong', 'việc', 'giải', 'quyết', 'bài', 'toán', 'xây', 'dựng', 'hệ', 'thống', '']
#
# # 15
# Predicted   : tuy nhiên, mục tiêu của p 4 là còn có thể tái cấu hình với cả các asic có chức năng cố định.
# Correct     : Tuy nhiên, mục tiêu của P4 là còn có thể tái cấu hình với cả các ASIC có chức năng cố định.
# Pred tokens : ['tuy', 'nhiên', '', 'mục', 'tiêu', 'của', 'p', '4', 'là', 'còn', 'có', 'thể', 'tái', 'cấu', 'hình', 'với', 'cả', 'các', 'asic', 'có', 'chức', 'năng', 'cố', 'định', '']
# Gold tokens : ['tuy', 'nhiên', '', 'mục', 'tiêu', 'của', 'p4', 'là', 'còn', 'có', 'thể', 'tái', 'cấu', 'hình', 'với', 'cả', 'các', 'asic', 'có', 'chức', 'năng', 'cố', 'định', '']
#
# # 18
# Predicted   : nhưng trong khi làm bài luận văn chắc chắn, cần chú trọng hơn các chợ.
# Correct     : Nhưng trong nhiều lớp bồi dưỡng vẫn chưa chú ý đến các phương pháp tích cực.
# Pred tokens : ['nhưng', 'trong', 'khi', 'làm', 'bài', 'luận', 'văn', 'chắc', 'chắn', '', 'cần', 'chú', 'trọng', 'hơn', 'các', 'chợ', '']
# Gold tokens : ['nhưng', 'trong', 'nhiều', 'lớp', 'bồi', 'dưỡng', 'vẫn', 'chưa', 'chú', 'ý', 'đến', 'các', 'phương', 'pháp', 'tích', 'cực', '']
#
# # 19
# Predicted   : vì vậy qua những câu chuyện với mục đích cung cấp hiểu biết về sự thích thú của bảng cho vay đối với trục x và quá trình phát triển của chúng.
# Correct     : Vì vậy qua những câu chuyện với mục đích cung cấp hiểu biết về sự thích nghi của động thực vật với môi trường, về quá trình phát triển của chúng.
# Pred tokens : ['vì', 'vậy', 'qua', 'những', 'câu', 'chuyện', 'với', 'mục', 'đích', 'cung', 'cấp', 'hiểu', 'biết', 'về', 'sự', 'thích', 'thú', 'của', 'bảng', 'cho', 'vay', 'đối', 'với', 'trục', 'x', 'và', 'quá', 'trình', 'phát', 'triển', 'của', 'chúng', '']
# Gold tokens : ['vì', 'vậy', 'qua', 'những', 'câu', 'chuyện', 'với', 'mục', 'đích', 'cung', 'cấp', 'hiểu', 'biết', 'về', 'sự', 'thích', 'nghi', 'của', 'động', 'thực', 'vật', 'với', 'môi', 'trường', '', 'về', 'quá', 'trình', 'phát', 'triển', 'của', 'chúng', '']
#
# # 23
# Predicted   : mỗi tháng 1 lần, công ty sẽ tổ chức một buổi giao lưu chia sẻ kinh nghiệm giữa các thành viên với nhau và đào tạo thêm về các kỹ năng ứng xử khác cho nhân viên.
# Correct     : Mỗi tháng 1 lần, công ty sẽ tổ chức một buổi giao lưu chia sẻ kinh nghiệm giữa các nhân viên với nhau và đào tạo thêm về các kỹ năng ứng xử khác cho nhân viên.
# Pred tokens : ['mỗi', 'tháng', '1', 'lần', '', 'công', 'ty', 'sẽ', 'tổ', 'chức', 'một', 'buổi', 'giao', 'lưu', 'chia', 'sẻ', 'kinh', 'nghiệm', 'giữa', 'các', 'thành', 'viên', 'với', 'nhau', 'và', 'đào', 'tạo', 'thêm', 'về', 'các', 'kỹ', 'năng', 'ứng', 'xử', 'khác', 'cho', 'nhân', 'viên', '']
# Gold tokens : ['mỗi', 'tháng', '1', 'lần', '', 'công', 'ty', 'sẽ', 'tổ', 'chức', 'một', 'buổi', 'giao', 'lưu', 'chia', 'sẻ', 'kinh', 'nghiệm', 'giữa', 'các', 'nhân', 'viên', 'với', 'nhau', 'và', 'đào', 'tạo', 'thêm', 'về', 'các', 'kỹ', 'năng', 'ứng', 'xử', 'khác', 'cho', 'nhân', 'viên', '']
#
# # 24
# Predicted   : trang trí chủ đề học tập mà thông tin thị trường ở lớp.
# Correct     : Trạng thái phòng đã được thuê và không cần thêm người ở ghép.
# Pred tokens : ['trang', 'trí', 'chủ', 'đề', 'học', 'tập', 'mà', 'thông', 'tin', 'thị', 'trường', 'ở', 'lớp', '']
# Gold tokens : ['trạng', 'thái', 'phòng', 'đã', 'được', 'thuê', 'và', 'không', 'cần', 'thêm', 'người', 'ở', 'ghép', '']
#
# # 25
# Predicted   : display ads: quảng cáo hiển thị) có thể khẳng định tính khách quan, hỉ, bđkh như: du lịch.
# Correct     : Display ads: Quảng cáo hiển thị, có nhiều dạng định dạng khác nhau: chữ, hình ảnh, video flash.
# Pred tokens : ['display', 'ads', '', 'quảng', 'cáo', 'hiển', 'thị', '', 'có', 'thể', 'khẳng', 'định', 'tính', 'khách', 'quan', '', 'hỉ', '', 'bđkh', 'như', '', 'du', 'lịch', '']
# Gold tokens : ['display', 'ads', '', 'quảng', 'cáo', 'hiển', 'thị', '', 'có', 'nhiều', 'dạng', 'định', 'dạng', 'khác', 'nhau', '', 'chữ', '', 'hình', 'ảnh', '', 'video', 'flash', '']
#
# # 32
# Predicted   : xây dựng mô hình để chuyển giao nhanh giống mới, những khía cạnh các tên tuổi, trình độ khoa học và công nghệ cho nông dân.
# Correct     : Xây dựng mô hình để chuyển giao nhanh giống mới, phương pháp canh tác tiên tiến, tiến bộ khoa học và công nghệ cho nông dân.
# Pred tokens : ['xây', 'dựng', 'mô', 'hình', 'để', 'chuyển', 'giao', 'nhanh', 'giống', 'mới', '', 'những', 'khía', 'cạnh', 'các', 'tên', 'tuổi', '', 'trình', 'độ', 'khoa', 'học', 'và', 'công', 'nghệ', 'cho', 'nông', 'dân', '']
# Gold tokens : ['xây', 'dựng', 'mô', 'hình', 'để', 'chuyển', 'giao', 'nhanh', 'giống', 'mới', '', 'phương', 'pháp', 'canh', 'tác', 'tiên', 'tiến', '', 'tiến', 'bộ', 'khoa', 'học', 'và', 'công', 'nghệ', 'cho', 'nông', 'dân', '']
#
# # 34
# Predicted   : đồng thời, tác giả cũng đã chỉ ra những khó khăn trong thực hiện các chính sách an sinh xã hội ở việt nam những năm gần đây trên cơ sở phân tích những đánh giá của nhóm cán bộ các đơn vị chủ đầu tư hệ thống chính sách an sinh xã hội.
# Correct     : Đồng thời, tác giả cũng đã chỉ ra những khó khăn trong thực hiện các chính sách an sinh xã hội ở Việt Nam những năm gần đây trên cơ sở phân tích những đánh giá của nhóm cán bộ thực hiện và các đối tượng thụ hưởng chính sách an sinh xã hội.
# Pred tokens : ['đồng', 'thời', '', 'tác', 'giả', 'cũng', 'đã', 'chỉ', 'ra', 'những', 'khó', 'khăn', 'trong', 'thực', 'hiện', 'các', 'chính', 'sách', 'an', 'sinh', 'xã', 'hội', 'ở', 'việt', 'nam', 'những', 'năm', 'gần', 'đây', 'trên', 'cơ', 'sở', 'phân', 'tích', 'những', 'đánh', 'giá', 'của', 'nhóm', 'cán', 'bộ', 'các', 'đơn', 'vị', 'chủ', 'đầu', 'tư', 'hệ', 'thống', 'chính', 'sách', 'an', 'sinh', 'xã', 'hội', '']
# Gold tokens : ['đồng', 'thời', '', 'tác', 'giả', 'cũng', 'đã', 'chỉ', 'ra', 'những', 'khó', 'khăn', 'trong', 'thực', 'hiện', 'các', 'chính', 'sách', 'an', 'sinh', 'xã', 'hội', 'ở', 'việt', 'nam', 'những', 'năm', 'gần', 'đây', 'trên', 'cơ', 'sở', 'phân', 'tích', 'những', 'đánh', 'giá', 'của', 'nhóm', 'cán', 'bộ', 'thực', 'hiện', 'và', 'các', 'đối', 'tượng', 'thụ', 'hưởng', 'chính', 'sách', 'an', 'sinh', 'xã', 'hội', '']
#
# # 35
# Predicted   : tác giả cũng cho rằng, việc lập kế hoạch đầu tư công phải được kiểm soát chặt chẽ và thông qua bởi cơ quan hành chính cao nhất là với các định chế then chốt khác.
# Correct     : Tác giả cũng cho rằng, việc lập kế hoạch đầu tư công phải được kiểm soát chặt chẽ và thông qua bởi cơ quan hành chính cao nhất và phải được công khai trước công chúng.
# Pred tokens : ['tác', 'giả', 'cũng', 'cho', 'rằng', '', 'việc', 'lập', 'kế', 'hoạch', 'đầu', 'tư', 'công', 'phải', 'được', 'kiểm', 'soát', 'chặt', 'chẽ', 'và', 'thông', 'qua', 'bởi', 'cơ', 'quan', 'hành', 'chính', 'cao', 'nhất', 'là', 'với', 'các', 'định', 'chế', 'then', 'chốt', 'khác', '']
# Gold tokens : ['tác', 'giả', 'cũng', 'cho', 'rằng', '', 'việc', 'lập', 'kế', 'hoạch', 'đầu', 'tư', 'công', 'phải', 'được', 'kiểm', 'soát', 'chặt', 'chẽ', 'và', 'thông', 'qua', 'bởi', 'cơ', 'quan', 'hành', 'chính', 'cao', 'nhất', 'và', 'phải', 'được', 'công', 'khai', 'trước', 'công', 'chúng', '']
#
# # 39
# Predicted   : năng suất lao động của chi phí tăng lên 6 % đến 7 % bằng cách chú trọng đào tạo chuyên môn, nâng cao tay nghề, tuyển chọn những lao động có trình độ cao hơn.
# Correct     : Năng suất lao động của công nhân tăng thêm 6% đến 7% bằng cách chú trọng đào tạo chuyên môn, nâng cao tay nghề, tuyển chọn những lao động có trình độ cao hơn.
# Pred tokens : ['năng', 'suất', 'lao', 'động', 'của', 'chi', 'phí', 'tăng', 'lên', '6', '', 'đến', '7', '', 'bằng', 'cách', 'chú', 'trọng', 'đào', 'tạo', 'chuyên', 'môn', '', 'nâng', 'cao', 'tay', 'nghề', '', 'tuyển', 'chọn', 'những', 'lao', 'động', 'có', 'trình', 'độ', 'cao', 'hơn', '']
# Gold tokens : ['năng', 'suất', 'lao', 'động', 'của', 'công', 'nhân', 'tăng', 'thêm', '6', '', 'đến', '7', '', 'bằng', 'cách', 'chú', 'trọng', 'đào', 'tạo', 'chuyên', 'môn', '', 'nâng', 'cao', 'tay', 'nghề', '', 'tuyển', 'chọn', 'những', 'lao', 'động', 'có', 'trình', 'độ', 'cao', 'hơn', '']
#
# # 44
# Predicted   : mức tái cấp vốn tối đa không vượt quá mức cung ứng dành cho học sinh cũng hứng thú trong học tại trung tâm.
# Correct     : Mức tái cấp vốn tối đa không vượt quá mức cung ứng dành cho mục tiêu cung ứng phương tiện thanh toán trong năm.
# Pred tokens : ['mức', 'tái', 'cấp', 'vốn', 'tối', 'đa', 'không', 'vượt', 'quá', 'mức', 'cung', 'ứng', 'dành', 'cho', 'học', 'sinh', 'cũng', 'hứng', 'thú', 'trong', 'học', 'tại', 'trung', 'tâm', '']
# Gold tokens : ['mức', 'tái', 'cấp', 'vốn', 'tối', 'đa', 'không', 'vượt', 'quá', 'mức', 'cung', 'ứng', 'dành', 'cho', 'mục', 'tiêu', 'cung', 'ứng', 'phương', 'tiện', 'thanh', 'toán', 'trong', 'năm', '']
#
# # 46
# Predicted   : kiểm soát được đưa ra nhằm thu thập thông tin, ý kiến khác nhau để phục vụ cho việc nghiên cứu đề tài.
# Correct     : Khảo sát được đưa ra nhằm thu thập thông tin, ý kiến khác nhau để phục vụ cho việc nghiên cứu đề tài.
# Pred tokens : ['kiểm', 'soát', 'được', 'đưa', 'ra', 'nhằm', 'thu', 'thập', 'thông', 'tin', '', 'ý', 'kiến', 'khác', 'nhau', 'để', 'phục', 'vụ', 'cho', 'việc', 'nghiên', 'cứu', 'đề', 'tài', '']
# Gold tokens : ['khảo', 'sát', 'được', 'đưa', 'ra', 'nhằm', 'thu', 'thập', 'thông', 'tin', '', 'ý', 'kiến', 'khác', 'nhau', 'để', 'phục', 'vụ', 'cho', 'việc', 'nghiên', 'cứu', 'đề', 'tài', '']
#
# # 48
# Predicted   : fanpage của hưng việt đã cung cấp đầy đủ cụ thể hóa vấn đề tương tự chủ trọ (đền chùa, cách thức liên hệ, … đồng thời cũng giới thiệu tổng quan về công ty.
# Correct     : Fanpage của Hưng Việt đã cung cấp đầy đủ cụ thể thông tin về công ty như tên, địa chỉ, cách thức liên hệ, … đồng thời cũng giới thiệu tổng quan về công ty.
# Pred tokens : ['fanpage', 'của', 'hưng', 'việt', 'đã', 'cung', 'cấp', 'đầy', 'đủ', 'cụ', 'thể', 'hóa', 'vấn', 'đề', 'tương', 'tự', 'chủ', 'trọ', '', 'đền', 'chùa', '', 'cách', 'thức', 'liên', 'hệ', '', '', 'đồng', 'thời', 'cũng', 'giới', 'thiệu', 'tổng', 'quan', 'về', 'công', 'ty', '']
# Gold tokens : ['fanpage', 'của', 'hưng', 'việt', 'đã', 'cung', 'cấp', 'đầy', 'đủ', 'cụ', 'thể', 'thông', 'tin', 'về', 'công', 'ty', 'như', 'tên', '', 'địa', 'chỉ', '', 'cách', 'thức', 'liên', 'hệ', '', '', 'đồng', 'thời', 'cũng', 'giới', 'thiệu', 'tổng', 'quan', 'về', 'công', 'ty', '']
#
# # 49
# Predicted   : chỉ đạo tổ trưởng chuyên môn / nhóm trưởng hướng dẫn gv, nhân viên chăm sóc trẻ lập kế hoạch cá nhân và duyệt kế hoạch của từng bộ môn, có sẵn.
# Correct     : Chỉ đạo tổ trưởng chuyên môn/nhóm trưởng hướng dẫn GV, nhân viên chăm sóc trẻ lập kế hoạch cá nhân và duyệt kế hoạch của từng bộ phận cá nhân.
# Pred tokens : ['chỉ', 'đạo', 'tổ', 'trưởng', 'chuyên', 'môn', '', 'nhóm', 'trưởng', 'hướng', 'dẫn', 'gv', '', 'nhân', 'viên', 'chăm', 'sóc', 'trẻ', 'lập', 'kế', 'hoạch', 'cá', 'nhân', 'và', 'duyệt', 'kế', 'hoạch', 'của', 'từng', 'bộ', 'môn', '', 'có', 'sẵn', '']
# Gold tokens : ['chỉ', 'đạo', 'tổ', 'trưởng', 'chuyên', 'môn', '', 'nhóm', 'trưởng', 'hướng', 'dẫn', 'gv', '', 'nhân', 'viên', 'chăm', 'sóc', 'trẻ', 'lập', 'kế', 'hoạch', 'cá', 'nhân', 'và', 'duyệt', 'kế', 'hoạch', 'của', 'từng', 'bộ', 'phận', 'cá', 'nhân', '']
#
# # 51
# Predicted   : nội dung vào không có giáo viên âm nhạc tiểu học tích cực tự học nâng cao trình độ sử dụng trong nội dung phù hợp hơn nữa để nâng cao năng lực nghiên cứu, đọc tài liệu bằng tiếng anh nhằm phát triển năng lực của mỗi giáo viên âm nhạc tiểu học.
# Correct     : Bồi dưỡng và khuyến khích giáo viên âm nhạc tiểu học tích cực tự học nâng cao trình độ sử dụng ngoại ngữ dưới nhiều hình thức qua đó nâng cao năng lực nghiên cứu, đọc tài liệu bằng tiếng anh nhằm phát triển năng lực của mỗi giáo viên âm nhạc tiểu học.
# Pred tokens : ['nội', 'dung', 'vào', 'không', 'có', 'giáo', 'viên', 'âm', 'nhạc', 'tiểu', 'học', 'tích', 'cực', 'tự', 'học', 'nâng', 'cao', 'trình', 'độ', 'sử', 'dụng', 'trong', 'nội', 'dung', 'phù', 'hợp', 'hơn', 'nữa', 'để', 'nâng', 'cao', 'năng', 'lực', 'nghiên', 'cứu', '', 'đọc', 'tài', 'liệu', 'bằng', 'tiếng', 'anh', 'nhằm', 'phát', 'triển', 'năng', 'lực', 'của', 'mỗi', 'giáo', 'viên', 'âm', 'nhạc', 'tiểu', 'học', '']
# Gold tokens : ['bồi', 'dưỡng', 'và', 'khuyến', 'khích', 'giáo', 'viên', 'âm', 'nhạc', 'tiểu', 'học', 'tích', 'cực', 'tự', 'học', 'nâng', 'cao', 'trình', 'độ', 'sử', 'dụng', 'ngoại', 'ngữ', 'dưới', 'nhiều', 'hình', 'thức', 'qua', 'đó', 'nâng', 'cao', 'năng', 'lực', 'nghiên', 'cứu', '', 'đọc', 'tài', 'liệu', 'bằng', 'tiếng', 'anh', 'nhằm', 'phát', 'triển', 'năng', 'lực', 'của', 'mỗi', 'giáo', 'viên', 'âm', 'nhạc', 'tiểu', 'học', '']
#
# # 52
# Predicted   : thái độ phục vụ sử dụng chuỗi ký tự đặc biệt, bản tin được chia thành các block với giá trị chiều dài ngẫu nhiên được thêm vào phía trước.
# Correct     : Theo đó thay vì sử dụng chuỗi ký tự đặc biệt, bản tin được chia thành các block với giá trị chiều dài ngẫu nhiên được thêm vào phía trước.
# Pred tokens : ['thái', 'độ', 'phục', 'vụ', 'sử', 'dụng', 'chuỗi', 'ký', 'tự', 'đặc', 'biệt', '', 'bản', 'tin', 'được', 'chia', 'thành', 'các', 'block', 'với', 'giá', 'trị', 'chiều', 'dài', 'ngẫu', 'nhiên', 'được', 'thêm', 'vào', 'phía', 'trước', '']
# Gold tokens : ['theo', 'đó', 'thay', 'vì', 'sử', 'dụng', 'chuỗi', 'ký', 'tự', 'đặc', 'biệt', '', 'bản', 'tin', 'được', 'chia', 'thành', 'các', 'block', 'với', 'giá', 'trị', 'chiều', 'dài', 'ngẫu', 'nhiên', 'được', 'thêm', 'vào', 'phía', 'trước', '']
#
# # 56
# Predicted   : với hình thức này vừa tạo cho trẻ những kỹ thuật máy, vui vẻ sau hoạt động nhưng cũng thông qua đó có thể thu được của từng nhân tố ảnh hưởng đến.
# Correct     : Với hình thức này vừa tạo cho trẻ không khí thoải mái, vui vẻ sau hoạt động nhưng cũng thông qua đó cơ thể trẻ được chuyển trạng thái từ tĩnh sang động.
# Pred tokens : ['với', 'hình', 'thức', 'này', 'vừa', 'tạo', 'cho', 'trẻ', 'những', 'kỹ', 'thuật', 'máy', '', 'vui', 'vẻ', 'sau', 'hoạt', 'động', 'nhưng', 'cũng', 'thông', 'qua', 'đó', 'có', 'thể', 'thu', 'được', 'của', 'từng', 'nhân', 'tố', 'ảnh', 'hưởng', 'đến', '']
# Gold tokens : ['với', 'hình', 'thức', 'này', 'vừa', 'tạo', 'cho', 'trẻ', 'không', 'khí', 'thoải', 'mái', '', 'vui', 'vẻ', 'sau', 'hoạt', 'động', 'nhưng', 'cũng', 'thông', 'qua', 'đó', 'cơ', 'thể', 'trẻ', 'được', 'chuyển', 'trạng', 'thái', 'từ', 'tĩnh', 'sang', 'động', '']
#
# # 57
# Predicted   : hạn chế cửa nhân tố kinh tế đối với doanh nghiệp là việt nam mở của nền kinh tế thị trường (gia nhập wto) tạo nên nhiều đối thủ cạnh tranh - nhiều tập đoàn bán lẻ hùng mạnh trên thế giới và khu vực xa nhằm tạo nên hiện nay.
# Correct     : Hạn chế cửa nhân tố kinh tế đối với doanh nghiệp là Việt Nam mở của nền kinh tế thị trường (gia nhập WTO) tạo nên nhiều đối thủ cạnh tranh - nhiều tập đoàn bán lẻ hùng mạnh trên thế giới và khu vực gia nhập thị trường Việt Nam.
# Pred tokens : ['hạn', 'chế', 'cửa', 'nhân', 'tố', 'kinh', 'tế', 'đối', 'với', 'doanh', 'nghiệp', 'là', 'việt', 'nam', 'mở', 'của', 'nền', 'kinh', 'tế', 'thị', 'trường', '', 'gia', 'nhập', 'wto', '', 'tạo', 'nên', 'nhiều', 'đối', 'thủ', 'cạnh', 'tranh', '', 'nhiều', 'tập', 'đoàn', 'bán', 'lẻ', 'hùng', 'mạnh', 'trên', 'thế', 'giới', 'và', 'khu', 'vực', 'xa', 'nhằm', 'tạo', 'nên', 'hiện', 'nay', '']
# Gold tokens : ['hạn', 'chế', 'cửa', 'nhân', 'tố', 'kinh', 'tế', 'đối', 'với', 'doanh', 'nghiệp', 'là', 'việt', 'nam', 'mở', 'của', 'nền', 'kinh', 'tế', 'thị', 'trường', '', 'gia', 'nhập', 'wto', '', 'tạo', 'nên', 'nhiều', 'đối', 'thủ', 'cạnh', 'tranh', '', 'nhiều', 'tập', 'đoàn', 'bán', 'lẻ', 'hùng', 'mạnh', 'trên', 'thế', 'giới', 'và', 'khu', 'vực', 'gia', 'nhập', 'thị', 'trường', 'việt', 'nam', '']
#
# # 64
# Predicted   : đối với các tổ chức cho hs nhận xét như vậy có thể sở hữu là tổ chức, sẽ có hội đồng thành viên, chủ sở hữu sẽ bổ nhiệm các vị trí thành viên hội đồng thành viên miễn nhiệm từ 03 đến 07 năm với nhiệm kì không được quá 05 năm.
# Correct     : Đối với công ty trách nhiệm hữu hạn một thành viên có chủ sở hữu là tổ chức, sẽ có Hội đồng thành viên, chủ sở hữu sẽ bổ nhiệm các vị trí thành viên Hội đồng thành viên miễn nhiệm từ 03 đến 07 năm với nhiệm kì không được quá 05 năm.
# Pred tokens : ['đối', 'với', 'các', 'tổ', 'chức', 'cho', 'hs', 'nhận', 'xét', 'như', 'vậy', 'có', 'thể', 'sở', 'hữu', 'là', 'tổ', 'chức', '', 'sẽ', 'có', 'hội', 'đồng', 'thành', 'viên', '', 'chủ', 'sở', 'hữu', 'sẽ', 'bổ', 'nhiệm', 'các', 'vị', 'trí', 'thành', 'viên', 'hội', 'đồng', 'thành', 'viên', 'miễn', 'nhiệm', 'từ', '03', 'đến', '07', 'năm', 'với', 'nhiệm', 'kì', 'không', 'được', 'quá', '05', 'năm', '']
# Gold tokens : ['đối', 'với', 'công', 'ty', 'trách', 'nhiệm', 'hữu', 'hạn', 'một', 'thành', 'viên', 'có', 'chủ', 'sở', 'hữu', 'là', 'tổ', 'chức', '', 'sẽ', 'có', 'hội', 'đồng', 'thành', 'viên', '', 'chủ', 'sở', 'hữu', 'sẽ', 'bổ', 'nhiệm', 'các', 'vị', 'trí', 'thành', 'viên', 'hội', 'đồng', 'thành', 'viên', 'miễn', 'nhiệm', 'từ', '03', 'đến', '07', 'năm', 'với', 'nhiệm', 'kì', 'không', 'được', 'quá', '05', 'năm', '']
#
# # 65
# Predicted   : điều này phản ánh thực tế và các hoạt động học trong lao động và trong hoạt động thể dục, thể thao không được đánh giá cao, cần có sự cải thiện và thiết kế chương trình sao cho phù hợp với lứa tuổi mẫu giáo.
# Correct     : Điều này phản ánh thực tế là các hoạt động học trong lao động và trong hoạt động thể dục, thể thao không được đánh giá cao, cần có sự cải thiện và thiết kế chương trình sao cho phù hợp với lứa tuổi mẫu giáo.
# Pred tokens : ['điều', 'này', 'phản', 'ánh', 'thực', 'tế', 'và', 'các', 'hoạt', 'động', 'học', 'trong', 'lao', 'động', 'và', 'trong', 'hoạt', 'động', 'thể', 'dục', '', 'thể', 'thao', 'không', 'được', 'đánh', 'giá', 'cao', '', 'cần', 'có', 'sự', 'cải', 'thiện', 'và', 'thiết', 'kế', 'chương', 'trình', 'sao', 'cho', 'phù', 'hợp', 'với', 'lứa', 'tuổi', 'mẫu', 'giáo', '']
# Gold tokens : ['điều', 'này', 'phản', 'ánh', 'thực', 'tế', 'là', 'các', 'hoạt', 'động', 'học', 'trong', 'lao', 'động', 'và', 'trong', 'hoạt', 'động', 'thể', 'dục', '', 'thể', 'thao', 'không', 'được', 'đánh', 'giá', 'cao', '', 'cần', 'có', 'sự', 'cải', 'thiện', 'và', 'thiết', 'kế', 'chương', 'trình', 'sao', 'cho', 'phù', 'hợp', 'với', 'lứa', 'tuổi', 'mẫu', 'giáo', '']
#
# # 66
# Predicted   : cách thức liên kết giúp cho câu được hoàn chỉnh, mạch lạc hơn.
# Correct     : Các phép liên kết giúp cho câu được hoàn chỉnh, mạch lạc hơn.
# Pred tokens : ['cách', 'thức', 'liên', 'kết', 'giúp', 'cho', 'câu', 'được', 'hoàn', 'chỉnh', '', 'mạch', 'lạc', 'hơn', '']
# Gold tokens : ['các', 'phép', 'liên', 'kết', 'giúp', 'cho', 'câu', 'được', 'hoàn', 'chỉnh', '', 'mạch', 'lạc', 'hơn', '']
#
# # 72
# Predicted   : trong một số nước không quan tâm đến vấn đề này, khi nguồn viện trợ oda ngày càng tăng thì việc lãng phí đầu tư tràn lan cũng có xu hướng ngày càng tăng, nhất là giai đoạn đầu của vốn vay, khi nghĩa vụ trả nợ gốc còn ẩn giấu sau thời gian ân hạn.
# Correct     : Nhưng một số nước không quan tâm đến vấn đề này, khi nguồn viện trợ ODA ngày càng tăng thì việc lãng phí đầu tư tràn lan cũng có xu hướng ngày càng tăng, nhất là giai đoạn đầu của vốn vay, khi nghĩa vụ trả nợ gốc còn ẩn giấu sau thời gian ân hạn.
# Pred tokens : ['trong', 'một', 'số', 'nước', 'không', 'quan', 'tâm', 'đến', 'vấn', 'đề', 'này', '', 'khi', 'nguồn', 'viện', 'trợ', 'oda', 'ngày', 'càng', 'tăng', 'thì', 'việc', 'lãng', 'phí', 'đầu', 'tư', 'tràn', 'lan', 'cũng', 'có', 'xu', 'hướng', 'ngày', 'càng', 'tăng', '', 'nhất', 'là', 'giai', 'đoạn', 'đầu', 'của', 'vốn', 'vay', '', 'khi', 'nghĩa', 'vụ', 'trả', 'nợ', 'gốc', 'còn', 'ẩn', 'giấu', 'sau', 'thời', 'gian', 'ân', 'hạn', '']
# Gold tokens : ['nhưng', 'một', 'số', 'nước', 'không', 'quan', 'tâm', 'đến', 'vấn', 'đề', 'này', '', 'khi', 'nguồn', 'viện', 'trợ', 'oda', 'ngày', 'càng', 'tăng', 'thì', 'việc', 'lãng', 'phí', 'đầu', 'tư', 'tràn', 'lan', 'cũng', 'có', 'xu', 'hướng', 'ngày', 'càng', 'tăng', '', 'nhất', 'là', 'giai', 'đoạn', 'đầu', 'của', 'vốn', 'vay', '', 'khi', 'nghĩa', 'vụ', 'trả', 'nợ', 'gốc', 'còn', 'ẩn', 'giấu', 'sau', 'thời', 'gian', 'ân', 'hạn', '']
#
# # 74
# Predicted   : trong đề tài: rèn kỹ làm hai hệ thống hóa, hỗ trợ, tạo sự gắn bó chặt chẽ với nhau giữa các cơ sở đào tạo hoặc giữa các cơ sở đào tạo với các bài tập kiểu phân hóa học của học sinh ý thức và củng cố ở đồ thị.
# Correct     : Trong đào tạo, liên kết là hình thức phối hợp, hỗ trợ, tạo sự gắn bó chặt chẽ với nhau giữa các cơ sở đào tạo hoặc giữa các cơ sở đào tạo với các đối tác khác nhằm thực hiện các chức năng, nhiệm vụ của cơ sở đào tạo.
# Pred tokens : ['trong', 'đề', 'tài', '', 'rèn', 'kỹ', 'làm', 'hai', 'hệ', 'thống', 'hóa', '', 'hỗ', 'trợ', '', 'tạo', 'sự', 'gắn', 'bó', 'chặt', 'chẽ', 'với', 'nhau', 'giữa', 'các', 'cơ', 'sở', 'đào', 'tạo', 'hoặc', 'giữa', 'các', 'cơ', 'sở', 'đào', 'tạo', 'với', 'các', 'bài', 'tập', 'kiểu', 'phân', 'hóa', 'học', 'của', 'học', 'sinh', 'ý', 'thức', 'và', 'củng', 'cố', 'ở', 'đồ', 'thị', '']
# Gold tokens : ['trong', 'đào', 'tạo', '', 'liên', 'kết', 'là', 'hình', 'thức', 'phối', 'hợp', '', 'hỗ', 'trợ', '', 'tạo', 'sự', 'gắn', 'bó', 'chặt', 'chẽ', 'với', 'nhau', 'giữa', 'các', 'cơ', 'sở', 'đào', 'tạo', 'hoặc', 'giữa', 'các', 'cơ', 'sở', 'đào', 'tạo', 'với', 'các', 'đối', 'tác', 'khác', 'nhằm', 'thực', 'hiện', 'các', 'chức', 'năng', '', 'nhiệm', 'vụ', 'của', 'cơ', 'sở', 'đào', 'tạo', '']
#
# # 75
# Predicted   : sử dụng phương pháp này giúp xây dựng cơ sở dữ liệu không gian thuộc tính và mô hình dem bao gồm các bản đồ chuyên đề về hiện trạng khu vực châu á.
# Correct     : Sử dụng phương pháp này giúp xây dựng cơ sở dữ liệu không gian thuộc tính và mô hình DEM bao gồm các bản đồ chuyên đề về hiện trạng khu vực khai thác.
# Pred tokens : ['sử', 'dụng', 'phương', 'pháp', 'này', 'giúp', 'xây', 'dựng', 'cơ', 'sở', 'dữ', 'liệu', 'không', 'gian', 'thuộc', 'tính', 'và', 'mô', 'hình', 'dem', 'bao', 'gồm', 'các', 'bản', 'đồ', 'chuyên', 'đề', 'về', 'hiện', 'trạng', 'khu', 'vực', 'châu', 'á', '']
# Gold tokens : ['sử', 'dụng', 'phương', 'pháp', 'này', 'giúp', 'xây', 'dựng', 'cơ', 'sở', 'dữ', 'liệu', 'không', 'gian', 'thuộc', 'tính', 'và', 'mô', 'hình', 'dem', 'bao', 'gồm', 'các', 'bản', 'đồ', 'chuyên', 'đề', 'về', 'hiện', 'trạng', 'khu', 'vực', 'khai', 'thác', '']
#
# # 77
# Predicted   : để đánh giá được hoạt động kinh doanh của công ty thì song song với việc phân tích tình hình biến động của bđkh như: các từ có thể phân tích rõ tình hình biến động của chi phí qua các năm và xem xét biến động đó so với biến động của công ty.
# Correct     : Để đánh giá được hoạt động kinh doanh của công ty thì song song với việc phân tích tình hình biến động của doanh thu, chúng ta cần phải phân tích rõ tình hình biến động của chi phí qua các năm và xem xét biến động đó so với biến động của doanh thu.
# Pred tokens : ['để', 'đánh', 'giá', 'được', 'hoạt', 'động', 'kinh', 'doanh', 'của', 'công', 'ty', 'thì', 'song', 'song', 'với', 'việc', 'phân', 'tích', 'tình', 'hình', 'biến', 'động', 'của', 'bđkh', 'như', '', 'các', 'từ', 'có', 'thể', 'phân', 'tích', 'rõ', 'tình', 'hình', 'biến', 'động', 'của', 'chi', 'phí', 'qua', 'các', 'năm', 'và', 'xem', 'xét', 'biến', 'động', 'đó', 'so', 'với', 'biến', 'động', 'của', 'công', 'ty', '']
# Gold tokens : ['để', 'đánh', 'giá', 'được', 'hoạt', 'động', 'kinh', 'doanh', 'của', 'công', 'ty', 'thì', 'song', 'song', 'với', 'việc', 'phân', 'tích', 'tình', 'hình', 'biến', 'động', 'của', 'doanh', 'thu', '', 'chúng', 'ta', 'cần', 'phải', 'phân', 'tích', 'rõ', 'tình', 'hình', 'biến', 'động', 'của', 'chi', 'phí', 'qua', 'các', 'năm', 'và', 'xem', 'xét', 'biến', 'động', 'đó', 'so', 'với', 'biến', 'động', 'của', 'doanh', 'thu', '']
#
# # 80
# Predicted   : các tổ chức mà có các chức năng xác định, tư vấn giá đất và xác định giá rõ ràng, cụ thể.
# Correct     : Các tổ chức mà có các chức năng xác định, tư vấn giá đất và xác định giá rõ ràng cụ thể.
# Pred tokens : ['các', 'tổ', 'chức', 'mà', 'có', 'các', 'chức', 'năng', 'xác', 'định', '', 'tư', 'vấn', 'giá', 'đất', 'và', 'xác', 'định', 'giá', 'rõ', 'ràng', '', 'cụ', 'thể', '']
# Gold tokens : ['các', 'tổ', 'chức', 'mà', 'có', 'các', 'chức', 'năng', 'xác', 'định', '', 'tư', 'vấn', 'giá', 'đất', 'và', 'xác', 'định', 'giá', 'rõ', 'ràng', 'cụ', 'thể', '']
#
# # 83
# Predicted   : thiết kế hở cũng sẽ giúp người dùng, kỹ thuật viên dễ dàng quan sát, nhắc nhở các hư hỏng để dễ dàng vệ sinh, sửa chữa.
# Correct     : Thiết kế hở cũng sẽ giúp người dùng, kỹ thuật viên dễ dàng quan sát, nhận thấy các hư hỏng để dễ dàng vệ sinh, sửa chữa.
# Pred tokens : ['thiết', 'kế', 'hở', 'cũng', 'sẽ', 'giúp', 'người', 'dùng', '', 'kỹ', 'thuật', 'viên', 'dễ', 'dàng', 'quan', 'sát', '', 'nhắc', 'nhở', 'các', 'hư', 'hỏng', 'để', 'dễ', 'dàng', 'vệ', 'sinh', '', 'sửa', 'chữa', '']
# Gold tokens : ['thiết', 'kế', 'hở', 'cũng', 'sẽ', 'giúp', 'người', 'dùng', '', 'kỹ', 'thuật', 'viên', 'dễ', 'dàng', 'quan', 'sát', '', 'nhận', 'thấy', 'các', 'hư', 'hỏng', 'để', 'dễ', 'dàng', 'vệ', 'sinh', '', 'sửa', 'chữa', '']
#
# # 85
# Predicted   : do vậy, quan hệ giữa người bán lẻ và sỉ là quan hệ với nhau.
# Correct     : Do vậy, quan hệ giữa người bán lẻ và sỉ là quan hệ hai chiều
# Pred tokens : ['do', 'vậy', '', 'quan', 'hệ', 'giữa', 'người', 'bán', 'lẻ', 'và', 'sỉ', 'là', 'quan', 'hệ', 'với', 'nhau', '']
# Gold tokens : ['do', 'vậy', '', 'quan', 'hệ', 'giữa', 'người', 'bán', 'lẻ', 'và', 'sỉ', 'là', 'quan', 'hệ', 'hai', 'chiều']
#
# # 88
# Predicted   : cuối cùng, em cũng xin gửi lời cảm ơn đến người thân, bạn bè đã động viên, giúp đỡ, tạo điều kiện để em hoàn thành luận văn này.
# Correct     : Cuối cùng, em cũng xin gửi lời cảm ơn đến người thân bạn bè đã động viên, giúp đỡ, tạo điều kiện để em hoàn thành luận văn này.
# Pred tokens : ['cuối', 'cùng', '', 'em', 'cũng', 'xin', 'gửi', 'lời', 'cảm', 'ơn', 'đến', 'người', 'thân', '', 'bạn', 'bè', 'đã', 'động', 'viên', '', 'giúp', 'đỡ', '', 'tạo', 'điều', 'kiện', 'để', 'em', 'hoàn', 'thành', 'luận', 'văn', 'này', '']
# Gold tokens : ['cuối', 'cùng', '', 'em', 'cũng', 'xin', 'gửi', 'lời', 'cảm', 'ơn', 'đến', 'người', 'thân', 'bạn', 'bè', 'đã', 'động', 'viên', '', 'giúp', 'đỡ', '', 'tạo', 'điều', 'kiện', 'để', 'em', 'hoàn', 'thành', 'luận', 'văn', 'này', '']
#
# # 94
# Predicted   : hậu quả là cụm từ được nhiều tổ chức và công ty sử dụng để nói chung cho các loại rau và quả được sử dụng làm thực phẩm.
# Correct     : Rau quả là cụm từ được nhiều tổ chức và công ty sử dụng để nói chung cho các loại rau và quả được sử dụng làm thực phẩm.
# Pred tokens : ['hậu', 'quả', 'là', 'cụm', 'từ', 'được', 'nhiều', 'tổ', 'chức', 'và', 'công', 'ty', 'sử', 'dụng', 'để', 'nói', 'chung', 'cho', 'các', 'loại', 'rau', 'và', 'quả', 'được', 'sử', 'dụng', 'làm', 'thực', 'phẩm', '']
# Gold tokens : ['rau', 'quả', 'là', 'cụm', 'từ', 'được', 'nhiều', 'tổ', 'chức', 'và', 'công', 'ty', 'sử', 'dụng', 'để', 'nói', 'chung', 'cho', 'các', 'loại', 'rau', 'và', 'quả', 'được', 'sử', 'dụng', 'làm', 'thực', 'phẩm', '']
#
# # 95
# Predicted   : việc lập kế hoạch là cơ sở đảm bảo cho quá trình quản lí đạt hiệu quả cao, nó thay thế cho các hoạt động rời rạc, tùy tiện.
# Correct     : Việc lập kế hoạch là cơ sở đảm bảo cho quá trình quản lý đạt hiệu quả cao, nó thay thế cho các hoạt động rời rạc, tùy tiện.
# Pred tokens : ['việc', 'lập', 'kế', 'hoạch', 'là', 'cơ', 'sở', 'đảm', 'bảo', 'cho', 'quá', 'trình', 'quản', 'lí', 'đạt', 'hiệu', 'quả', 'cao', '', 'nó', 'thay', 'thế', 'cho', 'các', 'hoạt', 'động', 'rời', 'rạc', '', 'tùy', 'tiện', '']
# Gold tokens : ['việc', 'lập', 'kế', 'hoạch', 'là', 'cơ', 'sở', 'đảm', 'bảo', 'cho', 'quá', 'trình', 'quản', 'lý', 'đạt', 'hiệu', 'quả', 'cao', '', 'nó', 'thay', 'thế', 'cho', 'các', 'hoạt', 'động', 'rời', 'rạc', '', 'tùy', 'tiện', '']
#
# # 97
# Predicted   : dù đang ở đâu, trong khoảng thời gian nào thì cũng chỉ cần có một thiết bị điện tử (điện thoại, máy tính, các văn bản, …) thì chúng ta có thể mua bất cứ loại hàng hóa nào mình với vài thao tác đơn giản.
# Correct     : Dù đang ở đâu, trong khoảng thời gian nào thì cũng chỉ cần có một thiết bị điện tử (điện thoại, máy tính, máy tính bảng, …) thì chúng ta có thể mua bất cứ loại hàng hóa nào mình với vài thao tác đơn giản.
# Pred tokens : ['dù', 'đang', 'ở', 'đâu', '', 'trong', 'khoảng', 'thời', 'gian', 'nào', 'thì', 'cũng', 'chỉ', 'cần', 'có', 'một', 'thiết', 'bị', 'điện', 'tử', '', 'điện', 'thoại', '', 'máy', 'tính', '', 'các', 'văn', 'bản', '', '', '', 'thì', 'chúng', 'ta', 'có', 'thể', 'mua', 'bất', 'cứ', 'loại', 'hàng', 'hóa', 'nào', 'mình', 'với', 'vài', 'thao', 'tác', 'đơn', 'giản', '']
# Gold tokens : ['dù', 'đang', 'ở', 'đâu', '', 'trong', 'khoảng', 'thời', 'gian', 'nào', 'thì', 'cũng', 'chỉ', 'cần', 'có', 'một', 'thiết', 'bị', 'điện', 'tử', '', 'điện', 'thoại', '', 'máy', 'tính', '', 'máy', 'tính', 'bảng', '', '', '', 'thì', 'chúng', 'ta', 'có', 'thể', 'mua', 'bất', 'cứ', 'loại', 'hàng', 'hóa', 'nào', 'mình', 'với', 'vài', 'thao', 'tác', 'đơn', 'giản', '']
#
# # 98
# Predicted   : ngoài ra, đảng ủy bộ y tế cũng yêu cầu thành lập ban chỉ đạo cấp tỉnh, thành phố trực thuộc trung ương, ban chỉ đạo các bệnh viện để đưa ra kế hoạch chi tiết, cụ thể phù hợp cho từng địa phương và từng điều kiện cụ thể của các công việc.
# Correct     : Ngoài ra, Đảng ủy Bộ Y tế cũng yêu cầu thành lập ban chỉ đạo cấp tỉnh, thành phố trực thuộc trung ương, Ban chỉ đạo các bệnh viện để đưa ra kế hoạch chi tiết, cụ thể phù hợp cho từng địa phương và từng điều kiện cụ thể của các bệnh viện.
# Pred tokens : ['ngoài', 'ra', '', 'đảng', 'ủy', 'bộ', 'y', 'tế', 'cũng', 'yêu', 'cầu', 'thành', 'lập', 'ban', 'chỉ', 'đạo', 'cấp', 'tỉnh', '', 'thành', 'phố', 'trực', 'thuộc', 'trung', 'ương', '', 'ban', 'chỉ', 'đạo', 'các', 'bệnh', 'viện', 'để', 'đưa', 'ra', 'kế', 'hoạch', 'chi', 'tiết', '', 'cụ', 'thể', 'phù', 'hợp', 'cho', 'từng', 'địa', 'phương', 'và', 'từng', 'điều', 'kiện', 'cụ', 'thể', 'của', 'các', 'công', 'việc', '']
# Gold tokens : ['ngoài', 'ra', '', 'đảng', 'ủy', 'bộ', 'y', 'tế', 'cũng', 'yêu', 'cầu', 'thành', 'lập', 'ban', 'chỉ', 'đạo', 'cấp', 'tỉnh', '', 'thành', 'phố', 'trực', 'thuộc', 'trung', 'ương', '', 'ban', 'chỉ', 'đạo', 'các', 'bệnh', 'viện', 'để', 'đưa', 'ra', 'kế', 'hoạch', 'chi', 'tiết', '', 'cụ', 'thể', 'phù', 'hợp', 'cho', 'từng', 'địa', 'phương', 'và', 'từng', 'điều', 'kiện', 'cụ', 'thể', 'của', 'các', 'bệnh', 'viện', '']
#
# # 100
# Predicted   : khi đơn vị cung cấp uy tín lớn họp họp thác kính thế, mỹ thuật 18/9/1991.
# Correct     : Hiệp định về thành lập Ủy ban hỗn hợp hợp tác kinh tế, kỹ thuật 18/9/1991.
# Pred tokens : ['khi', 'đơn', 'vị', 'cung', 'cấp', 'uy', 'tín', 'lớn', 'họp', 'họp', 'thác', 'kính', 'thế', '', 'mỹ', 'thuật', '18', '', '9', '', '1991', '']
# Gold tokens : ['hiệp', 'định', 'về', 'thành', 'lập', 'ủy', 'ban', 'hỗn', 'hợp', 'hợp', 'tác', 'kinh', 'tế', '', 'kỹ', 'thuật', '18', '', '9', '', '1991', '']
#
# # 107
# Predicted   : đây là cơ hội và các bệnh lây lan với đó ảnh hưởng đến việc thái độ cá nhân đó đã làm cho sản xuất điện, nước, có khoảng gần 850 điểm):
# Correct     : Điều này có nghĩa là các bugi sấy loại mới có tính năng đạt được nhiệt độ cần thiết để đánh lửa nhanh hơn rất nhiều (850°C trong vòng 4 giây).
# Pred tokens : ['đây', 'là', 'cơ', 'hội', 'và', 'các', 'bệnh', 'lây', 'lan', 'với', 'đó', 'ảnh', 'hưởng', 'đến', 'việc', 'thái', 'độ', 'cá', 'nhân', 'đó', 'đã', 'làm', 'cho', 'sản', 'xuất', 'điện', '', 'nước', '', 'có', 'khoảng', 'gần', '850', 'điểm', '', '']
# Gold tokens : ['điều', 'này', 'có', 'nghĩa', 'là', 'các', 'bugi', 'sấy', 'loại', 'mới', 'có', 'tính', 'năng', 'đạt', 'được', 'nhiệt', 'độ', 'cần', 'thiết', 'để', 'đánh', 'lửa', 'nhanh', 'hơn', 'rất', 'nhiều', '', '850', '', 'c', 'trong', 'vòng', '4', 'giây', '', '']
#
# # 108
# Predicted   : kết quả chung của các nghiên cứu về trung quốc đều chỉ rõ vai trò của việc nằm cạnh biển đối với thu hút fdi.
# Correct     : Kết quả chung của các nghiên cứu về Trung Quốc đều chỉ ra vai trò của việc nằm cạnh biển đối với thu hút FDI.
# Pred tokens : ['kết', 'quả', 'chung', 'của', 'các', 'nghiên', 'cứu', 'về', 'trung', 'quốc', 'đều', 'chỉ', 'rõ', 'vai', 'trò', 'của', 'việc', 'nằm', 'cạnh', 'biển', 'đối', 'với', 'thu', 'hút', 'fdi', '']
# Gold tokens : ['kết', 'quả', 'chung', 'của', 'các', 'nghiên', 'cứu', 'về', 'trung', 'quốc', 'đều', 'chỉ', 'ra', 'vai', 'trò', 'của', 'việc', 'nằm', 'cạnh', 'biển', 'đối', 'với', 'thu', 'hút', 'fdi', '']
#
# # 109
# Predicted   : chi phí quảng cáo được nâng cao, đây là một hình thức mà khá nhiều các công ty áp dụng vào học sinh làm các sản phẩm đó dẫn đến từ thời tiết tại các ao ấp đụng khác nữa.
# Correct     : Chi phí quảng cáo được nâng cao, đây là một hình thức mà khá nhiều các công ty áp dụng và đặc biệt là các doanh nghiệp có vốn đầu tư trực tiếp từ nước ngoài áp dụng khá nhiều.
# Pred tokens : ['chi', 'phí', 'quảng', 'cáo', 'được', 'nâng', 'cao', '', 'đây', 'là', 'một', 'hình', 'thức', 'mà', 'khá', 'nhiều', 'các', 'công', 'ty', 'áp', 'dụng', 'vào', 'học', 'sinh', 'làm', 'các', 'sản', 'phẩm', 'đó', 'dẫn', 'đến', 'từ', 'thời', 'tiết', 'tại', 'các', 'ao', 'ấp', 'đụng', 'khác', 'nữa', '']
# Gold tokens : ['chi', 'phí', 'quảng', 'cáo', 'được', 'nâng', 'cao', '', 'đây', 'là', 'một', 'hình', 'thức', 'mà', 'khá', 'nhiều', 'các', 'công', 'ty', 'áp', 'dụng', 'và', 'đặc', 'biệt', 'là', 'các', 'doanh', 'nghiệp', 'có', 'vốn', 'đầu', 'tư', 'trực', 'tiếp', 'từ', 'nước', 'ngoài', 'áp', 'dụng', 'khá', 'nhiều', '']
#
# # 110
# Predicted   : s (1,2 - 5,6 % vào t. 4): mở rộng thị trường ra nước ngoài, củng cố uy tín, hình ảnh của công ty.
# Correct     : S (1,2,5,6) và T (4): Mở rộng thị trường ra nước ngoài, củng cố uy tín, hình ảnh của công ty.
# Pred tokens : ['s', '', '12', '', '56', '', 'vào', 't', '', '4', '', '', 'mở', 'rộng', 'thị', 'trường', 'ra', 'nước', 'ngoài', '', 'củng', 'cố', 'uy', 'tín', '', 'hình', 'ảnh', 'của', 'công', 'ty', '']
# Gold tokens : ['s', '', '1256', '', 'và', 't', '', '4', '', '', 'mở', 'rộng', 'thị', 'trường', 'ra', 'nước', 'ngoài', '', 'củng', 'cố', 'uy', 'tín', '', 'hình', 'ảnh', 'của', 'công', 'ty', '']
#
# # 113
# Predicted   : kết quả như sau: - với giáo viên: để biết được tình trạng của dạy học gdhn trong nhà trường tôi tiến hành phiếu hỏi ý kiến đối với các giáo viên trong trường thcs phùng chí kiên, nam định.
# Correct     : Kết quả khảo sát: - Với giáo viên: Để biết được thực trạng của dạy học GDHN trong nhà trường tôi tiến hành Phiếu hỏi ý kiến đối với các giáo viên trong trường THCS Phùng Chí Kiên, Nam Định.
# Pred tokens : ['kết', 'quả', 'như', 'sau', '', '', 'với', 'giáo', 'viên', '', 'để', 'biết', 'được', 'tình', 'trạng', 'của', 'dạy', 'học', 'gdhn', 'trong', 'nhà', 'trường', 'tôi', 'tiến', 'hành', 'phiếu', 'hỏi', 'ý', 'kiến', 'đối', 'với', 'các', 'giáo', 'viên', 'trong', 'trường', 'thcs', 'phùng', 'chí', 'kiên', '', 'nam', 'định', '']
# Gold tokens : ['kết', 'quả', 'khảo', 'sát', '', '', 'với', 'giáo', 'viên', '', 'để', 'biết', 'được', 'thực', 'trạng', 'của', 'dạy', 'học', 'gdhn', 'trong', 'nhà', 'trường', 'tôi', 'tiến', 'hành', 'phiếu', 'hỏi', 'ý', 'kiến', 'đối', 'với', 'các', 'giáo', 'viên', 'trong', 'trường', 'thcs', 'phùng', 'chí', 'kiên', '', 'nam', 'định', '']
#
# # 119
# Predicted   : đến khi kết thúc quá trình thì tất cả các nút trên mạng đều sẽ tìm ra được bước truyền kế tiếp tối ưu đến tất cả mọi đích, là công cụ hỗ trợ một nền văn hóa trong sản phẩm tối ưu.
# Correct     : Đến khi kết thúc quá trình thì tất cả các nút trên mạng đều sẽ tìm ra được bước truyền kế tiếp tối ưu đến tất cả mọi đích, và tổng chi phí tốt nhất nhờ vào thuật toán phân phối tối ưu.
# Pred tokens : ['đến', 'khi', 'kết', 'thúc', 'quá', 'trình', 'thì', 'tất', 'cả', 'các', 'nút', 'trên', 'mạng', 'đều', 'sẽ', 'tìm', 'ra', 'được', 'bước', 'truyền', 'kế', 'tiếp', 'tối', 'ưu', 'đến', 'tất', 'cả', 'mọi', 'đích', '', 'là', 'công', 'cụ', 'hỗ', 'trợ', 'một', 'nền', 'văn', 'hóa', 'trong', 'sản', 'phẩm', 'tối', 'ưu', '']
# Gold tokens : ['đến', 'khi', 'kết', 'thúc', 'quá', 'trình', 'thì', 'tất', 'cả', 'các', 'nút', 'trên', 'mạng', 'đều', 'sẽ', 'tìm', 'ra', 'được', 'bước', 'truyền', 'kế', 'tiếp', 'tối', 'ưu', 'đến', 'tất', 'cả', 'mọi', 'đích', '', 'và', 'tổng', 'chi', 'phí', 'tốt', 'nhất', 'nhờ', 'vào', 'thuật', 'toán', 'phân', 'phối', 'tối', 'ưu', '']
#
# # 120
# Predicted   : đây là môn học hiện đại với độ phủ sóng bởi đầu việt nam.
# Correct     : Đây là một thương hiệu mới với một thị trường mới đầy tiềm năng.
# Pred tokens : ['đây', 'là', 'môn', 'học', 'hiện', 'đại', 'với', 'độ', 'phủ', 'sóng', 'bởi', 'đầu', 'việt', 'nam', '']
# Gold tokens : ['đây', 'là', 'một', 'thương', 'hiệu', 'mới', 'với', 'một', 'thị', 'trường', 'mới', 'đầy', 'tiềm', 'năng', '']
#
# # 121
# Predicted   : thiệt hại về việc chưa sử dụng các dịch vụ 24 đơn, chiếm 9,20 %.
# Correct     : Khiếu nại về việc chưa sử dụng được dịch vụ 24 đơn, chiếm 9,20%.
# Pred tokens : ['thiệt', 'hại', 'về', 'việc', 'chưa', 'sử', 'dụng', 'các', 'dịch', 'vụ', '24', 'đơn', '', 'chiếm', '920', '', '']
# Gold tokens : ['khiếu', 'nại', 'về', 'việc', 'chưa', 'sử', 'dụng', 'được', 'dịch', 'vụ', '24', 'đơn', '', 'chiếm', '920', '', '']
#
# # 122
# Predicted   : sự kết hợp là yếu tố tinh thần trách nhiệm thực hiện chính sách ưu đãi đầu tư, rà soát, nhận và xử lý các khiếu nại của các nhà đầu tư và hỗ trợ việc thực hiện các dự án fdi.
# Correct     : Sở Kế hoạch và Đầu tư tỉnh chịu trách nhiệm thực hiện chính sách ưu đãi đầu tư, rà soát, nhận và xử lý các khiếu nại của các nhà đầu tư và hỗ trợ việc thực hiện các dự án FDI.
# Pred tokens : ['sự', 'kết', 'hợp', 'là', 'yếu', 'tố', 'tinh', 'thần', 'trách', 'nhiệm', 'thực', 'hiện', 'chính', 'sách', 'ưu', 'đãi', 'đầu', 'tư', '', 'rà', 'soát', '', 'nhận', 'và', 'xử', 'lý', 'các', 'khiếu', 'nại', 'của', 'các', 'nhà', 'đầu', 'tư', 'và', 'hỗ', 'trợ', 'việc', 'thực', 'hiện', 'các', 'dự', 'án', 'fdi', '']
# Gold tokens : ['sở', 'kế', 'hoạch', 'và', 'đầu', 'tư', 'tỉnh', 'chịu', 'trách', 'nhiệm', 'thực', 'hiện', 'chính', 'sách', 'ưu', 'đãi', 'đầu', 'tư', '', 'rà', 'soát', '', 'nhận', 'và', 'xử', 'lý', 'các', 'khiếu', 'nại', 'của', 'các', 'nhà', 'đầu', 'tư', 'và', 'hỗ', 'trợ', 'việc', 'thực', 'hiện', 'các', 'dự', 'án', 'fdi', '']
#
# # 126
# Predicted   : các chi phí bán hàng, họ có cơ sở hạ trợ trực tiếp từ chính phủ cho doanh nghiệp không còn phù hợp với quy định của evfta.
# Correct     : Chính sách chậm ban hành: Hiện các chính sách hỗ trợ trực tiếp từ Chính phủ cho doanh nghiệp không còn phù hợp với quy định của EVFTA.
# Pred tokens : ['các', 'chi', 'phí', 'bán', 'hàng', '', 'họ', 'có', 'cơ', 'sở', 'hạ', 'trợ', 'trực', 'tiếp', 'từ', 'chính', 'phủ', 'cho', 'doanh', 'nghiệp', 'không', 'còn', 'phù', 'hợp', 'với', 'quy', 'định', 'của', 'evfta', '']
# Gold tokens : ['chính', 'sách', 'chậm', 'ban', 'hành', '', 'hiện', 'các', 'chính', 'sách', 'hỗ', 'trợ', 'trực', 'tiếp', 'từ', 'chính', 'phủ', 'cho', 'doanh', 'nghiệp', 'không', 'còn', 'phù', 'hợp', 'với', 'quy', 'định', 'của', 'evfta', '']
#
# # 127
# Predicted   : thứ nhất làm 75 g vào đó hoàn toàn thay đổi từ mô hình b 100), nhưng tỉ lệ học sinh chưa nắm vững kiến thức của các trạm thông tin thứ cấp và trẻ cũng như với cả các biện pháp trên sâu sắc hơn nữa để nâng cao hiệu quả dạy học.
# Correct     : Thấp nhất là 75% và có nhiều biện pháp được thầy cô đồng ý 100%, nhưng tỉ lệ học sinh chưa nắm vững kiến thức của các trường cũng còn khá cao vì thế cần phải nghiên cứu các biện pháp trên sâu sắc hơn nữa để nâng cao hiệu quả dạy học.
# Pred tokens : ['thứ', 'nhất', 'làm', '75', 'g', 'vào', 'đó', 'hoàn', 'toàn', 'thay', 'đổi', 'từ', 'mô', 'hình', 'b', '100', '', '', 'nhưng', 'tỉ', 'lệ', 'học', 'sinh', 'chưa', 'nắm', 'vững', 'kiến', 'thức', 'của', 'các', 'trạm', 'thông', 'tin', 'thứ', 'cấp', 'và', 'trẻ', 'cũng', 'như', 'với', 'cả', 'các', 'biện', 'pháp', 'trên', 'sâu', 'sắc', 'hơn', 'nữa', 'để', 'nâng', 'cao', 'hiệu', 'quả', 'dạy', 'học', '']
# Gold tokens : ['thấp', 'nhất', 'là', '75', '', 'và', 'có', 'nhiều', 'biện', 'pháp', 'được', 'thầy', 'cô', 'đồng', 'ý', '100', '', '', 'nhưng', 'tỉ', 'lệ', 'học', 'sinh', 'chưa', 'nắm', 'vững', 'kiến', 'thức', 'của', 'các', 'trường', 'cũng', 'còn', 'khá', 'cao', 'vì', 'thế', 'cần', 'phải', 'nghiên', 'cứu', 'các', 'biện', 'pháp', 'trên', 'sâu', 'sắc', 'hơn', 'nữa', 'để', 'nâng', 'cao', 'hiệu', 'quả', 'dạy', 'học', '']
#
# # 136
# Predicted   : đầu thế kỉ xx, các nhà khoa học phương tây tìm ra các biện pháp dạy học với mục đích khai thác cái cá thể dựa trên những thành tựu lý luận của tâm lý học, xem con người với tư cách là con người cá thể.
# Correct     : Đầu thế kỉ XX, các nhà khoa học phương Tây tìm ra các phương pháp dạy học với mục đích khai thác cái cá thể dựa trên những thành tựu lý luận của Tâm lý học, xem con người với tư cách là con người cá thể.
# Pred tokens : ['đầu', 'thế', 'kỉ', 'xx', '', 'các', 'nhà', 'khoa', 'học', 'phương', 'tây', 'tìm', 'ra', 'các', 'biện', 'pháp', 'dạy', 'học', 'với', 'mục', 'đích', 'khai', 'thác', 'cái', 'cá', 'thể', 'dựa', 'trên', 'những', 'thành', 'tựu', 'lý', 'luận', 'của', 'tâm', 'lý', 'học', '', 'xem', 'con', 'người', 'với', 'tư', 'cách', 'là', 'con', 'người', 'cá', 'thể', '']
# Gold tokens : ['đầu', 'thế', 'kỉ', 'xx', '', 'các', 'nhà', 'khoa', 'học', 'phương', 'tây', 'tìm', 'ra', 'các', 'phương', 'pháp', 'dạy', 'học', 'với', 'mục', 'đích', 'khai', 'thác', 'cái', 'cá', 'thể', 'dựa', 'trên', 'những', 'thành', 'tựu', 'lý', 'luận', 'của', 'tâm', 'lý', 'học', '', 'xem', 'con', 'người', 'với', 'tư', 'cách', 'là', 'con', 'người', 'cá', 'thể', '']
#
# # 137
# Predicted   : song song với ảnh hưởng đến thực hiện và hình thức, tự giáo dục cần tổ chức đánh giá rõ nét nhất về đều đề mới và nâng cấp cơ sở đào tạo.
# ...
# Correct     : Tận dụng tối đa cơ giới nhất là đối với những công việc nặng, phải kết hợp tốt giữa máy thi công chủ đạo với các thiết bị hỗ trợ khác, kết hợp giữa máy và thi công thủ công.
# Pred tokens : ['tăng', 'cường', 'tối', 'đa', 'cơ', 'giới', 'nhất', 'là', 'đối', 'với', 'những', 'công', 'việc', 'nặng', '', 'phải', 'kết', 'hợp', 'tốt', 'giữa', 'máy', 'thi', 'công', 'chủ', 'đạo', 'với', 'các', 'thiết', 'bị', 'hỗ', 'trợ', 'khác', '', 'kết', 'hợp', 'giữa', 'mỹ', 'và', 'phơi', 'nắng', 'thủ', 'công', '']
# Gold tokens : ['tận', 'dụng', 'tối', 'đa', 'cơ', 'giới', 'nhất', 'là', 'đối', 'với', 'những', 'công', 'việc', 'nặng', '', 'phải', 'kết', 'hợp', 'tốt', 'giữa', 'máy', 'thi', 'công', 'chủ', 'đạo', 'với', 'các', 'thiết', 'bị', 'hỗ', 'trợ', 'khác', '', 'kết', 'hợp', 'giữa', 'máy', 'và', 'thi', 'công', 'thủ', 'công', '']
#
# # 1967
# Predicted   : giá trị của h càng cao có nghĩa là doanh nghiệp thu về được càng nhiều trên mỗi đồng chi phí là đưa ra cho hà cho nhân thọ là loại hình thanh toán l khi phân phối hiệu quả và cần có các biện pháp để cải thiện tình hình trên.
# Correct     : Giá trị của H càng cao có nghĩa là doanh nghiệp thu về được càng nhiều trên mỗi đồng chi phí và giá trị của H càng thấp nghĩa là doanh nghiệp đang quản lý chi phí chưa hiệu quả và cần có các biện pháp để cải thiện tình hình trên.
# Pred tokens : ['giá', 'trị', 'của', 'h', 'càng', 'cao', 'có', 'nghĩa', 'là', 'doanh', 'nghiệp', 'thu', 'về', 'được', 'càng', 'nhiều', 'trên', 'mỗi', 'đồng', 'chi', 'phí', 'là', 'đưa', 'ra', 'cho', 'hà', 'cho', 'nhân', 'thọ', 'là', 'loại', 'hình', 'thanh', 'toán', 'l', 'khi', 'phân', 'phối', 'hiệu', 'quả', 'và', 'cần', 'có', 'các', 'biện', 'pháp', 'để', 'cải', 'thiện', 'tình', 'hình', 'trên', '']
# Gold tokens : ['giá', 'trị', 'của', 'h', 'càng', 'cao', 'có', 'nghĩa', 'là', 'doanh', 'nghiệp', 'thu', 'về', 'được', 'càng', 'nhiều', 'trên', 'mỗi', 'đồng', 'chi', 'phí', 'và', 'giá', 'trị', 'của', 'h', 'càng', 'thấp', 'nghĩa', 'là', 'doanh', 'nghiệp', 'đang', 'quản', 'lý', 'chi', 'phí', 'chưa', 'hiệu', 'quả', 'và', 'cần', 'có', 'các', 'biện', 'pháp', 'để', 'cải', 'thiện', 'tình', 'hình', 'trên', '']
#
# # 1970
# Predicted   : một số khó khăn chuẩn bị cẩn thận và giá trị các mục tiêu tốn để làm. vị dự, công nghệ đang được bán).
# Correct     : Mua sự không chắc chắn bị bản chất và giá trị của các yếu tố đầu vào (ví dụ, công nghệ đang được bán).
# Pred tokens : ['một', 'số', 'khó', 'khăn', 'chuẩn', 'bị', 'cẩn', 'thận', 'và', 'giá', 'trị', 'các', 'mục', 'tiêu', 'tốn', 'để', 'làm', '', 'vị', 'dự', '', 'công', 'nghệ', 'đang', 'được', 'bán', '', '']
# Gold tokens : ['mua', 'sự', 'không', 'chắc', 'chắn', 'bị', 'bản', 'chất', 'và', 'giá', 'trị', 'của', 'các', 'yếu', 'tố', 'đầu', 'vào', '', 'ví', 'dụ', '', 'công', 'nghệ', 'đang', 'được', 'bán', '', '']
#
# # 1971
# Predicted   : tác giả đã khẳng định rằng, nếu hoạt động quản lý không tốt thì quá trình giáo dục và đào tạo trong nhà trường cũng không đạt được những mục tiêu như mong muốn.
# Correct     : Thực tiễn đã chứng minh rằng, nếu hoạt động quản lý không tốt thì quá trình giáo dục và đào tạo trong nhà trường cũng không đạt được những mục tiêu như mong muốn.
# Pred tokens : ['tác', 'giả', 'đã', 'khẳng', 'định', 'rằng', '', 'nếu', 'hoạt', 'động', 'quản', 'lý', 'không', 'tốt', 'thì', 'quá', 'trình', 'giáo', 'dục', 'và', 'đào', 'tạo', 'trong', 'nhà', 'trường', 'cũng', 'không', 'đạt', 'được', 'những', 'mục', 'tiêu', 'như', 'mong', 'muốn', '']
# Gold tokens : ['thực', 'tiễn', 'đã', 'chứng', 'minh', 'rằng', '', 'nếu', 'hoạt', 'động', 'quản', 'lý', 'không', 'tốt', 'thì', 'quá', 'trình', 'giáo', 'dục', 'và', 'đào', 'tạo', 'trong', 'nhà', 'trường', 'cũng', 'không', 'đạt', 'được', 'những', 'mục', 'tiêu', 'như', 'mong', 'muốn', '']
#
# # 1973
# Predicted   : để đảm bảo nguồn vốn đầu tư cho phát triển, các tác giả đưa ra vào hai nguồn: vốn tích lũy trong nước và vốn nước ngoài.
# Correct     : Để đảm bảo nguồn vốn đầu tư cho phát triển, các quốc gia đều dựa vào hai nguồn: vốn tích lũy trong nước và vốn nước ngoài.
# Pred tokens : ['để', 'đảm', 'bảo', 'nguồn', 'vốn', 'đầu', 'tư', 'cho', 'phát', 'triển', '', 'các', 'tác', 'giả', 'đưa', 'ra', 'vào', 'hai', 'nguồn', '', 'vốn', 'tích', 'lũy', 'trong', 'nước', 'và', 'vốn', 'nước', 'ngoài', '']
# Gold tokens : ['để', 'đảm', 'bảo', 'nguồn', 'vốn', 'đầu', 'tư', 'cho', 'phát', 'triển', '', 'các', 'quốc', 'gia', 'đều', 'dựa', 'vào', 'hai', 'nguồn', '', 'vốn', 'tích', 'lũy', 'trong', 'nước', 'và', 'vốn', 'nước', 'ngoài', '']
#
# # 1974
# Predicted   : về cơ bản, điểm tương đồng giữa dạy học chủ đề và dạy học truyền thống là vẫn coi trọng việc lĩnh hội một nội dung kiến thức nền tảng, vì thế dạy học theo chủ đề là mô hình dạy học có thể vận dụng vào thực tiễn hiện nay dễ dàng hơn một số môn học khác.
# Correct     : Về cơ bản, điểm tương đồng giữa dạy học chủ đề và dạy học truyền thống là vẫn coi trọng việc lĩnh hội một nội dung kiến thức nền tảng, vì thế dạy học theo chủ đề là mô hình dạy học có thể vận dụng vào thực tiễn hiện nay dễ dàng hơn một số mô hình khác.
# Pred tokens : ['về', 'cơ', 'bản', '', 'điểm', 'tương', 'đồng', 'giữa', 'dạy', 'học', 'chủ', 'đề', 'và', 'dạy', 'học', 'truyền', 'thống', 'là', 'vẫn', 'coi', 'trọng', 'việc', 'lĩnh', 'hội', 'một', 'nội', 'dung', 'kiến', 'thức', 'nền', 'tảng', '', 'vì', 'thế', 'dạy', 'học', 'theo', 'chủ', 'đề', 'là', 'mô', 'hình', 'dạy', 'học', 'có', 'thể', 'vận', 'dụng', 'vào', 'thực', 'tiễn', 'hiện', 'nay', 'dễ', 'dàng', 'hơn', 'một', 'số', 'môn', 'học', 'khác', '']
# Gold tokens : ['về', 'cơ', 'bản', '', 'điểm', 'tương', 'đồng', 'giữa', 'dạy', 'học', 'chủ', 'đề', 'và', 'dạy', 'học', 'truyền', 'thống', 'là', 'vẫn', 'coi', 'trọng', 'việc', 'lĩnh', 'hội', 'một', 'nội', 'dung', 'kiến', 'thức', 'nền', 'tảng', '', 'vì', 'thế', 'dạy', 'học', 'theo', 'chủ', 'đề', 'là', 'mô', 'hình', 'dạy', 'học', 'có', 'thể', 'vận', 'dụng', 'vào', 'thực', 'tiễn', 'hiện', 'nay', 'dễ', 'dàng', 'hơn', 'một', 'số', 'mô', 'hình', 'khác', '']
#
# # 1975
# Predicted   : điều gì cũng bị ảnh thuế ngày càng được trang bị những kiến thức chuyên sâu, chuyên nghiệp, có các kỹ năng quản lý thuế hiện đại, các kỹ năng áp dụng, sử dụng các phương tiện điện tử trong việc phân tích, đánh giá, tổng hợp, . . .
# Correct     : Đội ngũ cán bộ ngành thuế ngày càng được trang bị những kiến thức chuyên sâu, chuyên nghiệp, có các kỹ năng quản lý thuế hiện đại, các kỹ năng áp dụng, sử dụng các phương tiện điện tử trong việc phân tích, đánh giá, tổng hợp, . . .
# Pred tokens : ['điều', 'gì', 'cũng', 'bị', 'ảnh', 'thuế', 'ngày', 'càng', 'được', 'trang', 'bị', 'những', 'kiến', 'thức', 'chuyên', 'sâu', '', 'chuyên', 'nghiệp', '', 'có', 'các', 'kỹ', 'năng', 'quản', 'lý', 'thuế', 'hiện', 'đại', '', 'các', 'kỹ', 'năng', 'áp', 'dụng', '', 'sử', 'dụng', 'các', 'phương', 'tiện', 'điện', 'tử', 'trong', 'việc', 'phân', 'tích', '', 'đánh', 'giá', '', 'tổng', 'hợp', '', '', '', '']
# Gold tokens : ['đội', 'ngũ', 'cán', 'bộ', 'ngành', 'thuế', 'ngày', 'càng', 'được', 'trang', 'bị', 'những', 'kiến', 'thức', 'chuyên', 'sâu', '', 'chuyên', 'nghiệp', '', 'có', 'các', 'kỹ', 'năng', 'quản', 'lý', 'thuế', 'hiện', 'đại', '', 'các', 'kỹ', 'năng', 'áp', 'dụng', '', 'sử', 'dụng', 'các', 'phương', 'tiện', 'điện', 'tử', 'trong', 'việc', 'phân', 'tích', '', 'đánh', 'giá', '', 'tổng', 'hợp', '', '', '', '']
#
# # 1979
# Predicted   : ngoài ra, giáo viên nghiên cứu đã đề xuất, chỉnh sửa các thang đo của thuyết hành vi dự định cho phù hợp với đối tượng nghiên cứu.
# Correct     : Ngoài ra, sinh viên nghiên cứu đã đề xuất, chỉnh sửa các thang đo của Thuyết hành vi dự định cho phù hợp với môi trường nghiên cứu.
# Pred tokens : ['ngoài', 'ra', '', 'giáo', 'viên', 'nghiên', 'cứu', 'đã', 'đề', 'xuất', '', 'chỉnh', 'sửa', 'các', 'thang', 'đo', 'của', 'thuyết', 'hành', 'vi', 'dự', 'định', 'cho', 'phù', 'hợp', 'với', 'đối', 'tượng', 'nghiên', 'cứu', '']
# Gold tokens : ['ngoài', 'ra', '', 'sinh', 'viên', 'nghiên', 'cứu', 'đã', 'đề', 'xuất', '', 'chỉnh', 'sửa', 'các', 'thang', 'đo', 'của', 'thuyết', 'hành', 'vi', 'dự', 'định', 'cho', 'phù', 'hợp', 'với', 'môi', 'trường', 'nghiên', 'cứu', '']
#
# # 1982
# Predicted   : tác giả có thể đọc một tờ báo in dễ dàng ở bất cứ đâu, trên bất kì phương tiện đi lại nào.
# Correct     : Độc giả có thể đọc một tờ báo in dễ dàng ở bất cứ đâu, trên bất kì phương tiện đi lại nào.
# Pred tokens : ['tác', 'giả', 'có', 'thể', 'đọc', 'một', 'tờ', 'báo', 'in', 'dễ', 'dàng', 'ở', 'bất', 'cứ', 'đâu', '', 'trên', 'bất', 'kì', 'phương', 'tiện', 'đi', 'lại', 'nào', '']
# Gold tokens : ['độc', 'giả', 'có', 'thể', 'đọc', 'một', 'tờ', 'báo', 'in', 'dễ', 'dàng', 'ở', 'bất', 'cứ', 'đâu', '', 'trên', 'bất', 'kì', 'phương', 'tiện', 'đi', 'lại', 'nào', '']
#
# # 1983
# Predicted   : th thích hợp như: tự trắc nghiệm bằng hệ thống câu hỏi trắc nghiệm khách quan; trắc nghiệm tự luận, hoặc tự so sánh kết quả học tập của mình với kết quả đạt được gv xác nhận.
# Correct     : TH thích hợp như: tự trắc nghiệm bằng hệ thống câu hỏi trắc nghiệm khách quan; trắc nghiệm tự luận, hoặc tự so sánh kết quả học tập của mình với kết quả đúng được GV xác nhận.
# Pred tokens : ['th', 'thích', 'hợp', 'như', '', 'tự', 'trắc', 'nghiệm', 'bằng', 'hệ', 'thống', 'câu', 'hỏi', 'trắc', 'nghiệm', 'khách', 'quan', '', 'trắc', 'nghiệm', 'tự', 'luận', '', 'hoặc', 'tự', 'so', 'sánh', 'kết', 'quả', 'học', 'tập', 'của', 'mình', 'với', 'kết', 'quả', 'đạt', 'được', 'gv', 'xác', 'nhận', '']
# Gold tokens : ['th', 'thích', 'hợp', 'như', '', 'tự', 'trắc', 'nghiệm', 'bằng', 'hệ', 'thống', 'câu', 'hỏi', 'trắc', 'nghiệm', 'khách', 'quan', '', 'trắc', 'nghiệm', 'tự', 'luận', '', 'hoặc', 'tự', 'so', 'sánh', 'kết', 'quả', 'học', 'tập', 'của', 'mình', 'với', 'kết', 'quả', 'đúng', 'được', 'gv', 'xác', 'nhận', '']
#
# # 1986
# Predicted   : kêu gọi đầu tư là làm tăng thêm hơn 12.500 căn hộ phục vụ tái định cư khu siêu đô thị thủ thiêm.
# Correct     : Khu tái định cư này nằm trong chương trình 12.500 căn hộ phục vụ tái định cư khu siêu đô thị Thủ Thiêm.
# Pred tokens : ['kêu', 'gọi', 'đầu', 'tư', 'là', 'làm', 'tăng', 'thêm', 'hơn', '12', '', '500', 'căn', 'hộ', 'phục', 'vụ', 'tái', 'định', 'cư', 'khu', 'siêu', 'đô', 'thị', 'thủ', 'thiêm', '']
# Gold tokens : ['khu', 'tái', 'định', 'cư', 'này', 'nằm', 'trong', 'chương', 'trình', '12', '', '500', 'căn', 'hộ', 'phục', 'vụ', 'tái', 'định', 'cư', 'khu', 'siêu', 'đô', 'thị', 'thủ', 'thiêm', '']
#
# # 1987
# Predicted   : thúc đẩy bán hàng: một trong những lý do quan trọng mà công ty nên sử dụng email marketing là chúng có thể được đưa vào vận hành.
# Correct     : Thúc đẩy bán hàng: Một trong những lý do quan trọng mà công ty nên sử dụng email marketing là chúng có thể thúc đẩy việc bán hàng.
# Pred tokens : ['thúc', 'đẩy', 'bán', 'hàng', '', 'một', 'trong', 'những', 'lý', 'do', 'quan', 'trọng', 'mà', 'công', 'ty', 'nên', 'sử', 'dụng', 'email', 'marketing', 'là', 'chúng', 'có', 'thể', 'được', 'đưa', 'vào', 'vận', 'hành', '']
# Gold tokens : ['thúc', 'đẩy', 'bán', 'hàng', '', 'một', 'trong', 'những', 'lý', 'do', 'quan', 'trọng', 'mà', 'công', 'ty', 'nên', 'sử', 'dụng', 'email', 'marketing', 'là', 'chúng', 'có', 'thể', 'thúc', 'đẩy', 'việc', 'bán', 'hàng', '']
#
# # 1988
# Predicted   : nhìn chung các rào cản phi thuế quan được áp dụng phổ biến giữa quan hệ thương mại quốc tế gây khó khăn cho ngành hàng thủy sản xuất chè.
# Correct     : Nhìn chung các rào cản phi thuế quan được áp dụng phổ biến giữa quan hệ thương mại quốc tế gây khó khăn cho ngành hàng thủy sản xuất khẩu.
# Pred tokens : ['nhìn', 'chung', 'các', 'rào', 'cản', 'phi', 'thuế', 'quan', 'được', 'áp', 'dụng', 'phổ', 'biến', 'giữa', 'quan', 'hệ', 'thương', 'mại', 'quốc', 'tế', 'gây', 'khó', 'khăn', 'cho', 'ngành', 'hàng', 'thủy', 'sản', 'xuất', 'chè', '']
# Gold tokens : ['nhìn', 'chung', 'các', 'rào', 'cản', 'phi', 'thuế', 'quan', 'được', 'áp', 'dụng', 'phổ', 'biến', 'giữa', 'quan', 'hệ', 'thương', 'mại', 'quốc', 'tế', 'gây', 'khó', 'khăn', 'cho', 'ngành', 'hàng', 'thủy', 'sản', 'xuất', 'khẩu', '']
#
# # 1989
# Predicted   : web server - web server là nơi quản trị viên trực tiếp thực hiện các thao tác để điều khiển của xe.
# Correct     : Web Server - Web server là nơi quản trị viên trực tiếp thực hiện các thao tác để điều khiển các node.
# Pred tokens : ['web', 'server', '', 'web', 'server', 'là', 'nơi', 'quản', 'trị', 'viên', 'trực', 'tiếp', 'thực', 'hiện', 'các', 'thao', 'tác', 'để', 'điều', 'khiển', 'của', 'xe', '']
# Gold tokens : ['web', 'server', '', 'web', 'server', 'là', 'nơi', 'quản', 'trị', 'viên', 'trực', 'tiếp', 'thực', 'hiện', 'các', 'thao', 'tác', 'để', 'điều', 'khiển', 'các', 'node', '']
#
# # 1990
# Predicted   : nền kinh tế, công ty cổ phần thương mại đầu tư thịnh vượng.
# Correct     : Tên công ty: Công ty Cô phần Thương mại đầu tư Thịnh Vượng.
# Pred tokens : ['nền', 'kinh', 'tế', '', 'công', 'ty', 'cổ', 'phần', 'thương', 'mại', 'đầu', 'tư', 'thịnh', 'vượng', '']
# Gold tokens : ['tên', 'công', 'ty', '', 'công', 'ty', 'cô', 'phần', 'thương', 'mại', 'đầu', 'tư', 'thịnh', 'vượng', '']
#
# # 1993
# Predicted   : chính vì sự thiếu hụt nguồn lao động có trình độ cao, dẫn đến năng lực sản xuất ra các sản phẩm gỗ việt nam vẫn còn thấp.
# Correct     : Chính vì sự thiếu hụt nguồn lao động có trình độ cao, dẫn đến năng lực sản xuất của các doanh nghiệp gỗ Việt Nam vẫn còn thấp.
# Pred tokens : ['chính', 'vì', 'sự', 'thiếu', 'hụt', 'nguồn', 'lao', 'động', 'có', 'trình', 'độ', 'cao', '', 'dẫn', 'đến', 'năng', 'lực', 'sản', 'xuất', 'ra', 'các', 'sản', 'phẩm', 'gỗ', 'việt', 'nam', 'vẫn', 'còn', 'thấp', '']
# Gold tokens : ['chính', 'vì', 'sự', 'thiếu', 'hụt', 'nguồn', 'lao', 'động', 'có', 'trình', 'độ', 'cao', '', 'dẫn', 'đến', 'năng', 'lực', 'sản', 'xuất', 'của', 'các', 'doanh', 'nghiệp', 'gỗ', 'việt', 'nam', 'vẫn', 'còn', 'thấp', '']
#
# # 1996
# Predicted   : kính thưa ban giám đốc và mảnh đất văn vật, có truyền thống cách mạng, nhiều danh nhân văn hóa và anh hùng dân tộc.
# Correct     : Quảng Trạch còn biết đến là vùng đất văn vật, có truyền thống cách mạng, nhiều danh nhân văn hóa và anh hùng dân tộc.
# Pred tokens : ['kính', 'thưa', 'ban', 'giám', 'đốc', 'và', 'mảnh', 'đất', 'văn', 'vật', '', 'có', 'truyền', 'thống', 'cách', 'mạng', '', 'nhiều', 'danh', 'nhân', 'văn', 'hóa', 'và', 'anh', 'hùng', 'dân', 'tộc', '']
# Gold tokens : ['quảng', 'trạch', 'còn', 'biết', 'đến', 'là', 'vùng', 'đất', 'văn', 'vật', '', 'có', 'truyền', 'thống', 'cách', 'mạng', '', 'nhiều', 'danh', 'nhân', 'văn', 'hóa', 'và', 'anh', 'hùng', 'dân', 'tộc', '']
#
# # 1997
# Predicted   : tổ chức quốc tế về tiêu chuẩn hóa iso, trong dự thảo dis 9000: 2000, đã đưa ra định nghĩa sau: chất lượng là khả năng của tập hợp các đặc trưng của một sản phẩm, hệ thống hay quá lớn để đáp ứng các yêu cầu của khách hàng mà chỉ cần có chiến tranh.
# Correct     : Tổ chức Quốc tế về tiêu chuẩn hóa ISO, trong dự thảo DIS 9000: 2000, đã đưa ra định nghĩa sau: Chất lượng là khả năng của tập hợp các đặc tính của một sản phẩm, hệ thống hay quá trình để đáp ứng các yêu cầu của khách hàng và các bên có liên quan.
# Pred tokens : ['tổ', 'chức', 'quốc', 'tế', 'về', 'tiêu', 'chuẩn', 'hóa', 'iso', '', 'trong', 'dự', 'thảo', 'dis', '9000', '', '2000', '', 'đã', 'đưa', 'ra', 'định', 'nghĩa', 'sau', '', 'chất', 'lượng', 'là', 'khả', 'năng', 'của', 'tập', 'hợp', 'các', 'đặc', 'trưng', 'của', 'một', 'sản', 'phẩm', '', 'hệ', 'thống', 'hay', 'quá', 'lớn', 'để', 'đáp', 'ứng', 'các', 'yêu', 'cầu', 'của', 'khách', 'hàng', 'mà', 'chỉ', 'cần', 'có', 'chiến', 'tranh', '']
# Gold tokens : ['tổ', 'chức', 'quốc', 'tế', 'về', 'tiêu', 'chuẩn', 'hóa', 'iso', '', 'trong', 'dự', 'thảo', 'dis', '9000', '', '2000', '', 'đã', 'đưa', 'ra', 'định', 'nghĩa', 'sau', '', 'chất', 'lượng', 'là', 'khả', 'năng', 'của', 'tập', 'hợp', 'các', 'đặc', 'tính', 'của', 'một', 'sản', 'phẩm', '', 'hệ', 'thống', 'hay', 'quá', 'trình', 'để', 'đáp', 'ứng', 'các', 'yêu', 'cầu', 'của', 'khách', 'hàng', 'và', 'các', 'bên', 'có', 'liên', 'quan', '']
# === Kết quả đánh giá ===
# 🔍 Detection (Phát hiện lỗi):
# Precision: 0.1649
# Recall   : 0.3587
# F1       : 0.2260
#
# 🛠️ Correction (Sửa lỗi):
# Precision: 0.0000
# Recall   : 0.0000
# F1       : 0.0000
