# %%
import pandas as pd

# %%
def min_edit_distance(s1, s2):
    """
    Tính khoảng cách chỉnh sửa (Levenshtein distance) giữa hai từ s1 và s2.
    Hỗ trợ tiếng Việt có dấu, đa ký tự.

    Trả về: số bước chỉnh sửa tối thiểu để biến s1 thành s2.
    """
    len_s1 = len(s1)
    len_s2 = len(s2)

    # Khởi tạo ma trận khoảng cách
    dp = [[0] * (len_s2 + 1) for _ in range(len_s1 + 1)]

    # Khoảng cách từ "" đến s1 hoặc s2
    for i in range(len_s1 + 1):
        dp[i][0] = i
    for j in range(len_s2 + 1):
        dp[0][j] = j

    # Tính khoảng cách
    for i in range(1, len_s1 + 1):
        for j in range(1, len_s2 + 1):
            cost = 0 if s1[i-1] == s2[j-1] else 1

            dp[i][j] = min(
                dp[i-1][j] + 1,      # xóa
                dp[i][j-1] + 1,      # thêm
                dp[i-1][j-1] + cost  # thay thế
            )
    # print(dp)
    return dp[len_s1][len_s2]

# %%
print(min_edit_distance("nhận", "nhân"))  # → 1
print(min_edit_distance("nhan", "cảh"))  # → 1
print(min_edit_distance("công", "cung"))  # → 1
print(min_edit_distance("công", "công"))  # → 0
# Out:
# 1
# 4
# 1
# 0

# %%
test = pd.read_csv("/kaggle/input/preprocessing/test.csv")
test = test[['text', 'preprocess', 'correct_text']]
test
# Out:
#                                                    text  \
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giam mà còn tăng thê...
# 3     Đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chù nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
#                                              preprocess  \
# 0     thông qua công tác tuyên truyền, vận động này ...
# 1     do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     giữ được chỉ số này không giam mà còn tăng thê...
# 3     đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  tuy nhiên, khi nói đến e-learning, các phương ...
# 8963  đứng trước những hành vi đi ngược lại với đạo ...
# 8964  quan điểm biện chứng của chù nghĩa mác - lênin...
# 8965  đối với biểu đồ histogram, nếu giá trị trung b...
# 8966  trong mỗi khu vực mà đội phát triển thị trường...
#
#                                            correct_text
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giảm mà còn tăng thê...
# 3     Đứng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chủ nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
# [8967 rows x 3 columns]

# %%
train = pd.read_csv("/kaggle/input/preprocessing/train.csv")
train
# Out:
#                                                       text  \
# 0                                   Chây ì nộp phạt nguội.
# 1                                  Chây ì ngộp phạt nguội.
# 2                                    Chây i nộp phạt ngội.
# 3        Hàng chục ngàn phươngg tiện bị ghi hình iv phạ...
# 4        Hàng chục ngàn phương tiệng bị ghy hình vi pha...
# ...                                                    ...
# 4980399  Phó thủ tướngg cũng yêu cầu hoàn thành cổ phầc...
# 4980400  Phó thủ tướng cũng Iu cầu hoờn thành cổ phần ó...
# 4980401  Phó thũ tướngx cũng yêu cầu hoàn thành cổ phần...
# 4980402  Pho thủ tướng cũng iu cầu hoàn thàh cổ phần hó...
# 4980403  Pho thủ tướngd cũng yêu vàu hoàn thành cổ phần...
#
#                                               correct_text
# 0                                   Chây ì nộp phạt nguội.
# 1                                   Chây ì nộp phạt nguội.
# 2                                   Chây ì nộp phạt nguội.
# 3        Hàng chục ngàn phương tiện bị ghi hình vi phạm...
# 4        Hàng chục ngàn phương tiện bị ghi hình vi phạm...
# ...                                                    ...
# 4980399  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980400  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980401  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980402  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980403  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
#
# [4980404 rows x 2 columns]

# %%
unique_correct_texts = pd.read_csv('/kaggle/input/preprocessing/unique_correct_texts.csv')
unique_correct_texts
# Out:
#                                            correct_text
# 0     Cung cấp những thông tin về tình hình kinh tế ...
# 1     Đảng, Nhà nước Việt Nam luôn coi trọng yếu tố ...
# 2     Việc giảng dạy mang lại cho hs những kiến thức...
# 3     Kết quả nghiên cứu cho thấy Môi trường giáo dụ...
# 4     Ứng dụng môi trường công nghệ đến các hoạt độn...
# ...                                                 ...
# 9326  Cấp trên của Giám đốc điều hành là Hội đồng qu...
# 9327  Theo nghĩa hẹp, nợ công bao gồm nghĩa vụ nợ củ...
# 9328  Cụ thể, trong phần nội dung sẽ có sự tập trung...
# 9329  Ví dụ khi đọc bài thơ Mẹ nếu câu cuối Mẹ là ng...
# 9330  Trong mỗi khu vực mà đội phát triển thị trường...
#
# [9331 rows x 1 columns]

# %% [markdown]
# ## 1. Tiền xử lý dữ liệu
# - Chuẩn hóa các câu đúng (lowercase, loại bỏ ký tự không cần thiết).
#
# - Tách từ và sinh ra mô hình 3-gram từ tập văn bản đúng.
#
# - Tạo tập từ vựng (vocab) gồm tất cả các từ đã xuất hiện.

# %%
import re
import pandas as pd

def clean_punctuation(text):
    # 0. Handle NaN values (already present)
    if pd.isnull(text):
        return text
    
    # Ensure text is a string (important for mixed data types in a DataFrame column)
    text = str(text)

    # --- Punctuation Normalization (Order matters!) ---

    # 1. Normalize ellipses: Ensure all sequences of 2 or more periods become '...'
    #    e.g., ".." -> "...", "...." -> "..."
    text = re.sub(r'\.{2,}', '...', text)

    # 2. Handle numbers with periods/commas (e.g., 1 . 2 -> 1.2, 1,000 -> 1,000)
    #    This is crucial to do early, before general space removal around punctuation.
    text = re.sub(r'(?<=\d)\s*([.,])\s*(?=\d)', r'\1', text)

    # 3. Remove quotation marks (single and double) entirely as per requirement #6
    #    This simplifies later rules as we don't need to account for them.
    text = re.sub(r'[\'"]', '', text)

    # 4. Consolidate repeated punctuation (e.g., '!!' -> '!', '???' -> '?')
    #    This excludes ellipses, which were handled in step 1.
    #    If you want to preserve '!!!' as '!!!', remove this rule or modify it.
    text = re.sub(r'([.,!?;:])\1+', r'\1', text)
    
    # 5. Standardize spacing around punctuation and parentheses
    
    # 5.1 Remove any space immediately before common punctuation (.,!?:;) and ellipses (...)
    #    e.g., "hello ." -> "hello.", "word ..." -> "word..."
    text = re.sub(r'\s+([.,!?:;])', r'\1', text)
    text = re.sub(r'\s+(\.\.\.)', r'\1', text) # Specific for ellipses

    # 5.2 Add space after punctuation (except when it's part of a number)
    text = re.sub(r'(?<!\d)([.,])(?!\d)(?=\S)', r'\1 ', text)
    text = re.sub(r'(?<=[!?;:])(?=\S)', r' \g<0>', text)  # safe spacing for other punctuations
    text = re.sub(r'(\.\.\.)(?=\S)', r'\1 ', text)  # ellipsis spacing

    # 5.3 Handle parentheses spacing (section #5 in original)
    #    Remove any spaces immediately inside or around parentheses:
    #    e.g., " ( hello ) " -> "(hello)", " (hello" -> "(hello"
    text = re.sub(r'\s*([()])\s*', r'\1', text)
    #    Add space before opening parenthesis if preceded by a word character:
    #    e.g., "word(content)" -> "word (content)"
    text = re.sub(r'(?<=\w)\(', ' (', text)
    #    Add space after closing parenthesis if followed by a word character:
    #    e.g., "(content)word" -> "(content) word"
    text = re.sub(r'\)(?=\w)', ') ', text)

    # --- Final Cleanup ---

    # 6. Reduce multiple spaces to single spaces (section #7 in original)
    text = re.sub(r'\s{2,}', ' ', text)

    # 7. Strip leading/trailing whitespace (already present)
    return text.strip()

# %%
clean_punctuation("13,5 triêu")
# Out:
# '13,5 triêu'

# %%
import re
from collections import defaultdict, Counter
from nltk.tokenize import word_tokenize
import nltk
import string

nltk.download('punkt')


import re

def clean_text(text):
    # Thay thế URL trước
    text = re.sub(r'https?://\S+|www\.\S+', '<url>', text)

    # Thay thế emoji bằng <emoji>
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U0001F700-\U0001F77F"  # alchemical
        u"\U0001F780-\U0001F7FF"  # geometric
        u"\U0001F800-\U0001F8FF"  # arrows
        u"\U0001F900-\U0001F9FF"  # supplemental symbols
        u"\U0001FA00-\U0001FA6F"  # chess
        u"\U0001FA70-\U0001FAFF"  # symbols extended
        u"\u2600-\u26FF"          # misc symbols
        u"\u2700-\u27BF"          # dingbats
        "]+", flags=re.UNICODE
    )
    text = emoji_pattern.sub('<emoji>', text)

    # Thay thế định dạng ngày (dd/mm/yyyy hoặc yyyy/mm/dd)
    text = re.sub(r'\b\d{1,2}[-/]\d{1,2}[-/]\d{2,4}\b', '<date>', text)
    text = re.sub(r'\b\d{4}[-/]\d{1,2}[-/]\d{1,2}\b', '<date>', text)

    # Thay thế thời gian (hh:mm hoặc hh:mm:ss)
    text = re.sub(r'\b\d{1,2}:\d{2}(:\d{2})?\b', '<time>', text)

    # Thay thế số (gồm số thập phân và số nguyên)
    text = re.sub(r'\d+([.,]\d+)?', '<num>', text)

    return text
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import re
from nltk.tokenize import word_tokenize

def custom_tokenize(text):
    # 1. Tìm các token đặc biệt dạng <...>
    special_tokens = list(set(re.findall(r'<[^<> ]+>', text)))
    token_map = {token: f"___SPECIALTOKEN{i}___" for i, token in enumerate(special_tokens)}

    # 2. Thay thế token đặc biệt bằng placeholder
    for orig, placeholder in token_map.items():
        text = text.replace(orig, placeholder
                           )

    # 3. Tách các placeholder nếu dính vào từ hoặc ký tự đặc biệt
    for placeholder in token_map.values():
        text = re.sub(rf'({re.escape(placeholder)})([^\W_]+)', r'\1 \2', text)
        text = re.sub(rf'([^\W_]+)({re.escape(placeholder)})', r'\1 \2', text)
        text = re.sub(rf'({re.escape(placeholder)})([/%°\-+=±≥<>\.])', r'\1 \2', text)
        text = re.sub(rf'([/%°\-+=±≥<>\.])({re.escape(placeholder)})', r'\1 \2', text)

    # 4. TÁCH CÁC DẤU NHƯ / - … ... THÀNH TOKEN RIÊNG
    # Chèn khoảng trắng quanh các ký hiệu phân tách
    text = re.sub(r'([/\-+=±%°₫.<>\[\]…])', r' \1 ', text)
    text = re.sub(r'\.\.\.', ' ... ', text)  # tách "..." riêng
    text = re.sub(r'…', ' … ', text)        # tách dấu ba chấm unicode riêng

    # 5. Token hóa
    tokens = word_tokenize(text)

    # 6. Thay lại placeholder bằng token đặc biệt gốc
    reverse_map = {v: k for k, v in token_map.items()}
    tokens = [reverse_map.get(t, t) for t in tokens]

    return tokens

# %%
text = "Ngày 12/06/2024 lúc 08:45, 30-days giá là 13.78triệu đồng 😂 www.example.com 12/3"
cleaned = clean_text(text)
print("Sau khi clean:", cleaned)
tokens = custom_tokenize(cleaned)
print("Token:", tokens)
# Out:
# Sau khi clean: Ngày <date> lúc <time>, <num>-days giá là <num>triệu đồng <emoji> <url> <num>/<num>
# Token: ['Ngày', '<date>', 'lúc', '<time>', ',', '<num>', '-', 'days', 'giá', 'là', '<num>', 'triệu', 'đồng', '<emoji>', '<url>', '<num>', '/', '<num>']

# %%
def preprocess(texts):
    ngrams = defaultdict(Counter)
    vocab = set()

    for text in texts:
        text = clean_punctuation(text)
        text = clean_text(text)
        tokens = custom_tokenize(text.lower())

        # Thêm token đặc biệt cho đầu và cuối câu
        tokens = ['<start1>', '<start2>'] + tokens + ['<end1>', '<end2>']

        vocab.update(tokens)

        for i in range(2, len(tokens)):
            context = (tokens[i - 2], tokens[i - 1])
            word = tokens[i]
            ngrams[context][word] += 1

    return ngrams, vocab

# %% [markdown]
# ## 2. Tính toán xác suất chuyển tiếp (Transition Probability)
# - Dựa trên mô hình 3-gram: P(w₃ | w₁, w₂)
#
# - Với mỗi bộ ba liên tiếp (w₁, w₂, w₃) trong văn bản đúng, đếm tần suất xuất hiện.
#
# - Chuẩn hóa tần suất để có xác suất chuyển tiếp giữa các từ đúng theo ngữ cảnh.

# %%
def get_transition_prob(ngrams, vocab, alpha=1.0):
    transition_prob = {}
    context_totals = {}

    V = len(vocab)

    for context, counter in ngrams.items():
        total = sum(counter.values())
        context_totals[context] = total

        for word, count in counter.items():
            prob = (count + alpha) / (total + alpha * V)
            trigram = (context[0], context[1], word)
            transition_prob[trigram] = prob

    return transition_prob, context_totals

# %% [markdown]
# ## 3. Tính xác suất phát xạ (Emission Probability)
# - Mỗi từ sai (quan sát được) có thể phát ra từ một số từ đúng.
#
# - Dựa vào Minimum Edit Distance giữa từ sai và từng từ đúng trong từ điển.
#
# - Những từ đúng có khoảng cách nhỏ nhất được coi là ứng viên thay thế hợp lý, và được gán xác suất tỷ lệ nghịch với khoảng cách.

# %%
def get_emission_prob(observed_word, vocab, max_distance=5):
    target_distance = min(len(observed_word) - 1, max_distance)
    candidates = []
    for word in vocab:
        dist = min_edit_distance(observed_word, word)
        if dist <= target_distance:
            candidates.append((word, dist))

    if not candidates:
        # Dự phòng: nếu không có ứng viên đúng khoảng cách thì fallback
        candidates = [(word, min_edit_distance(observed_word, word)) for word in vocab
                      if min_edit_distance(observed_word, word) <= max_distance]

        if not candidates:
            return {}

    # for word, dist in candidates:
        # print(f"  - '{word}' (khoảng cách: {dist})")

    # Tính xác suất ngược lại với khoảng cách
    probs = {}
    for word, dist in candidates:
        prob = 1 / (1 + dist)
        probs[word] = prob

    # Chuẩn hóa
    total = sum(probs.values())
    for word in probs:
        probs[word] /= total

    return probs

# %% [markdown]
# ## 4. Thuật toán Viterbi (Giải mã chuỗi tối ưu)
# - Với chuỗi từ quan sát (câu cần sửa), tìm chuỗi từ đúng (ẩn) sao cho:
#     - Xác suất tổng (transition * emission) là lớn nhất.
# - Áp dụng Viterbi để tìm dãy từ đúng có xác suất cao nhất, từng bước một, sử dụng:
#     - Các từ ứng viên ở mỗi bước (từ có khoảng cách edit nhỏ với từ đầu vào).
#     - Xác suất chuyển tiếp giữa các từ ứng viên liên tiếp (3-gram).

# %%
from math import log

def viterbi(observed, vocab, ngrams, transition_prob, context_totals, alpha, epsilon=1e-8):
    # Thêm token đặc biệt vào đầu và cuối
    observed = ['<start1>', '<start2>'] + observed + ['<end1>', '<end2>']
    T = len(observed)
    V = [{} for _ in range(T)]
    path = {}

    vocab_size = len(vocab)

    # Khởi tạo bước đầu tiên tại vị trí t=2 (vì t=0,1 là <start>)
    emis_probs = get_emission_prob(observed[2], vocab)
    for y in emis_probs:
        context = ('<start1>', '<start2>')
        count = ngrams.get(context, {}).get(y, 0)
        total = context_totals.get(context, 0)
        trans_prob = (count + alpha) / (total + alpha * vocab_size)
        emis_prob = emis_probs.get(y, epsilon)

        V[2][y] = log(trans_prob + epsilon) + log(emis_prob + epsilon)
        path[y] = ['<start1>', '<start2>', y]

    # Duyệt từ t = 3 trở đi
    for t in range(3, T):
        emis_probs = get_emission_prob(observed[t], vocab)
        V[t] = {}
        newpath = {}

        for y in emis_probs:
            max_prob = float('-inf')
            best_prev = None

            for y1 in V[t - 1]:  # trạng thái trước
                y0 = path[y1][-2]  # từ trước của y1
                context = (y0, y1)
                count = ngrams.get(context, {}).get(y, 0)
                total = context_totals.get(context, 0)
                trans_prob = (count + alpha) / (total + alpha * vocab_size)
                emis_prob = emis_probs.get(y, epsilon)

                prob = V[t - 1][y1] + log(trans_prob + epsilon) + log(emis_prob + epsilon)

                if prob > max_prob:
                    max_prob = prob
                    best_prev = y1

            if best_prev is not None:
                V[t][y] = max_prob
                newpath[y] = path[best_prev] + [y]

        if not newpath:
            raise ValueError(f"No valid path at step {t}. Check transition/emission coverage.")
        path = newpath

    # Tìm chuỗi có xác suất cao nhất ở bước cuối
    n = T - 1
    prob, state = max((V[n][y], y) for y in V[n])
    return path[state]

# %% [markdown]
# ## 5. Tái tạo câu đã sửa
# - Chuỗi từ đúng tìm được là kết quả sau khi sửa.
#
# - Ghép lại các từ theo đúng thứ tự để tạo thành câu đã sửa lỗi.

# %%
import re

def clean_text_with_mapping(text):
    replacements = {
        "<url>": [],
        "<emoji>": [],
        "<date>": [],
        "<time>": [],
        "<num>": [],
    }

    # Danh sách các pattern với placeholder ưu tiên
    patterns = [
        (r'https?://\S+|www\.\S+', "<url>"),
        ("[" + u"\U0001F600-\U0001F64F"
             + u"\U0001F300-\U0001F5FF"
             + u"\U0001F680-\U0001F6FF"
             + u"\U0001F1E0-\U0001F1FF"
             + u"\u2600-\u26FF"
             + u"\u2700-\u27BF" + "]", "<emoji>"),
        (r'\b\d{1,2}[-/]\d{1,2}[-/]\d{2,4}\b', "<date>"),   # dd/mm/yyyy hoặc dd-mm-yyyy
        (r'\b\d{4}[-/]\d{1,2}[-/]\d{1,2}\b', "<date>"),     # yyyy/mm/dd hoặc yyyy-mm-dd
        (r'\b\d{1,2}:\d{2}(?::\d{2})?\b', "<time>"),        # hh:mm hoặc hh:mm:ss
        (r'\d+(?:[.,]\d+)?', "<num>"),                     # số thực hoặc số nguyên
    ]

    # Ghi lại vị trí đã thay để tránh chồng lặp
    replaced = [False] * len(text)
    new_text = ""
    last_pos = 0
    matches = []

    for pattern, placeholder in patterns:
        for match in re.finditer(pattern, text):
            start, end = match.start(), match.end()
            if any(replaced[start:end]):
                continue  # Tránh thay chồng

            matches.append((start, end, match.group(), placeholder))
            for i in range(start, end):
                replaced[i] = True  # Đánh dấu đã xử lý

    # Sắp xếp lại theo thứ tự xuất hiện
    matches.sort()
    last_pos = 0
    for start, end, original, placeholder in matches:
        new_text += text[last_pos:start]
        new_text += placeholder
        replacements[placeholder].append(original)
        last_pos = end

    new_text += text[last_pos:]
    return new_text, replacements

# %%
text = "Hôm nay là 2024-12-01, mai là 02/12/2024 và 14:30. Website là https://openai.com và giá là 12.345,67₫ 😊"
cleaned, repl = clean_text_with_mapping(text)

print("➡ Văn bản sau khi clean:", cleaned)
print("➡ Mapping:")
for k, v in repl.items():
    print(f"  {k}: {v}")
# Out:
# ➡ Văn bản sau khi clean: Hôm nay là <date>, mai là <date> và <time>. Website là <url> và giá là <num>,<num>₫ <emoji>
# ➡ Mapping:
#   <url>: ['https://openai.com']
#   <emoji>: ['😊']
#   <date>: ['2024-12-01', '02/12/2024']
#   <time>: ['14:30']
#   <num>: ['12.345', '67']

# %%
clean_text(text)
# Out:
# 'Hôm nay là <date>, mai là <date> và <time>. Website là <url> và giá là <num>,<num>₫ <emoji>'

# %%
from collections import defaultdict

def restore_tokens(tokens, replacements):
    # Đếm số lần đã dùng của mỗi placeholder

    print(tokens)
    counts = {k: 0 for k in replacements}

    restored = []
    for token in tokens:
        if token in replacements:
            index = counts[token]
            if index < len(replacements[token]):
                restored.append(replacements[token][index])
                counts[token] += 1
            else:
                # Trường hợp placeholder nhiều hơn số bản ghi, giữ nguyên
                restored.append(token)
        else:
            restored.append(token)

    return restored

# %%
def correct_text(input_text, vocab, ngrams, transition_prob, context_totals, alpha):
    # print("\n===== Bắt đầu sửa lỗi chính tả =====")

    # 1. Làm sạch dấu câu
    input_text = clean_punctuation(input_text.lower())

    # 2. Chuẩn hóa và ghi nhớ các token đặc biệt
    cleaned_text, replacements = clean_text_with_mapping(input_text.lower())
    
    # 3. Tách từ (với xử lý placeholder dính liền)
    tokens = custom_tokenize(cleaned_text)

    # print(f"Tách từ sau clean: {tokens}")
    # print(f"Replacements: {replacements}")

    # 4. Xác định token cần sửa và giữ nguyên
    special_placeholders = set(replacements.keys())
    to_correct = []
    mask = []  # True nếu cần sửa

    for t in tokens:
        if t in special_placeholders:
            to_correct.append(t)
            mask.append(False)
        else:
            to_correct.append(t)
            mask.append(True)

    # 5. Sửa lỗi chính tả bằng Viterbi
    # tokens = [t for t, m in zip(to_correct, mask) if m]
    # print("input for viterbi ", tokens)
    corrected_tokens = viterbi(tokens, vocab, ngrams, transition_prob, context_totals, alpha)
    corrected_tokens = corrected_tokens[2:-2]
    # print("corrected tokens ",corrected_tokens)
    
    # 7. Khôi phục placeholder thành gốc
    restored = restore_tokens(corrected_tokens, replacements)

    # 8. Ghép lại thành văn bản hoàn chỉnh
    corrected_text = ' '.join(restored)

    corrected_text = clean_punctuation(corrected_text)

    # print("\n===== Hoàn tất sửa lỗi =====")
    print(f"Kết quả sau sửa: {corrected_text}")

    return corrected_text

# %%
# Step 1: huấn luyện với tập văn bản đúng
texts = list(unique_correct_texts['correct_text'])
ngrams, vocab = preprocess(texts)
transition_prob, context_totals = get_transition_prob(ngrams, vocab, alpha=0.5)
print(len(ngrams))
print(vocab)
# Out:
# 82696
# {'ws', 'epc', 'bây', 'thương', 'nodejs', 'thung', 'chống', 'giơnevơ', 'em', 'man', 'nứt', 'nung', 'mà', 'cục', 'lớn', 'môn', 'hut', 'imgroup', 'tua', 'economic', 'bong', 'đích', 'ngân', 'ibm', 'mạ', 'ngòi', 'rau', 'lội', 'thâm', 'container', 'background', 'coppha', 'trào', 'ổn', 'khiêm', 'manpower', 'hoại', 'ten', 'nre', 'stft', 'global', 'truy', 'kttt', 'câu', 'rách', 'hào', 'sòng', 'hôm', 'xilanh', 'pr', 'vksndtc', 'nhưng', 'vắt', 'đổng', 'hích', 'ngon', 'lưỡng', 'ròng', 'circle', 'thcs', 'net', 'hđqt', 'mail', 'lượng', 'thuẫn', 'spin', 'unit', 'để', 'mãnh', 'ưu', 'cpe', 'route', 'request', 'arabica', 'ẩn', 'internet', 'will', 'mẫu', 'media', 'khắc', 'geogebra', 'quyền', 'asphalt', 'cách', 'lập', 'trùng', 'nợ', 'đong', 'thạo', 'trật', 'haberler', 'lưới', 'etl', 'thtt', 'dãi', 'mún', 'bát', 'trái', 'like', 'axetic', 'mờ', 'ftp', 'fiber', 'viển', 'grep', '–tn', 'trực', 'tẩu', 'trù', 'hạt', 'struct', 'ở', 'bé', 'lãm', 'binh', 'bitum', 'thực', 'đỗ', 'khâu', 'smart', 'based', 'xử', 'cauchy', 'chạm', 'aaker', 'far', 'ingress', 'ninh', 'sac', 'lút', 'quên', 'thoi', 'trọt', 'stem', 'peroxid', 'bức', 'thừa', 'tmđt', 'xúc', 'vết', 'cảng', 'lưỡi', 'soe', 'hoạn', 'pwa', 'nhiệt', 'hàng', 'dưới', 'powerpoint', 'đ', 'vks', '<num>', 'all', '<source>', '/', 'kqht', 'dẹp', 'bảng', 'manh', 'ngu', 'bọt', 'juergen', 'ào', 'ắt', 'khứu', 'bóc', 'unesco', 'võ', 'tụt', 'ipcc', 'group', 'toán', 'plvn', 'vẫy', 'archibald', 'virusshare', 'top', 'talk', 'rệt', 'wqi', 'nhấn', 'thúc', 'key', 'tt', 'nhìn', 'kè', 'điều', 'messages', 'hận', 'destroy', 'đem', 'chẽ', 'logistics', 'lãi', ']', 'arndt', 'nếp', 'vietjetair', 'niño', 'chừ', 'bừa', 'mc', 'elasticsearch', 'ut', 'đủ', 'hầm', 'angular', 'vọng', 'sarbanes', 'trót', 'wcdma', 'rét', 'nhòe', 'bữa', 'thậm', 'khoác', 'camnangceo', 'pha', '<start1>', 'vời', 'chíp', 'canada', 'chỗ', 'ndvn', 'rườm', 'quỹ', 'pe', 'nam', 'hơn', 'chùm', 'crawler', 'knth', 'iras', 'làm', 'tivi', 'giếng', 'tmcp', 'rộng', 'suy', 'calculator', 'acb', 'nẵng', 'hạm', 'nhóm', 'đọng', 'nghĩ', 'cam', 'lẽ', 'phía', 'thiết', 'vì', 'nhượng', 'cent', 'càng', 'thưởng', 'simple', 'ico', 'nguyễn', 'chuyện', 'gốm', 'map', 'tu', 'freedom', 'phá', 'thomsson', 'bằng', 'chàng', 'quản', 'mập', 'ngừ', 'khoảng', 'bơ', 'nắng', 'golang', 'dunford', 'hlkhxhvn', 'bot', 'tròn', 'ap', 'hít', 'apec', 'sar', 'form', 'boj', 'phủ', 'thờ', 'nổi', 'broadman', 'ht', 'lẽo', 'aws', 'se', 'lợi', 'mpos', 'giỏ', 'csc', 'dianetillman', 'vitme', 'total', 'pisa', 'kiện', 'dàng', 'dán', 'khiếu', 'factor', 'gds', 'khuynh', 'soạn', 'nd', 'snapfish', 'openflow', 'bptt', 'nạ', 'mộng', 'scheduler', 'xí', 'ngay', 'đắng', 'vạt', 'heat', 'lướt', 'quặc', 'wr', 'vựng', 'ngăn', 'hướng', 'drx', 'cồn', 'hồn', 'đón', 'vu', 'file', 'hidrocacbon', 'sinh', 'hường', 'jayasinghe', 'kỳ', 'thúy', 'vecto', 'dọa', 'olkin', 'sau', 'nhập', 'thuận', 'kg', 'vài', 'cân', 'nhyt', '[', 'henri', 'bịa', 'tai', 'tinh', 'khiếp', 'hòn', 'hài', 'miệng', 'triệt', 'bhxh', 'xoắn', 'staple', 'ipa', 'rưỡi', 'kênh', 'tập', 'quán', 'root', 'xã', 'ván', 'lagged', 'xếp', 'thói', 'hợi', 'exel', 'bể', 'center', 'hermann', 'thư', 'giấc', 'giường', 'lật', 'gpmb', 'cecem', 'bánh', 'lầm', 'iv', 'cbtd', 'nồng', 'lây', 'hà', 'chat', 'no', 'tĩnh', 'thí', 'nhòa', 'gv', 'đời', 'france', 'ueb', 'nhôm', 'dong', 'mua', 'item', 'biến', 'thiếu', 'nhở', 'okinawa', 'google', 'úc', 'danh', 'chết', 'bạn', 'bởi', 'cào', 'kpmg', 'dis', 'amadeo', 'thổ', 'debt', 'user', 'any', 'seo', 'log', 'spam', 'băng', 'fletcher', 'rượi', 'pentek', 'dựa', 'diệp', 'kaengnam', 'ofdm', 'pss', 'phất', 'ghg', 'gồm', 'asset', 'chôn', 'pp', 'score', 'hắc', 'benzen', 'ứ', 'tầm', 'hàn', 'tham', 'rác', 'ký', 'âm', 'khổ', 'đam', 'chập', 'xạ', 'mọc', 'dmz', 'đại', 'activating', 'vốn', 'đôi', 'làng', 'trượt', 'vsat', 'ozon', 'đề', 'mỏng', 'sự', 'kdqt', 'whitmore', 'sdk', 'miss', 'backpropagation', 'eigenvalue', 'sales', 'vision', 'lợ', 'sứ', 'price', 'ray', 'plus', 'ovretveit', 'bí', 'nhọn', 'cnv', 'ths', 'keller', 'xnk', 'lặng', 'rang', 'nhẹ', 'asian', 'mậu', 'nhả', ' ...

# %%
# Step 2: sửa lỗi
wrong_text = "thông qua công tác tuyên truyeenf, van động này phu huynh sẽ hiểu rỏ hơn tầm quan trọng của việc giáo dục."
corrected = correct_text(wrong_text, vocab, ngrams, transition_prob, context_totals, alpha=0.001)
# Out:
# ['thông', 'qua', 'công', 'tác', 'tuyên', 'truyền', ',', 'vận', 'động', 'này', 'phụ', 'huynh', 'sẽ', 'hiểu', 'rõ', 'hơn', 'tầm', 'quan', 'trọng', 'của', 'việc', 'giáo', 'dục', '.']
# Kết quả sau sửa: thông qua công tác tuyên truyền, vận động này phụ huynh sẽ hiểu rõ hơn tầm quan trọng của việc giáo dục.

# %%
wrong_text = "quan điểm biện chứng của chù nghĩa mác - lênin không chỉ khẳng định tính khách quan, tính phổ biến của các mối liên hệ mà còn nhấn mạnh tin phong phú, đa dạng của các mối liên hệ."
corrected = correct_text(wrong_text, vocab, ngrams, transition_prob, context_totals, alpha=0.01)
# Out:
# ['quan', 'điểm', 'biện', 'chứng', 'của', 'chủ', 'nghĩa', 'mác', '-', 'lênin', 'không', 'chỉ', 'khẳng', 'định', 'tính', 'khách', 'quan', ',', 'tính', 'phổ', 'biến', 'của', 'các', 'mối', 'quan', 'hệ', 'mà', 'còn', 'nhấn', 'mạnh', 'tính', 'phong', 'phú', ',', 'đa', 'dạng', 'hóa', 'các', 'mối', 'quan', 'hệ', '.']
# Kết quả sau sửa: quan điểm biện chứng của chủ nghĩa mác - lênin không chỉ khẳng định tính khách quan, tính phổ biến của các mối quan hệ mà còn nhấn mạnh tính phong phú, đa dạng hóa các mối quan hệ.

# %%
wrong_text = "đối với biểu đồ histogram, nếu giá trị trung bình mean gần bằng 0, độ lệch chuẩn gần bằng 1 và đường cong phân phối có hình dạng chuông thì có thể khẳng định phân phối là xếp xỉ chuẩn, giả định phân phối chuẩn của phần dư không bị vi phạm."
corrected = correct_text(wrong_text, vocab, ngrams, transition_prob, context_totals, alpha=1)
# Out:
# ['đối', 'với', 'việc', 'đồ', 'histogram', ',', 'nếu', 'giá', 'trị', 'trung', 'bình', 'mean', 'gần', 'bằng', '<num>', ',', 'độ', 'lệch', 'chuẩn', 'gần', 'bằng', '<num>', 'và', 'vận', 'dụng', 'kiến', 'thức', 'cơ', 'bản', 'trong', 'công', 'ty', 'có', 'thể', 'khẳng', 'định', 'phân', 'phối', 'và', 'xếp', 'xỉ', 'chuẩn', ',', 'khả', 'năng', 'phân', 'phối', 'chuẩn', 'của', 'phần', 'dư', 'không', 'bị', 'vi', 'phạm', '.']
# Kết quả sau sửa: đối với việc đồ histogram, nếu giá trị trung bình mean gần bằng 0, độ lệch chuẩn gần bằng 1 và vận dụng kiến thức cơ bản trong công ty có thể khẳng định phân phối và xếp xỉ chuẩn, khả năng phân phối chuẩn của phần dư không bị vi phạm.

# %% [markdown]
# ## Đánh giá trên tập test

# %%
test
# Out:
#                                                    text  \
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giam mà còn tăng thê...
# 3     Đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chù nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
#                                              preprocess  \
# 0     thông qua công tác tuyên truyền, vận động này ...
# 1     do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     giữ được chỉ số này không giam mà còn tăng thê...
# 3     đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  tuy nhiên, khi nói đến e-learning, các phương ...
# 8963  đứng trước những hành vi đi ngược lại với đạo ...
# 8964  quan điểm biện chứng của chù nghĩa mác - lênin...
# 8965  đối với biểu đồ histogram, nếu giá trị trung b...
# 8966  trong mỗi khu vực mà đội phát triển thị trường...
#
#                                            correct_text
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giảm mà còn tăng thê...
# 3     Đứng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chủ nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
# [8967 rows x 3 columns]

# %%
test = test[:2000]

# %%
def correct_wrapper(text):
    return correct_text(text, vocab, ngrams, transition_prob, context_totals, alpha=0.0001)

# Áp dụng sửa lỗi cho toàn bộ cột "preprocess"
test["predicted"] = test["preprocess"].apply(correct_wrapper)
# Out:
# ['thông', 'qua', 'công', 'tác', 'tuyên', 'truyền', ',', 'vận', 'động', 'này', 'phụ', 'huynh', 'sẽ', 'hiểu', 'rõ', 'hơn', 'tầm', 'quan', 'trọng', 'của', 'việc', 'giáo', 'dục', 'ý', 'thức', 'bảo', 'vệ', 'môi', 'trường', 'cho', 'trẻ', 'không', 'phải', 'chỉ', 'ở', 'phía', 'nhà', 'trường', 'mà', 'còn', 'ở', 'gia', 'đình', ',', 'góp', 'phần', 'vào', 'việc', 'gìn', 'giữ', 'môi', 'trường', 'xanh', ',', 'sạch', ',', 'đẹp', '.']
# Kết quả sau sửa: thông qua công tác tuyên truyền, vận động này phụ huynh sẽ hiểu rõ hơn tầm quan trọng của việc giáo dục ý thức bảo vệ môi trường cho trẻ không phải chỉ ở phía nhà trường mà còn ở gia đình, góp phần vào việc gìn giữ môi trường xanh, sạch, đẹp.
# ['do', 'đó', ',', 'doanh', 'nghiệp', 'cần', 'chú', 'trọng', 'đến', 'yếu', 'tố', 'này', 'để', 'làm', 'thỏa', 'mãn', ',', 'hài', 'hòa', 'các', 'nhóm', 'đối', 'tượng', 'này', '.']
# Kết quả sau sửa: do đó, doanh nghiệp cần chú trọng đến yếu tố này để làm thỏa mãn, hài hòa các nhóm đối tượng này.
# ['giữ', 'được', 'chỉ', 'số', 'này', 'không', 'giảm', 'mà', 'còn', 'tăng', 'thêm', 'cũng', 'được', 'xem', 'là', 'một', 'bước', 'thành', 'công', 'của', 'ngân', 'hàng', '.']
# Kết quả sau sửa: giữ được chỉ số này không giảm mà còn tăng thêm cũng được xem là một bước thành công của ngân hàng.
# ['đứng', 'trước', 'thực', 'tế', 'này', 'đòi', 'hỏi', 'chúng', 'ta', 'cần', 'phải', 'có', 'những', 'nghiên', 'cứu', 'chi', 'li', ',', 'cụ', 'thể', 'nhằm', 'tìm', 'ra', 'những', 'nhân', 'tố', 'ảnh', 'hưởng', 'đến', 'sự', 'lựa', 'chọn', 'kênh', 'mua', 'sắm', 'của', 'người', 'tiêu', 'dùng', 'ở', 'tp', '.']
# Kết quả sau sửa: đứng trước thực tế này đòi hỏi chúng ta cần phải có những nghiên cứu chi li, cụ thể nhằm tìm ra những nhân tố ảnh hưởng đến sự lựa chọn kênh mua sắm của người tiêu dùng ở tp.
# ['trình', 'độ', 'học', 'vấn', 'của', 'nhân', 'viên', 'được', 'tuyển', 'dụng', 'ngày', 'càng', 'cao', 'hơn', ',', 'thợ', 'lành', 'nghề', 'cũng', 'được', 'sàng', 'lọc', 'kỹ', 'hơn', '.']
# Kết quả sau sửa: trình độ học vấn của nhân viên được tuyển dụng ngày càng cao hơn, thợ lành nghề cũng được sàng lọc kỹ hơn.
# ['ở', 'các', 'nước', 'phát', 'triển', ',', 'đa', 'số', 'các', 'ấn', 'phẩm', 'nhật', 'báo', 'hoặc', 'tuần', 'báo', 'có', 'con', 'số', 'từ', 'vài', 'chục', 'đến', 'hàng', 'trăm', 'trang', '(', 'tính', 'cả', 'phụ', 'trang', 'quảng', 'cáo', ',', 'dịch', 'vụ', 'xã', 'hội', ')', '.']
# Kết quả sau sửa: ở các nước phát triển, đa số các ấn phẩm nhật báo hoặc tuần báo có con số từ vài chục đến hàng trăm trang (tính cả phụ trang quảng cáo, dịch vụ xã hội).
# ['các', 'bất', 'cập', 'đó', 'đã', 'làm', 'nảy', 'sinh', 'ra', 'việc', 'sử', 'dụng', 'đất', 'chưa', 'hợp', 'lí', ',', 'ảnh', 'hưởng', 'từ', 'quá', 'trình', 'công', 'nghiệp', 'hóa', 'làm', 'suy', 'giảm', 'diện', 'tích', 'đất', 'nông', 'nghiệp', '.']
# Kết quả sau sửa: các bất cập đó đã làm nảy sinh ra việc sử dụng đất chưa hợp lí, ảnh hưởng từ quá trình công nghiệp hóa làm suy giảm diện tích đất nông nghiệp.
# ['các', 'công', 'việc', 'tại', 'tổ', 'home', 'gateway', 'mà', 'ổ', 'điện', 'thông', 'minh', 'cần', 'xử', 'lý', 'ở', 'đây', 'sẽ', 'thường', 'là', 'yêu', 'cầu', 'bật', '/', 'tắt', 'ổ', 'điện', ',', 'yêu', 'cầu', 'thông', 'báo', 'trạng', 'thái', 'bật', '/', 'tắt', 'của', 'ổ', 'điện', ',', 'yêu', 'cầu', 'thông', 'báo', 'vị', 'trí', 'lắp', 'đặt', 'của', 'ổ', 'điện', '.']
# Kết quả sau sửa: các công việc tại tổ home gateway mà ổ điện thông minh cần xử lý ở đây sẽ thường là yêu cầu bật / tắt ổ điện, yêu cầu thông báo trạng thái bật / tắt của ổ điện, yêu cầu thông báo vị trí lắp đặt của ổ điện.
# ['với', 'khuôn', 'khổ', 'này', ',', 'chính', 'trị', 'học', 'so', 'sánh', 'có', 'thể', 'áp', 'dụng', 'vào', 'phân', 'tích', 'nhằm', 'xác', 'định', 'được', 'sự', 'tương', 'đồng', 'và', 'khác', 'biệt', 'giữa', 'các', 'quá', 'trình', 'học', 'tập', ',', 'tương', 'ứng', 'với', 'sự', 'tương', 'đồng', 'và', 'khác', 'biệt', 'của', 'cấu', 'trúc', 'chính', 'trị', '.']
# Kết quả sau sửa: với khuôn khổ này, chính trị học so sánh có thể áp dụng vào phân tích nhằm xác định được sự tương đồng và khác biệt giữa các quá trình học tập, tương ứng với sự tương đồng và khác biệt của cấu trúc chính trị.
# ['việc', 'điều', 'khiển', 'xe', 'sẽ', 'trở', 'nên', 'dễ', 'dàng', 'hơn', 'nếu', 'các', 'bánh', 'xe', 'được', 'đặt', 'theo', 'một', 'góc', 'chính', 'xác', 'theo', 'yêu', 'cầu', 'thiết', 'kế', ',', 'việc', 'đặt', 'sai', 'góc', 'sẽ', 'tạo', 'ra', 'tính', 'ổn', 'định', 'khi', 'lái', 'kém', 'và', 'khiến', 'lốp', 'xe', 'nhanh', 'mòn', '.']
# Kết quả sau sửa: việc điều khiển xe sẽ trở nên dễ dàng hơn nếu các bánh xe được đặt theo một góc chính xác theo yêu cầu thiết kế, việc đặt sai góc sẽ tạo ra tính ổn định khi lái kém và khiến lốp xe nhanh mòn.
# ['trong', 'chương', 'này', ',', 'ta', 'nêu', 'lên', 'những', 'cơ', 'sở', 'lý', 'thuyết', 'được', 'áp', 'dụng', 'trong', 'việc', 'giải', 'quyết', 'bài', 'toán', 'xây', 'dựng', 'hệ', 'thống', '.']
# Kết quả sau sửa: trong chương này, ta nêu lên những cơ sở lý thuyết được áp dụng trong việc giải quyết bài toán xây dựng hệ thống.
# ['tài', 'liệu', 'bồi', 'dưỡng', 'và', 'nâng', 'cao', 'năng', 'lực', 'chuyên', 'môn', 'nghiệp', 'vụ', 'và', 'đạo', 'đức', 'nghề', 'nghiệp', 'cho', 'cán', 'bộ', 'công', 'nhân', 'viên', '.']
# Kết quả sau sửa: tài liệu bồi dưỡng và nâng cao năng lực chuyên môn nghiệp vụ và đạo đức nghề nghiệp cho cán bộ công nhân viên.
# ['xây', 'dựng', 'nội', 'dung', 'học', 'dưới', 'dạng', 'các', 'tư', 'liệu', 'học', 'tập', ':', 'phiếu', 'học', 'tập', '.']
# Kết quả sau sửa: xây dựng nội dung học dưới dạng các tư liệu học tập: phiếu học tập.
# ['người', 'đến', 'thăm', 'chùa', 'bà', 'đá', ',', 'dự', 'lễ', 'kỷ', 'niệm', 'khổng', 'tử', 'và', 'đến', 'thăm', 'các', 'phòng', 'triển', 'lãm', 'tranh', 'của', 'các', 'họa', 'sĩ', 'nổi', 'tiếng', '.']
# Kết quả sau sửa: người đến thăm chùa bà đá, dự lễ kỷ niệm khổng tử và đến thăm các phòng triển lãm tranh của các họa sĩ nổi tiếng.
# ['kho', 'chứa', 'cốt', 'thép', 'phải', 'có', 'nền', 'cao', 'ráo', ',', 'không', 'để', 'nước', 'mưa', 'chảy', 'vào', ',', 'mái', 'và', 'tường', 'không', 'bị', 'dột', ',', 'không', 'bị', 'nước', 'mưa', 'hắt', ',', 'có', 'khả', 'năng', 'chống', 'ẩm', '.']
# Kết quả sau sửa: kho chứa cốt thép phải có nền cao ráo, không để nước mưa chảy vào, mái và tường không bị dột, không bị nước mưa hắt, có khả năng chống ẩm.
# ['tuy', 'nhiên', ',', 'mục', 'tiêu', 'của', 'p', '<num>', 'là', 'còn', 'có', 'thể', 'tái', 'cấu', 'hình', 'với', 'cả', 'các', 'asic', 'có', 'chức', 'năng', 'cố', 'định', '.']
# Kết quả sau sửa: tuy nhiên, mục tiêu của p 4 là còn có thể tái cấu hình với cả các asic có chức năng cố định.
# ['nhờ', 'việc', 'hoạt', 'động', 'theo', 'nhóm', ',', 'học', 'sinh', 'được', 'rèn', 'luyện', 'các', 'kỹ', 'năng', 'cần', 'thiết', 'như', 'hợp', 'tác', ',', 'trình', 'bày', 'trước', 'đám', 'đông', ',', 'kỹ', 'năng', 'lập', 'kế', 'hoạch', ',', 'thực', 'hiện', 'kế', 'hoạch', 'và', 'đánh', 'giá', 'kế', 'hoạch', '.']
# Kết quả sau sửa: nhờ việc hoạt động theo nhóm, học sinh được rèn luyện các kỹ năng cần thiết như hợp tác, trình bày trước đám đông, kỹ năng lập kế hoạch, thực hiện kế hoạch và đánh giá kế hoạch.
# ['trong', 'công', 'tác', 'tuyển', 'dụng', 'cán', 'bộ', 'làm', 'công', 'tác', 'thẩm', 'định', 'dự', 'án', ',', 'báo', 'cáo', 'kinh', 'tế', 'kỹ', 'thuật', 'đầu', 'tư', 'đòi', 'hỏi', 'phải', 'có', 'trình', 'độ', 'chuyên', 'môn', 'nghiệp', 'vụ', 'theo', 'quy', 'định', ',', 'cán', 'bộ', 'thẩm', 'định', 'phải', 'có', 'kinh', 'nghiệm', '.']
# Kết quả sau sửa: trong công tác tuyển dụng cán bộ làm công tác thẩm định dự án, báo cáo kinh tế kỹ thuật đầu tư đòi hỏi phải có trình độ chuyên môn nghiệp vụ theo quy định, cán bộ thẩm định phải có kinh nghiệm.
# ['nhưng', 'trong', 'nhiều', 'lớp', 'bồi', 'dưỡng', 'vẫn', 'chưa', 'chú', 'ý', 'đến', 'các', 'phương', 'pháp', 'tích', 'cực', '.']
# Kết quả sau sửa: nhưng trong nhiều lớp bồi dưỡng vẫn chưa chú ý đến các phương pháp tích cực.
# ['vì', 'vậy', 'qua', 'những', 'câu', 'chuyện', 'với', 'mục', 'đích', 'cung', 'cấp', 'hiểu', 'biết', 'về', 'sự', 'thích', 'nghi', 'của', 'động', 'thực', 'vật', 'với', 'môi', 'trường', ',', 'về', 'quá', 'trình', 'phát', 'triển', 'của', 'chúng', '.']
# Kết quả sau sửa: vì vậy qua những câu chuyện với mục đích cung cấp hiểu biết về sự thích nghi của động thực vật với môi trường, về quá trình phát triển của chúng.
# ['tên', 'đề', 'tài', 'biện', 'pháp', 'để', 'phục', 'vụ', 'tốt', 'cho', 'bản', 'thân', 'mình', 'bằng', 'cách', 'vươn', 'xa', ',', 'mở', 'rộng', 'phạm', 'vi', 'hoạt', 'động', 'trên', 'toàn', 'thế', 'giới', '.']
# Kết quả sau sửa: tên đề tài biện pháp để phục vụ tốt cho bản thân mình bằng cách vươn xa, mở rộng phạm vi hoạt động trên toàn thế giới.
# ['học', 'sinh', 'quan', 'sát', 'tranh', ',', 'cảm', 'nhận', 'và', 'ghi', 'nhớ', '.']
# Kết quả sau sửa: học sinh quan sát tranh, cảm nhận và ghi nhớ.
# ['dưới', 'triều', 'lê', 'sơ', ',', 'ngự', 'sử', 'đài', 'vẫn', 'là', 'cơ', 'quan', 'có', 'vai', 'trò', 'lớn', 'hơn', 'lục', 'khoa', ',', 'quan', 'lại', 'thuộc', 'ngự', 'sử', 'đài', 'là', 'những', 'người', 'có', 'quyền', 'lực', 'từ', 'tể', 'tướng', 'đến', 'võ', 'tướng', '-', 'những', 'chức', 'vụ', 'cao', 'nhất', 'trong', 'triều', '.']
# Kết quả sau sửa: dưới triều lê sơ, ngự sử đài vẫn là cơ quan có vai trò lớn hơn lục khoa, quan lại thuộc ngự sử đài là những người có quyền lực từ tể tướng đến võ tướng - những chức vụ cao nhất trong triều.
# ['mỗi', 'tháng', '<num>', 'lần', ',', 'công', 'ty', 'sẽ', 'tổ', 'chức', 'một', 'buổi', 'giao', 'lưu', 'chia', 'sẻ', 'kinh', 'nghiệm', 'giữa', 'các', 'thành', 'viên', 'với', 'nhau', 'và', 'đào', 'tạo', 'thêm', 'về', 'các', 'kỹ', 'năng', 'ứng', 'xử', 'khác', 'cho', 'nhân', 'viên', '.']
# Kết quả sau sửa: mỗi tháng 1 lần, công ty sẽ tổ chức một buổi giao lưu chia sẻ kinh nghiệm giữa các thành viên với nhau và đào tạo thêm về các kỹ năng ứng xử khác cho nhân viên.
# ['trong', 'thị', 'trường', 'đi', 'đầu', 'tiên', 'mà', 'không', 'cần', 'thêm', 'người', 'ở', 'ghép', '.']
# Kết quả sau sửa: trong thị trường đi đầu tiên mà không cần thêm người ở ghép.
# ['display', 'ads', ':', 'quảng', 'cáo', 'điện', 'tử', ',', 'có', 'nhiều', 'dạng', 'định', 'dạng', 'khác', 'nhau', ':', 'chữ', ',', 'hình', 'ảnh', ',', 'video', 'flash', '.']
# Kết quả sau sửa: display ads: quảng cáo điện tử, có nhiều dạng định dạng khác nhau: chữ, hình ảnh, video flash.
# ['nền', 'kinh', 'tế', 'nước', 'ta', 'đang', 'tiến', 'từng', 'bước', 'vững', 'chắc', 'tới', 'công', 'cuộc', 'cải', 'cách', 'kinh', 'tế', 'theo', 'hướng', 'mở', 'cửa', 'để', 'nhanh', 'chóng', 'hòa', 'nhập', 'với', 'nền', 'kinh', 'tế', 'thế', 'giới', '.']
# Kết quả sau sửa: nền kinh tế nước ta đang tiến từng bước vững chắc tới công cuộc cải cách kinh tế theo hướng mở cửa để nhanh chóng hòa nhập với nền kinh tế thế giới.
# ['trong', 'trường', 'hợp', 'có', 'hai', 'người', 'hoặc', 'nhiều', 'người', 'cùng', 'sáng', 'tạo', 'ra', 'tác', 'phẩm', 'thì', 'những', 'người', 'đó', 'là', 'đồng', 'tác', 'giả', '.']
# Kết quả sau sửa: trong trường hợp có hai người hoặc nhiều người cùng sáng tạo ra tác phẩm thì những người đó là đồng tác giả.
# ['nghiên', 'cứu', 'về', 'phát', 'triển', 'nhanh', 'và', 'bền', 'vững', 'nền', 'kinh', 'tế', 'việt', 'nam', '(', '<num>', '-', '<num>', ')', ',', 'bùi', 'tất', 'thắng', '(', '<num>', ')', ',', 'đã', 'đi', 'sâu', 'vào', 'phân', 'tích', 'các', 'lý', 'thuyết', 'về', 'phát', 'triển', 'nhanh', 'và', 'bền', 'vững', 'của', 'các', 'tác', 'giả', 'trên', 'thế', 'giới', '.']
# Kết quả sau sửa: nghiên cứu về phát triển nhanh và bền vững nền kinh tế việt nam (2011 - 2020), bùi tất thắng (2010), đã đi sâu vào phân tích các lý thuyết về phát triển nhanh và bền vững của các tác giả trên thế giới.
# ['chú', 'ý', 'đến', 'việc', 'giảm', 'giá', 'thành', 'sản', 'phẩm', 'bằng', 'cách', 'hạn', 'chế', 'đến', 'mức', 'thấp', 'nhất', 'tỷ', 'lệ', 'hao', 'hụt', ',', 'giảm', 'các', 'công', 'đoạn', 'thừa', ',', 'không', 'tạo', 'ra', 'giá', 'trị', '.']
# Kết quả sau sửa: chú ý đến việc giảm giá thành sản phẩm bằng cách hạn chế đến mức thấp nhất tỷ lệ hao hụt, giảm các công đoạn thừa, không tạo ra giá trị.
# ['từ', 'sơ', 'đồ', 'phản', 'ứng', ',', 'sản', 'phẩm', 'chính', 'phụ', 'tổ', 'chức', 'cho', 'hs', 'nhận', 'xét', 'rút', 'ra', 'hướng', 'phản', 'ứng', 'và', 'đi', 'đến', 'quy', 'tắc', 'mac', '-', 'côp', '-', 'nhi', '-', 'côp', '.']
# Kết quả sau sửa: từ sơ đồ phản ứng, sản phẩm chính phụ tổ chức cho hs nhận xét rút ra hướng phản ứng và đi đến quy tắc mac - côp - nhi - côp.
# ['khó', 'khăn', 'trong', 'việc', 'truyền', 'đạt', 'đầy', 'đủ', 'kiến', 'thức', 'cho', 'hs', 'để', 'hs', 'hiểu', 'rõ', 'tác', 'phẩm', 'và', 'thể', 'loại', '.']
# Kết quả sau sửa: khó khăn trong việc truyền đạt đầy đủ kiến thức cho hs để hs hiểu rõ tác phẩm và thể loại.
# ['xây', 'dựng', 'mô', 'hình', 'để', 'chuyển', 'giao', 'nhanh', 'giống', 'mới', ',', 'phương', 'pháp', 'canh', 'tác', 'tiên', 'tiến', ',', 'tiến', 'bộ', 'khoa', 'học', 'và', 'công', 'nghệ', 'cho', 'nông', 'dân', '.']
# Kết quả sau sửa: xây dựng mô hình để chuyển giao nhanh giống mới, phương pháp canh tác tiên tiến, tiến bộ khoa học và công nghệ cho nông dân.
# ['bên', 'cạnh', 'đó', ',', 'ai', 'trong', 'forum', 'cũng', 'có', 'quyền', 'lên', 'tiếng', 'nói', ',', 'có', 'quyền', 'tự', 'do', 'ngôn', 'luận', 'do', 'đó', 'forum', 'cũng', 'là', 'một', 'phương', 'tiện', 'truyền', 'tải', 'thông', 'tin', 'ewom', 'hiệu', 'quả', '.']
# Kết quả sau sửa: bên cạnh đó, ai trong forum cũng có quyền lên tiếng nói, có quyền tự do ngôn luận do đó forum cũng là một phương tiện truyền tải thông tin ewom hiệu quả.
# ['đồng', 'thời', ',', 'tác', 'giả', 'cũng', 'đã', 'chỉ', 'ra', 'những', 'khó', 'khăn', 'trong', 'thực', 'hiện', 'các', 'chính', 'sách', 'an', 'sinh', 'xã', 'hội', 'ở', 'việt', 'nam', 'những', 'năm', 'gần', 'đây', 'trên', 'cơ', 'sở', 'phân', 'tích', 'những', 'đánh', 'giá', 'của', 'nhóm', 'cán', 'bộ', 'các', 'đơn', 'vị', 'chủ', 'đầu', 'tư', 'hệ', 'thống', 'chính', 'sách', 'an', 'sinh', 'xã', 'hội', '.']
# Kết quả sau sửa: đồng thời, tác giả cũng đã chỉ ra những khó khăn trong thực hiện các chính sách an sinh xã hội ở việt nam những năm gần đây trên cơ sở phân tích những đánh giá của nhóm cán bộ các đơn vị chủ đầu tư hệ thống chính sách an sinh xã hội.
# ['tác', 'giả', 'cũng', 'cho', 'rằng', ',', 'việc', 'lập', 'kế', 'hoạch', 'đầu', 'tư', 'công', 'phải', 'được', 'kiểm', 'soát', 'chặt', 'chẽ', 'và', 'thông', 'qua', 'bởi', 'cơ', 'quan', 'hành', 'chính', 'cao', 'nhất', 'và', 'phải', 'được', 'công', 'khai', 'trước', 'công', 'chúng', '.']
# Kết quả sau sửa: tác giả cũng cho rằng, việc lập kế hoạch đầu tư công phải được kiểm soát chặt chẽ và thông qua bởi cơ quan hành chính cao nhất và phải được công khai trước công chúng.
# ['phấn', 'đấu', 'đến', 'năm', '<num>', ',', 'toàn', 'tỉnh', 'có', '<num>', '%', 'số', 'xã', 'có', 'cơ', 'sở', 'hạ', 'tầng', 'kinh', 'tế', 'xã', 'hội', 'cơ', 'bản', 'đạt', 'tiêu', 'chí', 'ntm', '.']
# Kết quả sau sửa: phấn đấu đến năm 2020, toàn tỉnh có 60 % số xã có cơ sở hạ tầng kinh tế xã hội cơ bản đạt tiêu chí ntm.
# ['các', 'nhà', 'kinh', 'doanh', 'báo', 'chí', 'sẽ', 'đưa', 'ra', 'câu', 'hỏi', ',', 'liệu', 'độc', 'giả', 'ở', 'những', 'vùng', 'sâu', ',', 'vùng', 'xa', 'chậm', 'phát', 'triển', 'có', 'nhu', 'cầu', 'mua', 'báo', 'hơn', 'nhu', 'cầu', 'mua', 'nhiều', 'thứ', 'thiết', 'thực', 'hơn', '.']
# Kết quả sau sửa: các nhà kinh doanh báo chí sẽ đưa ra câu hỏi, liệu độc giả ở những vùng sâu, vùng xa chậm phát triển có nhu cầu mua báo hơn nhu cầu mua nhiều thứ thiết thực hơn.
# ['khi', 'đầm', 'lớp', 'bê', 'tông', 'phía', 'trên', 'phải', 'ăn', 'sâu', 'xuống', 'lớp', 'bê', 'tông', 'phía', 'dưới', 'khoảng', '<num>', '-', '<num>', 'cm', 'để', 'làm', 'cho', '<num>', 'lớp', 'bê', 'tông', 'liên', 'kết', 'với', 'nhau', '.']
# Kết quả sau sửa: khi đầm lớp bê tông phía trên phải ăn sâu xuống lớp bê tông phía dưới khoảng 5 - 10 cm để làm cho 2 lớp bê tông liên kết với nhau.
# ['năng', 'suất', 'lao', 'động', 'của', 'chi', 'phí', 'tăng', 'lên', '<num>', '%', 'đến', '<num>', '%', 'bằng', 'cách', 'chú', 'trọng', 'đào', 'tạo', 'chuyên', 'môn', ',', 'nâng', 'cao', 'tay', 'nghề', ',', 'tuyển', 'chọn', 'những', 'lao', 'động', 'có', 'trình', 'độ', 'cao', 'hơn', '.']
# Kết quả sau sửa: năng suất lao động của chi phí tăng lên 6 % đến 7 % bằng cách chú trọng đào tạo chuyên môn, nâng cao tay nghề, tuyển chọn những lao động có trình độ cao hơn.
# ['ở', 'dạng', 'quỹ', 'đạo', 'này', 'vệ', 'tinh', 'bay', 'trực', 'tiếp', 'trên', 'mặt', 'phẳng', 'quỹ', 'đạo', 'trùng', 'với', 'mặt', 'phẳng', 'xích', 'đạo', ',', 'nó', 'thích', 'hợp', 'với', 'các', 'vệ', 'tinh', 'thông', 'tin', '.']
# Kết quả sau sửa: ở dạng quỹ đạo này vệ tinh bay trực tiếp trên mặt phẳng quỹ đạo trùng với mặt phẳng xích đạo, nó thích hợp với các vệ tinh thông tin.
# ['do', 'vậy', ',', 'trên', 'thế', 'giới', 'ngoài', 'những', 'vấn', 'đề', 'nóng', 'do', 'tranh', 'chấp', 'lượng', 'dự', 'trữ', 'năng', 'lượng', 'hóa', 'thạch', 'thì', 'năng', 'lượng', 'tái', 'tạo', ',', 'một', 'nguồn', 'năng', 'lượng', 'sạch', 'và', 'vô', 'tận', ',', 'đang', 'được', 'ưu', 'tiên', ',', 'đầu', 'tư', 'cho', 'nghiên', 'cứu', ',', 'khai', 'thác', 'và', 'sử', 'dụng', '.']
# Kết quả sau sửa: do vậy, trên thế giới ngoài những vấn đề nóng do tranh chấp lượng dự trữ năng lượng hóa thạch thì năng lượng tái tạo, một nguồn năng lượng sạch và vô tận, đang được ưu tiên, đầu tư cho nghiên cứu, khai thác và sử dụng.
# ['sau', 'quá', 'trình', 'hoạt', 'động', 'của', 'công', 'ty', 'nguồn', 'vốn', 'công', 'ty', 'mới', 'được', 'huy', 'động', 'thêm', 'từ', 'bên', 'ngoài', '.']
# Kết quả sau sửa: sau quá trình hoạt động của công ty nguồn vốn công ty mới được huy động thêm từ bên ngoài.
# ['tạo', 'ra', 'mức', 'độ', 'hứng', 'thú', 'của', 'hs', 'qua', 'phương', 'pháp', 'học', 'tập', 'mới', ',', 'thông', 'qua', 'các', 'hình', 'thức', 'học', 'khác', 'nhau', 'từ', 'đó', 'lựa', 'chọn', 'các', 'hình', 'thức', 'học', 'mang', 'tính', 'khả', 'thi', 'và', 'hiệu', 'quả', 'nhất', '.']
# Kết quả sau sửa: tạo ra mức độ hứng thú của hs qua phương pháp học tập mới, thông qua các hình thức học khác nhau từ đó lựa chọn các hình thức học mang tính khả thi và hiệu quả nhất.
# ['mức', 'tái', 'cấp', 'vốn', 'tối', 'đa', 'không', 'vượt', 'quá', 'mức', 'cung', 'ứng', 'dành', 'cho', 'mục', 'tiêu', 'cung', 'ứng', 'phương', 'tiện', 'thanh', 'toán', 'trong', 'năm', '.']
# Kết quả sau sửa: mức tái cấp vốn tối đa không vượt quá mức cung ứng dành cho mục tiêu cung ứng phương tiện thanh toán trong năm.
# ['để', 'bắt', 'kịp', 'nhu', 'cầu', 'của', 'khách', 'hàng', 'các', 'ngân', 'hàng', 'cần', 'có', 'những', 'bước', 'đi', 'đầy', 'sáng', 'tạo', '.']
# Kết quả sau sửa: để bắt kịp nhu cầu của khách hàng các ngân hàng cần có những bước đi đầy sáng tạo.
# ['khảo', 'sát', 'được', 'đưa', 'ra', 'nhằm', 'thu', 'thập', 'thông', 'tin', ',', 'ý', 'kiến', 'khác', 'nhau', 'để', 'phục', 'vụ', 'cho', 'việc', 'nghiên', 'cứu', 'đề', 'tài', '.']
# Kết quả sau sửa: khảo sát được đưa ra nhằm thu thập thông tin, ý kiến khác nhau để phục vụ cho việc nghiên cứu đề tài.
# ['momen', 'phanh', 'sinh', 'ra', 'trên', '<num>', 'cơ', 'cấu', 'phanh', 'đĩa', 'được', 'xác', 'định', 'theo', 'công', 'thức', ':']
# Kết quả sau sửa: momen phanh sinh ra trên 1 cơ cấu phanh đĩa được xác định theo công thức:
# ['fanpage', 'của', 'hưng', 'việt', 'đã', 'cung', 'cấp', 'đầy', 'đủ', 'cụ', 'thể', 'thông', 'tin', 'về', 'công', 'ty', 'như', 'tên', ',', 'địa', 'chỉ', ',', 'cách', 'thức', 'liên', 'hệ', ',', '…', 'đồng', 'thời', 'cũng', 'giới', 'thiệu', 'tổng', 'quan', 'về', 'công', 'ty', '.']
# Kết quả sau sửa: fanpage của hưng việt đã cung cấp đầy đủ cụ thể thông tin về công ty như tên, địa chỉ, cách thức liên hệ, … đồng thời cũng giới thiệu tổng quan về công ty.
# ['chỉ', 'đạo', 'tổ', 'trưởng', 'chuyên', 'môn', '/', 'nhóm', 'trưởng', 'hướng', 'dẫn', 'gv', ',', 'nhân', 'viên', 'chăm', 'sóc', 'trẻ', 'lập', 'kế', 'hoạch', 'cá', 'nhân', 'và', 'duyệt', 'kế', 'hoạch', 'của', 'từng', 'bộ', 'môn', ',', 'có', 'sẵn', '.']
# Kết quả sau sửa: chỉ đạo tổ trưởng chuyên môn / nhóm trưởng hướng dẫn gv, nhân viên chăm sóc trẻ lập kế hoạch cá nhân và duyệt kế hoạch của từng bộ môn, có sẵn.
# ['giai', 'đoạn', 'giới', 'thiệu', ':', 'đây', 'là', 'một', 'giai', 'đoạn', 'khó', 'khăn', 'nhất', 'đối', 'với', 'colgate', 'và', 'ở', 'thị', 'trường', 'việt', 'nam', ',', 'colgate', 'gần', 'như', 'thất', 'bại', 'ở', 'giai', 'đoạn', 'này', '.']
# Kết quả sau sửa: giai đoạn giới thiệu: đây là một giai đoạn khó khăn nhất đối với colgate và ở thị trường việt nam, colgate gần như thất bại ở giai đoạn này.
# ['nội', 'dung', 'và', 'phương', 'pháp', 'phát', 'hiện', 'xâm', 'nhập', 'tiểu', 'học', 'tích', 'cực', 'tự', 'học', 'nâng', 'cao', 'trình', 'độ', 'sử', 'dụng', 'trong', 'nội', 'dung', 'phù', 'hợp', 'hơn', 'nữa', 'để', 'nâng', 'cao', 'năng', 'lực', 'nghiên', 'cứu', ',', 'đọc', 'tài', 'liệu', 'bằng', 'tiếng', 'anh', 'nhằm', 'phát', 'triển', 'năng', 'lực', 'của', 'mỗi', 'giáo', 'viên', 'âm', 'nhạc', 'tiểu', 'học', '.']
# Kết quả sau sửa: nội dung và phương pháp phát hiện xâm nhập tiểu học tích cực tự học nâng cao trình độ sử dụng trong nội dung phù hợp hơn nữa để nâng cao năng lực nghiên cứu, đọc tài liệu bằng tiếng anh nhằm phát triển năng lực của mỗi giáo viên âm nhạc tiểu học.
# ['thái', 'độ', 'phục', 'vụ', 'sử', 'dụng', 'chuỗi', 'ký', 'tự', 'đặc', 'biệt', ',', 'bản', 'tin', 'được', 'chia', 'thành', 'các', 'block', 'với', 'giá', 'trị', 'chiều', 'dài', 'ngẫu', 'nhiên', 'được', 'thêm', 'vào', 'phía', 'trước', '.']
# Kết quả sau sửa: thái độ phục vụ sử dụng chuỗi ký tự đặc biệt, bản tin được chia thành các block với giá trị chiều dài ngẫu nhiên được thêm vào phía trước.
# ['mặc', 'dù', 'thừa', 'hưởng', 'hoàn', 'toàn', 'từ', 'phiên', 'bản', 'tại', 'hàn', 'quốc', 'nhưng', 'baemin', 'vẫn', 'tiếp', 'tục', 'được', 'đầu', 'tư', ',', 'thiết', 'kế', 'dành', 'riêng', 'cho', 'thị', 'trường', 'vn', ',', 'từ', 'màu', 'xanh', 'thương', 'hiệu', 'đến', 'font', 'chữ', 'hay', 'biểu', 'tượng', 'mèo', 'mập', '.']
# Kết quả sau sửa: mặc dù thừa hưởng hoàn toàn từ phiên bản tại hàn quốc nhưng baemin vẫn tiếp tục được đầu tư, thiết kế dành riêng cho thị trường vn, từ màu xanh thương hiệu đến font chữ hay biểu tượng mèo mập.
# ['bản', 'chất', 'của', 'hoạt', 'động', 'smm', ':', 'quá', 'trình', 'trao', 'đổi', 'nội', 'dung', 'giữa', 'thương', 'hiệu', 'và', 'khách', 'hàng', 'trong', 'đó', 'thương', 'hiệu', 'chủ', 'động', 'tạo', 'ra', 'cuộc', 'đối', 'thoại', 'một', 'cách', 'có', 'mục', 'đích', 'chứ', 'không', 'phải', 'là', 'người', 'quyết', 'định', 'nội', 'dung', 'cho', 'cuộc', 'hội', 'thoại', 'đó', '.']
# Kết quả sau sửa: bản chất của hoạt động smm: quá trình trao đổi nội dung giữa thương hiệu và khách hàng trong đó thương hiệu chủ động tạo ra cuộc đối thoại một cách có mục đích chứ không phải là người quyết định nội dung cho cuộc hội thoại đó.
# ['cách', 'thức', 'thực', 'hiện', ':', 'giáo', 'viên', 'hướng', 'dẫn', 'học', 'sinh', 'giải', 'các', 'bài', 'toán', 'cơ', 'bản', 'từ', 'đó', 'rèn', 'luyện', 'kỹ', 'năng', 'cho', 'học', 'sinh', 'giải', 'các', 'bài', 'toán', 'tương', 'tự', 'thông', 'qua', 'hệ', 'thống', 'các', 'bài', 'tập', 'giao', 'về', 'nhà', 'đã', 'được', 'biên', 'soạn', '.']
# Kết quả sau sửa: cách thức thực hiện: giáo viên hướng dẫn học sinh giải các bài toán cơ bản từ đó rèn luyện kỹ năng cho học sinh giải các bài toán tương tự thông qua hệ thống các bài tập giao về nhà đã được biên soạn.
# ['với', 'hình', 'thức', 'này', 'vừa', 'tạo', 'cho', 'trẻ', 'không', 'khí', 'thoải', 'mái', ',', 'vui', 'vẻ', 'sau', 'hoạt', 'động', 'nhưng', 'cũng', 'thông', 'qua', 'đó', 'cơ', 'thể', 'trẻ', 'được', 'chuyển', 'trạng', 'thái', 'từ', 'tĩnh', 'sang', 'động', '.']
# Kết quả sau sửa: với hình thức này vừa tạo cho trẻ không khí thoải mái, vui vẻ sau hoạt động nhưng cũng thông qua đó cơ thể trẻ được chuyển trạng thái từ tĩnh sang động.
# ['hạn', 'chế', 'cửa', 'nhân', 'tố', 'kinh', 'tế', 'đối', 'với', 'doanh', 'nghiệp', 'là', 'việt', 'nam', 'mở', 'của', 'nền', 'kinh', 'tế', 'thị', 'trường', '(', 'gia', 'nhập', 'wto', ')', 'tạo', 'nên', 'nhiều', 'đối', 'thủ', 'cạnh', 'tranh', '-', 'nhiều', 'tập', 'đoàn', 'bán', 'lẻ', 'hùng', 'mạnh', 'trên', 'thế', 'giới', 'và', 'khu', 'vực', 'xa', 'nhập', 'thị', 'trường', 'việt', 'nam', '.']
# Kết quả sau sửa: hạn chế cửa nhân tố kinh tế đối với doanh nghiệp là việt nam mở của nền kinh tế thị trường (gia nhập wto) tạo nên nhiều đối thủ cạnh tranh - nhiều tập đoàn bán lẻ hùng mạnh trên thế giới và khu vực xa nhập thị trường việt nam.
# ['có', 'thể', 'nêu', 'ra', 'một', 'số', 'điểm', 'mới', 'của', 'luận', 'văn', 'về', 'đề', 'tài', 'lỗi', 'trong', 'trách', 'nhiệm', 'dân', 'sự', 'bồi', 'thường', 'thiệt', 'hại', 'ngoài', 'hợp', 'đồng', 'như', 'sau', ':']
# Kết quả sau sửa: có thể nêu ra một số điểm mới của luận văn về đề tài lỗi trong trách nhiệm dân sự bồi thường thiệt hại ngoài hợp đồng như sau:
# ['đồng', 'thời', ',', 'doanh', 'nghiệp', 'cố', 'gắng', 'đàm', 'phán', 'để', 'có', 'lợi', 'nhất', 'cho', 'phía', 'mình', 'trong', 'mọi', 'tình', 'huống', '.']
# Kết quả sau sửa: đồng thời, doanh nghiệp cố gắng đàm phán để có lợi nhất cho phía mình trong mọi tình huống.
# ['vai', 'trò', 'của', 'văn', 'hóa', 'đọc', 'đối', 'với', 'sinh', 'viên', 'đại', 'học', 'kinh', 'tế', '-', 'đại', 'học', 'quốc', 'gia', 'hà', 'nội', '.']
# Kết quả sau sửa: vai trò của văn hóa đọc đối với sinh viên đại học kinh tế - đại học quốc gia hà nội.
# ['mười', 'hai', 'cộng', 'ba', 'mươi', 'lăm', '.']
# Kết quả sau sửa: mười hai cộng ba mươi lăm.
# ['các', 'em', 'có', 'những', 'kỹ', 'năng', 'tổ', 'chức', 'hoạt', 'động', 'tư', 'duy', ',', 'tiến', 'hành', 'các', 'thao', 'tác', 'như', 'so', 'sánh', ',', 'hệ', 'thống', 'hóa', ',', 'phân', 'loại', 'nhằm', 'ghi', 'nhớ', 'tài', 'liệu', '.']
# Kết quả sau sửa: các em có những kỹ năng tổ chức hoạt động tư duy, tiến hành các thao tác như so sánh, hệ thống hóa, phân loại nhằm ghi nhớ tài liệu.
# ['gần', 'đây', 'công', 'tác', 'đấu', 'thầu', 'qua', 'mạng', 'đang', 'được', 'tiếp', 'cận', ',', 'tuy', 'vẫn', 'còn', 'gặp', 'khó', 'khăn', 'trong', 'việc', 'tiếp', 'cận', ',', 'kiểm', 'tra', 'giám', 'sát', 'hồ', 'sơ', 'trước', 'khi', 'thẩm', 'định', '.']
# Kết quả sau sửa: gần đây công tác đấu thầu qua mạng đang được tiếp cận, tuy vẫn còn gặp khó khăn trong việc tiếp cận, kiểm tra giám sát hồ sơ trước khi thẩm định.
# ['đối', 'với', 'công', 'ty', 'trách', 'nhiệm', 'hữu', 'hạn', 'một', 'thành', 'viên', 'có', 'cơ', 'sở', 'hạ', 'là', 'tổ', 'chức', ',', 'sẽ', 'có', 'hội', 'đồng', 'thành', 'viên', ',', 'chủ', 'sở', 'hữu', 'sẽ', 'bổ', 'nhiệm', 'các', 'vị', 'trí', 'thành', 'viên', 'hội', 'đồng', 'thành', 'viên', 'miễn', 'nhiệm', 'từ', '<num>', 'đến', '<num>', 'năm', 'với', 'nhiệm', 'kì', 'không', 'được', 'quá', '<num>', 'năm', '.']
# Kết quả sau sửa: đối với công ty trách nhiệm hữu hạn một thành viên có cơ sở hạ là tổ chức, sẽ có hội đồng thành viên, chủ sở hữu sẽ bổ nhiệm các vị trí thành viên hội đồng thành viên miễn nhiệm từ 03 đến 07 năm với nhiệm kì không được quá 05 năm.
# ['điều', 'này', 'phản', 'ánh', 'thực', 'tế', 'là', 'các', 'hoạt', 'động', 'học', 'trong', 'lao', 'động', 'và', 'trong', 'hoạt', 'động', 'thể', 'dục', ',', 'thể', 'thao', 'không', 'được', 'đánh', 'giá', 'cao', ',', 'cần', 'có', 'sự', 'cải', 'thiện', 'và', 'thiết', 'kế', 'chương', 'trình', 'sao', 'cho', 'phù', 'hợp', 'với', 'lứa', 'tuổi', 'mẫu', 'giáo', '.']
# Kết quả sau sửa: điều này phản ánh thực tế là các hoạt động học trong lao động và trong hoạt động thể dục, thể thao không được đánh giá cao, cần có sự cải thiện và thiết kế chương trình sao cho phù hợp với lứa tuổi mẫu giáo.
# ['các', 'phép', 'liên', 'kết', 'giúp', 'cho', 'câu', 'được', 'hoàn', 'chỉnh', ',', 'mạch', 'lạc', 'hơn', '.']
# Kết quả sau sửa: các phép liên kết giúp cho câu được hoàn chỉnh, mạch lạc hơn.
# ['văn', 'học', 'dân', 'gian', 'được', 'xem', 'là', 'một', 'tài', 'sản', 'quốc', 'gia', ',', 'được', 'thể', 'hiện', 'rất', 'phong', 'phú', 'và', 'đa', 'dạng', 'nhưng', 'lại', 'gần', 'như', 'chưa', 'có', 'cơ', 'quan', 'nào', 'được', 'thành', 'lập', 'để', 'thực', 'hiện', 'việc', 'này', '.']
# Kết quả sau sửa: văn học dân gian được xem là một tài sản quốc gia, được thể hiện rất phong phú và đa dạng nhưng lại gần như chưa có cơ quan nào được thành lập để thực hiện việc này.
# ['việc', 'phân', 'loại', 'và', 'trích', 'lập', 'dự', 'phòng', 'rủi', 'ro', 'chưa', 'phản', 'ánh', 'thực', 'chất', 'rủi', 'ro', 'tín', 'dụng', 'của', 'ngân', 'hàng', '.']
# Kết quả sau sửa: việc phân loại và trích lập dự phòng rủi ro chưa phản ánh thực chất rủi ro tín dụng của ngân hàng.
# ['tạo', 'ra', 'sản', 'phẩm', 'phong', 'phú', 'và', 'đa', 'dạng', 'với', 'nhiều', 'phiên', 'bản', 'khác', 'nhau', ',', 'đáp', 'ứng', 'được', 'nhu', 'cầu', 'của', 'thị', 'trường', 'đặc', 'biệt', 'là', 'phái', 'nữ', '.']
# Kết quả sau sửa: tạo ra sản phẩm phong phú và đa dạng với nhiều phiên bản khác nhau, đáp ứng được nhu cầu của thị trường đặc biệt là phái nữ.
# ['các', 'yếu', 'tố', 'nhân', 'khẩu', 'học', 'bao', 'gồm', 'những', 'gì', '?']
# Kết quả sau sửa: các yếu tố nhân khẩu học bao gồm những gì?
# ['ba', 'mẹ', 'huy', 'bận', 'công', 'việc', 'nên', 'không', 'có', 'thời', 'gian', 'quan', 'tâm', 'đến', 'việc', 'học', 'của', 'huy', '.']
# Kết quả sau sửa: ba mẹ huy bận công việc nên không có thời gian quan tâm đến việc học của huy.
# ['trong', 'một', 'số', 'nước', 'không', 'quan', 'tâm', 'đến', 'vấn', 'đề', 'này', ',', 'khi', 'nguồn', 'viện', 'trợ', 'oda', 'ngày', 'càng', 'tăng', 'thì', 'việc', 'lãng', 'phí', 'đầu', 'tư', 'tràn', 'lan', 'cũng', 'có', 'xu', 'hướng', 'ngày', 'càng', 'tăng', ',', 'nhất', 'là', 'giai', 'đoạn', 'đầu', 'của', 'vốn', 'vay', ',', 'khi', 'nghĩa', 'vụ', 'trả', 'nợ', 'gốc', 'còn', 'ẩn', 'giấu', 'sau', 'thời', 'gian', 'ân', 'hạn', '.']
# Kết quả sau sửa: trong một số nước không quan tâm đến vấn đề này, khi nguồn viện trợ oda ngày càng tăng thì việc lãng phí đầu tư tràn lan cũng có xu hướng ngày càng tăng, nhất là giai đoạn đầu của vốn vay, khi nghĩa vụ trả nợ gốc còn ẩn giấu sau thời gian ân hạn.
# ['dốc', 'hết', 'âm', 'thanh', 'của', 'máy', 'xuống', 'quảng', 'trường', '.']
# Kết quả sau sửa: dốc hết âm thanh của máy xuống quảng trường.
# ['trong', 'đào', 'tạo', ',', 'liên', 'kết', 'là', 'hình', 'thức', 'học', 'tập', ',', 'hỗ', 'trợ', ',', 'tạo', 'sự', 'gắn', 'bó', 'chặt', 'chẽ', 'với', 'nhau', 'giữa', 'các', 'cơ', 'sở', 'đào', 'tạo', 'hoặc', 'giữa', 'các', 'cơ', 'sở', 'đào', 'tạo', 'với', 'các', 'bài', 'học', 'kinh', 'nghiệm', 'thực', 'hành', 'các', 'phép', 'tính', ',', 'nhiệm', 'vụ', 'của', 'cơ', 'sở', 'đào', 'tạo', '.']
# Kết quả sau sửa: trong đào tạo, liên kết là hình thức học tập, hỗ trợ, tạo sự gắn bó chặt chẽ với nhau giữa các cơ sở đào tạo hoặc giữa các cơ sở đào tạo với các bài học kinh nghiệm thực hành các phép tính, nhiệm vụ của cơ sở đào tạo.
# ['sử', 'dụng', 'phương', 'pháp', 'này', 'giúp', 'xây', 'dựng', 'cơ', 'sở', 'dữ', 'liệu', 'không', 'gian', 'thuộc', 'tính', 'và', 'mô', 'hình', 'dem', 'bao', 'gồm', 'các', 'bản', 'đồ', 'chuyên', 'đề', 'về', 'hiện', 'trạng', 'khu', 'vực', 'châu', 'á', '.']
# Kết quả sau sửa: sử dụng phương pháp này giúp xây dựng cơ sở dữ liệu không gian thuộc tính và mô hình dem bao gồm các bản đồ chuyên đề về hiện trạng khu vực châu á.
# ['trầu', 'bà', 'tỷ', 'phú', 'là', 'một', 'loại', 'cây', 'cảnh', 'đẹp', 'không', 'có', 'hoa', ',', 'cây', 'có', 'sức', 'sống', 'mạnh', 'mẽ', 'và', 'có', 'khả', 'năng', 'chịu', 'được', 'râm', 'mát', 'nên', 'thường', 'được', 'nhiều', 'người', 'ưu', 'ái', 'chọn', 'trồng', '.']
# Kết quả sau sửa: trầu bà tỷ phú là một loại cây cảnh đẹp không có hoa, cây có sức sống mạnh mẽ và có khả năng chịu được râm mát nên thường được nhiều người ưu ái chọn trồng.
# ['để', 'đánh', 'giá', 'được', 'hoạt', 'động', 'kinh', 'doanh', 'của', 'công', 'ty', 'thì', 'song', 'song', 'với', 'việc', 'phân', 'tích', 'tình', 'hình', 'biến', 'động', 'của', 'doanh', 'thu', ',', 'chúng', 'ta', 'cần', 'phải', 'phân', 'minh', 'rõ', 'tình', 'hình', 'biến', 'động', 'của', 'chi', 'phí', 'của', 'các', 'nhóm', 'là', 'xem', 'xét', 'biến', 'động', 'đó', 'so', 'với', 'biến', 'động', 'của', 'công', 'ty', '.']
# Kết quả sau sửa: để đánh giá được hoạt động kinh doanh của công ty thì song song với việc phân tích tình hình biến động của doanh thu, chúng ta cần phải phân minh rõ tình hình biến động của chi phí của các nhóm là xem xét biến động đó so với biến động của công ty.
# ['để', 'cho', 'ra', 'một', 'dòng', 'sữa', 'nguyên', 'chất', 'tươi', 'ngon', 'th', 'đã', 'luôn', 'tiếp', 'cận', 'sản', 'xuất', 'theo', 'chuỗi', 'đồng', 'cỏ', 'sạch', ',', 'trang', 'trại', 'sạch', ',', 'cho', 'đến', 'ly', 'sữa', 'sạch', '.']
# Kết quả sau sửa: để cho ra một dòng sữa nguyên chất tươi ngon th đã luôn tiếp cận sản xuất theo chuỗi đồng cỏ sạch, trang trại sạch, cho đến ly sữa sạch.
# ['bản', 'đồ', 'các', 'hệ', 'thống', 'tiêu', 'thụ', 'dầu', 'diesel', 'oil', '.']
# Kết quả sau sửa: bản đồ các hệ thống tiêu thụ dầu diesel oil.
# ['các', 'tổ', 'chức', 'mà', 'có', 'các', 'chức', 'năng', 'xác', 'định', ',', 'tư', 'vấn', 'giá', 'đất', 'và', 'xác', 'định', 'giá', 'rõ', 'ràng', ',', 'cụ', 'thể', '.']
# Kết quả sau sửa: các tổ chức mà có các chức năng xác định, tư vấn giá đất và xác định giá rõ ràng, cụ thể.
# ['thiết', 'bị', 'và', 'tài', 'liệu', 'học', 'tập', 'đủ', 'dùng', '.']
# Kết quả sau sửa: thiết bị và tài liệu học tập đủ dùng.
# ['qua', 'phân', 'tích', 'hồi', 'quy', 'và', 'kiểm', 'định', 'khuyết', 'tật', 'của', 'mô', 'hình', 'cho', 'thấy', ',', 'kết', 'quả', 'nghiên', 'cứu', 'cũng', 'khá', 'tương', 'đồng', 'với', 'các', 'nghiên', 'cứu', 'trước', 'đây', 'của', 'các', 'tác', 'giả', 'trong', 'và', 'ngoài', 'nước', '.']
# Kết quả sau sửa: qua phân tích hồi quy và kiểm định khuyết tật của mô hình cho thấy, kết quả nghiên cứu cũng khá tương đồng với các nghiên cứu trước đây của các tác giả trong và ngoài nước.
# ['thiết', 'kế', 'hở', 'cũng', 'sẽ', 'giúp', 'người', 'dùng', ',', 'kỹ', 'thuật', 'viên', 'dễ', 'dàng', 'quan', 'sát', ',', 'nhắc', 'nhở', 'các', 'hư', 'hỏng', 'để', 'dễ', 'dàng', 'vệ', 'sinh', ',', 'sửa', 'chữa', '.']
# Kết quả sau sửa: thiết kế hở cũng sẽ giúp người dùng, kỹ thuật viên dễ dàng quan sát, nhắc nhở các hư hỏng để dễ dàng vệ sinh, sửa chữa.
# ['tuy', 'nhiên', ',', 'việc', 'quảng', 'bá', 'thương', 'hiệu', 'sẽ', 'rất', 'tốn', 'kém', ',', 'do', 'đó', 'việc', 'hiểu', 'rõ', 'mức', 'độ', 'ảnh', 'hưởng', 'của', 'sự', 'nhận', 'biết', 'đến', 'tiến', 'trình', 'lựa', 'chọn', 'sản', 'phẩm', 'sẽ', 'giúp', 'các', 'doanh', 'nghiệp', 'có', 'được', 'cách', 'thức', 'xây', 'dựng', 'thương', 'hiệu', 'đạt', 'hiệu', 'quả', 'với', 'chi', 'phí', 'hợp', 'lý', '.']
# Kết quả sau sửa: tuy nhiên, việc quảng bá thương hiệu sẽ rất tốn kém, do đó việc hiểu rõ mức độ ảnh hưởng của sự nhận biết đến tiến trình lựa chọn sản phẩm sẽ giúp các doanh nghiệp có được cách thức xây dựng thương hiệu đạt hiệu quả với chi phí hợp lý.
# ['do', 'vậy', ',', 'quan', 'hệ', 'giữa', 'người', 'bán', 'lẻ', 'và', 'sỉ', 'là', 'quan', 'hệ', 'với', 'nhau', '.']
# Kết quả sau sửa: do vậy, quan hệ giữa người bán lẻ và sỉ là quan hệ với nhau.
# ['ping', ':', 'độ', 'trễ', 'mạng', 'được', 'đo', 'bằng', 'thời', 'gian', 'khứ', 'hồi', 'theo', 'mili', 'giây', '(', 'ms', ')', '.']
# Kết quả sau sửa: ping: độ trễ mạng được đo bằng thời gian khứ hồi theo mili giây (ms).
# ['niềm', 'tin', 'và', 'thái', 'độ', ':', 'thông', 'qua', 'hoạt', 'động', 'và', 'tri', 'thức', ',', 'người', 'ta', 'có', 'được', 'niềm', 'tin', 'và', 'thái', 'độ', '.']
# Kết quả sau sửa: niềm tin và thái độ: thông qua hoạt động và tri thức, người ta có được niềm tin và thái độ.
# ['cuối', 'cùng', ',', 'em', 'cũng', 'xin', 'gửi', 'lời', 'cảm', 'ơn', 'đến', 'người', 'khác', ',', 'bạn', 'bè', 'đã', 'động', 'viên', ',', 'giúp', 'đỡ', ',', 'tạo', 'điều', 'kiện', 'để', 'em', 'hoàn', 'thành', 'luận', 'văn', 'này', '.']
# Kết quả sau sửa: cuối cùng, em cũng xin gửi lời cảm ơn đến người khác, bạn bè đã động viên, giúp đỡ, tạo điều kiện để em hoàn thành luận văn này.
# ['gv', 'tổ', 'chức', 'cho', 'hs', 'suy', 'nghĩ', 'và', 'thảo', 'luận', 'về', 'những', 'số', 'liệu', 'cần', 'thiết', ',', 'cần', 'thu', 'thập', 'nhằm', 'đơn', 'giản', 'hóa', 'bài', 'toán', '.']
# Kết quả sau sửa: gv tổ chức cho hs suy nghĩ và thảo luận về những số liệu cần thiết, cần thu thập nhằm đơn giản hóa bài toán.
# ['kiến', 'nghị', 'mức', 'cổ', 'tức', 'được', 'trả', ',', 'quyết', 'định', 'thời', 'hạn', 'và', 'thủ', 'tục', 'trả', 'cổ', 'tức', 'hoặc', 'xử', 'lý', 'các', 'khoản', 'lỗ', 'phát', 'sinh', 'trong', 'quá', 'trình', 'kinh', 'doanh', '.']
# Kết quả sau sửa: kiến nghị mức cổ tức được trả, quyết định thời hạn và thủ tục trả cổ tức hoặc xử lý các khoản lỗ phát sinh trong quá trình kinh doanh.
# ['giáo', 'viên', 'cần', 'bồi', 'dưỡng', ',', 'trau', 'dồi', 'thêm', 'kiến', 'thức', 'chuyên', 'môn', ',', 'nghiệp', 'vụ', 'sư', 'phạm', ',', 'tìm', 'tòi', 'những', 'sáng', 'kiến', 'mới', ',', 'những', 'phương', 'pháp', 'và', 'các', 'cách', 'giải', 'quyết', 'bài', 'tập', 'mới', 'giúp', 'bản', 'thân', 'trở', 'nên', 'hoàn', 'thiện', 'hơn', 'và', 'học', 'sinh', 'cũng', 'hứng', 'thú', 'học', 'tập', 'hơn', '.']
# Kết quả sau sửa: giáo viên cần bồi dưỡng, trau dồi thêm kiến thức chuyên môn, nghiệp vụ sư phạm, tìm tòi những sáng kiến mới, những phương pháp và các cách giải quyết bài tập mới giúp bản thân trở nên hoàn thiện hơn và học sinh cũng hứng thú học tập hơn.
# ['chu', 'trình', 'sản', 'xuất', 'khép', 'kín', 'chuẩn', 'quốc', 'tế', ',', 'từ', 'nguồn', 'nguyên', 'liệu', 'cho', 'đến', 'công', 'nghệ', 'làm', 'sữa', 'sạch', 'nhằm', 'giữ', 'vẹn', 'nguyên', 'tinh', 'túy', 'của', 'thiên', 'nhiên', 'trong', 'tuần', 'giọt', 'sữa', '.']
# Kết quả sau sửa: chu trình sản xuất khép kín chuẩn quốc tế, từ nguồn nguyên liệu cho đến công nghệ làm sữa sạch nhằm giữ vẹn nguyên tinh túy của thiên nhiên trong tuần giọt sữa.
# ['dựa', 'vào', 'biểu', 'đồ', ',', 'ta', 'có', 'thể', 'thấy', 'dung', 'lượng', 'của', 'ổ', 'c', 'là', '<num>', 'gb', '(', 'màu', 'đỏ', ')', ',', 'màu', 'xanh', 'lá', 'cây', 'là', 'dung', 'lượng', 'còn', 'trống', '<num>', 'gb', '.']
# Kết quả sau sửa: dựa vào biểu đồ, ta có thể thấy dung lượng của ổ c là 200 gb (màu đỏ), màu xanh lá cây là dung lượng còn trống 180.15 gb.
# ['rau', 'quả', 'là', 'cụm', 'từ', 'được', 'nhiều', 'tổ', 'chức', 'và', 'công', 'ty', 'sử', 'dụng', 'để', 'nói', 'chung', 'cho', 'các', 'loại', 'rau', 'và', 'quả', 'được', 'sử', 'dụng', 'làm', 'thực', 'phẩm', '.']
# Kết quả sau sửa: rau quả là cụm từ được nhiều tổ chức và công ty sử dụng để nói chung cho các loại rau và quả được sử dụng làm thực phẩm.
# ['việc', 'lập', 'kế', 'hoạch', 'là', 'cơ', 'sở', 'đảm', 'bảo', 'cho', 'quá', 'trình', 'quản', 'lí', 'đạt', 'hiệu', 'quả', 'cao', ',', 'nó', 'thay', 'thế', 'cho', 'các', 'hoạt', 'động', 'rời', 'rạc', ',', 'tùy', 'tiện', '.']
# Kết quả sau sửa: việc lập kế hoạch là cơ sở đảm bảo cho quá trình quản lí đạt hiệu quả cao, nó thay thế cho các hoạt động rời rạc, tùy tiện.
# ['kỹ', 'năng', ':', 'rèn', 'kỹ', 'năng', 'đo', 'đạc', 'thực', 'tế', ',', 'rèn', 'ý', 'thức', 'làm', 'việc', 'tập', 'thể', '.']
# Kết quả sau sửa: kỹ năng: rèn kỹ năng đo đạc thực tế, rèn ý thức làm việc tập thể.
# ['dù', 'đang', 'ở', 'đâu', ',', 'trong', 'khoảng', 'thời', 'gian', 'nào', 'thì', 'cũng', 'chỉ', 'cần', 'có', 'một', 'thiết', 'bị', 'điện', 'tử', '(', 'điện', 'thoại', ',', 'máy', 'tính', ',', 'máy', 'tính', 'bảng', ',', '…', ')', 'thì', 'chúng', 'ta', 'có', 'thể', 'mua', 'bất', 'cứ', 'loại', 'hàng', 'hóa', 'nào', 'mình', 'với', 'vài', 'thao', 'tác', 'đơn', 'giản', '.']
# Kết quả sau sửa: dù đang ở đâu, trong khoảng thời gian nào thì cũng chỉ cần có một thiết bị điện tử (điện thoại, máy tính, máy tính bảng, …) thì chúng ta có thể mua bất cứ loại hàng hóa nào mình với vài thao tác đơn giản.
# ['ngoài', 'ra', ',', 'đảng', 'ủy', 'bộ', 'y', 'tế', 'cũng', 'yêu', 'cầu', 'thành', 'lập', 'ban', 'chỉ', 'đạo', 'cấp', 'tỉnh', ',', 'thành', 'phố', 'trực', 'thuộc', 'trung', 'ương', ',', 'ban', 'chỉ', 'đạo', 'các', 'bệnh', 'viện', 'để', 'đưa', 'ra', 'kế', 'hoạch', 'chi', 'tiết', ',', 'cụ', 'thể', 'phù', 'hợp', 'cho', 'từng', 'địa', 'phương', 'và', 'từng', 'điều', 'kiện', 'cụ', 'thể', 'của', 'các', 'công', 'việc', '.']
# Kết quả sau sửa: ngoài ra, đảng ủy bộ y tế cũng yêu cầu thành lập ban chỉ đạo cấp tỉnh, thành phố trực thuộc trung ương, ban chỉ đạo các bệnh viện để đưa ra kế hoạch chi tiết, cụ thể phù hợp cho từng địa phương và từng điều kiện cụ thể của các công việc.
# ['các', 'đặc', 'điểm', 'về', 'môi', 'trường', 'thể', 'chế', 'cấp', 'địa', 'phương', 'bao', 'gồm', 'những', 'chính', 'sách', 'ưu', 'đãi', 'về', 'tài', 'khóa', 'như', 'thuế', ',', 'trợ', 'cấp', ',', 'ưu', 'đãi', 'về', 'quy', 'trình', ',', 'thủ', 'tục', '(', 'oman', ',', '<num>', ')', '.']
# Kết quả sau sửa: các đặc điểm về môi trường thể chế cấp địa phương bao gồm những chính sách ưu đãi về tài khóa như thuế, trợ cấp, ưu đãi về quy trình, thủ tục (oman, 2000).
# ['giám', 'đốc', 'về', 'thành', 'lập', 'ủy', 'ban', 'hỗn', 'hợp', 'hợp', 'tác', 'kinh', 'tế', ',', 'kỹ', 'thuật', '<date>', '.']
# Kết quả sau sửa: giám đốc về thành lập ủy ban hỗn hợp hợp tác kinh tế, kỹ thuật 18/9/1991.
# ['kiểm', 'định', 'sự', 'bằng', 'nhau', 'của', 'phương', 'sai', '.']
# Kết quả sau sửa: kiểm định sự bằng nhau của phương sai.
# ['như', 'vậy', ',', 'trong', 'hoạt', 'động', 'mua', 'bán', ',', 'tình', 'hình', 'thu', 'nợ', 'với', 'khách', 'hàng', 'được', 'công', 'ty', 'quản', 'lý', 'tốt', '.']
# Kết quả sau sửa: như vậy, trong hoạt động mua bán, tình hình thu nợ với khách hàng được công ty quản lý tốt.
# ['sự', 'tương', 'trợ', 'giúp', 'đỡ', 'lẫn', 'nhau', 'trong', 'cộng', 'đồng', 'còn', 'được', 'thể', 'hiện', 'rất', 'rõ', 'khi', 'có', 'những', 'sự', 'cố', 'của', 'một', 'cá', 'nhân', 'hoặc', 'biến', 'động', 'chung', 'của', 'toàn', 'xã', 'hội', '.']
# Kết quả sau sửa: sự tương trợ giúp đỡ lẫn nhau trong cộng đồng còn được thể hiện rất rõ khi có những sự cố của một cá nhân hoặc biến động chung của toàn xã hội.
# ['g', ':', 'nêu', 'cách', 'xác', 'định', 'đỉnh', 'tương', 'ứng', 'của', '<num>', 'tam', 'giác', 'đồng', 'dạng', 'khi', 'đã', 'thỏa', 'mãn', 'gt', 'của', 'định', 'lí', '.']
# Kết quả sau sửa: g: nêu cách xác định đỉnh tương ứng của 2 tam giác đồng dạng khi đã thỏa mãn gt của định lí.
# ['trong', 'cuốn', 'sách', 'này', ',', 'tác', 'giả', 'đồng', 'nhất', 'khái', 'niệm', 'tác', 'phong', 'và', 'phong', 'cách', 'và', 'dùng', 'hai', 'khái', 'niệm', 'này', 'tương', 'đương', 'ý', 'hiểu', 'như', 'nhau', '.']
# Kết quả sau sửa: trong cuốn sách này, tác giả đồng nhất khái niệm tác phong và phong cách và dùng hai khái niệm này tương đương ý hiểu như nhau.
# ['thông', 'qua', 'hệ', 'giữa', 'các', 'cell', 'dẫn', 'đến', 'gây', 'nhiễu', '.']
# Kết quả sau sửa: thông qua hệ giữa các cell dẫn đến gây nhiễu.
# ['điều', 'này', 'có', 'nghĩa', 'là', 'các', 'bugi', 'sấy', 'loại', 'mới', 'có', 'tính', 'năng', 'đạt', 'được', 'nhiệt', 'độ', 'cần', 'thiết', 'để', 'đánh', 'lửa', 'nhanh', 'hơn', 'rất', 'nhiều', '(', '<num>', '°', 'c', 'trong', 'vòng', '<num>', 'giây', ')', '.']
# Kết quả sau sửa: điều này có nghĩa là các bugi sấy loại mới có tính năng đạt được nhiệt độ cần thiết để đánh lửa nhanh hơn rất nhiều (850 ° c trong vòng 4 giây).
# ['kết', 'quả', 'chung', 'của', 'các', 'nghiên', 'cứu', 'về', 'trung', 'quốc', 'đều', 'chỉ', 'rõ', 'vai', 'trò', 'của', 'việc', 'nằm', 'cạnh', 'biển', 'đối', 'với', 'thu', 'hút', 'fdi', '.']
# Kết quả sau sửa: kết quả chung của các nghiên cứu về trung quốc đều chỉ rõ vai trò của việc nằm cạnh biển đối với thu hút fdi.
# ['chi', 'phí', 'quảng', 'cáo', 'được', 'nâng', 'cao', ',', 'đây', 'là', 'một', 'hình', 'thức', 'mà', 'khá', 'nhiều', 'các', 'công', 'ty', 'áp', 'dụng', 'và', 'đặc', 'biệt', 'là', 'các', 'doanh', 'nghiệp', 'có', 'vốn', 'đầu', 'tư', 'trực', 'tiếp', 'từ', 'nước', 'ngoài', 'áp', 'dụng', 'khá', 'nhiều', '.']
# Kết quả sau sửa: chi phí quảng cáo được nâng cao, đây là một hình thức mà khá nhiều các công ty áp dụng và đặc biệt là các doanh nghiệp có vốn đầu tư trực tiếp từ nước ngoài áp dụng khá nhiều.
# ['s', '(', '<num>', ',', '<num>', ')', 'và', 't', '(', '<num>', ')', ':', 'mở', 'rộng', 'thị', 'trường', 'ra', 'nước', 'ngoài', ',', 'củng', 'cố', 'uy', 'tín', ',', 'hình', 'ảnh', 'của', 'công', 'ty', '.']
# Kết quả sau sửa: s (1,2,5,6) và t (4): mở rộng thị trường ra nước ngoài, củng cố uy tín, hình ảnh của công ty.
# ['qua', 'thống', 'kê', 'có', 'thể', 'thấy', 'đa', 'số', 'các', 'em', 'đều', 'thấy', 'môn', 'sinh', 'học', 'có', 'thể', 'giúp', 'các', 'em', 'trả', 'lời', 'các', 'vấn', 'đề', 'cụ', 'thể', 'trong', 'thực', 'tiễn', 'cũng', 'như', 'là', 'hình', 'thành', 'và', 'củng', 'cố', 'được', 'nhiều', 'năng', 'lực', ',', 'kĩ', 'năng', 'thực', 'hành', ',', 'hợp', 'tác', ',', 'sáng', 'tạo', '.']
# Kết quả sau sửa: qua thống kê có thể thấy đa số các em đều thấy môn sinh học có thể giúp các em trả lời các vấn đề cụ thể trong thực tiễn cũng như là hình thành và củng cố được nhiều năng lực, kĩ năng thực hành, hợp tác, sáng tạo.
# ['chỉ', 'tiêu', 'này', 'phản', 'ánh', 'mức', 'doanh', 'thu', 'đạt', 'được', 'trên', 'một', 'đồng', 'chi', 'phí', 'tiền', 'lương', '.']
# Kết quả sau sửa: chỉ tiêu này phản ánh mức doanh thu đạt được trên một đồng chi phí tiền lương.
# ['kết', 'quả', 'như', 'sau', ':', '-', 'với', 'giáo', 'viên', ':', 'để', 'biết', 'được', 'tình', 'trạng', 'của', 'dạy', 'học', 'gdhn', 'trong', 'nhà', 'trường', 'tôi', 'tiến', 'hành', 'phiếu', 'hỏi', 'ý', 'kiến', 'đối', 'với', 'các', 'giáo', 'viên', 'trong', 'trường', 'thcs', 'phùng', 'chí', 'kiên', ',', 'nam', 'định', '.']
# Kết quả sau sửa: kết quả như sau: - với giáo viên: để biết được tình trạng của dạy học gdhn trong nhà trường tôi tiến hành phiếu hỏi ý kiến đối với các giáo viên trong trường thcs phùng chí kiên, nam định.
# ['tuy', 'cầu', 'về', 'gạo', 'là', 'ít', 'biến', 'động', 'nhưng', 'với', 'sản', 'phẩm', 'đặc', 'sản', 'thì', 'giá', 'quyết', 'định', 'khá', 'lớn', '.']
# Kết quả sau sửa: tuy cầu về gạo là ít biến động nhưng với sản phẩm đặc sản thì giá quyết định khá lớn.
# ['và', 'giúp', 'cho', 'tác', 'giả', 'có', 'thể', 'dễ', 'dàng', 'tiếp', 'cận', 'được', 'người', 'có', 'nhu', 'cầu', 'sử', 'dụng', 'tác', 'phẩm', '.']
# Kết quả sau sửa: và giúp cho tác giả có thể dễ dàng tiếp cận được người có nhu cầu sử dụng tác phẩm.
# ['tham', 'gia', 'vào', 'nghiên', 'cứu', 'đa', 'dạng', 'hóa', 'các', 'sản', 'phẩm', ',', 'phát', 'triển', 'nhiều', 'sản', 'phẩm', 'khác', 'để', 'đáp', 'ứng', 'thị', 'trường', '.']
# Kết quả sau sửa: tham gia vào nghiên cứu đa dạng hóa các sản phẩm, phát triển nhiều sản phẩm khác để đáp ứng thị trường.
# ['để', 'chứng', 'minh', 'hai', 'cạnh', 'trên', 'vuông', 'góc', 'ta', 'cần', 'chứng', 'minh', 'góc', 'giữa', 'chúng', 'bằng', '<num>', 'độ', '.']
# Kết quả sau sửa: để chứng minh hai cạnh trên vuông góc ta cần chứng minh góc giữa chúng bằng 90 độ.
# ['các', 'trò', 'chơi', 'tôi', 'thường', 'sử', 'dụng', ':', 'ai', 'nhanh', 'hơn', '?', ',', 'gắn', 'tên', ',', 'rung', 'chuông', 'vàng', '.']
# Kết quả sau sửa: các trò chơi tôi thường sử dụng: ai nhanh hơn? , gắn tên, rung chuông vàng.
# ['đến', 'khi', 'kết', 'thúc', 'quá', 'trình', 'thì', 'tất', 'cả', 'các', 'nút', 'trên', 'mạng', 'đều', 'sẽ', 'tìm', 'ra', 'được', 'bước', 'truyền', 'kế', 'tiếp', 'tối', 'ưu', 'đến', 'tất', 'cả', 'mọi', 'đích', ',', 'và', 'tổng', 'chi', 'phí', 'tốt', 'nhất', 'nhờ', 'vào', 'thuật', 'toán', 'phân', 'phối', 'tối', 'ưu', '.']
# Kết quả sau sửa: đến khi kết thúc quá trình thì tất cả các nút trên mạng đều sẽ tìm ra được bước truyền kế tiếp tối ưu đến tất cả mọi đích, và tổng chi phí tốt nhất nhờ vào thuật toán phân phối tối ưu.
# ['đây', 'là', 'một', 'thương', 'hiệu', 'mới', 'với', 'một', 'thị', 'trường', 'mới', 'đầy', 'tiềm', 'năng', '.']
# Kết quả sau sửa: đây là một thương hiệu mới với một thị trường mới đầy tiềm năng.
# ['khiếu', 'nại', 'về', 'việc', 'chưa', 'sử', 'dụng', 'các', 'dịch', 'vụ', '<num>', 'đơn', ',', 'chiếm', '<num>', '%', '.']
# Kết quả sau sửa: khiếu nại về việc chưa sử dụng các dịch vụ 24 đơn, chiếm 9,20 %.
# ['sở', 'kế', 'hoạch', 'và', 'đầu', 'tư', 'tỉnh', 'chịu', 'trách', 'nhiệm', 'thực', 'hiện', 'chính', 'sách', 'ưu', 'đãi', 'đầu', 'tư', ',', 'rà', 'soát', ',', 'nhận', 'và', 'xử', 'lý', 'các', 'khiếu', 'nại', 'của', 'các', 'nhà', 'đầu', 'tư', 'và', 'hỗ', 'trợ', 'việc', 'thực', 'hiện', 'các', 'dự', 'án', 'fdi', '.']
# Kết quả sau sửa: sở kế hoạch và đầu tư tỉnh chịu trách nhiệm thực hiện chính sách ưu đãi đầu tư, rà soát, nhận và xử lý các khiếu nại của các nhà đầu tư và hỗ trợ việc thực hiện các dự án fdi.
# ['trên', 'thực', 'tế', ',', 'seo', 'spam', 'là', 'một', 'trong', 'những', 'cách', 'kiếm', 'tiền', 'sinh', 'lợi', 'hơn', 'từ', 'một', 'website', 'tấn', 'công', 'và', 'cũng', 'là', 'một', 'trong', 'những', 'hình', 'thức', 'lây', 'nhiễm', 'phổ', 'biến', 'nhất', '.']
# ...
# Kết quả sau sửa: sản phẩm tồn tại dưới hai dạng chủ yếu là sản phẩm vật chất và sản phẩm phi vật chất nhằm thỏa mãn nhu cầu của khách hàng trong một thời điểm nhất định.
# ['phương', 'pháp', 'cân', 'đong', 'vật', 'liệu', 'theo', 'thể', 'tích', 'được', 'xác', 'định', 'theo', 'khối', 'vật', 'liệu', 'cung', 'cấp', 'qua', 'thiết', 'bị', 'qua', 'một', 'đơn', 'vị', 'thời', 'gian', '.']
# Kết quả sau sửa: phương pháp cân đong vật liệu theo thể tích được xác định theo khối vật liệu cung cấp qua thiết bị qua một đơn vị thời gian.
# ['mọi', 'hoạt', 'động', 'trong', 'xã', 'hội', 'hiện', 'đại', 'đều', 'phải', 'dựa', 'trên', 'thông', 'tin', '.']
# Kết quả sau sửa: mọi hoạt động trong xã hội hiện đại đều phải dựa trên thông tin.
# ['chất', 'lượng', 'hàng', 'hóa', '(', 'đỡ', 'đập', 'tấn', 'công', ',', 'chắn', ',', 'đỡ', 'bóng', 'và', 'đưa', 'qua', 'tấn', 'công', ')', '.']
# Kết quả sau sửa: chất lượng hàng hóa (đỡ đập tấn công, chắn, đỡ bóng và đưa qua tấn công).
# ['quản', 'lý', 'ngân', 'sách', 'đòi', 'hỏi', 'phải', 'công', 'khai', ',', 'minh', 'bạch', 'xuất', 'phát', 'từ', 'đòi', 'hỏi', 'chính', 'đáng', 'của', 'người', 'dân', 'với', 'tư', 'cách', 'là', 'người', 'nộp', 'thuế', 'cho', 'nhà', 'nước', '.']
# Kết quả sau sửa: quản lý ngân sách đòi hỏi phải công khai, minh bạch xuất phát từ đòi hỏi chính đáng của người dân với tư cách là người nộp thuế cho nhà nước.
# ['mô', 'hình', 'swot', 'là', 'mô', 'hình', 'phân', 'tích', 'kinh', 'doanh', 'nổi', 'tiếng', 'dành', 'cho', 'mọi', 'doanh', 'nghiệp', 'muốn', 'cải', 'thiện', 'tình', 'hình', 'kinh', 'doanh', 'bằng', 'định', 'hướng', 'đúng', 'đắn', 'và', 'xây', 'dựng', 'những', 'nền', 'tảng', 'phát', 'triển', 'vững', 'chắc', '.']
# Kết quả sau sửa: mô hình swot là mô hình phân tích kinh doanh nổi tiếng dành cho mọi doanh nghiệp muốn cải thiện tình hình kinh doanh bằng định hướng đúng đắn và xây dựng những nền tảng phát triển vững chắc.
# ['tăng', 'cường', 'tối', 'đa', 'cơ', 'giới', 'nhất', 'là', 'đối', 'với', 'những', 'công', 'việc', 'nặng', ',', 'phải', 'kết', 'hợp', 'tốt', 'giữa', 'máy', 'thi', 'công', 'chủ', 'đạo', 'với', 'các', 'thiết', 'bị', 'hỗ', 'trợ', 'khác', ',', 'kết', 'hợp', 'giữa', 'mỹ', 'và', 'phơi', 'nắng', 'thủ', 'công', '.']
# Kết quả sau sửa: tăng cường tối đa cơ giới nhất là đối với những công việc nặng, phải kết hợp tốt giữa máy thi công chủ đạo với các thiết bị hỗ trợ khác, kết hợp giữa mỹ và phơi nắng thủ công.
# ['giá', 'trị', 'của', 'h', 'càng', 'cao', 'có', 'nghĩa', 'là', 'doanh', 'nghiệp', 'thu', 'về', 'được', 'càng', 'nhiều', 'trên', 'mỗi', 'đồng', 'chi', 'phí', 'là', 'phí', 'thì', 'tòa', 'h', 'càng', 'thấp', 'nghĩa', 'là', 'doanh', 'nghiệp', 'đang', 'quản', 'lý', 'chi', 'phí', 'chưa', 'hiệu', 'quả', 'và', 'cần', 'có', 'các', 'biện', 'pháp', 'để', 'cải', 'thiện', 'tình', 'hình', 'trên', '.']
# Kết quả sau sửa: giá trị của h càng cao có nghĩa là doanh nghiệp thu về được càng nhiều trên mỗi đồng chi phí là phí thì tòa h càng thấp nghĩa là doanh nghiệp đang quản lý chi phí chưa hiệu quả và cần có các biện pháp để cải thiện tình hình trên.
# ['chú', 'ý', 'phải', 'đảm', 'bảo', 'cho', 'các', 'góc', 'cạnh', ',', 'bề', 'mặt', 'không', 'bị', 'sứt', 'mẻ', '.']
# Kết quả sau sửa: chú ý phải đảm bảo cho các góc cạnh, bề mặt không bị sứt mẻ.
# ['theo', 'một', 'ý', 'kiến', 'khá', 'phổ', 'biến', ',', 'cơ', 'sở', 'của', 'toàn', 'cầu', 'hóa', 'trước', 'hết', 'đó', 'là', 'chiến', 'lược', 'văn', 'hóa', 'nhằm', 'tuyên', 'truyền', ',', 'phổ', 'biến', 'và', 'khẳng', 'định', 'những', 'chuẩn', 'mực', ',', 'những', 'giá', 'trị', 'và', 'những', 'quy', 'chế', 'của', 'hiện', 'thực', 'phương', 'tây', 'trong', 'toàn', 'nhân', 'loại', '.']
# Kết quả sau sửa: theo một ý kiến khá phổ biến, cơ sở của toàn cầu hóa trước hết đó là chiến lược văn hóa nhằm tuyên truyền, phổ biến và khẳng định những chuẩn mực, những giá trị và những quy chế của hiện thực phương tây trong toàn nhân loại.
# ['mua', 'sự', 'không', 'chắc', 'chắn', 'bị', 'bản', 'chất', 'và', 'giá', 'trị', 'của', 'các', 'yếu', 'tố', 'đầu', 'vào', '(', 'ví', 'dụ', ',', 'công', 'nghệ', 'đang', 'được', 'bán', ')', '.']
# Kết quả sau sửa: mua sự không chắc chắn bị bản chất và giá trị của các yếu tố đầu vào (ví dụ, công nghệ đang được bán).
# ['tác', 'giả', 'đã', 'khẳng', 'định', 'rằng', ',', 'nếu', 'hoạt', 'động', 'quản', 'lý', 'không', 'tốt', 'thì', 'quá', 'trình', 'giáo', 'dục', 'và', 'đào', 'tạo', 'trong', 'nhà', 'trường', 'cũng', 'không', 'đạt', 'được', 'những', 'mục', 'tiêu', 'như', 'mong', 'muốn', '.']
# Kết quả sau sửa: tác giả đã khẳng định rằng, nếu hoạt động quản lý không tốt thì quá trình giáo dục và đào tạo trong nhà trường cũng không đạt được những mục tiêu như mong muốn.
# ['các', 'thành', 'viên', 'hội', 'đồng', 'quản', 'trị', 'công', 'ty', 'được', 'báo', 'chí', 'việt', 'nam', 'bình', 'chọn', 'là', 'những', 'cá', 'nhân', 'giàu', 'nhất', 'việt', 'nam', 'dựa', 'trên', 'tài', 'sản', 'chứng', 'khoán', '.']
# Kết quả sau sửa: các thành viên hội đồng quản trị công ty được báo chí việt nam bình chọn là những cá nhân giàu nhất việt nam dựa trên tài sản chứng khoán.
# ['để', 'đảm', 'bảo', 'nguồn', 'vốn', 'đầu', 'tư', 'cho', 'phát', 'triển', ',', 'các', 'quốc', 'gia', 'đều', 'dựa', 'vào', 'hai', 'nguồn', ':', 'vốn', 'tích', 'lũy', 'trong', 'nước', 'và', 'vốn', 'nước', 'ngoài', '.']
# Kết quả sau sửa: để đảm bảo nguồn vốn đầu tư cho phát triển, các quốc gia đều dựa vào hai nguồn: vốn tích lũy trong nước và vốn nước ngoài.
# ['về', 'cơ', 'bản', ',', 'điểm', 'tương', 'đồng', 'giữa', 'dạy', 'học', 'chủ', 'đề', 'và', 'dạy', 'học', 'truyền', 'thống', 'là', 'vẫn', 'coi', 'trọng', 'việc', 'lĩnh', 'hội', 'một', 'nội', 'dung', 'kiến', 'thức', 'nền', 'tảng', ',', 'vì', 'thế', 'dạy', 'học', 'theo', 'chủ', 'đề', 'là', 'mô', 'hình', 'dạy', 'học', 'có', 'thể', 'vận', 'dụng', 'vào', 'thực', 'tiễn', 'hiện', 'nay', 'dễ', 'dàng', 'hơn', 'một', 'số', 'môn', 'học', 'khác', '.']
# Kết quả sau sửa: về cơ bản, điểm tương đồng giữa dạy học chủ đề và dạy học truyền thống là vẫn coi trọng việc lĩnh hội một nội dung kiến thức nền tảng, vì thế dạy học theo chủ đề là mô hình dạy học có thể vận dụng vào thực tiễn hiện nay dễ dàng hơn một số môn học khác.
# ['điều', 'gì', 'cũng', 'bộ', 'ngành', 'thuế', 'ngày', 'càng', 'được', 'trang', 'bị', 'những', 'kiến', 'thức', 'chuyên', 'sâu', ',', 'chuyên', 'nghiệp', ',', 'có', 'các', 'kỹ', 'năng', 'quản', 'lý', 'thuế', 'hiện', 'đại', ',', 'các', 'kỹ', 'năng', 'áp', 'dụng', ',', 'sử', 'dụng', 'các', 'phương', 'tiện', 'điện', 'tử', 'trong', 'việc', 'phân', 'tích', ',', 'đánh', 'giá', ',', 'tổng', 'hợp', ',', '.', '.', '.']
# Kết quả sau sửa: điều gì cũng bộ ngành thuế ngày càng được trang bị những kiến thức chuyên sâu, chuyên nghiệp, có các kỹ năng quản lý thuế hiện đại, các kỹ năng áp dụng, sử dụng các phương tiện điện tử trong việc phân tích, đánh giá, tổng hợp, . . .
# ['trên', 'cơ', 'sở', 'phân', 'tích', 'về', 'mặt', 'lý', 'luận', 'các', 'quy', 'định', 'của', 'bộ', 'luật', 'dân', 'sự', '<num>', 'về', 'lỗi', 'trong', 'trách', 'nhiệm', 'bồi', 'thường', 'thiệt', 'hại', 'ngoài', 'hợp', 'đồng', ',', 'báo', 'cáo', 'tích', 'thực', 'tiễn', 'áp', 'dụng', 'các', 'quy', 'định', 'về', 'lỗi', 'trong', 'trách', 'nhiệm', 'bồi', 'thường', 'thiệt', 'hại', 'ngoài', 'hợp', 'đồng', '.']
# Kết quả sau sửa: trên cơ sở phân tích về mặt lý luận các quy định của bộ luật dân sự 2015 về lỗi trong trách nhiệm bồi thường thiệt hại ngoài hợp đồng, báo cáo tích thực tiễn áp dụng các quy định về lỗi trong trách nhiệm bồi thường thiệt hại ngoài hợp đồng.
# ['mối', 'quan', 'hệ', 'giữa', 'các', 'giải', 'pháp', ',', 'biện', 'pháp', 'phòng', 'chống', '.']
# Kết quả sau sửa: mối quan hệ giữa các giải pháp, biện pháp phòng chống.
# ['giảm', 'tỷ', 'lệ', 'dự', 'trữ', 'bắt', 'buộc', ':', 'ngân', 'hàng', 'chờ', 'được', 'thưởng', '.']
# Kết quả sau sửa: giảm tỷ lệ dự trữ bắt buộc: ngân hàng chờ được thưởng.
# ['ngoài', 'ra', ',', 'giáo', 'viên', 'cần', 'có', 'để', 'đề', 'xuất', ',', 'chỉnh', 'sửa', 'các', 'thang', 'đo', 'của', 'thuyết', 'hành', 'vi', 'dự', 'định', 'cho', 'phù', 'hợp', 'với', 'đối', 'tượng', 'nghiên', 'cứu', '.']
# Kết quả sau sửa: ngoài ra, giáo viên cần có để đề xuất, chỉnh sửa các thang đo của thuyết hành vi dự định cho phù hợp với đối tượng nghiên cứu.
# ['sóng', 'siêu', 'âm', 'được', 'sử', 'dụng', 'để', 'hỗ', 'trợ', 'cho', 'quá', 'trình', 'loại', 'các', 'khí', 'này', 'khỏi', 'điện', 'cực', 'và', 'tạo', 'điều', 'kiện', 'cho', 'điện', 'thế', 'cao', 'hơn', 'và', 'tốc', 'độ', 'sấy', 'nhanh', 'hơn', '.']
# Kết quả sau sửa: sóng siêu âm được sử dụng để hỗ trợ cho quá trình loại các khí này khỏi điện cực và tạo điều kiện cho điện thế cao hơn và tốc độ sấy nhanh hơn.
# ['trong', 'quá', 'trình', 'giảng', 'dạy', 'ở', 'lớp', ',', 'bản', 'thân', 'tôi', 'nhận', 'thấy', 'những', 'ưu', 'điểm', 'và', 'hạn', 'chế', 'như', 'sau', '.']
# Kết quả sau sửa: trong quá trình giảng dạy ở lớp, bản thân tôi nhận thấy những ưu điểm và hạn chế như sau.
# ['tác', 'giả', 'có', 'thể', 'đọc', 'một', 'tờ', 'báo', 'in', 'dễ', 'dàng', 'ở', 'bất', 'cứ', 'đâu', ',', 'trên', 'bất', 'kì', 'phương', 'tiện', 'đi', 'lại', 'nào', '.']
# Kết quả sau sửa: tác giả có thể đọc một tờ báo in dễ dàng ở bất cứ đâu, trên bất kì phương tiện đi lại nào.
# ['th', 'thích', 'hợp', 'như', ':', 'tự', 'trắc', 'nghiệm', 'bằng', 'hệ', 'thống', 'câu', 'hỏi', 'trắc', 'nghiệm', 'khách', 'quan', ';', 'trắc', 'nghiệm', 'tự', 'luận', ',', 'hoặc', 'tự', 'so', 'sánh', 'kết', 'quả', 'học', 'tập', 'của', 'mình', 'với', 'kết', 'quả', 'đạt', 'được', 'gì', 'xác', 'thấp', '.']
# Kết quả sau sửa: th thích hợp như: tự trắc nghiệm bằng hệ thống câu hỏi trắc nghiệm khách quan; trắc nghiệm tự luận, hoặc tự so sánh kết quả học tập của mình với kết quả đạt được gì xác thấp.
# ['nếu', 'đem', 'gửi', 'ngân', 'hàng', 'một', 'số', 'vốn', 'ban', 'đầu', 'là', 'p', 'với', 'lãi', 'suất', 'mỗi', 'năm', 'là', 'r', 'theo', 'thể', 'thức', 'lãi', 'kép', 'thì', 'sau', 'r', 'năm', 'gửi', 'số', 'tiền', 'thu', 'về', 'cả', 'vốn', 'lẫn', 'lãi', 'sẽ', 'là', ':']
# Kết quả sau sửa: nếu đem gửi ngân hàng một số vốn ban đầu là p với lãi suất mỗi năm là r theo thể thức lãi kép thì sau r năm gửi số tiền thu về cả vốn lẫn lãi sẽ là:
# ['khuyến', 'khích', 'các', 'tổ', 'chức', ',', 'cá', 'nhân', 'áp', 'dụng', 'công', 'nghệ', 'tiên', 'tiến', 'hiện', 'đại', 'về', 'kinh', 'nghiệm', 'truyền', 'thống', 'để', 'tạo', 'sản', 'phẩm', 'có', 'giá', 'trị', 'cao', 'và', 'có', 'sức', 'mạnh', 'trên', 'thị', 'trường', '.']
# Kết quả sau sửa: khuyến khích các tổ chức, cá nhân áp dụng công nghệ tiên tiến hiện đại về kinh nghiệm truyền thống để tạo sản phẩm có giá trị cao và có sức mạnh trên thị trường.
# ['khu', 'tái', 'định', 'cư', 'này', 'nằm', 'trong', 'chương', 'không', 'yêu', 'cầu', 'hội', 'nhập', 'và', 'tháp', 'tách', 'cà', 'phê', 'việt', 'đã', 'hỗ', 'trợ', 'nhau', '.']
# Kết quả sau sửa: khu tái định cư này nằm trong chương không yêu cầu hội nhập và tháp tách cà phê việt đã hỗ trợ nhau.
# ['thúc', 'đẩy', 'bán', 'hàng', ':', 'một', 'trong', 'những', 'lý', 'do', 'quan', 'trọng', 'mà', 'công', 'ty', 'nên', 'sử', 'dụng', 'email', 'marketing', 'là', 'chúng', 'có', 'thể', 'thúc', 'đẩy', 'việc', 'bán', 'hàng', '.']
# Kết quả sau sửa: thúc đẩy bán hàng: một trong những lý do quan trọng mà công ty nên sử dụng email marketing là chúng có thể thúc đẩy việc bán hàng.
# ['nhìn', 'chung', 'các', 'rào', 'cản', 'phi', 'thuế', 'quan', 'được', 'áp', 'dụng', 'phổ', 'biến', 'giữa', 'quan', 'hệ', 'thương', 'mại', 'quốc', 'tế', 'gây', 'khó', 'khăn', 'cho', 'ngành', 'hàng', 'thủy', 'sản', 'xuất', 'chè', '.']
# Kết quả sau sửa: nhìn chung các rào cản phi thuế quan được áp dụng phổ biến giữa quan hệ thương mại quốc tế gây khó khăn cho ngành hàng thủy sản xuất chè.
# ['web', 'server', '-', 'web', 'server', 'là', 'nơi', 'quản', 'trị', 'viên', 'trực', 'tiếp', 'thực', 'hiện', 'các', 'thao', 'tác', 'để', 'điều', 'khiển', 'của', 'xe', '.']
# Kết quả sau sửa: web server - web server là nơi quản trị viên trực tiếp thực hiện các thao tác để điều khiển của xe.
# ['nền', 'kinh', 'tế', ':', 'công', 'ty', 'cổ', 'phần', 'thương', 'mại', 'đầu', 'tư', 'thịnh', 'vượng', '.']
# Kết quả sau sửa: nền kinh tế: công ty cổ phần thương mại đầu tư thịnh vượng.
# ['trong', 'công', 'tác', 'quản', 'lý', 'ngân', 'sách', ',', 'việt', 'yên', 'có', 'kết', 'quả', 'nhất', 'định', 'đặc', 'biệt', 'công', 'tác', 'dự', 'toán', 'và', 'quyết', 'toán', 'ngân', 'sách', '.']
# Kết quả sau sửa: trong công tác quản lý ngân sách, việt yên có kết quả nhất định đặc biệt công tác dự toán và quyết toán ngân sách.
# ['sau', 'đó', 'hướng', 'dẫn', 'hs', 'đưa', 'ra', 'các', 'ý', 'tưởng', 'thông', 'qua', 'sơ', 'đồ', 'tư', 'duy', 'để', 'xây', 'dựng', 'các', 'chủ', 'đề', 'con', 'và', 'phân', 'công', 'thực', 'hiện', 'chủ', 'đề', '.']
# Kết quả sau sửa: sau đó hướng dẫn hs đưa ra các ý tưởng thông qua sơ đồ tư duy để xây dựng các chủ đề con và phân công thực hiện chủ đề.
# ['chính', 'vì', 'sự', 'thiếu', 'hụt', 'nguồn', 'lao', 'động', 'có', 'trình', 'độ', 'cao', ',', 'dẫn', 'đến', 'năng', 'lực', 'sản', 'xuất', 'ra', 'các', 'sản', 'phẩm', 'gỗ', 'việt', 'nam', 'vẫn', 'còn', 'thấp', '.']
# Kết quả sau sửa: chính vì sự thiếu hụt nguồn lao động có trình độ cao, dẫn đến năng lực sản xuất ra các sản phẩm gỗ việt nam vẫn còn thấp.
# ['chị', 'mua', 'thêm', 'thuốc', 'rửa', 'phụ', 'khoa', 'nữa', ',', 'bột', 'màu', 'vàng', 'vàng', '.']
# Kết quả sau sửa: chị mua thêm thuốc rửa phụ khoa nữa, bột màu vàng vàng.
# ['trục', 'vít', '–', 'bánh', 'vít', ':', 'bánh', 'vít', 'chế', 'tạo', 'liền', 'với', 'trục', '<num>', ',', 'trục', 'vít', 'nối', 'với', 'motor', 'điện', '.']
# Kết quả sau sửa: trục vít – bánh vít: bánh vít chế tạo liền với trục 2, trục vít nối với motor điện.
# ['quảng', 'trạch', 'còn', 'biết', 'đến', 'là', 'vùng', 'đất', 'văn', 'vật', ',', 'có', 'truyền', 'thống', 'cách', 'mạng', ',', 'nhiều', 'danh', 'nhân', 'văn', 'hóa', 'và', 'anh', 'hùng', 'dân', 'tộc', '.']
# Kết quả sau sửa: quảng trạch còn biết đến là vùng đất văn vật, có truyền thống cách mạng, nhiều danh nhân văn hóa và anh hùng dân tộc.
# ['tổ', 'chức', 'quốc', 'tế', 'về', 'tiêu', 'chuẩn', 'hóa', 'iso', ',', 'trong', 'dự', 'thảo', 'dis', '<num>', ':', '<num>', ',', 'đã', 'đưa', 'ra', 'định', 'nghĩa', 'sau', ':', 'chất', 'lượng', 'là', 'khả', 'năng', 'của', 'tập', 'hợp', 'các', 'đặc', 'trưng', 'của', 'mẫu', 'số', 'phức', ',', 'hệ', 'thống', 'hay', 'quá', 'lớn', 'để', 'đáp', 'ứng', 'các', 'yêu', 'cầu', 'của', 'khách', 'hàng', 'và', 'các', 'bên', 'có', 'liên', 'quan', '.']
# Kết quả sau sửa: tổ chức quốc tế về tiêu chuẩn hóa iso, trong dự thảo dis 9000: 2000, đã đưa ra định nghĩa sau: chất lượng là khả năng của tập hợp các đặc trưng của mẫu số phức, hệ thống hay quá lớn để đáp ứng các yêu cầu của khách hàng và các bên có liên quan.
# ['do', 'vậy', ',', 'muốn', 'nâng', 'cao', 'được', 'chất', 'lượng', 'dịch', 'vụ', 'công', 'trong', 'nhà', 'trường', 'cần', 'có', 'một', 'đội', 'ngũ', 'có', 'phẩm', 'chất', 'tốt', ',', 'có', 'năng', 'lực', 'chuyên', 'môn', 'nghiệp', 'vụ', ',', 'có', 'đạo', 'đức', 'tốt', 'và', 'có', 'trách', 'nhiệm', 'và', 'tâm', 'huyết', 'với', 'nghề', '.']
# Kết quả sau sửa: do vậy, muốn nâng cao được chất lượng dịch vụ công trong nhà trường cần có một đội ngũ có phẩm chất tốt, có năng lực chuyên môn nghiệp vụ, có đạo đức tốt và có trách nhiệm và tâm huyết với nghề.
# ['hình', '<num>', 'ví', 'dụ', 'và', 'định', 'nghĩa', 'exchange', 'và', 'queue', '-', 'trong', 'hình', '<num>', 'là', 'cách', 'tạo', 'ra', 'một', 'dead', 'letter', 'exchange', 'đồng', 'thời', 'tạo', 'một', 'queue', 'với', 'tham', 'số', 'x', '-', 'dead', '-', 'letter', '-', 'exchange', '.']
# Kết quả sau sửa: hình 2.23 ví dụ và định nghĩa exchange và queue - trong hình 2.23 là cách tạo ra một dead letter exchange đồng thời tạo một queue với tham số x - dead - letter - exchange.
# /tmp/ipykernel_19/1692509634.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["predicted"] = test["preprocess"].apply(correct_wrapper)

# %%
test.to_csv("results.csv", index = False)

# %%
import re
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
import re
from sklearn.metrics import precision_recall_fscore_support

def clean_and_tokenize(sentence):
    # Lowercase
    sentence = sentence.lower()
    # Tokenize first, before removing punctuation
    tokens = custom_tokenize(sentence)
    # Remove punctuation from each token
    cleaned_tokens = [re.sub(r'[^\w\s]', '', token) for token in tokens]
    return cleaned_tokens

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

def evaluate_corrections(test_df, save_path="evaluated_test.csv"):
    y_true_detection = []
    y_pred_detection = []
    y_true_correction = []
    y_pred_correction = []

    wrong_sentences = []

    for i, (prep_sent, pred_sent, gold_sent) in enumerate(zip(test_df['preprocess'], test_df['predicted'], test_df['correct_text'])):
        prep_tokens = clean_and_tokenize(prep_sent)
        pred_tokens = clean_and_tokenize(pred_sent)
        gold_tokens = clean_and_tokenize(gold_sent)

        min_len = min(len(prep_tokens), len(pred_tokens), len(gold_tokens))

        sent_has_error = False

        for j in range(min_len):
            prep_token = prep_tokens[j]
            pred_token = pred_tokens[j]
            gold_token = gold_tokens[j]


            # Detection labels
            y_true_detection.append(prep_token != gold_token)
            y_pred_detection.append(pred_token != gold_token)

            # Correction labels
            if pred_token != gold_token:
                y_true_correction.append(gold_token)
                y_pred_correction.append(pred_token)
                sent_has_error = True

        if sent_has_error:
            wrong_sentences.append({
                "index": i,
                "predicted": pred_sent,
                "correct_text": gold_sent,
                "pred_tokens": pred_tokens,
                "gold_tokens": gold_tokens
            })


    # Detection metrics
    p_det, r_det, f1_det, _ = precision_recall_fscore_support(
        y_true_detection, y_pred_detection, average='binary'
    )

    print("\n Detection Results:")
    print(f"Precision: {p_det:.4f} | Recall: {r_det:.4f} | F1: {f1_det:.4f}")

    # Confusion Matrix for Detection
    cm_det = confusion_matrix(y_true_detection, y_pred_detection)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm_det, display_labels=["Correct", "Error"])
    disp.plot(cmap='Blues')
    plt.title("Detection Confusion Matrix")
    plt.show()

    # Correction metrics
    if y_true_correction:
        p_corr, r_corr, f1_corr, _ = precision_recall_fscore_support(
            y_true_correction, y_pred_correction, average='micro'
        )

        print("\n Correction Results (on detected tokens):")
        print(f"Precision: {p_corr:.4f} | Recall: {r_corr:.4f} | F1: {f1_corr:.4f}")

        # Confusion Matrix for Correction
        labels = list(set(y_true_correction + y_pred_correction))
        cm_corr = confusion_matrix(y_true_correction, y_pred_correction, labels=labels)
        disp_corr = ConfusionMatrixDisplay(confusion_matrix=cm_corr, display_labels=labels)
        disp_corr.plot(cmap='Oranges', xticks_rotation=90)
        plt.title("Correction Confusion Matrix")
        plt.show()

    else:
        print("\n No corrections made or needed.")
        p_corr = r_corr = f1_corr = 0.0

    # Print wrong predictions
    print("\n===== Các câu dự đoán sai =====")
    for wrong in wrong_sentences:
        print(f"\n# {wrong['index']}")
        print(f"Predicted   : {wrong['predicted']}")
        print(f"Correct     : {wrong['correct_text']}")
        print(f"Pred tokens : {wrong['pred_tokens']}")
        print(f"Gold tokens : {wrong['gold_tokens']}")

    # Save wrong sentences
    pd.DataFrame(wrong_sentences).to_csv("wrong_sentences.csv", index=False)

    return {
        "detection": {"precision": p_det, "recall": r_det, "f1": f1_det},
        "correction": {"precision": p_corr, "recall": r_corr, "f1": f1_corr}
    }

# %%
# results = evaluate_corrections(test, save_path="test_with_prediction.csv")

# print("=== Kết quả đánh giá ===")
# print("🔍 Detection (Phát hiện lỗi):")
# print(f"Precision: {results['detection']['precision']:.4f}")
# print(f"Recall   : {results['detection']['recall']:.4f}")
# print(f"F1       : {results['detection']['f1']:.4f}")

# print("\n🛠️ Correction (Sửa lỗi):")
# print(f"Precision: {results['correction']['precision']:.4f}")
# print(f"Recall   : {results['correction']['recall']:.4f}")
# print(f"F1       : {results['correction']['f1']:.4f}")
