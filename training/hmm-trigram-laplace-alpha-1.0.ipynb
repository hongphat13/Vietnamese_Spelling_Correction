# %%
import pandas as pd

# %%
def min_edit_distance(s1, s2):
    """
    Tính khoảng cách chỉnh sửa (Levenshtein distance) giữa hai từ s1 và s2.
    Hỗ trợ tiếng Việt có dấu, đa ký tự.

    Trả về: số bước chỉnh sửa tối thiểu để biến s1 thành s2.
    """
    len_s1 = len(s1)
    len_s2 = len(s2)

    # Khởi tạo ma trận khoảng cách
    dp = [[0] * (len_s2 + 1) for _ in range(len_s1 + 1)]

    # Khoảng cách từ "" đến s1 hoặc s2
    for i in range(len_s1 + 1):
        dp[i][0] = i
    for j in range(len_s2 + 1):
        dp[0][j] = j

    # Tính khoảng cách
    for i in range(1, len_s1 + 1):
        for j in range(1, len_s2 + 1):
            cost = 0 if s1[i-1] == s2[j-1] else 1

            dp[i][j] = min(
                dp[i-1][j] + 1,      # xóa
                dp[i][j-1] + 1,      # thêm
                dp[i-1][j-1] + cost  # thay thế
            )
    # print(dp)
    return dp[len_s1][len_s2]

# %%
print(min_edit_distance("nhận", "nhân"))  # → 1
print(min_edit_distance("nhan", "cảh"))  # → 1
print(min_edit_distance("công", "cung"))  # → 1
print(min_edit_distance("công", "công"))  # → 0
# Out:
# 1
# 4
# 1
# 0

# %%
test = pd.read_csv("/kaggle/input/preprocessing/test.csv")
test = test[['text', 'preprocess', 'correct_text']]
test
# Out:
#                                                    text  \
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giam mà còn tăng thê...
# 3     Đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chù nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
#                                              preprocess  \
# 0     thông qua công tác tuyên truyền, vận động này ...
# 1     do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     giữ được chỉ số này không giam mà còn tăng thê...
# 3     đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  tuy nhiên, khi nói đến e-learning, các phương ...
# 8963  đứng trước những hành vi đi ngược lại với đạo ...
# 8964  quan điểm biện chứng của chù nghĩa mác - lênin...
# 8965  đối với biểu đồ histogram, nếu giá trị trung b...
# 8966  trong mỗi khu vực mà đội phát triển thị trường...
#
#                                            correct_text
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giảm mà còn tăng thê...
# 3     Đứng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chủ nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
# [8967 rows x 3 columns]

# %%
train = pd.read_csv("/kaggle/input/preprocessing/train.csv")
train
# Out:
#                                                       text  \
# 0                                   Chây ì nộp phạt nguội.
# 1                                  Chây ì ngộp phạt nguội.
# 2                                    Chây i nộp phạt ngội.
# 3        Hàng chục ngàn phươngg tiện bị ghi hình iv phạ...
# 4        Hàng chục ngàn phương tiệng bị ghy hình vi pha...
# ...                                                    ...
# 4980399  Phó thủ tướngg cũng yêu cầu hoàn thành cổ phầc...
# 4980400  Phó thủ tướng cũng Iu cầu hoờn thành cổ phần ó...
# 4980401  Phó thũ tướngx cũng yêu cầu hoàn thành cổ phần...
# 4980402  Pho thủ tướng cũng iu cầu hoàn thàh cổ phần hó...
# 4980403  Pho thủ tướngd cũng yêu vàu hoàn thành cổ phần...
#
#                                               correct_text
# 0                                   Chây ì nộp phạt nguội.
# 1                                   Chây ì nộp phạt nguội.
# 2                                   Chây ì nộp phạt nguội.
# 3        Hàng chục ngàn phương tiện bị ghi hình vi phạm...
# 4        Hàng chục ngàn phương tiện bị ghi hình vi phạm...
# ...                                                    ...
# 4980399  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980400  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980401  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980402  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
# 4980403  Phó thủ tướng cũng yêu cầu hoàn thành cổ phần ...
#
# [4980404 rows x 2 columns]

# %%
unique_correct_texts = pd.read_csv('/kaggle/input/preprocessing/unique_correct_texts.csv')
unique_correct_texts
# Out:
#                                            correct_text
# 0     Cung cấp những thông tin về tình hình kinh tế ...
# 1     Đảng, Nhà nước Việt Nam luôn coi trọng yếu tố ...
# 2     Việc giảng dạy mang lại cho hs những kiến thức...
# 3     Kết quả nghiên cứu cho thấy Môi trường giáo dụ...
# 4     Ứng dụng môi trường công nghệ đến các hoạt độn...
# ...                                                 ...
# 9326  Cấp trên của Giám đốc điều hành là Hội đồng qu...
# 9327  Theo nghĩa hẹp, nợ công bao gồm nghĩa vụ nợ củ...
# 9328  Cụ thể, trong phần nội dung sẽ có sự tập trung...
# 9329  Ví dụ khi đọc bài thơ Mẹ nếu câu cuối Mẹ là ng...
# 9330  Trong mỗi khu vực mà đội phát triển thị trường...
#
# [9331 rows x 1 columns]

# %% [markdown]
# ## 1. Tiền xử lý dữ liệu
# - Chuẩn hóa các câu đúng (lowercase, loại bỏ ký tự không cần thiết).
#
# - Tách từ và sinh ra mô hình 3-gram từ tập văn bản đúng.
#
# - Tạo tập từ vựng (vocab) gồm tất cả các từ đã xuất hiện.

# %%
import re
import pandas as pd

def clean_punctuation(text):
    # 0. Handle NaN values (already present)
    if pd.isnull(text):
        return text
    
    # Ensure text is a string (important for mixed data types in a DataFrame column)
    text = str(text)

    # --- Punctuation Normalization (Order matters!) ---

    # 1. Normalize ellipses: Ensure all sequences of 2 or more periods become '...'
    #    e.g., ".." -> "...", "...." -> "..."
    text = re.sub(r'\.{2,}', '...', text)

    # 2. Handle numbers with periods/commas (e.g., 1 . 2 -> 1.2, 1,000 -> 1,000)
    #    This is crucial to do early, before general space removal around punctuation.
    text = re.sub(r'(?<=\d)\s*([.,])\s*(?=\d)', r'\1', text)

    # 3. Remove quotation marks (single and double) entirely as per requirement #6
    #    This simplifies later rules as we don't need to account for them.
    text = re.sub(r'[\'"]', '', text)

    # 4. Consolidate repeated punctuation (e.g., '!!' -> '!', '???' -> '?')
    #    This excludes ellipses, which were handled in step 1.
    #    If you want to preserve '!!!' as '!!!', remove this rule or modify it.
    text = re.sub(r'([.,!?;:])\1+', r'\1', text)
    
    # 5. Standardize spacing around punctuation and parentheses
    
    # 5.1 Remove any space immediately before common punctuation (.,!?:;) and ellipses (...)
    #    e.g., "hello ." -> "hello.", "word ..." -> "word..."
    text = re.sub(r'\s+([.,!?:;])', r'\1', text)
    text = re.sub(r'\s+(\.\.\.)', r'\1', text) # Specific for ellipses

    # 5.2 Add space after punctuation (except when it's part of a number)
    text = re.sub(r'(?<!\d)([.,])(?!\d)(?=\S)', r'\1 ', text)
    text = re.sub(r'(?<=[!?;:])(?=\S)', r' \g<0>', text)  # safe spacing for other punctuations
    text = re.sub(r'(\.\.\.)(?=\S)', r'\1 ', text)  # ellipsis spacing

    # 5.3 Handle parentheses spacing (section #5 in original)
    #    Remove any spaces immediately inside or around parentheses:
    #    e.g., " ( hello ) " -> "(hello)", " (hello" -> "(hello"
    text = re.sub(r'\s*([()])\s*', r'\1', text)
    #    Add space before opening parenthesis if preceded by a word character:
    #    e.g., "word(content)" -> "word (content)"
    text = re.sub(r'(?<=\w)\(', ' (', text)
    #    Add space after closing parenthesis if followed by a word character:
    #    e.g., "(content)word" -> "(content) word"
    text = re.sub(r'\)(?=\w)', ') ', text)

    # --- Final Cleanup ---

    # 6. Reduce multiple spaces to single spaces (section #7 in original)
    text = re.sub(r'\s{2,}', ' ', text)

    # 7. Strip leading/trailing whitespace (already present)
    return text.strip()

# %%
clean_punctuation("13,5 triêu")
# Out:
# '13,5 triêu'

# %%
import re
from collections import defaultdict, Counter
from nltk.tokenize import word_tokenize
import nltk
import string

nltk.download('punkt')


import re

def clean_text(text):
    # Thay thế URL trước
    text = re.sub(r'https?://\S+|www\.\S+', '<url>', text)

    # Thay thế emoji bằng <emoji>
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U0001F700-\U0001F77F"  # alchemical
        u"\U0001F780-\U0001F7FF"  # geometric
        u"\U0001F800-\U0001F8FF"  # arrows
        u"\U0001F900-\U0001F9FF"  # supplemental symbols
        u"\U0001FA00-\U0001FA6F"  # chess
        u"\U0001FA70-\U0001FAFF"  # symbols extended
        u"\u2600-\u26FF"          # misc symbols
        u"\u2700-\u27BF"          # dingbats
        "]+", flags=re.UNICODE
    )
    text = emoji_pattern.sub('<emoji>', text)

    # Thay thế định dạng ngày (dd/mm/yyyy hoặc yyyy/mm/dd)
    text = re.sub(r'\b\d{1,2}[-/]\d{1,2}[-/]\d{2,4}\b', '<date>', text)
    text = re.sub(r'\b\d{4}[-/]\d{1,2}[-/]\d{1,2}\b', '<date>', text)

    # Thay thế thời gian (hh:mm hoặc hh:mm:ss)
    text = re.sub(r'\b\d{1,2}:\d{2}(:\d{2})?\b', '<time>', text)

    # Thay thế số (gồm số thập phân và số nguyên)
    text = re.sub(r'\d+([.,]\d+)?', '<num>', text)

    return text
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import re
from nltk.tokenize import word_tokenize

def custom_tokenize(text):
    # 1. Tìm các token đặc biệt dạng <...>
    special_tokens = list(set(re.findall(r'<[^<> ]+>', text)))
    token_map = {token: f"___SPECIALTOKEN{i}___" for i, token in enumerate(special_tokens)}

    # 2. Thay thế token đặc biệt bằng placeholder
    for orig, placeholder in token_map.items():
        text = text.replace(orig, placeholder
                           )

    # 3. Tách các placeholder nếu dính vào từ hoặc ký tự đặc biệt
    for placeholder in token_map.values():
        text = re.sub(rf'({re.escape(placeholder)})([^\W_]+)', r'\1 \2', text)
        text = re.sub(rf'([^\W_]+)({re.escape(placeholder)})', r'\1 \2', text)
        text = re.sub(rf'({re.escape(placeholder)})([/%°\-+=±≥<>\.])', r'\1 \2', text)
        text = re.sub(rf'([/%°\-+=±≥<>\.])({re.escape(placeholder)})', r'\1 \2', text)

    # 4. TÁCH CÁC DẤU NHƯ / - … ... THÀNH TOKEN RIÊNG
    # Chèn khoảng trắng quanh các ký hiệu phân tách
    text = re.sub(r'([/\-+=±%°₫.<>\[\]…])', r' \1 ', text)
    text = re.sub(r'\.\.\.', ' ... ', text)  # tách "..." riêng
    text = re.sub(r'…', ' … ', text)        # tách dấu ba chấm unicode riêng

    # 5. Token hóa
    tokens = word_tokenize(text)

    # 6. Thay lại placeholder bằng token đặc biệt gốc
    reverse_map = {v: k for k, v in token_map.items()}
    tokens = [reverse_map.get(t, t) for t in tokens]

    return tokens

# %%
text = "Ngày 12/06/2024 lúc 08:45, 30-days giá là 13.78triệu đồng 😂 www.example.com 12/3"
cleaned = clean_text(text)
print("Sau khi clean:", cleaned)
tokens = custom_tokenize(cleaned)
print("Token:", tokens)
# Out:
# Sau khi clean: Ngày <date> lúc <time>, <num>-days giá là <num>triệu đồng <emoji> <url> <num>/<num>
# Token: ['Ngày', '<date>', 'lúc', '<time>', ',', '<num>', '-', 'days', 'giá', 'là', '<num>', 'triệu', 'đồng', '<emoji>', '<url>', '<num>', '/', '<num>']

# %%
def preprocess(texts):
    ngrams = defaultdict(Counter)
    vocab = set()

    for text in texts:
        text = clean_punctuation(text)
        text = clean_text(text)
        tokens = custom_tokenize(text.lower())

        # Thêm token đặc biệt cho đầu và cuối câu
        tokens = ['<start1>', '<start2>'] + tokens + ['<end1>', '<end2>']

        vocab.update(tokens)

        for i in range(2, len(tokens)):
            context = (tokens[i - 2], tokens[i - 1])
            word = tokens[i]
            ngrams[context][word] += 1

    return ngrams, vocab

# %% [markdown]
# ## 2. Tính toán xác suất chuyển tiếp (Transition Probability)
# - Dựa trên mô hình 3-gram: P(w₃ | w₁, w₂)
#
# - Với mỗi bộ ba liên tiếp (w₁, w₂, w₃) trong văn bản đúng, đếm tần suất xuất hiện.
#
# - Chuẩn hóa tần suất để có xác suất chuyển tiếp giữa các từ đúng theo ngữ cảnh.

# %%
def get_transition_prob(ngrams, vocab, alpha=1.0):
    transition_prob = {}
    context_totals = {}

    V = len(vocab)

    for context, counter in ngrams.items():
        total = sum(counter.values())
        context_totals[context] = total

        for word, count in counter.items():
            prob = (count + alpha) / (total + alpha * V)
            trigram = (context[0], context[1], word)
            transition_prob[trigram] = prob

    return transition_prob, context_totals

# %% [markdown]
# ## 3. Tính xác suất phát xạ (Emission Probability)
# - Mỗi từ sai (quan sát được) có thể phát ra từ một số từ đúng.
#
# - Dựa vào Minimum Edit Distance giữa từ sai và từng từ đúng trong từ điển.
#
# - Những từ đúng có khoảng cách nhỏ nhất được coi là ứng viên thay thế hợp lý, và được gán xác suất tỷ lệ nghịch với khoảng cách.

# %%
def get_emission_prob(observed_word, vocab, max_distance=5):
    target_distance = min(len(observed_word) - 1, max_distance)
    candidates = []
    for word in vocab:
        dist = min_edit_distance(observed_word, word)
        if dist <= target_distance:
            candidates.append((word, dist))

    if not candidates:
        # Dự phòng: nếu không có ứng viên đúng khoảng cách thì fallback
        candidates = [(word, min_edit_distance(observed_word, word)) for word in vocab
                      if min_edit_distance(observed_word, word) <= max_distance]

        if not candidates:
            return {}

    # for word, dist in candidates:
        # print(f"  - '{word}' (khoảng cách: {dist})")

    # Tính xác suất ngược lại với khoảng cách
    probs = {}
    for word, dist in candidates:
        prob = 1 / (1 + dist)
        probs[word] = prob

    # Chuẩn hóa
    total = sum(probs.values())
    for word in probs:
        probs[word] /= total

    return probs

# %% [markdown]
# ## 4. Thuật toán Viterbi (Giải mã chuỗi tối ưu)
# - Với chuỗi từ quan sát (câu cần sửa), tìm chuỗi từ đúng (ẩn) sao cho:
#     - Xác suất tổng (transition * emission) là lớn nhất.
# - Áp dụng Viterbi để tìm dãy từ đúng có xác suất cao nhất, từng bước một, sử dụng:
#     - Các từ ứng viên ở mỗi bước (từ có khoảng cách edit nhỏ với từ đầu vào).
#     - Xác suất chuyển tiếp giữa các từ ứng viên liên tiếp (3-gram).

# %%
from math import log

def viterbi(observed, vocab, ngrams, transition_prob, context_totals, alpha, epsilon=1e-8):
    # Thêm token đặc biệt vào đầu và cuối
    observed = ['<start1>', '<start2>'] + observed + ['<end1>', '<end2>']
    T = len(observed)
    V = [{} for _ in range(T)]
    path = {}

    vocab_size = len(vocab)

    # Khởi tạo bước đầu tiên tại vị trí t=2 (vì t=0,1 là <start>)
    emis_probs = get_emission_prob(observed[2], vocab)
    for y in emis_probs:
        context = ('<start1>', '<start2>')
        count = ngrams.get(context, {}).get(y, 0)
        total = context_totals.get(context, 0)
        trans_prob = (count + alpha) / (total + alpha * vocab_size)
        emis_prob = emis_probs.get(y, epsilon)

        V[2][y] = log(trans_prob + epsilon) + log(emis_prob + epsilon)
        path[y] = ['<start1>', '<start2>', y]

    # Duyệt từ t = 3 trở đi
    for t in range(3, T):
        emis_probs = get_emission_prob(observed[t], vocab)
        V[t] = {}
        newpath = {}

        for y in emis_probs:
            max_prob = float('-inf')
            best_prev = None

            for y1 in V[t - 1]:  # trạng thái trước
                y0 = path[y1][-2]  # từ trước của y1
                context = (y0, y1)
                count = ngrams.get(context, {}).get(y, 0)
                total = context_totals.get(context, 0)
                trans_prob = (count + alpha) / (total + alpha * vocab_size)
                emis_prob = emis_probs.get(y, epsilon)

                prob = V[t - 1][y1] + log(trans_prob + epsilon) + log(emis_prob + epsilon)

                if prob > max_prob:
                    max_prob = prob
                    best_prev = y1

            if best_prev is not None:
                V[t][y] = max_prob
                newpath[y] = path[best_prev] + [y]

        if not newpath:
            raise ValueError(f"No valid path at step {t}. Check transition/emission coverage.")
        path = newpath

    # Tìm chuỗi có xác suất cao nhất ở bước cuối
    n = T - 1
    prob, state = max((V[n][y], y) for y in V[n])
    return path[state]

# %% [markdown]
# ## 5. Tái tạo câu đã sửa
# - Chuỗi từ đúng tìm được là kết quả sau khi sửa.
#
# - Ghép lại các từ theo đúng thứ tự để tạo thành câu đã sửa lỗi.

# %%
import re

def clean_text_with_mapping(text):
    replacements = {
        "<url>": [],
        "<emoji>": [],
        "<date>": [],
        "<time>": [],
        "<num>": [],
    }

    # Danh sách các pattern với placeholder ưu tiên
    patterns = [
        (r'https?://\S+|www\.\S+', "<url>"),
        ("[" + u"\U0001F600-\U0001F64F"
             + u"\U0001F300-\U0001F5FF"
             + u"\U0001F680-\U0001F6FF"
             + u"\U0001F1E0-\U0001F1FF"
             + u"\u2600-\u26FF"
             + u"\u2700-\u27BF" + "]", "<emoji>"),
        (r'\b\d{1,2}[-/]\d{1,2}[-/]\d{2,4}\b', "<date>"),   # dd/mm/yyyy hoặc dd-mm-yyyy
        (r'\b\d{4}[-/]\d{1,2}[-/]\d{1,2}\b', "<date>"),     # yyyy/mm/dd hoặc yyyy-mm-dd
        (r'\b\d{1,2}:\d{2}(?::\d{2})?\b', "<time>"),        # hh:mm hoặc hh:mm:ss
        (r'\d+(?:[.,]\d+)?', "<num>"),                     # số thực hoặc số nguyên
    ]

    # Ghi lại vị trí đã thay để tránh chồng lặp
    replaced = [False] * len(text)
    new_text = ""
    last_pos = 0
    matches = []

    for pattern, placeholder in patterns:
        for match in re.finditer(pattern, text):
            start, end = match.start(), match.end()
            if any(replaced[start:end]):
                continue  # Tránh thay chồng

            matches.append((start, end, match.group(), placeholder))
            for i in range(start, end):
                replaced[i] = True  # Đánh dấu đã xử lý

    # Sắp xếp lại theo thứ tự xuất hiện
    matches.sort()
    last_pos = 0
    for start, end, original, placeholder in matches:
        new_text += text[last_pos:start]
        new_text += placeholder
        replacements[placeholder].append(original)
        last_pos = end

    new_text += text[last_pos:]
    return new_text, replacements

# %%
text = "Hôm nay là 2024-12-01, mai là 02/12/2024 và 14:30. Website là https://openai.com và giá là 12.345,67₫ 😊"
cleaned, repl = clean_text_with_mapping(text)

print("➡ Văn bản sau khi clean:", cleaned)
print("➡ Mapping:")
for k, v in repl.items():
    print(f"  {k}: {v}")
# Out:
# ➡ Văn bản sau khi clean: Hôm nay là <date>, mai là <date> và <time>. Website là <url> và giá là <num>,<num>₫ <emoji>
# ➡ Mapping:
#   <url>: ['https://openai.com']
#   <emoji>: ['😊']
#   <date>: ['2024-12-01', '02/12/2024']
#   <time>: ['14:30']
#   <num>: ['12.345', '67']

# %%
clean_text(text)
# Out:
# 'Hôm nay là <date>, mai là <date> và <time>. Website là <url> và giá là <num>,<num>₫ <emoji>'

# %%
from collections import defaultdict

def restore_tokens(tokens, replacements):
    # Đếm số lần đã dùng của mỗi placeholder

    print(tokens)
    counts = {k: 0 for k in replacements}

    restored = []
    for token in tokens:
        if token in replacements:
            index = counts[token]
            if index < len(replacements[token]):
                restored.append(replacements[token][index])
                counts[token] += 1
            else:
                # Trường hợp placeholder nhiều hơn số bản ghi, giữ nguyên
                restored.append(token)
        else:
            restored.append(token)

    return restored

# %%
def correct_text(input_text, vocab, ngrams, transition_prob, context_totals, alpha):
    # print("\n===== Bắt đầu sửa lỗi chính tả =====")

    # 1. Làm sạch dấu câu
    input_text = clean_punctuation(input_text.lower())

    # 2. Chuẩn hóa và ghi nhớ các token đặc biệt
    cleaned_text, replacements = clean_text_with_mapping(input_text.lower())
    
    # 3. Tách từ (với xử lý placeholder dính liền)
    tokens = custom_tokenize(cleaned_text)

    # print(f"Tách từ sau clean: {tokens}")
    # print(f"Replacements: {replacements}")

    # 4. Xác định token cần sửa và giữ nguyên
    special_placeholders = set(replacements.keys())
    to_correct = []
    mask = []  # True nếu cần sửa

    for t in tokens:
        if t in special_placeholders:
            to_correct.append(t)
            mask.append(False)
        else:
            to_correct.append(t)
            mask.append(True)

    # 5. Sửa lỗi chính tả bằng Viterbi
    # tokens = [t for t, m in zip(to_correct, mask) if m]
    # print("input for viterbi ", tokens)
    corrected_tokens = viterbi(tokens, vocab, ngrams, transition_prob, context_totals, alpha)
    corrected_tokens = corrected_tokens[2:-2]
    # print("corrected tokens ",corrected_tokens)
    
    # 7. Khôi phục placeholder thành gốc
    restored = restore_tokens(corrected_tokens, replacements)

    # 8. Ghép lại thành văn bản hoàn chỉnh
    corrected_text = ' '.join(restored)

    corrected_text = clean_punctuation(corrected_text)

    # print("\n===== Hoàn tất sửa lỗi =====")
    print(f"Kết quả sau sửa: {corrected_text}")

    return corrected_text

# %%
# Step 1: huấn luyện với tập văn bản đúng
texts = list(unique_correct_texts['correct_text'])
ngrams, vocab = preprocess(texts)
transition_prob, context_totals = get_transition_prob(ngrams, vocab, alpha=0.5)
print(len(ngrams))
print(vocab)
# Out:
# 82696
# {'chạp', 'đứng', 'thách', 'tp', 'eigenvalue', 'phỏng', 'no', 'cười', 'vươn', 'dương', 'cmhs', 'knight', 'trùm', 'rỡ', 'vision', 'so', 'vỉ', 'góa', 'attribute', 'vcd', 'ngẫm', 'audit', 'cá', 'châm', 'bạc', 'hái', 'huyết', 'greendragon', 'tắt', 'chỉ', 'cash', 'bill', 'tươi', 'tỏa', 'gióng', 'trội', 'htx', 'vksnd', 'chăm', 'kiđô', 'bài', 'tây', 'brexit', 'vector', 'hán', 'môn', 'tôm', 'lão', 'ngạt', 'tuyết', 'manpower', 'nlth', 'đu', 'gạt', 'shan', 'đựng', 'khắt', 'anken', 'github', 'gầy', 'explained', 'latinh', 'sao', 'ocr', 'quyện', 'đụng', 'mì', '°', 'tịnh', 'ajcep', 'chậu', 'xử', 'xộc', 'nielsen', 'tableau', 'nhóm', 'hóc', 'chàng', 'mặn', 'ipsos', 'tw', 'tải', 'hoảng', 'nâu', 'cong', 'nại', 'bỉ', 'thiệp', 'vùng', 'rcp', 'nhuộm', 'bám', '%', 'bình', 'ngủi', 'kông', 'usd', 'cronnin', 'đứt', 'nhựa', 'lật', 'chat', 'mưa', 'nhiễu', 'dồi', 'bê', 'wichita', 'rá', 'tri', 'tháng', 'nhãn', 'bội', 'crossover', 'tắm', 'plug', 'râm', 'đâm', 'mẹo', 'lùi', 'chải', 'thường', 'soichiro', 'variance', 'www', 'tong', 'apple', 'rằng', 'jayasinghe', 'socket', 'rớt', 'đỏ', 'about', 'vass', 'nhuận', 'thanh', 'prudential', 'chữa', 'lộ', 'toàn', 'nhạc', 'đe', 'tẩy', 'cisg', 'chập', 'làn', 'nhọn', 'dở', 'partner', 'android', 'greek', 'pali', 'millward', 'trách', 'cáo', 'sạc', 'bằng', 'lược', 'gắt', 'thu', 'khưu', 'lẻ', 'bại', 'classroom', 'ths', 'lén', 'transexual', 'vô', 'xót', 'trót', 'cõng', 'xnk', 'cn', 'tàn', 'thúc', 'reasoned', 'freighter', 'edition', 'cd', 'araki', 'tăng', 'buồn', 'learning', 'gartner', 'ín', 'chuẩn', 'wessels', 'nghiệt', 'xu', 'bàn', 'rạch', 'ngọng', 'ecm', 'mason', 'khdn', 'vks', 'mẫu', 'view', 'lệ', 'chọc', '<', 'validation', 'đua', 'việt', 'xay', 'form', 'khăn', 'esl', 'bẫy', 'chóa', 'cqđt', 'trở', 'nhôm', 'bày', 'mẹ', 'đầu', 'dặt', 'rosli', 'dắt', 'nề', 'gói', 'bã', 'ch', 'sú', 'plan', 'tảng', 'mất', 'von', 'oxley', 'news', 'tốt', 'mbps', 'kỳ', 'brown', 'tskh', 'êke', 'nixon', 'ruộng', 'ngành', 'tấm', 'dã', 'băng', 'imgroup', 'đêm', 'hở', 'qh', 'điêu', 'cử', 'investigation', 'ngộ', 'ngăn', 'mẻ', 'thổi', 'nguội', 'nướu', 'tọa', 'coppha', 'triển', 'khuyến', 'trước', 'gắp', 'toan', 'bin', 'lóa', 'as', 'ngắt', 'kạn', 'kít', 'bể', 'quở', 'omo', 'bazơ', 'chè', 'thần', 'nav', 'xuống', 'khtn', 'phước', 'block', 'thảo', 'hoa', 'đà', 'hđh', 'lay', 'nhả', 'rãnh', 'bóc', 'đã', 'tết', 'hờ', 'key', 'influencing', 'ugur', 'transfe', 'cp', 'đọng', 'mọc', 'súc', 'sáp', 'mún', 'angten', 'để', 'của', 'sea', 'vr', 'ác', 'trống', 'thòi', 'sem', 'nhủ', 'tai', 'short', 'mờ', 'management', 'vênh', 'hài', 'datacenter', 'dựa', 'mou', 'rise', 'á', 'lít', 'ebay', 'ten', 'nghĩa', 'tắc', 'ro', 'mỏ', 'sin', 'đô', 'benzen', 'ranh', 'sinh', 'foody', 'iii', 'cản', 'chocolate', 'tdpb', 'khác', '(', 'metro', 'ok', 'boj', 'hảo', 'shopify', 'isle', 'jo', 'mét', 'trốn', 'hợi', 'chém', 'khóa', 'vectơ', 'mxh', 'vinatex', 'dọc', 'behavior', 'sảnh', 'cút', 'rain', 'agreement', 'goujon', 'loucanova', 'what', 'dn', 'trừng', 'cạnh', 'eu', 'hít', 'george', 'xao', 'xanh', 'tách', 'dtt', 'hắn', 'triệu', 'sarbanes', 'luận', 'dối', 'đông', 'khoát', 'big', 'cdgnl', 'màng', 'hởi', 'vòng', 'lạc', 'iub', 'axetic', 'nữ', 'xoáy', 'nêu', 'xxi', 'pos', 'chạm', 'giống', 'lệnh', 'combo', 'u', 'gen', 'nl', 'mừng', 'thấu', 'mới', 'dị', 'sales', 'tuyl', 'đãng', 'trụ', 'nghiêm', 'trong', 'gửi', 'load_longterm', 'lazychin', 'màn', 'thành', 'phấn', 'quản', 'cellfiles', 'khai', 'staple', 'hùng', 'for', 'túng', 'tang', 'misa', 'cbkh', 'lao', 'thăng', 'trượt', 'lặp', 'khoán', 'ức', 'bangladesh', 'nhtw', 'tranh', 'aditxterrec', 'nghĩnh', 'behavioral', 'đau', 'vietjet', 'marketecology', 'gót', 'backend', 'nghĩ', 'moftec', 'ngừ', 'max\u200b', 'dột', 'hương', 'neighbor', 'khuỷu', 'bim', 'đùm', 'j', 'thomsson', 'nh', 'nhận', 'ngay', 'ập', 'chắp', 'ủy', 'hân', ',', 'qua', 'rét', 'knn', 'nỗi', 'vặn', 'f', 'branc', 'fed', 'mth', 'hữu', 'đế', 'dhth', 'bazan', 'perceived', 'ips', 'tetrafloetilen', 'heo', 'nhn', 'rsync', 'lan', 'docking', 'báo', 'khói', 'level', 'trị', 'cov', 'xupap', 'trực', 'sửa', 'ró ...

# %%
# Step 2: sửa lỗi
wrong_text = "thông qua công tác tuyên truyeenf, van động này phu huynh sẽ hiểu rỏ hơn tầm quan trọng của việc giáo dục."
corrected = correct_text(wrong_text, vocab, ngrams, transition_prob, context_totals, alpha=0.001)
# Out:
# ['thông', 'qua', 'công', 'tác', 'tuyên', 'truyền', ',', 'vận', 'động', 'này', 'phụ', 'huynh', 'sẽ', 'hiểu', 'rõ', 'hơn', 'tầm', 'quan', 'trọng', 'của', 'việc', 'giáo', 'dục', '.']
# Kết quả sau sửa: thông qua công tác tuyên truyền, vận động này phụ huynh sẽ hiểu rõ hơn tầm quan trọng của việc giáo dục.

# %%
wrong_text = "quan điểm biện chứng của chù nghĩa mác - lênin không chỉ khẳng định tính khách quan, tính phổ biến của các mối liên hệ mà còn nhấn mạnh tin phong phú, đa dạng của các mối liên hệ."
corrected = correct_text(wrong_text, vocab, ngrams, transition_prob, context_totals, alpha=0.01)
# Out:
# ['quan', 'điểm', 'biện', 'chứng', 'của', 'chủ', 'nghĩa', 'mác', '-', 'lênin', 'không', 'chỉ', 'khẳng', 'định', 'tính', 'khách', 'quan', ',', 'tính', 'phổ', 'biến', 'của', 'các', 'mối', 'quan', 'hệ', 'mà', 'còn', 'nhấn', 'mạnh', 'tính', 'phong', 'phú', ',', 'đa', 'dạng', 'hóa', 'các', 'mối', 'quan', 'hệ', '.']
# Kết quả sau sửa: quan điểm biện chứng của chủ nghĩa mác - lênin không chỉ khẳng định tính khách quan, tính phổ biến của các mối quan hệ mà còn nhấn mạnh tính phong phú, đa dạng hóa các mối quan hệ.

# %%
wrong_text = "đối với biểu đồ histogram, nếu giá trị trung bình mean gần bằng 0, độ lệch chuẩn gần bằng 1 và đường cong phân phối có hình dạng chuông thì có thể khẳng định phân phối là xếp xỉ chuẩn, giả định phân phối chuẩn của phần dư không bị vi phạm."
corrected = correct_text(wrong_text, vocab, ngrams, transition_prob, context_totals, alpha=1)
# Out:
# ['đối', 'với', 'việc', 'đồ', 'histogram', ',', 'nếu', 'giá', 'trị', 'trung', 'bình', 'mean', 'gần', 'bằng', '<num>', ',', 'độ', 'lệch', 'chuẩn', 'gần', 'bằng', '<num>', 'và', 'vận', 'dụng', 'kiến', 'thức', 'cơ', 'bản', 'trong', 'công', 'ty', 'có', 'thể', 'khẳng', 'định', 'phân', 'phối', 'và', 'xếp', 'xỉ', 'chuẩn', ',', 'khả', 'năng', 'phân', 'phối', 'chuẩn', 'của', 'phần', 'dư', 'không', 'bị', 'vi', 'phạm', '.']
# Kết quả sau sửa: đối với việc đồ histogram, nếu giá trị trung bình mean gần bằng 0, độ lệch chuẩn gần bằng 1 và vận dụng kiến thức cơ bản trong công ty có thể khẳng định phân phối và xếp xỉ chuẩn, khả năng phân phối chuẩn của phần dư không bị vi phạm.

# %% [markdown]
# ## Đánh giá trên tập test

# %%
test
# Out:
#                                                    text  \
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giam mà còn tăng thê...
# 3     Đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chù nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
#                                              preprocess  \
# 0     thông qua công tác tuyên truyền, vận động này ...
# 1     do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     giữ được chỉ số này không giam mà còn tăng thê...
# 3     đúng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  tuy nhiên, khi nói đến e-learning, các phương ...
# 8963  đứng trước những hành vi đi ngược lại với đạo ...
# 8964  quan điểm biện chứng của chù nghĩa mác - lênin...
# 8965  đối với biểu đồ histogram, nếu giá trị trung b...
# 8966  trong mỗi khu vực mà đội phát triển thị trường...
#
#                                            correct_text
# 0     Thông qua công tác tuyên truyền, vận động này ...
# 1     Do đó, doanh nghiệp cần chú trọng đến yếu tố n...
# 2     Giữ được chỉ số này không giảm mà còn tăng thê...
# 3     Đứng trước thực tế này đòi hỏi chúng ta cần ph...
# 4     Trình độ học vấn của nhân viên được tuyển dụng...
# ...                                                 ...
# 8962  Tuy nhiên, khi nói đến E-Learning, các phương ...
# 8963  Đứng trước những hành vi đi ngược lại với đạo ...
# 8964  Quan điểm biện chứng của chủ nghĩa Mác - Lênin...
# 8965  Đối với biểu đồ Histogram, nếu giá trị trung b...
# 8966  Trong mỗi khu vực mà đội phát triển thị trường...
#
# [8967 rows x 3 columns]

# %%
test = test[:2000]

# %%
def correct_wrapper(text):
    return correct_text(text, vocab, ngrams, transition_prob, context_totals, alpha=1)

# Áp dụng sửa lỗi cho toàn bộ cột "preprocess"
test["predicted"] = test["preprocess"].apply(correct_wrapper)
# Out:
# ['thông', 'qua', 'công', 'tác', 'tuyên', 'truyền', ',', 'vấn', 'đề', 'này', 'phụ', 'huynh', 'sẽ', 'hiểu', 'rõ', 'hơn', 'tầm', 'quan', 'trọng', 'của', 'việc', 'giáo', 'dục', 'ý', 'thức', 'bảo', 'vệ', 'môi', 'trường', 'cho', 'trẻ', 'không', 'phải', 'chỉ', 'ở', 'phía', 'nhà', 'trường', 'và', 'còn', 'ở', 'gia', 'đình', ',', 'góp', 'phần', 'vào', 'việc', 'gìn', 'giữ', 'môi', 'trường', 'sống', ',', 'sạch', ',', 'đẹp', '.']
# Kết quả sau sửa: thông qua công tác tuyên truyền, vấn đề này phụ huynh sẽ hiểu rõ hơn tầm quan trọng của việc giáo dục ý thức bảo vệ môi trường cho trẻ không phải chỉ ở phía nhà trường và còn ở gia đình, góp phần vào việc gìn giữ môi trường sống, sạch, đẹp.
# ['do', 'đó', ',', 'doanh', 'nghiệp', 'cần', 'chú', 'trọng', 'đến', 'yếu', 'tố', 'này', 'để', 'làm', 'thỏa', 'mãn', ',', 'hệ', 'thống', 'các', 'nhóm', 'đối', 'tượng', 'này', '.']
# Kết quả sau sửa: do đó, doanh nghiệp cần chú trọng đến yếu tố này để làm thỏa mãn, hệ thống các nhóm đối tượng này.
# ['giáo', 'dục', 'phổ', 'số', 'này', 'không', 'giảm', 'mà', 'còn', 'tăng', 'thêm', 'cũng', 'được', 'xem', 'là', 'một', 'bước', 'thành', 'công', 'của', 'ngân', 'hàng', '.']
# Kết quả sau sửa: giáo dục phổ số này không giảm mà còn tăng thêm cũng được xem là một bước thành công của ngân hàng.
# ['đối', 'với', 'thực', 'tế', 'và', 'đối', 'với', 'công', 'ty', 'cần', 'phải', 'có', 'những', 'nghiên', 'cứu', 'của', 'li', ',', 'cụ', 'thể', 'nhằm', 'tìm', 'ra', 'những', 'nhân', 'tố', 'ảnh', 'hưởng', 'đến', 'sự', 'lựa', 'chọn', 'kênh', 'mua', 'sắm', 'của', 'người', 'tiêu', 'dùng', 'ở', 'tp', '.']
# Kết quả sau sửa: đối với thực tế và đối với công ty cần phải có những nghiên cứu của li, cụ thể nhằm tìm ra những nhân tố ảnh hưởng đến sự lựa chọn kênh mua sắm của người tiêu dùng ở tp.
# ['trong', 'đó', 'các', 'bên', 'có', 'liên', 'quan', 'đến', 'tình', 'hình', 'tài', 'chính', 'của', 'họ', ',', 'thỏa', 'mãn', 'nhu', 'cầu', 'được', 'sàng', 'lọc', 'kỹ', 'hơn', '.']
# Kết quả sau sửa: trong đó các bên có liên quan đến tình hình tài chính của họ, thỏa mãn nhu cầu được sàng lọc kỹ hơn.
# ['ở', 'các', 'nước', 'phát', 'triển', ',', 'đa', 'số', 'các', 'ấn', 'phẩm', 'nhật', 'báo', 'hoặc', 'tuần', 'báo', 'có', 'con', 'số', 'từ', 'vài', 'chục', 'đến', 'hàng', 'trăm', 'trang', '(', 'tính', 'cả', 'phụ', 'trang', 'quảng', 'cáo', ',', 'dịch', 'vụ', 'xã', 'hội', ')', '.']
# Kết quả sau sửa: ở các nước phát triển, đa số các ấn phẩm nhật báo hoặc tuần báo có con số từ vài chục đến hàng trăm trang (tính cả phụ trang quảng cáo, dịch vụ xã hội).
# ['các', 'bài', 'tập', 'đó', 'đã', 'làm', 'nảy', 'sinh', 'ra', 'việc', 'sử', 'dụng', 'đất', 'chưa', 'hợp', 'lí', ',', 'ảnh', 'hưởng', 'từ', 'quá', 'trình', 'công', 'nghiệp', 'hóa', 'làm', 'suy', 'giảm', 'diện', 'tích', 'đất', 'nông', 'nghiệp', '.']
# Kết quả sau sửa: các bài tập đó đã làm nảy sinh ra việc sử dụng đất chưa hợp lí, ảnh hưởng từ quá trình công nghiệp hóa làm suy giảm diện tích đất nông nghiệp.
# ['các', 'vấn', 'đề', 'đài', 'tử', 'home', 'gateway', 'mà', 'ổ', 'điện', 'thông', 'minh', 'cần', 'xử', 'lý', 'ở', 'đây', 'sẽ', 'thường', 'là', 'yêu', 'cầu', 'bật', '/', 'tắt', 'ổ', 'điện', ',', 'yêu', 'cầu', 'thông', 'báo', 'trạng', 'thái', 'bật', '/', 'tắt', 'của', 'ổ', 'điện', ',', 'yêu', 'cầu', 'thông', 'báo', 'vị', 'trí', 'lắp', 'đặt', 'của', 'ổ', 'điện', '.']
# Kết quả sau sửa: các vấn đề đài tử home gateway mà ổ điện thông minh cần xử lý ở đây sẽ thường là yêu cầu bật / tắt ổ điện, yêu cầu thông báo trạng thái bật / tắt của ổ điện, yêu cầu thông báo vị trí lắp đặt của ổ điện.
# ['với', 'khuôn', 'khổ', 'này', ',', 'chính', 'trị', 'học', 'so', 'sánh', 'có', 'thể', 'áp', 'dụng', 'vào', 'phân', 'tích', 'nhân', 'xác', 'định', 'được', 'sự', 'tương', 'đồng', 'và', 'khác', 'biệt', 'giữa', 'các', 'quá', 'trình', 'học', 'tập', ',', 'tương', 'ứng', 'với', 'sự', 'tương', 'đồng', 'và', 'thực', 'hiện', 'các', 'yếu', 'tố', 'chính', 'trị', '.']
# Kết quả sau sửa: với khuôn khổ này, chính trị học so sánh có thể áp dụng vào phân tích nhân xác định được sự tương đồng và khác biệt giữa các quá trình học tập, tương ứng với sự tương đồng và thực hiện các yếu tố chính trị.
# ['việc', 'điều', 'khiển', 'xe', 'sẽ', 'trở', 'nên', 'dễ', 'dàng', 'hơn', 'nếu', 'các', 'bánh', 'xe', 'được', 'đặt', 'theo', 'một', 'góc', 'chính', 'xác', 'theo', 'yêu', 'cầu', 'thiết', 'kế', ',', 'việc', 'đặt', 'sai', 'góc', 'sẽ', 'tạo', 'ra', 'tính', 'ổn', 'định', 'khi', 'lái', 'kém', 'và', 'khiến', 'lốp', 'xe', 'nhanh', 'mòn', '.']
# Kết quả sau sửa: việc điều khiển xe sẽ trở nên dễ dàng hơn nếu các bánh xe được đặt theo một góc chính xác theo yêu cầu thiết kế, việc đặt sai góc sẽ tạo ra tính ổn định khi lái kém và khiến lốp xe nhanh mòn.
# ['trong', 'chương', 'này', ',', 'ta', 'nêu', 'lên', 'những', 'cơ', 'sở', 'lý', 'thuyết', 'được', 'áp', 'dụng', 'trong', 'việc', 'giải', 'quyết', 'bài', 'toán', 'xây', 'dựng', 'hệ', 'thống', '.']
# Kết quả sau sửa: trong chương này, ta nêu lên những cơ sở lý thuyết được áp dụng trong việc giải quyết bài toán xây dựng hệ thống.
# ['tài', 'liệu', 'bồi', 'dưỡng', 'và', 'nâng', 'cao', 'năng', 'lực', 'chuyên', 'môn', 'nghiệp', 'vụ', 'và', 'đạo', 'đức', 'nghề', 'nghiệp', 'cho', 'cán', 'bộ', 'công', 'nhân', 'viên', '.']
# Kết quả sau sửa: tài liệu bồi dưỡng và nâng cao năng lực chuyên môn nghiệp vụ và đạo đức nghề nghiệp cho cán bộ công nhân viên.
# ['xây', 'dựng', 'nội', 'dung', 'học', 'dưới', 'dạng', 'các', 'tư', 'liệu', 'học', 'tập', ':', 'phiếu', 'học', 'tập', '.']
# Kết quả sau sửa: xây dựng nội dung học dưới dạng các tư liệu học tập: phiếu học tập.
# ['những', 'sản', 'phẩm', 'của', 'bà', 'đá', ',', 'dự', 'lễ', 'kỷ', 'niệm', 'khổng', 'tử', 'và', 'đến', 'thăm', 'các', 'phòng', 'triển', 'lãm', 'tranh', 'của', 'các', 'họa', 'sĩ', 'nổi', 'tiếng', '.']
# Kết quả sau sửa: những sản phẩm của bà đá, dự lễ kỷ niệm khổng tử và đến thăm các phòng triển lãm tranh của các họa sĩ nổi tiếng.
# ['thứ', 'hai', 'có', 'thể', 'thấy', 'cơ', 'bản', 'của', 'máy', ',', 'không', 'để', 'đưa', 'ra', 'các', 'vào', ',', 'mái', 'và', 'tường', 'không', 'bị', 'dột', ',', 'không', 'bị', 'nước', 'mưa', 'hắt', ',', 'có', 'khả', 'năng', 'chống', 'ẩm', '.']
# Kết quả sau sửa: thứ hai có thể thấy cơ bản của máy, không để đưa ra các vào, mái và tường không bị dột, không bị nước mưa hắt, có khả năng chống ẩm.
# ['tuy', 'nhiên', ',', 'mục', 'tiêu', 'của', 'p', '<num>', 'là', 'còn', 'có', 'thể', 'nói', 'cấu', 'hình', 'với', 'cả', 'các', 'asic', 'có', 'chức', 'năng', 'cố', 'định', '.']
# Kết quả sau sửa: tuy nhiên, mục tiêu của p 4 là còn có thể nói cấu hình với cả các asic có chức năng cố định.
# ['như', 'vậy', 'hoạt', 'động', 'trải', 'nghiệm', ',', 'học', 'sinh', 'được', 'rèn', 'luyện', 'các', 'kỹ', 'năng', 'cần', 'thiết', 'như', 'hợp', 'tác', ',', 'trình', 'bày', 'trước', 'đám', 'đông', ',', 'kỹ', 'năng', 'lập', 'kế', 'hoạch', ',', 'thực', 'hiện', 'kế', 'hoạch', 'và', 'đánh', 'giá', 'kết', 'hoạt', '.']
# Kết quả sau sửa: như vậy hoạt động trải nghiệm, học sinh được rèn luyện các kỹ năng cần thiết như hợp tác, trình bày trước đám đông, kỹ năng lập kế hoạch, thực hiện kế hoạch và đánh giá kết hoạt.
# ['trong', 'công', 'tác', 'quản', 'dụng', 'cán', 'bộ', 'làm', 'công', 'tác', 'thẩm', 'định', 'dự', 'án', ',', 'báo', 'cáo', 'kinh', 'tế', 'kỹ', 'thuật', 'đầu', 'tư', 'đòi', 'hỏi', 'phải', 'có', 'trình', 'độ', 'chuyên', 'môn', 'nghiệp', 'vụ', 'theo', 'quy', 'định', ',', 'cán', 'bộ', 'thẩm', 'định', 'phải', 'có', 'kinh', 'nghiệm', '.']
# Kết quả sau sửa: trong công tác quản dụng cán bộ làm công tác thẩm định dự án, báo cáo kinh tế kỹ thuật đầu tư đòi hỏi phải có trình độ chuyên môn nghiệp vụ theo quy định, cán bộ thẩm định phải có kinh nghiệm.
# ['trong', 'thời', 'gian', 'tới', 'bồi', 'dưỡng', 'nâng', 'cao', 'chất', 'ý', 'đến', 'các', 'phương', 'pháp', 'tích', 'cực', '.']
# Kết quả sau sửa: trong thời gian tới bồi dưỡng nâng cao chất ý đến các phương pháp tích cực.
# ['vì', 'vậy', 'qua', 'những', 'câu', 'chuyện', 'với', 'mục', 'đích', 'của', 'cấp', 'hiểu', 'biết', 'về', 'sự', 'tham', 'gia', 'các', 'công', 'ty', 'và', 'với', 'môi', 'trường', ',', 'về', 'quá', 'trình', 'phát', 'triển', 'của', 'mình', '.']
# Kết quả sau sửa: vì vậy qua những câu chuyện với mục đích của cấp hiểu biết về sự tham gia các công ty và với môi trường, về quá trình phát triển của mình.
# ['từ', 'đó', 'từng', 'bước', 'khẳng', 'định', 'được', 'vị', 'trí', 'của', 'bản', 'thân', 'mình', 'bằng', 'cách', 'vươn', 'xa', ',', 'mở', 'rộng', 'phạm', 'vi', 'hoạt', 'động', 'trên', 'toàn', 'thế', 'giới', '.']
# Kết quả sau sửa: từ đó từng bước khẳng định được vị trí của bản thân mình bằng cách vươn xa, mở rộng phạm vi hoạt động trên toàn thế giới.
# ['học', 'sinh', 'quan', 'sát', 'tranh', ',', 'cá', 'nhân', 'và', 'ngoài', 'nước', '.']
# Kết quả sau sửa: học sinh quan sát tranh, cá nhân và ngoài nước.
# ['đối', 'với', 'lê', 'sơ', ',', 'ngự', 'sử', 'đài', 'vẫn', 'là', 'cơ', 'quan', 'có', 'vai', 'trò', 'lớn', 'hơn', 'lục', 'khoa', ',', 'quan', 'lại', 'thuộc', 'ngự', 'sử', 'đài', 'là', 'những', 'người', 'có', 'quyền', 'lực', 'từ', 'tể', 'tướng', 'đến', 'võ', 'tướng', '-', 'những', 'chức', 'vụ', 'cao', 'nhất', 'trong', 'triều', '.']
# Kết quả sau sửa: đối với lê sơ, ngự sử đài vẫn là cơ quan có vai trò lớn hơn lục khoa, quan lại thuộc ngự sử đài là những người có quyền lực từ tể tướng đến võ tướng - những chức vụ cao nhất trong triều.
# ['với', 'các', 'nước', 'lớn', ',', 'công', 'ty', 'sẽ', 'tổ', 'chức', 'một', 'buổi', 'giao', 'lưu', 'chia', 'sẻ', 'kinh', 'nghiệm', 'của', 'các', 'thành', 'viên', 'với', 'nhau', 'và', 'đào', 'tạo', 'thêm', 'về', 'các', 'kỹ', 'năng', 'sống', 'xã', 'hội', 'chủ', 'nghĩa', 'việt', '.']
# Kết quả sau sửa: với các nước lớn, công ty sẽ tổ chức một buổi giao lưu chia sẻ kinh nghiệm của các thành viên với nhau và đào tạo thêm về các kỹ năng sống xã hội chủ nghĩa việt.
# ['trong', 'quá', 'trình', 'độ', 'học', 'tập', 'và', 'nâng', 'cao', 'chất', 'người', 'ở', 'ghép', '.']
# Kết quả sau sửa: trong quá trình độ học tập và nâng cao chất người ở ghép.
# ['sau', 'ads', ':', 'quảng', 'cáo', 'điện', 'tử', ',', 'có', 'khả', 'năng', 'vận', 'dụng', 'kiến', 'thức', ':', 'chữ', ',', 'hình', 'ảnh', ',', 'việt', 'nam', '.']
# Kết quả sau sửa: sau ads: quảng cáo điện tử, có khả năng vận dụng kiến thức: chữ, hình ảnh, việt nam.
# ['nền', 'kinh', 'tế', 'nước', 'ta', 'đang', 'tiến', 'từng', 'bước', 'vững', 'chắc', 'tới', 'công', 'cuộc', 'cải', 'cách', 'kinh', 'tế', 'thị', 'trường', 'mở', 'cửa', 'để', 'nhanh', 'chóng', 'hòa', 'nhập', 'với', 'nền', 'kinh', 'tế', 'thế', 'giới', '.']
# Kết quả sau sửa: nền kinh tế nước ta đang tiến từng bước vững chắc tới công cuộc cải cách kinh tế thị trường mở cửa để nhanh chóng hòa nhập với nền kinh tế thế giới.
# ['trong', 'trường', 'hợp', 'có', 'hai', 'người', 'hoặc', 'nhiều', 'người', 'cùng', 'sáng', 'tạo', 'ra', 'các', 'nhân', 'tố', 'ảnh', 'người', 'đó', 'là', 'đồng', 'tác', 'giả', '.']
# Kết quả sau sửa: trong trường hợp có hai người hoặc nhiều người cùng sáng tạo ra các nhân tố ảnh người đó là đồng tác giả.
# ['nghiên', 'cứu', 'về', 'phát', 'triển', 'nhanh', 'và', 'bền', 'vững', 'nền', 'kinh', 'tế', 'việt', 'nam', '(', '<num>', '-', '<num>', ')', ',', 'bùi', 'tất', 'thắng', '(', '<num>', ')', ',', 'đã', 'đi', 'sâu', 'vào', 'phân', 'tích', 'các', 'lý', 'thuyết', 'về', 'phát', 'triển', 'nhanh', 'và', 'bền', 'vững', 'của', 'các', 'tác', 'giả', 'trên', 'thế', 'giới', '.']
# Kết quả sau sửa: nghiên cứu về phát triển nhanh và bền vững nền kinh tế việt nam (2011 - 2020), bùi tất thắng (2010), đã đi sâu vào phân tích các lý thuyết về phát triển nhanh và bền vững của các tác giả trên thế giới.
# ['có', 'ý', 'đến', 'việc', 'giảm', 'giá', 'thành', 'sản', 'phẩm', 'bằng', 'cách', 'hạn', 'chế', 'đến', 'mức', 'thấp', 'nhất', 'tỷ', 'lệ', 'cao', 'nhất', ',', 'giúp', 'các', 'cơ', 'quan', 'thuế', ',', 'sáng', 'tạo', 'ra', 'giá', 'trị', '.']
# Kết quả sau sửa: có ý đến việc giảm giá thành sản phẩm bằng cách hạn chế đến mức thấp nhất tỷ lệ cao nhất, giúp các cơ quan thuế, sáng tạo ra giá trị.
# ['từ', 'sơ', 'đồ', 'phản', 'ứng', ',', 'sản', 'phẩm', 'chính', 'phụ', 'tổ', 'chức', 'cho', 'hs', 'nhận', 'xét', 'rút', 'ra', 'hướng', 'phản', 'ứng', 'và', 'đi', 'đến', 'quy', 'tắc', 'mac', '-', 'côp', '-', 'nhi', '-', 'côp', '.']
# Kết quả sau sửa: từ sơ đồ phản ứng, sản phẩm chính phụ tổ chức cho hs nhận xét rút ra hướng phản ứng và đi đến quy tắc mac - côp - nhi - côp.
# ['khi', 'thực', 'hiện', 'các', 'vấn', 'đề', 'này', 'để', 'hạn', 'chế', 'của', 'hs', 'để', 'hs', 'hiểu', 'rõ', 'tác', 'phẩm', 'và', 'thể', 'loại', '.']
# Kết quả sau sửa: khi thực hiện các vấn đề này để hạn chế của hs để hs hiểu rõ tác phẩm và thể loại.
# ['xây', 'dựng', 'mô', 'hình', 'để', 'chuyển', 'giao', 'nhanh', 'giống', 'mới', ',', 'trong', 'quá', 'trình', 'thực', 'hiện', 'tốt', ',', 'tiến', 'bộ', 'khoa', 'học', 'và', 'công', 'nghệ', 'cho', 'nông', 'dân', '.']
# Kết quả sau sửa: xây dựng mô hình để chuyển giao nhanh giống mới, trong quá trình thực hiện tốt, tiến bộ khoa học và công nghệ cho nông dân.
# ['bên', 'cạnh', 'đó', ',', 'ai', 'trong', 'hoạt', 'động', 'có', 'quyền', 'lên', 'tiếng', 'nói', ',', 'cá', 'nhân', ',', 'do', 'ngôn', 'luận', 'do', 'đó', 'forum', 'cũng', 'là', 'một', 'phương', 'tiện', 'truyền', 'tải', 'thông', 'tin', 'ewom', 'hiệu', 'quả', '.']
# Kết quả sau sửa: bên cạnh đó, ai trong hoạt động có quyền lên tiếng nói, cá nhân, do ngôn luận do đó forum cũng là một phương tiện truyền tải thông tin ewom hiệu quả.
# ['đồng', 'thời', ',', 'tác', 'giả', 'cũng', 'đã', 'chỉ', 'ra', 'những', 'khó', 'khăn', 'trong', 'thực', 'hiện', 'các', 'chính', 'sách', 'an', 'sinh', 'xã', 'hội', 'ở', 'việt', 'nam', 'những', 'năm', 'gần', 'đây', 'trên', 'cơ', 'sở', 'phân', 'tích', 'những', 'đánh', 'giá', 'của', 'nhóm', 'cán', 'bộ', 'thực', 'hiện', 'và', 'các', 'đối', 'tượng', 'thụ', 'hưởng', 'chính', 'sách', 'an', 'sinh', 'xã', 'hội', '.']
# Kết quả sau sửa: đồng thời, tác giả cũng đã chỉ ra những khó khăn trong thực hiện các chính sách an sinh xã hội ở việt nam những năm gần đây trên cơ sở phân tích những đánh giá của nhóm cán bộ thực hiện và các đối tượng thụ hưởng chính sách an sinh xã hội.
# ['tác', 'giả', 'cũng', 'cho', 'rằng', ',', 'việc', 'lập', 'kế', 'hoạch', 'đầu', 'tư', 'công', 'phải', 'được', 'kiểm', 'soát', 'chặt', 'chẽ', 'và', 'thông', 'qua', 'bởi', 'cơ', 'quan', 'hành', 'chính', 'cao', 'nhất', 'và', 'phải', 'được', 'công', 'khai', 'trước', 'công', 'chúng', '.']
# Kết quả sau sửa: tác giả cũng cho rằng, việc lập kế hoạch đầu tư công phải được kiểm soát chặt chẽ và thông qua bởi cơ quan hành chính cao nhất và phải được công khai trước công chúng.
# ['theo', 'đó', 'cần', 'năm', '<num>', ',', 'bên', 'cạnh', 'đó', '<num>', '%', 'số', 'xã', 'có', 'cơ', 'sở', 'hạ', 'tầng', 'kinh', 'tế', 'xã', 'hội', 'có', 'vốn', 'đầu', 'tư', 'cho', 'ntm', '.']
# Kết quả sau sửa: theo đó cần năm 2020, bên cạnh đó 60 % số xã có cơ sở hạ tầng kinh tế xã hội có vốn đầu tư cho ntm.
# ['các', 'nhà', 'kinh', 'doanh', 'báo', 'chí', 'sẽ', 'đưa', 'ra', 'các', 'hỏi', ',', 'liệu', 'độc', 'giả', 'ở', 'những', 'vùng', 'sâu', ',', 'chúng', 'ta', 'có', 'thể', 'thấy', 'cơ', 'nhu', 'cầu', 'của', 'các', 'bên', 'như', 'cầu', 'mua', 'nhiều', 'thời', 'gian', 'thực', 'hiện', '.']
# Kết quả sau sửa: các nhà kinh doanh báo chí sẽ đưa ra các hỏi, liệu độc giả ở những vùng sâu, chúng ta có thể thấy cơ nhu cầu của các bên như cầu mua nhiều thời gian thực hiện.
# ['khi', 'đầm', 'lớp', 'bê', 'tông', 'phía', 'trên', 'phải', 'ăn', 'sâu', 'xuống', 'lớp', 'bê', 'tông', 'phía', 'dưới', 'khoảng', '<num>', '-', '<num>', 'cm', 'để', 'đảm', 'bảo', 'an', 'lớp', 'bê', 'tông', 'liên', 'kết', 'với', 'nhau', '.']
# Kết quả sau sửa: khi đầm lớp bê tông phía trên phải ăn sâu xuống lớp bê tông phía dưới khoảng 5 - 10 cm để đảm bảo an lớp bê tông liên kết với nhau.
# ['trong', 'quá', 'lao', 'động', 'của', 'công', 'nghệ', 'thông', 'tin', 'quan', '%', 'đến', '<num>', '%', 'tổng', 'cách', 'chú', 'trọng', 'đến', 'tạo', 'chuyên', 'môn', ',', 'nâng', 'cao', 'tay', 'nghề', ',', 'ta', 'có', 'thể', 'là', 'công', 'cụ', 'trình', 'độ', 'cao', 'hơn', '.']
# Kết quả sau sửa: trong quá lao động của công nghệ thông tin quan % đến 6 % tổng cách chú trọng đến tạo chuyên môn, nâng cao tay nghề, ta có thể là công cụ trình độ cao hơn.
# ['ở', 'dạng', 'quỹ', 'đạo', 'này', 'vệ', 'tinh', 'bay', 'trực', 'tiếp', 'trên', 'mặt', 'phẳng', 'quỹ', 'đạo', 'trùng', 'với', 'mặt', 'phẳng', 'xích', 'đạo', ',', 'nó', 'thích', 'hợp', 'với', 'các', 'hệ', 'thống', 'thông', 'tin', '.']
# Kết quả sau sửa: ở dạng quỹ đạo này vệ tinh bay trực tiếp trên mặt phẳng quỹ đạo trùng với mặt phẳng xích đạo, nó thích hợp với các hệ thống thông tin.
# ['do', 'vậy', ',', 'trên', 'thế', 'giới', 'ngoài', 'những', 'vấn', 'đề', 'nóng', 'do', 'tranh', 'chấp', 'lượng', 'dự', 'trữ', 'năng', 'lượng', 'hóa', 'thạch', 'thì', 'năng', 'lượng', 'tái', 'tạo', ',', 'một', 'nguồn', 'năng', 'lượng', 'dịch', 'vụ', 'và', 'tận', ',', 'đang', 'được', 'ưu', 'tiên', ',', 'đầu', 'tư', 'cho', 'nghiên', 'cứu', ',', 'khai', 'thác', 'và', 'sử', 'dụng', '.']
# Kết quả sau sửa: do vậy, trên thế giới ngoài những vấn đề nóng do tranh chấp lượng dự trữ năng lượng hóa thạch thì năng lượng tái tạo, một nguồn năng lượng dịch vụ và tận, đang được ưu tiên, đầu tư cho nghiên cứu, khai thác và sử dụng.
# ['sau', 'quá', 'trình', 'hoạt', 'động', 'của', 'công', 'ty', 'nguồn', 'vốn', 'công', 'ty', 'mới', 'được', 'xây', 'dựng', 'hệ', 'từ', 'bên', 'ngoài', '.']
# Kết quả sau sửa: sau quá trình hoạt động của công ty nguồn vốn công ty mới được xây dựng hệ từ bên ngoài.
# ['tạo', 'ra', 'một', 'độ', 'hứng', 'thú', 'của', 'hs', 'qua', 'phương', 'pháp', 'học', 'tập', 'mới', ',', 'thông', 'qua', 'các', 'hình', 'thức', 'học', 'khác', 'nhau', 'từ', 'đó', 'lựa', 'chọn', 'các', 'hình', 'thức', 'học', 'mang', 'tính', 'khả', 'thi', 'và', 'hiệu', 'quả', 'nhất', '.']
# Kết quả sau sửa: tạo ra một độ hứng thú của hs qua phương pháp học tập mới, thông qua các hình thức học khác nhau từ đó lựa chọn các hình thức học mang tính khả thi và hiệu quả nhất.
# ['các', 'bài', 'tập', 'vận', 'tối', 'đa', 'không', 'vượt', 'quá', 'mức', 'cung', 'ứng', 'dành', 'cho', 'mục', 'tiêu', 'của', 'công', 'nhân', 'viên', 'trong', 'quá', 'trình', 'làm', '.']
# Kết quả sau sửa: các bài tập vận tối đa không vượt quá mức cung ứng dành cho mục tiêu của công nhân viên trong quá trình làm.
# ['để', 'bắt', 'kịp', 'nhu', 'cầu', 'của', 'khách', 'hàng', 'có', 'ngân', 'hàng', 'cần', 'có', 'những', 'bước', 'đi', 'đầy', 'sáng', 'tạo', '.']
# Kết quả sau sửa: để bắt kịp nhu cầu của khách hàng có ngân hàng cần có những bước đi đầy sáng tạo.
# ['kiểm', 'soát', 'được', 'đưa', 'ra', 'những', 'yếu', 'tố', 'thông', 'tin', ',', 'ý', 'kiến', 'khác', 'nhau', 'để', 'phục', 'vụ', 'cho', 'việc', 'nghiên', 'cứu', 'đề', 'tài', '.']
# Kết quả sau sửa: kiểm soát được đưa ra những yếu tố thông tin, ý kiến khác nhau để phục vụ cho việc nghiên cứu đề tài.
# ['hoạt', 'động', 'kinh', 'ra', 'trên', '<num>', 'cơ', 'cấu', 'phanh', 'đĩa', 'được', 'xác', 'định', 'theo', 'công', 'thức', ':']
# Kết quả sau sửa: hoạt động kinh ra trên 1 cơ cấu phanh đĩa được xác định theo công thức:
# ['nâng', 'cao', 'hiệu', 'việt', 'đã', 'cung', 'cấp', 'đầy', 'đủ', 'cụ', 'thể', 'thông', 'tin', 'về', 'công', 'ty', 'như', 'tên', ',', 'địa', 'chỉ', ',', 'cách', 'thức', 'liên', 'hệ', ',', '…', 'đồng', 'thời', 'cũng', 'giới', 'thiệu', 'tổng', 'quan', 'về', 'công', 'ty', '.']
# Kết quả sau sửa: nâng cao hiệu việt đã cung cấp đầy đủ cụ thể thông tin về công ty như tên, địa chỉ, cách thức liên hệ, … đồng thời cũng giới thiệu tổng quan về công ty.
# ['các', 'đại', 'tổ', 'trưởng', 'chuyên', 'môn', '/', 'nhóm', 'trưởng', 'hướng', 'dẫn', 'gv', ',', 'nhân', 'viên', 'chăm', 'sóc', 'trẻ', 'lập', 'kế', 'hoạch', 'cá', 'nhân', 'và', 'duyệt', 'kế', 'hoạch', 'của', 'từng', 'bộ', 'môn', ',', 'cá', 'nhân', '.']
# Kết quả sau sửa: các đại tổ trưởng chuyên môn / nhóm trưởng hướng dẫn gv, nhân viên chăm sóc trẻ lập kế hoạch cá nhân và duyệt kế hoạch của từng bộ môn, cá nhân.
# ['giai', 'đoạn', 'giới', 'thiệu', ':', 'đây', 'là', 'một', 'giáo', 'viên', 'có', 'thể', 'kết', 'nối', 'với', 'colgate', 'và', 'ở', 'thị', 'trường', 'việt', 'nam', ',', 'colgate', 'gần', 'như', 'thất', 'bại', 'ở', 'giai', 'đoạn', 'này', '.']
# Kết quả sau sửa: giai đoạn giới thiệu: đây là một giáo viên có thể kết nối với colgate và ở thị trường việt nam, colgate gần như thất bại ở giai đoạn này.
# ['nội', 'dung', 'và', 'khuyến', 'khích', 'giáo', 'viên', 'âm', 'nhạc', 'tiểu', 'học', 'tích', 'cực', 'tự', 'học', 'nâng', 'cao', 'trình', 'độ', 'sử', 'dụng', 'ngôn', 'ngữ', 'dưới', 'nhiều', 'hình', 'thức', 'qua', 'đó', 'nâng', 'cao', 'năng', 'lực', 'nghiên', 'cứu', ',', 'các', 'tác', 'giả', 'cũng', 'tiếng', 'anh', 'nhằm', 'phát', 'triển', 'năng', 'lực', 'của', 'mỗi', 'giáo', 'viên', 'âm', 'nhạc', 'tiểu', 'học', '.']
# Kết quả sau sửa: nội dung và khuyến khích giáo viên âm nhạc tiểu học tích cực tự học nâng cao trình độ sử dụng ngôn ngữ dưới nhiều hình thức qua đó nâng cao năng lực nghiên cứu, các tác giả cũng tiếng anh nhằm phát triển năng lực của mỗi giáo viên âm nhạc tiểu học.
# ['theo', 'đó', 'thay', 'vì', 'sử', 'dụng', 'các', 'kỹ', 'tự', 'đặc', 'biệt', ',', 'dẫn', 'đến', 'việc', 'thực', 'hiện', 'các', 'dịch', 'vụ', 'giá', 'trị', 'của', 'đội', 'ngũ', 'nhân', 'được', 'thêm', 'vào', 'thị', 'trường', '.']
# Kết quả sau sửa: theo đó thay vì sử dụng các kỹ tự đặc biệt, dẫn đến việc thực hiện các dịch vụ giá trị của đội ngũ nhân được thêm vào thị trường.
# ['mặc', 'dù', 'thừa', 'hưởng', 'hoàn', 'toàn', 'từ', 'phiên', 'bản', 'tại', 'hàn', 'quốc', 'nhưng', 'baemin', 'vẫn', 'tiếp', 'tục', 'được', 'đầu', 'tư', ',', 'thiết', 'kế', 'dành', 'riêng', 'cho', 'thị', 'trường', 'và', ',', 'từ', 'màu', 'xanh', 'thương', 'hiệu', 'đến', 'font', 'chữ', 'hay', 'biểu', 'tượng', 'mèo', 'mập', '.']
# Kết quả sau sửa: mặc dù thừa hưởng hoàn toàn từ phiên bản tại hàn quốc nhưng baemin vẫn tiếp tục được đầu tư, thiết kế dành riêng cho thị trường và, từ màu xanh thương hiệu đến font chữ hay biểu tượng mèo mập.
# ['sản', 'phẩm', 'của', 'hoạt', 'động', 'sản', ':', 'quá', 'trình', 'trao', 'đổi', 'nội', 'dung', 'của', 'doanh', 'nghiệp', 'và', 'các', 'hoạt', 'động', 'đó', 'thương', 'hiệu', 'của', 'công', 'ty', 'đa', 'cuộc', 'đối', 'thoại', 'một', 'cách', 'có', 'mục', 'đích', 'của', 'không', 'phải', 'là', 'người', 'quyết', 'định', 'nội', 'dung', 'của', 'các', 'đối', 'tượng', 'đó', '.']
# Kết quả sau sửa: sản phẩm của hoạt động sản: quá trình trao đổi nội dung của doanh nghiệp và các hoạt động đó thương hiệu của công ty đa cuộc đối thoại một cách có mục đích của không phải là người quyết định nội dung của các đối tượng đó.
# ['có', 'thể', 'thực', 'hiện', ':', 'giáo', 'viên', 'hướng', 'dẫn', 'học', 'sinh', 'giải', 'các', 'bài', 'toán', 'cơ', 'bản', 'từ', 'đó', 'rèn', 'luyện', 'kỹ', 'năng', 'cho', 'học', 'sinh', 'giải', 'các', 'bài', 'toán', 'tương', 'tự', 'thông', 'qua', 'hệ', 'thống', 'các', 'bài', 'tập', 'giao', 'về', 'nhà', 'đã', 'được', 'kiểm', 'soát', '.']
# Kết quả sau sửa: có thể thực hiện: giáo viên hướng dẫn học sinh giải các bài toán cơ bản từ đó rèn luyện kỹ năng cho học sinh giải các bài toán tương tự thông qua hệ thống các bài tập giao về nhà đã được kiểm soát.
# ['với', 'hình', 'thức', 'này', 'vừa', 'tạo', 'cho', 'trẻ', 'không', 'khí', 'thoải', 'mái', ',', 'vui', 'vẻ', 'sau', 'hoạt', 'động', 'trong', 'công', 'tác', 'quản', 'đó', 'có', 'thể', 'tổ', 'chức', 'các', 'thông', 'tin', 'từ', 'tỉnh', 'hưng', 'yên', '.']
# Kết quả sau sửa: với hình thức này vừa tạo cho trẻ không khí thoải mái, vui vẻ sau hoạt động trong công tác quản đó có thể tổ chức các thông tin từ tỉnh hưng yên.
# ['hạn', 'chế', 'của', 'nhân', 'tố', 'kinh', 'tế', 'đối', 'với', 'doanh', 'nghiệp', 'là', 'việt', 'nam', 'mở', 'của', 'nền', 'kinh', 'tế', 'thị', 'trường', '(', 'gia', 'nhập', 'wto', ')', 'tạo', 'nên', 'nhiều', 'đối', 'thủ', 'cạnh', 'tranh', '-', 'nhiều', 'tập', 'đoàn', 'bán', 'lẻ', 'hùng', 'mạnh', 'trên', 'thế', 'giới', 'và', 'khu', 'vực', 'ra', 'nhập', 'thị', 'trường', 'việt', 'nam', '.']
# Kết quả sau sửa: hạn chế của nhân tố kinh tế đối với doanh nghiệp là việt nam mở của nền kinh tế thị trường (gia nhập wto) tạo nên nhiều đối thủ cạnh tranh - nhiều tập đoàn bán lẻ hùng mạnh trên thế giới và khu vực ra nhập thị trường việt nam.
# ['có', 'thể', 'nêu', 'ra', 'một', 'số', 'điểm', 'mới', 'của', 'luận', 'văn', 'về', 'đề', 'tài', 'lỗi', 'trong', 'trách', 'nhiệm', 'dân', 'sự', 'bồi', 'thường', 'thiệt', 'hại', 'ngoài', 'hợp', 'đồng', 'như', 'sau', ':']
# Kết quả sau sửa: có thể nêu ra một số điểm mới của luận văn về đề tài lỗi trong trách nhiệm dân sự bồi thường thiệt hại ngoài hợp đồng như sau:
# ['đồng', 'thời', ',', 'doanh', 'nghiệp', 'có', 'gắng', 'đàm', 'phán', 'để', 'có', 'lợi', 'nhất', 'cho', 'học', 'sinh', 'trong', 'một', 'thời', 'gian', '.']
# Kết quả sau sửa: đồng thời, doanh nghiệp có gắng đàm phán để có lợi nhất cho học sinh trong một thời gian.
# ['vai', 'trò', 'của', 'văn', 'hóa', 'đọc', 'đối', 'với', 'giáo', 'viên', 'đại', 'học', 'kinh', 'tế', '-', 'đại', 'học', 'quốc', 'gia', 'hà', 'nội', '.']
# Kết quả sau sửa: vai trò của văn hóa đọc đối với giáo viên đại học kinh tế - đại học quốc gia hà nội.
# ['đối', 'với', 'các', 'bộ', 'sưu', 'lăm', '.']
# Kết quả sau sửa: đối với các bộ sưu lăm.
# ['các', 'em', 'có', 'những', 'kỹ', 'năng', 'tổ', 'chức', 'hoạt', 'động', 'tư', 'duy', ',', 'tiến', 'hành', 'các', 'thao', 'tác', 'như', 'so', 'sánh', ',', 'hệ', 'thống', 'hóa', ',', 'phân', 'loại', 'nhằm', 'ghi', 'nhớ', 'tài', 'liệu', '.']
# Kết quả sau sửa: các em có những kỹ năng tổ chức hoạt động tư duy, tiến hành các thao tác như so sánh, hệ thống hóa, phân loại nhằm ghi nhớ tài liệu.
# ['cần', 'xây', 'dựng', 'các', 'yếu', 'tố', 'quan', 'trọng', 'trong', 'việc', 'tiếp', 'cận', ',', 'tuy', 'vẫn', 'còn', 'gặp', 'khó', 'khăn', 'trong', 'việc', 'tiếp', 'cận', ',', 'kiểm', 'tra', 'giám', 'sát', 'hồ', 'sơ', 'trước', 'khi', 'thẩm', 'định', '.']
# Kết quả sau sửa: cần xây dựng các yếu tố quan trọng trong việc tiếp cận, tuy vẫn còn gặp khó khăn trong việc tiếp cận, kiểm tra giám sát hồ sơ trước khi thẩm định.
# ['đối', 'với', 'công', 'ty', 'trách', 'nhiệm', 'hữu', 'hạn', 'một', 'thành', 'viên', 'có', 'cơ', 'sở', 'hạ', 'là', 'tổ', 'chức', ',', 'sẽ', 'có', 'hội', 'đồng', 'thành', 'viên', ',', 'chủ', 'sở', 'hữu', 'sẽ', 'bổ', 'nhiệm', 'các', 'vị', 'trí', 'thành', 'viên', 'hội', 'đồng', 'thành', 'viên', 'miễn', 'nhiệm', 'từ', '<num>', 'đến', '<num>', 'năm', 'với', 'nhiệm', 'kì', 'không', 'được', 'quá', '<num>', 'năm', '.']
# Kết quả sau sửa: đối với công ty trách nhiệm hữu hạn một thành viên có cơ sở hạ là tổ chức, sẽ có hội đồng thành viên, chủ sở hữu sẽ bổ nhiệm các vị trí thành viên hội đồng thành viên miễn nhiệm từ 03 đến 07 năm với nhiệm kì không được quá 05 năm.
# ['điều', 'này', 'phản', 'ánh', 'thực', 'tế', 'và', 'các', 'hoạt', 'động', 'học', 'trong', 'lao', 'động', 'và', 'trong', 'hoạt', 'động', 'thể', 'dục', ',', 'tổ', 'chức', 'cho', 'học', 'sinh', 'khá', 'cao', ',', 'cần', 'có', 'sự', 'cải', 'thiện', 'và', 'thiết', 'kế', 'chương', 'trình', 'sao', 'cho', 'phù', 'hợp', 'với', 'lứa', 'tuổi', 'mẫu', 'giáo', '.']
# Kết quả sau sửa: điều này phản ánh thực tế và các hoạt động học trong lao động và trong hoạt động thể dục, tổ chức cho học sinh khá cao, cần có sự cải thiện và thiết kế chương trình sao cho phù hợp với lứa tuổi mẫu giáo.
# ['các', 'phép', 'liên', 'kết', 'giúp', 'cho', 'câu', 'được', 'hoàn', 'chỉnh', ',', 'mạch', 'lạc', 'hơn', '.']
# Kết quả sau sửa: các phép liên kết giúp cho câu được hoàn chỉnh, mạch lạc hơn.
# ['với', 'các', 'dự', 'án', 'đầu', 'xem', 'là', 'một', 'tài', 'sản', 'quốc', 'gia', ',', 'được', 'thể', 'hiện', 'rất', 'phong', 'phú', 'và', 'đa', 'dạng', 'hóa', 'lại', 'gần', 'như', 'chưa', 'có', 'cơ', 'quan', 'nhà', 'nước', 'thành', 'lập', 'để', 'thực', 'hiện', 'việc', 'này', '.']
# Kết quả sau sửa: với các dự án đầu xem là một tài sản quốc gia, được thể hiện rất phong phú và đa dạng hóa lại gần như chưa có cơ quan nhà nước thành lập để thực hiện việc này.
# ['việc', 'phân', 'phối', 'và', 'trích', 'lập', 'dự', 'phòng', 'rủi', 'ro', 'cho', 'học', 'sinh', 'thực', 'chất', 'rủi', 'ro', 'tín', 'dụng', 'của', 'ngân', 'hàng', '.']
# Kết quả sau sửa: việc phân phối và trích lập dự phòng rủi ro cho học sinh thực chất rủi ro tín dụng của ngân hàng.
# ['tạo', 'ra', 'sản', 'phẩm', 'phong', 'phú', 'và', 'đa', 'dạng', 'và', 'phát', 'triển', 'bền', 'khác', 'nhau', ',', 'đáp', 'ứng', 'được', 'nhu', 'cầu', 'của', 'thị', 'trường', 'đặc', 'biệt', 'là', 'phái', 'nữ', '.']
# Kết quả sau sửa: tạo ra sản phẩm phong phú và đa dạng và phát triển bền khác nhau, đáp ứng được nhu cầu của thị trường đặc biệt là phái nữ.
# ['các', 'yếu', 'tố', 'ảnh', 'khấu', 'học', 'bao', 'gồm', 'những', 'gì', '?']
# Kết quả sau sửa: các yếu tố ảnh khấu học bao gồm những gì?
# ['ba', 'mẹ', 'huy', 'bận', 'công', 'việc', 'nên', 'không', 'có', 'thời', 'gian', 'quan', 'tâm', 'đến', 'việc', 'học', 'của', 'họ', '.']
# Kết quả sau sửa: ba mẹ huy bận công việc nên không có thời gian quan tâm đến việc học của họ.
# ['trong', 'một', 'số', 'nước', 'không', 'quan', 'tâm', 'đến', 'vấn', 'đề', 'này', ',', 'khả', 'năng', 'vận', 'trợ', 'oda', 'ngày', 'càng', 'tăng', 'thì', 'việc', 'lãng', 'phí', 'đầu', 'tư', 'và', 'lao', 'động', 'có', 'xu', 'hướng', 'ngày', 'càng', 'tăng', ',', 'nhất', 'là', 'giai', 'đoạn', 'đầu', 'của', 'vốn', 'vay', ',', 'khi', 'nghĩa', 'vụ', 'trả', 'nợ', 'gốc', 'còn', 'ẩn', 'giấu', 'sau', 'thời', 'gian', 'ân', 'hạn', '.']
# Kết quả sau sửa: trong một số nước không quan tâm đến vấn đề này, khả năng vận trợ oda ngày càng tăng thì việc lãng phí đầu tư và lao động có xu hướng ngày càng tăng, nhất là giai đoạn đầu của vốn vay, khi nghĩa vụ trả nợ gốc còn ẩn giấu sau thời gian ân hạn.
# ['các', 'yếu', 'âm', 'thanh', 'của', 'mô', 'hình', 'kinh', 'tế', '.']
# Kết quả sau sửa: các yếu âm thanh của mô hình kinh tế.
# ['trong', 'đó', 'tập', ',', 'liên', 'kết', 'là', 'hình', 'thức', 'học', 'tập', ',', 'hỗ', 'trợ', ',', 'tạo', 'sự', 'gắn', 'bó', 'chặt', 'chẽ', 'với', 'nhau', 'giữa', 'các', 'cơ', 'sở', 'đào', 'tạo', 'hoặc', 'giữa', 'các', 'cơ', 'sở', 'đào', 'tạo', 'với', 'các', 'đối', 'thủ', 'khác', 'nhằm', 'thực', 'hiện', 'các', 'chức', 'năng', ',', 'nhiệm', 'vụ', 'của', 'cơ', 'sở', 'đào', 'tạo', '.']
# Kết quả sau sửa: trong đó tập, liên kết là hình thức học tập, hỗ trợ, tạo sự gắn bó chặt chẽ với nhau giữa các cơ sở đào tạo hoặc giữa các cơ sở đào tạo với các đối thủ khác nhằm thực hiện các chức năng, nhiệm vụ của cơ sở đào tạo.
# ['sử', 'dụng', 'phương', 'pháp', 'này', 'giúp', 'xây', 'dựng', 'cơ', 'sở', 'dữ', 'liệu', 'không', 'gian', 'thuộc', 'tính', 'và', 'mô', 'hình', 'dem', 'bao', 'gồm', 'các', 'vấn', 'đề', 'này', 'đề', 'về', 'hiện', 'trạng', 'khu', 'vực', 'khác', 'nhau', '.']
# Kết quả sau sửa: sử dụng phương pháp này giúp xây dựng cơ sở dữ liệu không gian thuộc tính và mô hình dem bao gồm các vấn đề này đề về hiện trạng khu vực khác nhau.
# ['thứ', 'ba', 'tỷ', 'phú', 'là', 'một', 'loại', 'cây', 'cảnh', 'đẹp', 'không', 'có', 'hoa', ',', 'cây', 'có', 'tác', 'động', 'mạnh', 'mẽ', 'và', 'có', 'khả', 'năng', 'chịu', 'được', 'râm', 'mát', 'nên', 'thường', 'được', 'nhiều', 'người', 'ưu', 'ái', 'chọn', 'trồng', '.']
# Kết quả sau sửa: thứ ba tỷ phú là một loại cây cảnh đẹp không có hoa, cây có tác động mạnh mẽ và có khả năng chịu được râm mát nên thường được nhiều người ưu ái chọn trồng.
# ['để', 'đánh', 'giá', 'được', 'hoạt', 'động', 'kinh', 'doanh', 'của', 'công', 'ty', 'thì', 'song', 'song', 'với', 'việc', 'phân', 'tích', 'tình', 'hình', 'biến', 'động', 'của', 'công', 'ty', ',', 'chúng', 'ta', 'có', 'thể', 'phân', 'tích', 'rõ', 'tình', 'hình', 'biến', 'động', 'của', 'các', 'nhà', 'quản', 'các', 'năm', 'và', 'xem', 'xét', 'biến', 'động', 'đó', 'so', 'với', 'biến', 'động', 'của', 'công', 'ty', '.']
# Kết quả sau sửa: để đánh giá được hoạt động kinh doanh của công ty thì song song với việc phân tích tình hình biến động của công ty, chúng ta có thể phân tích rõ tình hình biến động của các nhà quản các năm và xem xét biến động đó so với biến động của công ty.
# ['để', 'cho', 'ra', 'một', 'dòng', 'sữa', 'nguyên', 'chất', 'tươi', 'ngon', 'th', 'đã', 'luôn', 'tiếp', 'cận', 'sản', 'xuất', 'khẩu', 'thủy', 'sản', 'có', 'sạch', ',', 'trang', 'trại', 'sạch', ',', 'cho', 'đến', 'ly', 'sữa', 'sạch', '.']
# Kết quả sau sửa: để cho ra một dòng sữa nguyên chất tươi ngon th đã luôn tiếp cận sản xuất khẩu thủy sản có sạch, trang trại sạch, cho đến ly sữa sạch.
# ['vấn', 'đề', 'của', 'hệ', 'thống', 'tiêu', 'thụ', 'dầu', 'diesel', 'oil', '.']
# Kết quả sau sửa: vấn đề của hệ thống tiêu thụ dầu diesel oil.
# ['các', 'tổ', 'chức', 'và', 'có', 'các', 'chức', 'năng', 'xác', 'định', ',', 'tư', 'vấn', 'giá', 'đất', 'và', 'xác', 'định', 'giá', 'rõ', 'ràng', ',', 'có', 'thể', '.']
# Kết quả sau sửa: các tổ chức và có các chức năng xác định, tư vấn giá đất và xác định giá rõ ràng, có thể.
# ['thiết', 'bị', 'và', 'tài', 'liệu', 'học', 'tập', 'đủ', 'dùng', '.']
# Kết quả sau sửa: thiết bị và tài liệu học tập đủ dùng.
# ['tuy', 'nhiên', 'tích', 'hồi', 'quy', 'và', 'kiểm', 'định', 'khuyết', 'tật', 'của', 'mô', 'hình', 'cho', 'thấy', ',', 'kết', 'quả', 'nghiên', 'cứu', 'của', 'khách', 'hàng', 'trong', 'khi', 'các', 'nghiên', 'cứu', 'trước', 'đây', 'của', 'các', 'tác', 'giả', 'trong', 'và', 'ngoài', 'nước', '.']
# Kết quả sau sửa: tuy nhiên tích hồi quy và kiểm định khuyết tật của mô hình cho thấy, kết quả nghiên cứu của khách hàng trong khi các nghiên cứu trước đây của các tác giả trong và ngoài nước.
# ['thiết', 'kế', 'hệ', 'thống', 'sẽ', 'giúp', 'người', 'dùng', ',', 'kỹ', 'thuật', 'viên', 'dễ', 'dàng', 'quan', 'sát', ',', 'hệ', 'thống', 'các', 'hệ', 'thống', 'để', 'dễ', 'dàng', 'vệ', 'sinh', ',', 'sửa', 'chữa', '.']
# Kết quả sau sửa: thiết kế hệ thống sẽ giúp người dùng, kỹ thuật viên dễ dàng quan sát, hệ thống các hệ thống để dễ dàng vệ sinh, sửa chữa.
# ['tuy', 'nhiên', ',', 'việc', 'quảng', 'bá', 'thương', 'hiệu', 'sẽ', 'rất', 'tốn', 'kém', ',', 'do', 'đó', 'việc', 'hiểu', 'rõ', 'mức', 'độ', 'ảnh', 'hưởng', 'của', 'sự', 'nhận', 'biết', 'đến', 'tiến', 'trình', 'lựa', 'chọn', 'sản', 'phẩm', 'sẽ', 'giúp', 'các', 'doanh', 'nghiệp', 'có', 'được', 'cách', 'thức', 'xây', 'dựng', 'thương', 'hiệu', 'đạt', 'hiệu', 'quả', 'với', 'chi', 'phí', 'hợp', 'lý', '.']
# Kết quả sau sửa: tuy nhiên, việc quảng bá thương hiệu sẽ rất tốn kém, do đó việc hiểu rõ mức độ ảnh hưởng của sự nhận biết đến tiến trình lựa chọn sản phẩm sẽ giúp các doanh nghiệp có được cách thức xây dựng thương hiệu đạt hiệu quả với chi phí hợp lý.
# ['do', 'vậy', ',', 'quan', 'hệ', 'giữa', 'người', 'bán', 'lẻ', 'và', 'sỉ', 'là', 'quan', 'hệ', 'với', 'nhau', '.']
# Kết quả sau sửa: do vậy, quan hệ giữa người bán lẻ và sỉ là quan hệ với nhau.
# ['trong', ':', 'độ', 'trễ', 'mạng', 'được', 'đo', 'bằng', 'thời', 'gian', 'cho', 'hệ', 'thống', 'điện', 'gây', '(', 'ms', ')', '.']
# Kết quả sau sửa: trong: độ trễ mạng được đo bằng thời gian cho hệ thống điện gây (ms).
# ['giáo', 'viên', 'và', 'thái', 'độ', ':', 'thông', 'qua', 'hoạt', 'động', 'và', 'tổ', 'chức', ',', 'người', 'ta', 'có', 'được', 'niềm', 'tin', 'và', 'thái', 'độ', '.']
# Kết quả sau sửa: giáo viên và thái độ: thông qua hoạt động và tổ chức, người ta có được niềm tin và thái độ.
# ['nội', 'dung', ',', 'em', 'cũng', 'xin', 'gửi', 'lời', 'cảm', 'ơn', 'đến', 'người', 'khác', ',', 'bạn', 'bè', 'đã', 'động', 'viên', ',', 'giúp', 'đỡ', ',', 'tạo', 'điều', 'kiện', 'để', 'em', 'hoàn', 'thành', 'luận', 'văn', 'này', '.']
# Kết quả sau sửa: nội dung, em cũng xin gửi lời cảm ơn đến người khác, bạn bè đã động viên, giúp đỡ, tạo điều kiện để em hoàn thành luận văn này.
# ['gv', 'tổ', 'chức', 'cho', 'hs', 'suy', 'nghĩ', 'và', 'thảo', 'luận', 'và', 'thực', 'số', 'liệu', 'cần', 'thiết', ',', 'có', 'thể', 'thấy', 'nhằm', 'đơn', 'giản', 'hóa', 'bài', 'toán', '.']
# Kết quả sau sửa: gv tổ chức cho hs suy nghĩ và thảo luận và thực số liệu cần thiết, có thể thấy nhằm đơn giản hóa bài toán.
# ['điều', 'này', 'mức', 'cổ', 'tức', 'được', 'trả', ',', 'quyết', 'định', 'thời', 'hạn', 'và', 'thủ', 'tục', 'trả', 'cổ', 'tức', 'hoặc', 'xử', 'lý', 'các', 'khoản', 'lỗ', 'phát', 'sinh', 'trong', 'quá', 'trình', 'kinh', 'doanh', '.']
# Kết quả sau sửa: điều này mức cổ tức được trả, quyết định thời hạn và thủ tục trả cổ tức hoặc xử lý các khoản lỗ phát sinh trong quá trình kinh doanh.
# ['giáo', 'viên', 'cần', 'bồi', 'dưỡng', ',', 'trau', 'dồi', 'thêm', 'kiến', 'thức', 'chuyên', 'môn', ',', 'nghiệp', 'vụ', 'sư', 'phạm', ',', 'tìm', 'tòi', 'những', 'sáng', 'kiến', 'mới', ',', 'những', 'phương', 'pháp', 'và', 'các', 'cách', 'giải', 'quyết', 'bài', 'tập', 'mới', 'giúp', 'bản', 'thân', 'trở', 'nên', 'hoàn', 'thiện', 'hơn', 'và', 'học', 'sinh', 'có', 'hứng', 'thú', 'học', 'tập', 'hơn', '.']
# Kết quả sau sửa: giáo viên cần bồi dưỡng, trau dồi thêm kiến thức chuyên môn, nghiệp vụ sư phạm, tìm tòi những sáng kiến mới, những phương pháp và các cách giải quyết bài tập mới giúp bản thân trở nên hoàn thiện hơn và học sinh có hứng thú học tập hơn.
# ['các', 'nhà', 'sản', 'xuất', 'kinh', 'kín', 'chuẩn', 'quốc', 'tế', ',', 'từ', 'nguồn', 'nguyên', 'liệu', 'cho', 'đến', 'công', 'nghệ', 'làm', 'sữa', 'sạch', 'nhằm', 'giữ', 'vẹn', 'nguyên', 'tinh', 'túy', 'của', 'học', 'sinh', 'trong', 'sản', 'xuất', 'sữa', '.']
# Kết quả sau sửa: các nhà sản xuất kinh kín chuẩn quốc tế, từ nguồn nguyên liệu cho đến công nghệ làm sữa sạch nhằm giữ vẹn nguyên tinh túy của học sinh trong sản xuất sữa.
# ['dựa', 'vào', 'biểu', 'đồ', ',', 'ta', 'có', 'thể', 'thấy', 'dung', 'lượng', 'của', 'ổ', 'c', 'là', '<num>', 'gb', '(', 'màu', 'đỏ', ')', ',', 'màu', 'xanh', 'là', 'cây', 'là', 'dung', 'lượng', 'còn', 'trống', '<num>', 'gb', '.']
# Kết quả sau sửa: dựa vào biểu đồ, ta có thể thấy dung lượng của ổ c là 200 gb (màu đỏ), màu xanh là cây là dung lượng còn trống 180.15 gb.
# ['sau', 'quá', 'là', 'cụm', 'từ', 'được', 'nhiều', 'tổ', 'chức', 'và', 'công', 'ty', 'sử', 'dụng', 'để', 'nói', 'chung', 'cho', 'các', 'loại', 'rau', 'và', 'quả', 'được', 'sử', 'dụng', 'và', 'phù', 'hợp', '.']
# Kết quả sau sửa: sau quá là cụm từ được nhiều tổ chức và công ty sử dụng để nói chung cho các loại rau và quả được sử dụng và phù hợp.
# ['việc', 'lập', 'kế', 'hoạch', 'và', 'cơ', 'sở', 'để', 'đảm', 'bảo', 'quy', 'trình', 'quản', 'lý', 'đạt', 'hiệu', 'quả', 'cao', ',', 'có', 'thể', 'thấy', 'cho', 'các', 'hoạt', 'động', 'trải', 'rạc', ',', 'tác', 'giả', '.']
# Kết quả sau sửa: việc lập kế hoạch và cơ sở để đảm bảo quy trình quản lý đạt hiệu quả cao, có thể thấy cho các hoạt động trải rạc, tác giả.
# ['kỹ', 'năng', ':', 'rèn', 'kỹ', 'năng', 'đo', 'đạc', 'thực', 'tế', ',', 'rèn', 'ý', 'thức', 'làm', 'việc', 'tập', 'thể', '.']
# Kết quả sau sửa: kỹ năng: rèn kỹ năng đo đạc thực tế, rèn ý thức làm việc tập thể.
# ['do', 'đó', 'ở', 'đâu', ',', 'trong', 'khoảng', 'thời', 'gian', 'và', 'thỏa', 'mãn', 'nhu', 'cầu', 'có', 'một', 'thiết', 'bị', 'điện', 'tử', '(', 'điện', 'thoại', ',', 'xây', 'dựng', ',', 'ủy', 'ban', 'hành', ',', '…', ')', 'thì', 'chúng', 'ta', 'có', 'thể', 'mua', 'bất', 'cứ', 'loại', 'hàng', 'hóa', 'và', 'dịch', 'vụ', 'và', 'thao', 'tác', 'đơn', 'giản', '.']
# Kết quả sau sửa: do đó ở đâu, trong khoảng thời gian và thỏa mãn nhu cầu có một thiết bị điện tử (điện thoại, xây dựng, ủy ban hành, …) thì chúng ta có thể mua bất cứ loại hàng hóa và dịch vụ và thao tác đơn giản.
# ['ngoài', 'ra', ',', 'đảng', 'ủy', 'bộ', 'y', 'tế', 'cũng', 'yêu', 'cầu', 'thành', 'lập', 'ban', 'chỉ', 'đạo', 'của', 'đảng', ',', 'thành', 'phố', 'trực', 'thuộc', 'trung', 'ương', ',', 'ban', 'chỉ', 'đạo', 'các', 'dịch', 'vụ', 'để', 'đưa', 'ra', 'kế', 'hoạch', 'cụ', 'thể', ',', 'có', 'thể', 'phát', 'hợp', 'cho', 'từng', 'địa', 'phương', 'và', 'từng', 'điều', 'kiện', 'cụ', 'thể', 'của', 'các', 'công', 'việc', '.']
# Kết quả sau sửa: ngoài ra, đảng ủy bộ y tế cũng yêu cầu thành lập ban chỉ đạo của đảng, thành phố trực thuộc trung ương, ban chỉ đạo các dịch vụ để đưa ra kế hoạch cụ thể, có thể phát hợp cho từng địa phương và từng điều kiện cụ thể của các công việc.
# ['các', 'đặc', 'điểm', 'về', 'môi', 'trường', 'thể', 'chế', 'cấp', 'địa', 'phương', 'bao', 'gồm', 'những', 'chính', 'sách', 'ưu', 'đãi', 'về', 'tài', 'khóa', 'như', 'thuế', ',', 'trợ', 'cấp', ',', 'ưu', 'đãi', 'về', 'quy', 'trình', ',', 'thủ', 'tục', '(', 'oman', ',', '<num>', ')', '.']
# Kết quả sau sửa: các đặc điểm về môi trường thể chế cấp địa phương bao gồm những chính sách ưu đãi về tài khóa như thuế, trợ cấp, ưu đãi về quy trình, thủ tục (oman, 2000).
# ['hoạt', 'động', 'và', 'thành', 'lập', 'ủy', 'ban', 'hành', 'hợp', 'hợp', 'tác', 'kinh', 'tế', ',', 'kỹ', 'thuật', '<date>', '.']
# Kết quả sau sửa: hoạt động và thành lập ủy ban hành hợp hợp tác kinh tế, kỹ thuật 18/9/1991.
# ['kiểm', 'định', 'sự', 'bằng', 'nhau', 'của', 'phương', 'sai', '.']
# Kết quả sau sửa: kiểm định sự bằng nhau của phương sai.
# ['như', 'vậy', ',', 'trong', 'hoạt', 'động', 'của', 'các', ',', 'nền', 'kinh', 'tế', 'nợ', 'với', 'khách', 'hàng', 'được', 'công', 'ty', 'cần', 'lý', 'tốt', '.']
# Kết quả sau sửa: như vậy, trong hoạt động của các, nền kinh tế nợ với khách hàng được công ty cần lý tốt.
# ['sự', 'tương', 'trợ', 'giúp', 'đỡ', 'lẫn', 'nhau', 'trong', 'cộng', 'đồng', 'còn', 'được', 'thể', 'hiện', 'rất', 'rõ', 'khi', 'có', 'những', 'sự', 'cố', 'của', 'một', 'cá', 'nhân', 'hoặc', 'biến', 'động', 'chung', 'của', 'toàn', 'xã', 'hội', '.']
# Kết quả sau sửa: sự tương trợ giúp đỡ lẫn nhau trong cộng đồng còn được thể hiện rất rõ khi có những sự cố của một cá nhân hoặc biến động chung của toàn xã hội.
# ['g', ':', 'nêu', 'cách', 'xác', 'định', 'được', 'ứng', 'dụng', 'của', '<num>', 'tam', 'giác', 'đồng', 'dạng', 'khi', 'đã', 'thỏa', 'mãn', 'gt', 'của', 'định', 'lí', '.']
# Kết quả sau sửa: g: nêu cách xác định được ứng dụng của 2 tam giác đồng dạng khi đã thỏa mãn gt của định lí.
# ['trong', 'công', 'tác', 'này', ',', 'tác', 'giả', 'đồng', 'nhất', 'khái', 'niệm', 'tác', 'phong', 'và', 'phân', 'tích', 'và', 'nâng', 'cao', 'chất', 'niệm', 'này', 'tương', 'đương', 'ý', 'hiểu', 'như', 'nhau', '.']
# Kết quả sau sửa: trong công tác này, tác giả đồng nhất khái niệm tác phong và phân tích và nâng cao chất niệm này tương đương ý hiểu như nhau.
# ['trong', 'quan', 'hệ', 'giữa', 'các', 'cell', 'dẫn', 'đến', 'gây', 'nhiễu', '.']
# Kết quả sau sửa: trong quan hệ giữa các cell dẫn đến gây nhiễu.
# ['điều', 'này', 'có', 'thể', 'là', 'các', 'bugi', 'sấy', 'loại', 'mới', 'có', 'ảnh', 'hưởng', 'đến', 'sức', 'khỏe', 'để', 'có', 'thể', 'kể', 'đến', 'là', 'nhanh', 'hơn', 'rất', 'nhiều', '(', '<num>', '°', 'c', 'trong', 'vòng', '<num>', 'giây', ')', '.']
# Kết quả sau sửa: điều này có thể là các bugi sấy loại mới có ảnh hưởng đến sức khỏe để có thể kể đến là nhanh hơn rất nhiều (850 ° c trong vòng 4 giây).
# ['kết', 'quả', 'của', 'các', 'tác', 'nghiên', 'cứu', 'về', 'trung', 'quốc', 'đều', 'chỉ', 'ra', 'vai', 'trò', 'của', 'việc', 'nằm', 'cạnh', 'biển', 'đối', 'với', 'thu', 'hút', 'fdi', '.']
# Kết quả sau sửa: kết quả của các tác nghiên cứu về trung quốc đều chỉ ra vai trò của việc nằm cạnh biển đối với thu hút fdi.
# ['chi', 'phí', 'quảng', 'cáo', 'được', 'nâng', 'cao', ',', 'đây', 'là', 'một', 'hình', 'thức', 'mà', 'khá', 'nhiều', 'các', 'công', 'ty', 'áp', 'dụng', 'và', 'đặc', 'biệt', 'là', 'các', 'doanh', 'nghiệp', 'có', 'vốn', 'đầu', 'tư', 'trực', 'tiếp', 'từ', 'nước', 'ngoài', 'áp', 'dụng', 'hệ', 'thống', '.']
# Kết quả sau sửa: chi phí quảng cáo được nâng cao, đây là một hình thức mà khá nhiều các công ty áp dụng và đặc biệt là các doanh nghiệp có vốn đầu tư trực tiếp từ nước ngoài áp dụng hệ thống.
# ['s', '(', '<num>', ',', '<num>', ')', 'và', 't', '(', '<num>', ')', ':', 'mở', 'rộng', 'thị', 'trường', 'ra', 'nước', 'ngoài', ',', 'củng', 'cố', 'uy', 'tín', ',', 'hình', 'ảnh', 'của', 'công', 'ty', '.']
# Kết quả sau sửa: s (1,2,5,6) và t (4): mở rộng thị trường ra nước ngoài, củng cố uy tín, hình ảnh của công ty.
# ['tuy', 'nhiên', 'kê', 'có', 'thể', 'thấy', 'đa', 'số', 'các', 'em', 'đều', 'thấy', 'môn', 'sinh', 'học', 'có', 'thể', 'giúp', 'các', 'em', 'trả', 'lời', 'các', 'vấn', 'đề', 'cụ', 'thể', 'trong', 'thực', 'tiễn', 'cũng', 'như', 'là', 'hình', 'thành', 'và', 'củng', 'cố', 'được', 'nhiều', 'năng', 'lực', ',', 'kĩ', 'năng', 'thực', 'hành', ',', 'hợp', 'tác', ',', 'sáng', 'tạo', '.']
# Kết quả sau sửa: tuy nhiên kê có thể thấy đa số các em đều thấy môn sinh học có thể giúp các em trả lời các vấn đề cụ thể trong thực tiễn cũng như là hình thành và củng cố được nhiều năng lực, kĩ năng thực hành, hợp tác, sáng tạo.
# ['có', 'thể', 'là', 'phản', 'ánh', 'mức', 'doanh', 'thu', 'đạt', 'được', 'trên', 'một', 'đồng', 'chi', 'phí', 'quản', 'lý', '.']
# Kết quả sau sửa: có thể là phản ánh mức doanh thu đạt được trên một đồng chi phí quản lý.
# ['kết', 'quả', 'như', 'sau', ':', '-', 'với', 'giáo', 'viên', ':', 'để', 'biết', 'được', 'thực', 'hiện', 'các', 'dạy', 'học', 'gdhn', 'trong', 'nhà', 'trường', 'tôi', 'tiến', 'hành', 'phiếu', 'hỏi', 'ý', 'kiến', 'đối', 'với', 'các', 'giáo', 'viên', 'trong', 'công', 'tác', 'quản', 'chí', 'kiên', ',', 'nam', 'định', '.']
# Kết quả sau sửa: kết quả như sau: - với giáo viên: để biết được thực hiện các dạy học gdhn trong nhà trường tôi tiến hành phiếu hỏi ý kiến đối với các giáo viên trong công tác quản chí kiên, nam định.
# ['tuy', 'cầu', 'về', 'gạo', 'là', 'ít', 'biến', 'động', 'nhưng', 'với', 'sản', 'phẩm', 'đặc', 'sản', 'thì', 'giá', 'quyết', 'định', 'khá', 'lớn', '.']
# Kết quả sau sửa: tuy cầu về gạo là ít biến động nhưng với sản phẩm đặc sản thì giá quyết định khá lớn.
# ['và', 'giúp', 'cho', 'tác', 'giả', 'có', 'thể', 'dễ', 'dàng', 'tiếp', 'cận', 'được', 'người', 'có', 'nhu', 'cầu', 'sử', 'dụng', 'các', 'năm', '.']
# Kết quả sau sửa: và giúp cho tác giả có thể dễ dàng tiếp cận được người có nhu cầu sử dụng các năm.
# ['tham', 'gia', 'vào', 'nghiên', 'cứu', 'đã', 'dạng', 'hóa', 'các', 'sản', 'phẩm', ',', 'phát', 'triển', 'kinh', 'sản', 'phẩm', 'khác', 'để', 'đáp', 'ứng', 'nhu', 'trường', '.']
# Kết quả sau sửa: tham gia vào nghiên cứu đã dạng hóa các sản phẩm, phát triển kinh sản phẩm khác để đáp ứng nhu trường.
# ['để', 'đánh', 'giá', 'học', 'sinh', 'thực', 'hiện', 'các', 'ta', 'cần', 'thực', 'hiện', 'các', 'biện', 'pháp', 'nâng', '<num>', 'độ', '.']
# Kết quả sau sửa: để đánh giá học sinh thực hiện các ta cần thực hiện các biện pháp nâng 90 độ.
# ['có', 'thể', 'có', 'thể', 'được', 'sử', 'dụng', ':', 'ai', 'nhanh', 'hơn', '?', ',', 'an', 'toàn', ',', 'ảnh', 'hưởng', 'đến', '.']
# Kết quả sau sửa: có thể có thể được sử dụng: ai nhanh hơn? , an toàn, ảnh hưởng đến.
# ['đối', 'với', 'một', 'thức', 'quá', 'trình', 'thực', 'tập', 'cả', 'các', 'nút', 'trên', 'mạng', 'đều', 'sẽ', 'tìm', 'ra', 'được', 'thực', 'hiện', 'kế', 'tiếp', 'tối', 'ưu', 'đến', 'tất', 'cả', 'mọi', 'đích', ',', 'và', 'tổng', 'chi', 'phí', 'tốt', 'nhất', 'nhờ', 'vào', 'thuật', 'toán', 'phân', 'phối', 'tối', 'ưu', '.']
# Kết quả sau sửa: đối với một thức quá trình thực tập cả các nút trên mạng đều sẽ tìm ra được thực hiện kế tiếp tối ưu đến tất cả mọi đích, và tổng chi phí tốt nhất nhờ vào thuật toán phân phối tối ưu.
# ['đây', 'là', 'một', 'trong', 'hiệu', 'mới', 'với', 'một', 'thị', 'trường', 'mới', 'đầy', 'tiềm', 'năng', '.']
# Kết quả sau sửa: đây là một trong hiệu mới với một thị trường mới đầy tiềm năng.
# ['điều', 'này', 'vô', 'việc', 'chưa', 'sử', 'dụng', 'các', 'dịch', 'vụ', '<num>', 'đơn', ',', 'chiếm', '<num>', '%', '.']
# Kết quả sau sửa: điều này vô việc chưa sử dụng các dịch vụ 24 đơn, chiếm 9,20 %.
# ['sự', 'kết', 'hợp', 'và', 'đầu', 'tư', 'tỉnh', 'chịu', 'trách', 'nhiệm', 'thực', 'hiện', 'chính', 'sách', 'ưu', 'đãi', 'đầu', 'tư', ',', 'rà', 'soát', ',', 'nhận', 'và', 'xử', 'lý', 'các', 'hành', 'vi', 'của', 'các', 'nhà', 'đầu', 'tư', 'và', 'hỗ', 'trợ', 'việc', 'thực', 'hiện', 'các', 'dự', 'án', 'fdi', '.']
# Kết quả sau sửa: sự kết hợp và đầu tư tỉnh chịu trách nhiệm thực hiện chính sách ưu đãi đầu tư, rà soát, nhận và xử lý các hành vi của các nhà đầu tư và hỗ trợ việc thực hiện các dự án fdi.
# ['trên', 'thực', 'tế', ',', 'sản', 'phẩm', 'là', 'một', 'trong', 'những', 'cách', 'kiếm', 'tiền', 'sinh', 'lợi', 'hơn', 'từ', 'một', 'website', 'tấn', 'công', 'và', 'cũng', 'là', 'một', 'trong', 'những', 'hình', 'thức', 'dạy', 'học', 'cho', 'việt', 'nam', '.']
# Kết quả sau sửa: trên thực tế, sản phẩm là một trong những cách kiếm tiền sinh lợi hơn từ một website tấn công và cũng là một trong những hình thức dạy học cho việt nam.
# ['công', 'ty', 'kỳ', 'thành', 'trưởng', 'phòng', 'kiểm', 'tra', 'chất', 'lượng', '.']
# Kết quả sau sửa: công ty kỳ thành trưởng phòng kiểm tra chất lượng.
# ['kết', 'quả', 'và', 'hệ', 'thống', 'gạt', 'nước', 'rửa', 'kính', 'cho', 'ô', 'tô', '.']
# Kết quả sau sửa: kết quả và hệ thống gạt nước rửa kính cho ô tô.
# ...
# Kết quả sau sửa: sản phẩm tồn tại dưới hai dạng chủ yếu là sản phẩm vật chất và sản phẩm phi vật chất nhằm thỏa mãn nhu cầu của khách hàng trong một thời điểm nhất định.
# ['phương', 'pháp', 'cân', 'đong', 'vật', 'liệu', 'theo', 'thể', 'tích', 'được', 'xác', 'định', 'theo', 'khối', 'vật', 'liệu', 'cung', 'cấp', 'qua', 'thiết', 'bị', 'qua', 'một', 'đơn', 'vị', 'thời', 'gian', '.']
# Kết quả sau sửa: phương pháp cân đong vật liệu theo thể tích được xác định theo khối vật liệu cung cấp qua thiết bị qua một đơn vị thời gian.
# ['mọi', 'hoạt', 'động', 'trong', 'xã', 'hội', 'hiện', 'đại', 'đều', 'phải', 'dựa', 'trên', 'thông', 'tin', '.']
# Kết quả sau sửa: mọi hoạt động trong xã hội hiện đại đều phải dựa trên thông tin.
# ['tuy', 'nhiên', 'vẫn', 'hợp', '(', 'đỡ', 'đập', 'tấn', 'công', ',', 'chắn', ',', 'đa', 'dạng', 'và', 'đưa', 'ra', 'tấn', 'công', ')', '.']
# Kết quả sau sửa: tuy nhiên vẫn hợp (đỡ đập tấn công, chắn, đa dạng và đưa ra tấn công).
# ['quản', 'lý', 'ngân', 'sách', 'đòi', 'hỏi', 'phải', 'công', 'khai', ',', 'minh', 'bạch', 'xuất', 'phát', 'từ', 'đòi', 'hỏi', 'chính', 'đáng', 'của', 'người', 'dân', 'với', 'tư', 'cách', 'là', 'người', 'nộp', 'thuế', 'cho', 'nhà', 'nước', '.']
# Kết quả sau sửa: quản lý ngân sách đòi hỏi phải công khai, minh bạch xuất phát từ đòi hỏi chính đáng của người dân với tư cách là người nộp thuế cho nhà nước.
# ['mô', 'hình', 'swot', 'là', 'mô', 'hình', 'phân', 'tích', 'kinh', 'doanh', 'nổi', 'tiếng', 'dành', 'cho', 'học', 'sinh', 'thực', 'hiện', 'các', 'hoạt', 'động', 'kinh', 'doanh', 'của', 'công', 'trình', 'hướng', 'đúng', 'đắn', 'và', 'xây', 'dựng', 'những', 'nền', 'tảng', 'phát', 'triển', 'năng', 'lực', '.']
# Kết quả sau sửa: mô hình swot là mô hình phân tích kinh doanh nổi tiếng dành cho học sinh thực hiện các hoạt động kinh doanh của công trình hướng đúng đắn và xây dựng những nền tảng phát triển năng lực.
# ['bên', 'cạnh', 'tối', 'đa', 'cơ', 'giới', 'nhất', 'là', 'đối', 'với', 'những', 'công', 'việc', 'nặng', ',', 'phải', 'kết', 'hợp', 'tác', 'giữa', 'các', 'nhà', 'cung', 'cấp', 'cho', 'với', 'các', 'thiết', 'bị', 'hỗ', 'trợ', 'khác', ',', 'kết', 'hợp', 'giữa', 'máy', 'và', 'thi', 'công', 'thủ', 'công', '.']
# Kết quả sau sửa: bên cạnh tối đa cơ giới nhất là đối với những công việc nặng, phải kết hợp tác giữa các nhà cung cấp cho với các thiết bị hỗ trợ khác, kết hợp giữa máy và thi công thủ công.
# ['giá', 'trị', 'của', 'h', 'càng', 'cao', 'có', 'nghĩa', 'là', 'doanh', 'nghiệp', 'thu', 'về', 'các', 'vấn', 'đề', 'trên', 'mỗi', 'đồng', 'chi', 'phí', 'và', 'đưa', 'ra', 'các', 'h', 'càng', 'thấp', 'nghĩa', 'là', 'doanh', 'nghiệp', 'đang', 'quản', 'lý', 'chi', 'phí', 'chưa', 'hiệu', 'quả', 'và', 'cần', 'có', 'các', 'biện', 'pháp', 'để', 'cải', 'thiện', 'tình', 'hình', 'trên', '.']
# Kết quả sau sửa: giá trị của h càng cao có nghĩa là doanh nghiệp thu về các vấn đề trên mỗi đồng chi phí và đưa ra các h càng thấp nghĩa là doanh nghiệp đang quản lý chi phí chưa hiệu quả và cần có các biện pháp để cải thiện tình hình trên.
# ['có', 'ý', 'thức', 'bảo', 'đảm', 'cho', 'các', 'học', 'sinh', ',', 'bề', 'mặt', 'không', 'bị', 'sứt', 'mẻ', '.']
# Kết quả sau sửa: có ý thức bảo đảm cho các học sinh, bề mặt không bị sứt mẻ.
# ['theo', 'một', 'ý', 'kiến', 'khá', 'phổ', 'biến', ',', 'cơ', 'sở', 'của', 'toàn', 'cầu', 'hóa', 'trước', 'hết', 'đó', 'là', 'chiến', 'lược', 'văn', 'hóa', 'nhằm', 'tuyên', 'truyền', ',', 'phổ', 'biến', 'và', 'khẳng', 'định', 'những', 'kiến', 'thức', ',', 'đánh', 'giá', 'trị', 'và', 'hiệu', 'quả', 'của', 'các', 'biện', 'pháp', 'quản', 'trị', 'trong', 'thời', 'gian', 'tới', '.']
# Kết quả sau sửa: theo một ý kiến khá phổ biến, cơ sở của toàn cầu hóa trước hết đó là chiến lược văn hóa nhằm tuyên truyền, phổ biến và khẳng định những kiến thức, đánh giá trị và hiệu quả của các biện pháp quản trị trong thời gian tới.
# ['một', 'số', 'biện', 'pháp', 'quản', 'bị', 'bản', 'chất', 'và', 'giá', 'trị', 'của', 'các', 'yếu', 'tố', 'đầu', 'vào', '(', 'ví', 'dụ', ',', 'công', 'nghệ', 'thông', 'được', 'bán', ')', '.']
# Kết quả sau sửa: một số biện pháp quản bị bản chất và giá trị của các yếu tố đầu vào (ví dụ, công nghệ thông được bán).
# ['thực', 'hiện', 'đề', 'chứng', 'minh', 'rằng', ',', 'nếu', 'hoạt', 'động', 'quản', 'lý', 'không', 'tốt', 'thì', 'quá', 'trình', 'giáo', 'dục', 'và', 'đào', 'tạo', 'trong', 'nhà', 'trường', 'cũng', 'không', 'đạt', 'được', 'những', 'mục', 'tiêu', 'như', 'mong', 'muốn', '.']
# Kết quả sau sửa: thực hiện đề chứng minh rằng, nếu hoạt động quản lý không tốt thì quá trình giáo dục và đào tạo trong nhà trường cũng không đạt được những mục tiêu như mong muốn.
# ['các', 'thành', 'viên', 'hội', 'đồng', 'quản', 'trị', 'công', 'ty', 'được', 'báo', 'chí', 'việt', 'nam', 'bình', 'chọn', 'là', 'những', 'cá', 'nhân', 'giàu', 'nhất', 'việt', 'nam', 'dựa', 'trên', 'tài', 'sản', 'chung', 'khoán', '.']
# Kết quả sau sửa: các thành viên hội đồng quản trị công ty được báo chí việt nam bình chọn là những cá nhân giàu nhất việt nam dựa trên tài sản chung khoán.
# ['để', 'đảm', 'bảo', 'nguồn', 'vốn', 'đầu', 'tư', 'cho', 'phát', 'triển', ',', 'các', 'quốc', 'gia', 'đều', 'dựa', 'vào', 'nội', 'dung', ':', 'vốn', 'tích', 'lũy', 'trong', 'nước', 'và', 'vốn', 'nước', 'ngoài', '.']
# Kết quả sau sửa: để đảm bảo nguồn vốn đầu tư cho phát triển, các quốc gia đều dựa vào nội dung: vốn tích lũy trong nước và vốn nước ngoài.
# ['về', 'cơ', 'bản', ',', 'kiểm', 'tra', 'đánh', 'giá', 'dạy', 'học', 'chủ', 'đề', 'và', 'dạy', 'học', 'truyền', 'thống', 'là', 'vẫn', 'coi', 'trọng', 'việc', 'lĩnh', 'hội', 'một', 'nội', 'dung', 'kiến', 'thức', 'nền', 'tảng', ',', 'vì', 'thế', 'dạy', 'học', 'theo', 'chủ', 'đề', 'là', 'mô', 'hình', 'dạy', 'học', 'có', 'thể', 'vận', 'dụng', 'vào', 'thực', 'tiễn', 'hiện', 'nay', 'dễ', 'dàng', 'hơn', 'một', 'số', 'mô', 'hình', 'hóa', '.']
# Kết quả sau sửa: về cơ bản, kiểm tra đánh giá dạy học chủ đề và dạy học truyền thống là vẫn coi trọng việc lĩnh hội một nội dung kiến thức nền tảng, vì thế dạy học theo chủ đề là mô hình dạy học có thể vận dụng vào thực tiễn hiện nay dễ dàng hơn một số mô hình hóa.
# ['điều', 'gì', 'cán', 'bộ', 'quản', 'trị', 'và', 'cũng', 'có', 'thể', 'bị', 'những', 'kiến', 'thức', 'chuyên', 'sâu', ',', 'tuy', 'nhiên', ',', 'có', 'các', 'kỹ', 'năng', 'quản', 'lý', 'thuế', 'hiện', 'đại', ',', 'các', 'kỹ', 'năng', 'áp', 'dụng', ',', 'sử', 'dụng', 'các', 'phương', 'tiện', 'điện', 'tử', 'trong', 'việc', 'phân', 'tích', ',', 'đánh', 'giá', ',', 'tổng', 'hợp', ',', '.', '.', '.']
# Kết quả sau sửa: điều gì cán bộ quản trị và cũng có thể bị những kiến thức chuyên sâu, tuy nhiên, có các kỹ năng quản lý thuế hiện đại, các kỹ năng áp dụng, sử dụng các phương tiện điện tử trong việc phân tích, đánh giá, tổng hợp, . . .
# ['trên', 'cơ', 'sở', 'phân', 'tích', 'về', 'mặt', 'lý', 'luận', 'các', 'quy', 'định', 'của', 'bộ', 'luật', 'dân', 'sự', '<num>', 'về', 'lỗi', 'trong', 'trách', 'nhiệm', 'bồi', 'thường', 'thiệt', 'hại', 'ngoài', 'hợp', 'đồng', ',', 'báo', 'cáo', 'tài', 'thực', 'tiễn', 'áp', 'dụng', 'các', 'quy', 'định', 'về', 'lỗi', 'trong', 'trách', 'nhiệm', 'bồi', 'thường', 'thiệt', 'hại', 'ngoài', 'hợp', 'đồng', '.']
# Kết quả sau sửa: trên cơ sở phân tích về mặt lý luận các quy định của bộ luật dân sự 2015 về lỗi trong trách nhiệm bồi thường thiệt hại ngoài hợp đồng, báo cáo tài thực tiễn áp dụng các quy định về lỗi trong trách nhiệm bồi thường thiệt hại ngoài hợp đồng.
# ['với', 'quan', 'hệ', 'giữa', 'các', 'giải', 'pháp', ',', 'biện', 'pháp', 'phòng', 'chống', '.']
# Kết quả sau sửa: với quan hệ giữa các giải pháp, biện pháp phòng chống.
# ['việc', 'tự', 'lệ', 'dự', 'trữ', 'bắt', 'buộc', ':', 'ngân', 'hàng', 'nhà', 'nước', 'ta', '.']
# Kết quả sau sửa: việc tự lệ dự trữ bắt buộc: ngân hàng nhà nước ta.
# ['ngoài', 'ra', ',', 'giáo', 'viên', 'nghiên', 'cứu', 'đã', 'đề', 'xuất', ',', 'chỉnh', 'sửa', 'các', 'vấn', 'đề', 'của', 'thuyết', 'hành', 'vi', 'dự', 'định', 'cho', 'phù', 'hợp', 'với', 'môi', 'trường', 'nghiên', 'cứu', '.']
# Kết quả sau sửa: ngoài ra, giáo viên nghiên cứu đã đề xuất, chỉnh sửa các vấn đề của thuyết hành vi dự định cho phù hợp với môi trường nghiên cứu.
# ['trong', 'giai', 'âm', 'được', 'sử', 'dụng', 'để', 'hỗ', 'trợ', 'cho', 'quá', 'trình', 'dạy', 'học', 'chủ', 'này', 'khỏi', 'điện', 'cực', 'và', 'tạo', 'điều', 'kiện', 'cho', 'điện', 'thế', 'cao', 'hơn', 'và', 'tốc', 'độ', 'sấy', 'nhanh', 'hơn', '.']
# Kết quả sau sửa: trong giai âm được sử dụng để hỗ trợ cho quá trình dạy học chủ này khỏi điện cực và tạo điều kiện cho điện thế cao hơn và tốc độ sấy nhanh hơn.
# ['trong', 'quá', 'trình', 'giảng', 'dạy', 'ở', 'lớp', ',', 'bản', 'thân', 'tôi', 'nhận', 'thấy', 'những', 'ưu', 'điểm', 'và', 'hạn', 'chế', 'như', 'sau', '.']
# Kết quả sau sửa: trong quá trình giảng dạy ở lớp, bản thân tôi nhận thấy những ưu điểm và hạn chế như sau.
# ['tác', 'giả', 'có', 'thể', 'được', 'mô', 'tờ', 'báo', 'in', 'dễ', 'dàng', 'ở', 'bất', 'cứ', 'đâu', ',', 'trên', 'bất', 'kì', 'phương', 'tiện', 'đi', 'lại', 'nào', '.']
# Kết quả sau sửa: tác giả có thể được mô tờ báo in dễ dàng ở bất cứ đâu, trên bất kì phương tiện đi lại nào.
# ['thứ', 'hai', 'hợp', 'như', ':', 'tự', 'trắc', 'nghiệm', 'bằng', 'hệ', 'thống', 'câu', 'hỏi', 'trắc', 'nghiệm', 'khách', 'quan', ';', 'trắc', 'nghiệm', 'tự', 'luận', ',', 'hoặc', 'tự', 'so', 'sánh', 'kết', 'quả', 'học', 'tập', 'của', 'mình', 'với', 'kết', 'quả', 'đạt', 'được', 'gv', 'xác', 'nhận', '.']
# Kết quả sau sửa: thứ hai hợp như: tự trắc nghiệm bằng hệ thống câu hỏi trắc nghiệm khách quan; trắc nghiệm tự luận, hoặc tự so sánh kết quả học tập của mình với kết quả đạt được gv xác nhận.
# ['nếu', 'đem', 'gửi', 'ngân', 'hàng', 'một', 'số', 'vốn', 'ban', 'đầu', 'là', 'p', 'với', 'lãi', 'suất', 'mỗi', 'năm', 'là', 'r', 'theo', 'thể', 'thức', 'lãi', 'kép', 'thì', 'sau', 'r', 'năm', 'gửi', 'số', 'tiền', 'thu', 'về', 'cả', 'vốn', 'lẫn', 'lãi', 'sẽ', 'là', ':']
# Kết quả sau sửa: nếu đem gửi ngân hàng một số vốn ban đầu là p với lãi suất mỗi năm là r theo thể thức lãi kép thì sau r năm gửi số tiền thu về cả vốn lẫn lãi sẽ là:
# ['tuy', 'nhiên', 'các', 'tổ', 'chức', ',', 'cá', 'nhân', 'áp', 'dụng', 'công', 'nghệ', 'thông', 'tin', 'hiện', 'đại', 'và', 'công', 'nghệ', 'thông', 'tin', 'để', 'tạo', 'sản', 'phẩm', 'có', 'giá', 'trị', 'cao', 'và', 'có', 'sức', 'mạnh', 'trên', 'thị', 'trường', '.']
# Kết quả sau sửa: tuy nhiên các tổ chức, cá nhân áp dụng công nghệ thông tin hiện đại và công nghệ thông tin để tạo sản phẩm có giá trị cao và có sức mạnh trên thị trường.
# ['khi', 'các', 'công', 'cụ', 'này', 'nằm', 'trong', 'chương', 'trình', '<num>', 'căn', 'hộ', 'phục', 'vụ', 'tái', 'định', 'cư', 'khu', 'siêu', 'đô', 'thị', 'thủ', 'thiêm', '.']
# Kết quả sau sửa: khi các công cụ này nằm trong chương trình 12.500 căn hộ phục vụ tái định cư khu siêu đô thị thủ thiêm.
# ['từ', 'đó', 'bán', 'hàng', ':', 'một', 'trong', 'những', 'lý', 'do', 'quan', 'trọng', 'mà', 'công', 'ty', 'nên', 'sử', 'dụng', 'email', 'marketing', 'là', 'chúng', 'có', 'thể', 'được', 'đưa', 'vào', 'bản', 'thân', '.']
# Kết quả sau sửa: từ đó bán hàng: một trong những lý do quan trọng mà công ty nên sử dụng email marketing là chúng có thể được đưa vào bản thân.
# ['hệ', 'thống', 'các', 'rào', 'cản', 'phi', 'thuế', 'quan', 'được', 'áp', 'dụng', 'phổ', 'biến', 'giữa', 'quan', 'hệ', 'thương', 'mại', 'quốc', 'tế', 'gây', 'khó', 'khăn', 'cho', 'khách', 'hàng', 'thủy', 'sản', 'xuất', 'khẩu', '.']
# Kết quả sau sửa: hệ thống các rào cản phi thuế quan được áp dụng phổ biến giữa quan hệ thương mại quốc tế gây khó khăn cho khách hàng thủy sản xuất khẩu.
# ['em', 'server', '-', 'web', 'server', 'là', 'nơi', 'quản', 'trị', 'viên', 'trực', 'tiếp', 'thực', 'hiện', 'các', 'thao', 'tác', 'để', 'điều', 'khiển', 'các', 'node', '.']
# Kết quả sau sửa: em server - web server là nơi quản trị viên trực tiếp thực hiện các thao tác để điều khiển các node.
# ['bên', 'cạnh', 'ty', ':', 'công', 'ty', 'cổ', 'phần', 'thương', 'mại', 'đầu', 'tư', 'thịnh', 'vượng', '.']
# Kết quả sau sửa: bên cạnh ty: công ty cổ phần thương mại đầu tư thịnh vượng.
# ['trong', 'công', 'tác', 'quản', 'lý', 'ngân', 'sách', ',', 'giáo', 'viên', 'có', 'kết', 'quả', 'hoạt', 'động', 'học', 'sinh', 'có', 'thể', 'tự', 'toán', 'và', 'phát', 'triển', 'năng', 'lực', '.']
# Kết quả sau sửa: trong công tác quản lý ngân sách, giáo viên có kết quả hoạt động học sinh có thể tự toán và phát triển năng lực.
# ['sau', 'đó', 'hướng', 'dẫn', 'hs', 'đưa', 'ra', 'các', 'ý', 'tưởng', 'thông', 'qua', 'sơ', 'đồ', 'tư', 'duy', 'để', 'xây', 'dựng', 'các', 'chủ', 'đề', 'con', 'và', 'xây', 'dựng', 'các', 'tiêu', 'chí', 'để', '.']
# Kết quả sau sửa: sau đó hướng dẫn hs đưa ra các ý tưởng thông qua sơ đồ tư duy để xây dựng các chủ đề con và xây dựng các tiêu chí để.
# ['chính', 'vì', 'sự', 'thiếu', 'hụt', 'nguồn', 'lao', 'động', 'có', 'trình', 'độ', 'cao', ',', 'dẫn', 'đến', 'năng', 'lực', 'sản', 'xuất', 'của', 'các', 'doanh', 'nghiệp', 'gỗ', 'việt', 'nam', 'vẫn', 'còn', 'thấp', '.']
# Kết quả sau sửa: chính vì sự thiếu hụt nguồn lao động có trình độ cao, dẫn đến năng lực sản xuất của các doanh nghiệp gỗ việt nam vẫn còn thấp.
# ['các', 'mục', 'tiêu', 'chung', 'rửa', 'phụ', 'khoa', 'nữa', ',', 'bột', 'màu', 'vàng', 'vàng', '.']
# Kết quả sau sửa: các mục tiêu chung rửa phụ khoa nữa, bột màu vàng vàng.
# ['các', 'kết', '–', 'bánh', 'vít', ':', 'bánh', 'vít', 'chế', 'tạo', 'liền', 'với', 'các', 'nước', ',', 'trục', 'vít', 'nối', 'với', 'giáo', 'viên', '.']
# Kết quả sau sửa: các kết – bánh vít: bánh vít chế tạo liền với các nước, trục vít nối với giáo viên.
# ['quá', 'trình', 'sản', 'xuất', 'đến', 'là', 'vùng', 'đất', 'văn', 'vật', ',', 'có', 'thể', 'thấy', 'các', 'mạng', ',', 'nâng', 'cao', 'chất', 'văn', 'hóa', 'và', 'ảnh', 'hưởng', 'đến', 'mức', '.']
# Kết quả sau sửa: quá trình sản xuất đến là vùng đất văn vật, có thể thấy các mạng, nâng cao chất văn hóa và ảnh hưởng đến mức.
# ['tổ', 'chức', 'quốc', 'tế', 'về', 'tiêu', 'chuẩn', 'hóa', 'iso', ',', 'trong', 'dự', 'thảo', 'dis', '<num>', ':', '<num>', ',', 'đã', 'đưa', 'ra', 'định', 'nghĩa', 'sau', ':', 'chất', 'lượng', 'là', 'khả', 'năng', 'của', 'tập', 'hợp', 'các', 'mục', 'tiêu', 'của', 'một', 'sản', 'phẩm', ',', 'hệ', 'thống', 'hay', 'quá', 'trình', 'để', 'đáp', 'ứng', 'các', 'yêu', 'cầu', 'của', 'khách', 'hàng', 'và', 'các', 'bên', 'có', 'liên', 'quan', '.']
# Kết quả sau sửa: tổ chức quốc tế về tiêu chuẩn hóa iso, trong dự thảo dis 9000: 2000, đã đưa ra định nghĩa sau: chất lượng là khả năng của tập hợp các mục tiêu của một sản phẩm, hệ thống hay quá trình để đáp ứng các yêu cầu của khách hàng và các bên có liên quan.
# ['do', 'vậy', ',', 'muốn', 'nâng', 'cao', 'được', 'chất', 'lượng', 'dịch', 'vụ', 'công', 'trong', 'nhà', 'trường', 'cần', 'có', 'một', 'đội', 'ngũ', 'có', 'phẩm', 'chất', 'tốt', ',', 'có', 'năng', 'lực', 'chuyên', 'môn', 'nghiệp', 'vụ', ',', 'có', 'đạo', 'đức', 'tốt', 'và', 'có', 'trách', 'nhiệm', 'và', 'tâm', 'huyết', 'với', 'nghề', '.']
# Kết quả sau sửa: do vậy, muốn nâng cao được chất lượng dịch vụ công trong nhà trường cần có một đội ngũ có phẩm chất tốt, có năng lực chuyên môn nghiệp vụ, có đạo đức tốt và có trách nhiệm và tâm huyết với nghề.
# ['hình', '<num>', 'ví', 'dụ', 'và', 'định', 'nghĩa', 'exchange', 'và', 'queue', '-', 'trong', 'hình', '<num>', 'là', 'cách', 'tạo', 'ra', 'một', 'dead', 'letter', 'exchange', 'đồng', 'thời', 'tạo', 'một', 'queue', 'với', 'tham', 'số', 'x', '-', 'dead', '-', 'letter', '-', 'exchange', '.']
# Kết quả sau sửa: hình 2.23 ví dụ và định nghĩa exchange và queue - trong hình 2.23 là cách tạo ra một dead letter exchange đồng thời tạo một queue với tham số x - dead - letter - exchange.
# /tmp/ipykernel_19/667271388.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["predicted"] = test["preprocess"].apply(correct_wrapper)

# %%
test.to_csv("results.csv", index = False)

# %%
import re
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
import re
from sklearn.metrics import precision_recall_fscore_support

def clean_and_tokenize(sentence):
    # Lowercase
    sentence = sentence.lower()
    # Tokenize first, before removing punctuation
    tokens = custom_tokenize(sentence)
    # Remove punctuation from each token
    cleaned_tokens = [re.sub(r'[^\w\s]', '', token) for token in tokens]
    return cleaned_tokens

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

def evaluate_corrections(test_df, save_path="evaluated_test.csv"):
    y_true_detection = []
    y_pred_detection = []
    y_true_correction = []
    y_pred_correction = []

    wrong_sentences = []

    for i, (prep_sent, pred_sent, gold_sent) in enumerate(zip(test_df['preprocess'], test_df['predicted'], test_df['correct_text'])):
        prep_tokens = clean_and_tokenize(prep_sent)
        pred_tokens = clean_and_tokenize(pred_sent)
        gold_tokens = clean_and_tokenize(gold_sent)

        min_len = min(len(prep_tokens), len(pred_tokens), len(gold_tokens))

        sent_has_error = False

        for j in range(min_len):
            prep_token = prep_tokens[j]
            pred_token = pred_tokens[j]
            gold_token = gold_tokens[j]


            # Detection labels
            y_true_detection.append(prep_token != gold_token)
            y_pred_detection.append(pred_token != gold_token)

            # Correction labels
            if pred_token != gold_token:
                y_true_correction.append(gold_token)
                y_pred_correction.append(pred_token)
                sent_has_error = True

        if sent_has_error:
            wrong_sentences.append({
                "index": i,
                "predicted": pred_sent,
                "correct_text": gold_sent,
                "pred_tokens": pred_tokens,
                "gold_tokens": gold_tokens
            })


    # Detection metrics
    p_det, r_det, f1_det, _ = precision_recall_fscore_support(
        y_true_detection, y_pred_detection, average='binary'
    )

    print("\n Detection Results:")
    print(f"Precision: {p_det:.4f} | Recall: {r_det:.4f} | F1: {f1_det:.4f}")

    # Confusion Matrix for Detection
    cm_det = confusion_matrix(y_true_detection, y_pred_detection)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm_det, display_labels=["Correct", "Error"])
    disp.plot(cmap='Blues')
    plt.title("Detection Confusion Matrix")
    plt.show()

    # Correction metrics
    if y_true_correction:
        p_corr, r_corr, f1_corr, _ = precision_recall_fscore_support(
            y_true_correction, y_pred_correction, average='micro'
        )

        print("\n Correction Results (on detected tokens):")
        print(f"Precision: {p_corr:.4f} | Recall: {r_corr:.4f} | F1: {f1_corr:.4f}")

        # Confusion Matrix for Correction
        labels = list(set(y_true_correction + y_pred_correction))
        cm_corr = confusion_matrix(y_true_correction, y_pred_correction, labels=labels)
        disp_corr = ConfusionMatrixDisplay(confusion_matrix=cm_corr, display_labels=labels)
        disp_corr.plot(cmap='Oranges', xticks_rotation=90)
        plt.title("Correction Confusion Matrix")
        plt.show()

    else:
        print("\n No corrections made or needed.")
        p_corr = r_corr = f1_corr = 0.0

    # Print wrong predictions
    print("\n===== Các câu dự đoán sai =====")
    for wrong in wrong_sentences:
        print(f"\n# {wrong['index']}")
        print(f"Predicted   : {wrong['predicted']}")
        print(f"Correct     : {wrong['correct_text']}")
        print(f"Pred tokens : {wrong['pred_tokens']}")
        print(f"Gold tokens : {wrong['gold_tokens']}")

    # Save wrong sentences
    pd.DataFrame(wrong_sentences).to_csv("wrong_sentences.csv", index=False)

    return {
        "detection": {"precision": p_det, "recall": r_det, "f1": f1_det},
        "correction": {"precision": p_corr, "recall": r_corr, "f1": f1_corr}
    }

# %%
# results = evaluate_corrections(test, save_path="test_with_prediction.csv")

# print("=== Kết quả đánh giá ===")
# print("🔍 Detection (Phát hiện lỗi):")
# print(f"Precision: {results['detection']['precision']:.4f}")
# print(f"Recall   : {results['detection']['recall']:.4f}")
# print(f"F1       : {results['detection']['f1']:.4f}")

# print("\n🛠️ Correction (Sửa lỗi):")
# print(f"Precision: {results['correction']['precision']:.4f}")
# print(f"Recall   : {results['correction']['recall']:.4f}")
# print(f"F1       : {results['correction']['f1']:.4f}")
